# %%
import os
import sys
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Define and set the working directory
new_directory = '/content/drive/Shareddrives/OM in Business Analytics/OM in BA - Project/Codice/03 - Indici'
if os.path.isdir(new_directory):
    os.chdir(new_directory)
    sys.path.append(new_directory)
    print("Current directory:", os.getcwd())
else:
    print("Directory does not exist:", new_directory)
# Out:
# Mounted at /content/drive
# Current directory: /content/drive/Shareddrives/OM in Business Analytics/OM in BA - Project/Codice/03 - Indici

# %% [markdown]
# # Load data

# %%
import geopandas as gpd

# Load the base GeoDataFrame containing spatial and attribute data
gdf = gpd.read_file("/content/drive/Shareddrives/OM in Business Analytics/OM in BA - Project/Codice/03 - Indici/gdf_finale_ind.gpkg")

# Load the GeoDataFrame for the conservative 2030 scenario
gdf_conservativo = gpd.read_file("/content/drive/Shareddrives/OM in Business Analytics/OM in BA - Project/Codice/03 - Indici/gdf_2030_conservativo_finale_ind.gpkg")

# Load the GeoDataFrame for the optimistic 2050 scenario
gdf_ottimistico = gpd.read_file("/content/drive/Shareddrives/OM in Business Analytics/OM in BA - Project/Codice/03 - Indici/gdf_2030_ottimistico_finale_ind.gpkg")

# %% [markdown]
# # ACTUAL MODELS

# %% [markdown]
# ## FIRST MODEL
# ## Charging Station Allocation Model – Hexagon-Based
#
# ### Objective
# Allocate *n* charging stations among the hexagons in the province of Brescia to **maximize the coverage of daily electricity demand** (in kWh), considering that each station has a fixed delivery capacity.
#
# ---
#
# ### Decision Variables
# - $ x_h \in \mathbb{Z}_{\geq 0} $: Number of charging stations installed in hexagon h
# - $ y_h \in [0, D_h] $: Amount of daily demand covered in hexagon h
#
# ---
#
# ### Parameters
# - $ D_h $: Daily electricity demand in hexagon h
# - $ \text{cap} = 555.43 $: Capacity of a single charging station (kWh/day)
# - $ p $: Maximum number of charging stations to be installed
# - $ n$: Total number of hexagons
#
# ---
#
# ### Constraints
#
# 1. **Total station limit**
#    $
#    \sum_{h=1}^{n} x_h \leq p
#   $
#
# 2. **Demand coverage cannot exceed actual demand**
#    $
#    y_h \leq D_h \quad \forall h
#    $
#
# 3. **Demand coverage limited by installed station capacity**
#   $
#    y_h \leq \text{cap} \cdot x_h \quad \forall h
#    $
#
# ---
#
# ### Objective Function
#
# Maximize total covered demand:
# $
# \max \sum_{h=1}^{n} y_h
# $
#
# This ensures that charging stations are placed to maximize the total amount of demand served across all hexagons.

# %%
pip install pulp
# Out:
# Collecting pulp
#   Downloading pulp-3.1.1-py3-none-any.whl.metadata (1.3 kB)
# Downloading pulp-3.1.1-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 97.1 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-3.1.1

# %% [markdown]
# ### Model function

# %%
import pulp

def ottimizza_colonnine_esagoni(gdf_mappa, p_colonnine=30, cap=555.43, verbose=True):
    """
    Solves the optimal allocation problem of charging stations for H3 hexagons.

    Parameters:
    - gdf_mappa: GeoDataFrame with at least 'h3_id' and 'Weighted Daily Demand (kWh)'
    - p_colonnine: total number of available charging stations
    - cap: daily capacity of a single charging station (kWh)
    - verbose: if True, prints the results

    Returns:
    - GeoDataFrame with additional columns: 'Allocated Stations', 'Covered Demand (kWh)'
    """
    df = gdf_mappa.copy()
    demand = df["Domanda Giornaliera Ponderata (kWh)"].tolist()
    n = len(demand)

    # Model
    model = pulp.LpProblem("Colonnine_multiple_per_esagono", pulp.LpMaximize)

    # Decision variables
    x = pulp.LpVariable.dicts("Colonnine", range(n), lowBound=0, cat="Integer")
    y = pulp.LpVariable.dicts("DomandaCoperta", range(n), lowBound=0)

    # Objective
    model += pulp.lpSum(y[i] for i in range(n))

    # Constraint: maximum total number of charging stations
    model += pulp.lpSum(x[i] for i in range(n)) <= p_colonnine

    # Constraints for each hexagon
    for i in range(n):
        model += y[i] <= demand[i]
        model += y[i] <= cap * x[i]

    # Solve
    model.solve()

    # Extract results
    colonnine_allocate = [int(x[i].varValue) if x[i].varValue else 0 for i in range(n)]
    domanda_coperta = [y[i].varValue if y[i].varValue else 0.0 for i in range(n)]

    df["Colonnine allocate"] = colonnine_allocate
    df["Domanda coperta (kWh)"] = domanda_coperta

    if verbose:
        for i in range(n):
            if colonnine_allocate[i] > 0:
                print(f"H3 {df.iloc[i]['h3_id']}: {colonnine_allocate[i]} colonnine, "
                      f"{domanda_coperta[i]:.1f} kWh coperti su {demand[i]:.1f} kWh")
        print(f"\nDomanda totale coperta: {pulp.value(model.objective):.2f} kWh")

    return df

# %% [markdown]
# ### Map function

# %%
import folium
import numpy as np
import branca.colormap as cm

def crea_mappa_colonnine_esagoni(gdf,
                                 colonna_domanda="Domanda Giornaliera Ponderata (kWh)",
                                 colonna_coperta="Domanda coperta (kWh)",
                                 colonna_colonnine="Colonnine allocate",
                                 nome_mappa="Mappa Colonnine",
                                 location=[45.54, 10.22],
                                 zoom_start=10):
    """
    Creates a Folium map of H3 hexagons with colors based on the NUMBER OF ALLOCATED CHARGING STATIONS.
    Tooltips show information on covered demand and allocated stations.

    Parameters:
    - gdf: GeoDataFrame with geometries and required columns
    - colonna_domanda: name of the column with daily demand
    - colonna_coperta: name of the column with covered demand (model output)
    - colonna_colonnine: name of the column with allocated charging stations
    - nome_mappa: title of the map
    - location: initial coordinates for the map center
    - zoom_start: initial zoom level

    Returns:
    - `folium.Map` object
    """

    # Prepare the logarithmic scale based on number of allocated charging stations
    colonnine_vals = gdf[colonna_colonnine].clip(lower=1e-2)  # Avoid log(0)
    log_min = np.log10(colonnine_vals.min())
    log_max = np.log10(colonnine_vals.max())
    colormap = cm.linear.YlGnBu_09.scale(log_min, log_max).to_step(n=10)

    # Create the map
    mappa = folium.Map(location=location, zoom_start=zoom_start, tiles="cartodbpositron")

    # Add polygons
    for _, row in gdf.iterrows():
        domanda = row.get(colonna_domanda, 0)
        coperta = row.get(colonna_coperta, 0)
        colonnine = row.get(colonna_colonnine, 0)

        # Color based on log of allocated stations
        color = colormap(np.log10(max(colonnine, 1e-2)))

        tooltip_text = (
            f"<b>H3 ID: {row.get('h3_id', 'N/A')}</b><br>"
            f"Domanda: {domanda:.1f} kWh<br>"
            f"Coperta: {coperta:.1f} kWh<br>"
            f"Colonnine allocate: {int(colonnine)}"
        )

        folium.GeoJson(
            row["geometry"],
            style_function=lambda feature, color=color: {
                "fillColor": color,
                "color": "black",
                "weight": 0.5,
                "fillOpacity": 0.7,
            },
            tooltip=folium.Tooltip(tooltip_text)
        ).add_to(mappa)

    # Add legend
    colormap.caption = f"{colonna_colonnine} (logarithmic scale)"
    colormap.add_to(mappa)

    return mappa

# %%
# Run the optimization on H3 cells
gdf_risultati_base = ottimizza_colonnine_esagoni(gdf, p_colonnine=1623)
# Out:
# H3 881f99274bfffff: 1 colonnine, 29.5 kWh coperti su 29.5 kWh
# H3 881f992215fffff: 1 colonnine, 37.4 kWh coperti su 37.4 kWh
# H3 881f992213fffff: 1 colonnine, 67.3 kWh coperti su 67.3 kWh
# H3 881f9935c7fffff: 1 colonnine, 18.6 kWh coperti su 18.6 kWh
# H3 881f9935a1fffff: 1 colonnine, 17.8 kWh coperti su 17.8 kWh
# H3 881f9922ddfffff: 1 colonnine, 106.8 kWh coperti su 106.8 kWh
# H3 881f992285fffff: 1 colonnine, 50.0 kWh coperti su 50.0 kWh
# H3 881f9922e3fffff: 1 colonnine, 18.2 kWh coperti su 18.2 kWh
# H3 881f992217fffff: 1 colonnine, 20.1 kWh coperti su 20.1 kWh
# H3 881f993501fffff: 1 colonnine, 71.3 kWh coperti su 71.3 kWh
# H3 881f99353bfffff: 1 colonnine, 108.0 kWh coperti su 108.0 kWh
# H3 881f992295fffff: 1 colonnine, 51.4 kWh coperti su 51.4 kWh
# H3 881f9922cdfffff: 1 colonnine, 76.6 kWh coperti su 76.6 kWh
# H3 881f9920d9fffff: 1 colonnine, 44.7 kWh coperti su 44.7 kWh
# H3 881f992745fffff: 1 colonnine, 46.8 kWh coperti su 46.8 kWh
# H3 881f992291fffff: 1 colonnine, 70.6 kWh coperti su 70.6 kWh
# H3 881f992233fffff: 1 colonnine, 67.0 kWh coperti su 67.0 kWh
# H3 881f993537fffff: 1 colonnine, 31.5 kWh coperti su 31.5 kWh
# H3 881f993531fffff: 1 colonnine, 84.1 kWh coperti su 84.1 kWh
# H3 881f9922c9fffff: 1 colonnine, 85.3 kWh coperti su 85.3 kWh
# H3 881f992741fffff: 1 colonnine, 67.4 kWh coperti su 67.4 kWh
# H3 881f993511fffff: 1 colonnine, 78.1 kWh coperti su 78.1 kWh
# H3 881f99270dfffff: 1 colonnine, 78.5 kWh coperti su 78.5 kWh
# H3 881f992287fffff: 1 colonnine, 29.4 kWh coperti su 29.4 kWh
# H3 881f992253fffff: 1 colonnine, 25.7 kWh coperti su 25.7 kWh
# H3 881f992211fffff: 1 colonnine, 82.0 kWh coperti su 82.0 kWh
# H3 881f992231fffff: 1 colonnine, 42.7 kWh coperti su 42.7 kWh
# H3 881f9922d7fffff: 1 colonnine, 56.7 kWh coperti su 56.7 kWh
# H3 881f9935a7fffff: 1 colonnine, 35.3 kWh coperti su 35.3 kWh
# H3 881f99221bfffff: 1 colonnine, 56.2 kWh coperti su 56.2 kWh
# H3 881f992239fffff: 1 colonnine, 19.7 kWh coperti su 19.7 kWh
# H3 881f992761fffff: 1 colonnine, 70.0 kWh coperti su 70.0 kWh
# H3 881f9935a5fffff: 1 colonnine, 65.7 kWh coperti su 65.7 kWh
# H3 881f993557fffff: 1 colonnine, 77.3 kWh coperti su 77.3 kWh
# H3 881f9935e1fffff: 1 colonnine, 19.0 kWh coperti su 19.0 kWh
# H3 881f99358dfffff: 1 colonnine, 18.0 kWh coperti su 18.0 kWh
# H3 881f9922b3fffff: 1 colonnine, 17.9 kWh coperti su 17.9 kWh
# H3 881f9922edfffff: 1 colonnine, 51.3 kWh coperti su 51.3 kWh
# H3 881f99223bfffff: 1 colonnine, 49.2 kWh coperti su 49.2 kWh
# H3 881f992283fffff: 1 colonnine, 85.3 kWh coperti su 85.3 kWh
# H3 881f993519fffff: 1 colonnine, 79.4 kWh coperti su 79.4 kWh
# H3 881f993553fffff: 1 colonnine, 80.6 kWh coperti su 80.6 kWh
# H3 881f993535fffff: 1 colonnine, 66.7 kWh coperti su 66.7 kWh
# H3 881f993585fffff: 1 colonnine, 60.6 kWh coperti su 60.6 kWh
# H3 881f993539fffff: 1 colonnine, 83.5 kWh coperti su 83.5 kWh
# H3 881f992203fffff: 1 colonnine, 40.1 kWh coperti su 40.1 kWh
# H3 881f9935e9fffff: 1 colonnine, 18.9 kWh coperti su 18.9 kWh
# H3 881f992299fffff: 1 colonnine, 43.8 kWh coperti su 43.8 kWh
# H3 881f9922d1fffff: 1 colonnine, 145.1 kWh coperti su 145.1 kWh
# H3 881f992251fffff: 1 colonnine, 20.4 kWh coperti su 20.4 kWh
# H3 881f993507fffff: 1 colonnine, 111.2 kWh coperti su 111.2 kWh
# H3 881f9922a9fffff: 1 colonnine, 87.3 kWh coperti su 87.3 kWh
# H3 881f992765fffff: 1 colonnine, 49.3 kWh coperti su 49.3 kWh
# H3 881f99229bfffff: 1 colonnine, 95.6 kWh coperti su 95.6 kWh
# H3 881f99276dfffff: 1 colonnine, 68.7 kWh coperti su 68.7 kWh
# H3 881f99353dfffff: 1 colonnine, 90.5 kWh coperti su 90.5 kWh
# H3 881f9922c7fffff: 1 colonnine, 74.4 kWh coperti su 74.4 kWh
# H3 881f993563fffff: 1 colonnine, 43.1 kWh coperti su 43.1 kWh
# H3 881f992293fffff: 1 colonnine, 20.2 kWh coperti su 20.2 kWh
# H3 881f99352bfffff: 1 colonnine, 87.6 kWh coperti su 87.6 kWh
# H3 881f9935cdfffff: 1 colonnine, 19.1 kWh coperti su 19.1 kWh
# H3 881f993581fffff: 1 colonnine, 18.4 kWh coperti su 18.4 kWh
# H3 881f99351bfffff: 1 colonnine, 24.3 kWh coperti su 24.3 kWh
# H3 881f992297fffff: 1 colonnine, 50.5 kWh coperti su 50.5 kWh
# H3 881f9922c5fffff: 1 colonnine, 134.7 kWh coperti su 134.7 kWh
# H3 881f992769fffff: 1 colonnine, 61.7 kWh coperti su 61.7 kWh
# H3 881f993425fffff: 1 colonnine, 56.7 kWh coperti su 56.7 kWh
# H3 881f9935adfffff: 1 colonnine, 22.5 kWh coperti su 22.5 kWh
# H3 881f992219fffff: 1 colonnine, 90.0 kWh coperti su 90.0 kWh
# H3 881f99274dfffff: 1 colonnine, 86.5 kWh coperti su 86.5 kWh
# H3 881f9922c1fffff: 1 colonnine, 118.2 kWh coperti su 118.2 kWh
# H3 881f993427fffff: 1 colonnine, 27.8 kWh coperti su 27.8 kWh
# H3 881f9922cbfffff: 1 colonnine, 86.3 kWh coperti su 86.3 kWh
# H3 881f993503fffff: 1 colonnine, 74.0 kWh coperti su 74.0 kWh
# H3 881f992237fffff: 1 colonnine, 72.6 kWh coperti su 72.6 kWh
# H3 881f99205bfffff: 1 colonnine, 37.1 kWh coperti su 37.1 kWh
# H3 881f9935a3fffff: 1 colonnine, 18.0 kWh coperti su 18.0 kWh
# H3 881f99229dfffff: 1 colonnine, 60.8 kWh coperti su 60.8 kWh
# H3 881f9935c5fffff: 1 colonnine, 18.8 kWh coperti su 18.8 kWh
# H3 881f99351dfffff: 1 colonnine, 52.4 kWh coperti su 52.4 kWh
# H3 881f993515fffff: 1 colonnine, 75.3 kWh coperti su 75.3 kWh
# H3 881f992749fffff: 1 colonnine, 51.8 kWh coperti su 51.8 kWh
# H3 881f9935e5fffff: 1 colonnine, 43.6 kWh coperti su 43.6 kWh
# H3 881f9935ebfffff: 1 colonnine, 17.9 kWh coperti su 17.9 kWh
# H3 881f99352dfffff: 1 colonnine, 61.4 kWh coperti su 61.4 kWh
# H3 881f99228dfffff: 1 colonnine, 109.6 kWh coperti su 109.6 kWh
# H3 881f9935e3fffff: 1 colonnine, 18.2 kWh coperti su 18.2 kWh
# H3 881f993513fffff: 1 colonnine, 23.7 kWh coperti su 23.7 kWh
# H3 881f993567fffff: 1 colonnine, 18.7 kWh coperti su 18.7 kWh
# H3 881f9922adfffff: 1 colonnine, 33.7 kWh coperti su 33.7 kWh
# H3 881f9935e7fffff: 1 colonnine, 84.6 kWh coperti su 84.6 kWh
# H3 881f992747fffff: 1 colonnine, 18.5 kWh coperti su 18.5 kWh
# H3 881f99276bfffff: 1 colonnine, 51.8 kWh coperti su 51.8 kWh
# H3 881f993527fffff: 1 colonnine, 22.9 kWh coperti su 22.9 kWh
# H3 881f993529fffff: 1 colonnine, 43.3 kWh coperti su 43.3 kWh
# H3 881f992289fffff: 1 colonnine, 83.9 kWh coperti su 83.9 kWh
# H3 881f9935edfffff: 1 colonnine, 22.5 kWh coperti su 22.5 kWh
# H3 881f9922d9fffff: 1 colonnine, 166.2 kWh coperti su 166.2 kWh
# H3 881f99350dfffff: 1 colonnine, 19.4 kWh coperti su 19.4 kWh
# H3 881f992281fffff: 1 colonnine, 134.0 kWh coperti su 134.0 kWh
# H3 881f99228bfffff: 1 colonnine, 59.4 kWh coperti su 59.4 kWh
# H3 881f9922e1fffff: 1 colonnine, 67.5 kWh coperti su 67.5 kWh
# H3 881f9922d5fffff: 1 colonnine, 72.1 kWh coperti su 72.1 kWh
# H3 881f993505fffff: 1 colonnine, 65.5 kWh coperti su 65.5 kWh
# H3 881f993517fffff: 1 colonnine, 52.0 kWh coperti su 52.0 kWh
# H3 881f9935abfffff: 1 colonnine, 18.9 kWh coperti su 18.9 kWh
# H3 881f9922bbfffff: 1 colonnine, 43.9 kWh coperti su 43.9 kWh
# H3 881f9922d3fffff: 1 colonnine, 92.4 kWh coperti su 92.4 kWh
# H3 881f993521fffff: 1 colonnine, 86.9 kWh coperti su 86.9 kWh
# H3 881f9922ebfffff: 1 colonnine, 86.1 kWh coperti su 86.1 kWh
# H3 881f9922e9fffff: 1 colonnine, 69.3 kWh coperti su 69.3 kWh
# H3 881f993525fffff: 1 colonnine, 45.9 kWh coperti su 45.9 kWh
# H3 881f9935b5fffff: 1 colonnine, 46.7 kWh coperti su 46.7 kWh
# H3 881f9922c3fffff: 1 colonnine, 63.9 kWh coperti su 63.9 kWh
# H3 881f9922e7fffff: 1 colonnine, 17.9 kWh coperti su 17.9 kWh
# H3 881f9935a9fffff: 1 colonnine, 95.7 kWh coperti su 95.7 kWh
# H3 881f99225bfffff: 1 colonnine, 59.4 kWh coperti su 59.4 kWh
# H3 881f9922dbfffff: 1 colonnine, 22.0 kWh coperti su 22.0 kWh
# H3 881f992059fffff: 1 colonnine, 19.0 kWh coperti su 19.0 kWh
# H3 881f9922e5fffff: 1 colonnine, 43.5 kWh coperti su 43.5 kWh
# H3 881f993523fffff: 1 colonnine, 58.3 kWh coperti su 58.3 kWh
# H3 881f993533fffff: 1 colonnine, 69.8 kWh coperti su 69.8 kWh
# H3 881f992497fffff: 1 colonnine, 10.6 kWh coperti su 10.6 kWh
# H3 881ea45135fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea45333fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh
# H3 881ea4510dfffff: 1 colonnine, 25.8 kWh coperti su 25.8 kWh
# H3 881ea45ad1fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea45addfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea45149fffff: 1 colonnine, 14.5 kWh coperti su 14.5 kWh
# H3 881ea4512dfffff: 1 colonnine, 10.6 kWh coperti su 10.6 kWh
# H3 881ea45109fffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh
# H3 881ea45a81fffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh
# H3 881ea451e7fffff: 1 colonnine, 30.8 kWh coperti su 30.8 kWh
# H3 881ea45161fffff: 1 colonnine, 22.0 kWh coperti su 22.0 kWh
# H3 881ea45a83fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea451e3fffff: 1 colonnine, 13.1 kWh coperti su 13.1 kWh
# H3 881ea45acbfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea45a89fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea451e1fffff: 1 colonnine, 18.4 kWh coperti su 18.4 kWh
# H3 881ea45025fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh
# H3 881ea45107fffff: 1 colonnine, 9.8 kWh coperti su 9.8 kWh
# H3 881ea45ad7fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea45ac3fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea451edfffff: 1 colonnine, 13.3 kWh coperti su 13.3 kWh
# H3 881ea45133fffff: 1 colonnine, 14.5 kWh coperti su 14.5 kWh
# H3 881ea45a99fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea4513dfffff: 1 colonnine, 13.7 kWh coperti su 13.7 kWh
# H3 881ea45103fffff: 1 colonnine, 24.0 kWh coperti su 24.0 kWh
# H3 881ea451a1fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh
# H3 881ea45151fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh
# H3 881ea45147fffff: 1 colonnine, 20.5 kWh coperti su 20.5 kWh
# H3 881ea45067fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh
# H3 881ea45143fffff: 1 colonnine, 10.1 kWh coperti su 10.1 kWh
# H3 881ea45ac9fffff: 1 colonnine, 12.6 kWh coperti su 12.6 kWh
# H3 881ea45ab9fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh
# H3 881ea4514bfffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh
# H3 881ea4513bfffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh
# H3 881ea45a87fffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh
# H3 881ea4515bfffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh
# H3 881ea45ad9fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh
# H3 881ea45117fffff: 1 colonnine, 21.6 kWh coperti su 21.6 kWh
# H3 881ea451abfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea45119fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh
# H3 881ea451e5fffff: 1 colonnine, 14.8 kWh coperti su 14.8 kWh
# H3 881ea45065fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh
# H3 881ea45129fffff: 1 colonnine, 19.1 kWh coperti su 19.1 kWh
# H3 881ea451adfffff: 1 colonnine, 13.5 kWh coperti su 13.5 kWh
# H3 881ea45115fffff: 1 colonnine, 21.6 kWh coperti su 21.6 kWh
# H3 881ea45ad3fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea45a8bfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea45169fffff: 1 colonnine, 14.0 kWh coperti su 14.0 kWh
# H3 881ea451e9fffff: 1 colonnine, 10.8 kWh coperti su 10.8 kWh
# H3 881ea4512bfffff: 1 colonnine, 18.7 kWh coperti su 18.7 kWh
# H3 881ea4514dfffff: 1 colonnine, 13.0 kWh coperti su 13.0 kWh
# H3 881ea45139fffff: 1 colonnine, 18.8 kWh coperti su 18.8 kWh
# H3 881ea45adbfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881ea45145fffff: 1 colonnine, 10.9 kWh coperti su 10.9 kWh
# H3 881ea45105fffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh
# H3 881ea451a5fffff: 1 colonnine, 12.5 kWh coperti su 12.5 kWh
# H3 881ea45141fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh
# H3 881ea45167fffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh
# H3 881ea45ac1fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881ea45163fffff: 1 colonnine, 19.6 kWh coperti su 19.6 kWh
# H3 881ea45113fffff: 1 colonnine, 16.1 kWh coperti su 16.1 kWh
# H3 881ea45101fffff: 1 colonnine, 23.1 kWh coperti su 23.1 kWh
# H3 881ea45ad5fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh
# H3 881ea45335fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh
# H3 881ea451a9fffff: 1 colonnine, 11.8 kWh coperti su 11.8 kWh
# H3 881ea45131fffff: 1 colonnine, 20.8 kWh coperti su 20.8 kWh
# H3 881ea45123fffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh
# H3 881ea4516bfffff: 1 colonnine, 25.5 kWh coperti su 25.5 kWh
# H3 881ea451ebfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881ea45137fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea45121fffff: 1 colonnine, 9.5 kWh coperti su 9.5 kWh
# H3 881ea45b53fffff: 1 colonnine, 7.1 kWh coperti su 7.1 kWh
# H3 881f9925e7fffff: 1 colonnine, 9.0 kWh coperti su 9.0 kWh
# H3 881f992e91fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh
# H3 881f992ec5fffff: 1 colonnine, 8.8 kWh coperti su 8.8 kWh
# H3 881f992583fffff: 1 colonnine, 8.3 kWh coperti su 8.3 kWh
# H3 881f992515fffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh
# H3 881f992ed3fffff: 1 colonnine, 8.8 kWh coperti su 8.8 kWh
# H3 881f99250bfffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh
# H3 881f992e9bfffff: 1 colonnine, 9.4 kWh coperti su 9.4 kWh
# H3 881ea45b4dfffff: 1 colonnine, 12.3 kWh coperti su 12.3 kWh
# H3 881f9925adfffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh
# H3 881ea45b0dfffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh
# H3 881f9925edfffff: 1 colonnine, 11.2 kWh coperti su 11.2 kWh
# H3 881ea45b0bfffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh
# H3 881f992e8dfffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh
# H3 881f9925a3fffff: 1 colonnine, 11.0 kWh coperti su 11.0 kWh
# H3 881f9925abfffff: 1 colonnine, 15.1 kWh coperti su 15.1 kWh
# H3 881f992e95fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881f992587fffff: 1 colonnine, 8.8 kWh coperti su 8.8 kWh
# H3 881f992ed5fffff: 1 colonnine, 10.2 kWh coperti su 10.2 kWh
# H3 881f992e99fffff: 1 colonnine, 13.9 kWh coperti su 13.9 kWh
# H3 881f9925a7fffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh
# H3 881f9925b1fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh
# H3 881ea45b4bfffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh
# H3 881f992581fffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh
# H3 881f992eddfffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh
# H3 881f99252bfffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh
# H3 881f9925a1fffff: 1 colonnine, 15.2 kWh coperti su 15.2 kWh
# H3 881f992503fffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh
# H3 881f992ec1fffff: 1 colonnine, 10.5 kWh coperti su 10.5 kWh
# H3 881ea45b55fffff: 1 colonnine, 13.9 kWh coperti su 13.9 kWh
# H3 881f992509fffff: 1 colonnine, 12.0 kWh coperti su 12.0 kWh
# H3 881f992ec7fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh
# H3 881f992585fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh
# H3 881ea45b6bfffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh
# H3 881ea45b49fffff: 1 colonnine, 9.0 kWh coperti su 9.0 kWh
# H3 881f9925e5fffff: 1 colonnine, 19.6 kWh coperti su 19.6 kWh
# H3 881f99253bfffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh
# H3 881f992589fffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh
# H3 881f9925a9fffff: 1 colonnine, 9.6 kWh coperti su 9.6 kWh
# H3 881f992ec3fffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh
# H3 881f992ed9fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh
# H3 881f992ec9fffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh
# H3 881ea45b57fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh
# H3 881f9925b7fffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh
# H3 881f9925a5fffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh
# H3 881ea45b51fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh
# H3 881f992529fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh
# H3 881f992ed7fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh
# H3 881f992523fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh
# H3 881ea45b43fffff: 1 colonnine, 12.4 kWh coperti su 12.4 kWh
# H3 881ea45b59fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea45b45fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh
# H3 881f992513fffff: 1 colonnine, 7.5 kWh coperti su 7.5 kWh
# H3 881f9925b9fffff: 1 colonnine, 6.3 kWh coperti su 6.3 kWh
# H3 881ea45b41fffff: 1 colonnine, 8.8 kWh coperti su 8.8 kWh
# H3 881f9925b5fffff: 1 colonnine, 10.7 kWh coperti su 10.7 kWh
# H3 881f992ebbfffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh
# H3 881f992eb3fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh
# H3 881f992517fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh
# H3 881f992edbfffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh
# H3 881f992ed1fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f99362bfffff: 1 colonnine, 9.9 kWh coperti su 9.9 kWh
# H3 881f993631fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881f9936e9fffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh
# H3 881f9936edfffff: 1 colonnine, 15.8 kWh coperti su 15.8 kWh
# H3 881f9936e1fffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh
# H3 881f993617fffff: 1 colonnine, 19.0 kWh coperti su 19.0 kWh
# H3 881f99363dfffff: 1 colonnine, 16.3 kWh coperti su 16.3 kWh
# H3 881f993605fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh
# H3 881f993607fffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh
# H3 881f993639fffff: 1 colonnine, 9.4 kWh coperti su 9.4 kWh
# H3 881f9936e3fffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh
# H3 881f99363bfffff: 1 colonnine, 20.3 kWh coperti su 20.3 kWh
# H3 881f993685fffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh
# H3 881f99069dfffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh
# H3 881f9906b3fffff: 1 colonnine, 20.7 kWh coperti su 20.7 kWh
# H3 881f9906a1fffff: 1 colonnine, 10.4 kWh coperti su 10.4 kWh
# H3 881f9904cdfffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh
# H3 881f99334dfffff: 1 colonnine, 14.1 kWh coperti su 14.1 kWh
# H3 881f9904c3fffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh
# H3 881f9906a3fffff: 1 colonnine, 45.5 kWh coperti su 45.5 kWh
# H3 881f993369fffff: 1 colonnine, 35.0 kWh coperti su 35.0 kWh
# H3 881f9904ddfffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh
# H3 881f9906a5fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh
# H3 881f990695fffff: 1 colonnine, 33.5 kWh coperti su 33.5 kWh
# H3 881f990693fffff: 1 colonnine, 34.4 kWh coperti su 34.4 kWh
# H3 881f9906e7fffff: 1 colonnine, 13.9 kWh coperti su 13.9 kWh
# H3 881f9906a9fffff: 1 colonnine, 31.1 kWh coperti su 31.1 kWh
# H3 881f9904cbfffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh
# H3 881f990691fffff: 1 colonnine, 11.8 kWh coperti su 11.8 kWh
# H3 881f9906a7fffff: 1 colonnine, 21.0 kWh coperti su 21.0 kWh
# H3 881f9906b1fffff: 1 colonnine, 25.2 kWh coperti su 25.2 kWh
# H3 881f9906adfffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh
# H3 881f9904c1fffff: 1 colonnine, 8.3 kWh coperti su 8.3 kWh
# H3 881f9906b9fffff: 1 colonnine, 30.9 kWh coperti su 30.9 kWh
# H3 881f9904c7fffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh
# H3 881f9906b7fffff: 1 colonnine, 24.1 kWh coperti su 24.1 kWh
# H3 881f990699fffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh
# H3 881f9904ebfffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh
# H3 881f9906bdfffff: 1 colonnine, 53.5 kWh coperti su 53.5 kWh
# H3 881f990685fffff: 1 colonnine, 24.0 kWh coperti su 24.0 kWh
# H3 881f9906b5fffff: 1 colonnine, 29.0 kWh coperti su 29.0 kWh
# H3 881f9906bbfffff: 1 colonnine, 29.6 kWh coperti su 29.6 kWh
# H3 881f990687fffff: 1 colonnine, 40.2 kWh coperti su 40.2 kWh
# H3 881f9906abfffff: 1 colonnine, 56.5 kWh coperti su 56.5 kWh
# H3 881f990697fffff: 1 colonnine, 41.7 kWh coperti su 41.7 kWh
# H3 881f9904c9fffff: 1 colonnine, 9.0 kWh coperti su 9.0 kWh
# H3 881f99302dfffff: 1 colonnine, 13.3 kWh coperti su 13.3 kWh
# H3 881f993157fffff: 1 colonnine, 19.3 kWh coperti su 19.3 kWh
# H3 881f993adbfffff: 1 colonnine, 16.8 kWh coperti su 16.8 kWh
# H3 881f99315bfffff: 1 colonnine, 23.4 kWh coperti su 23.4 kWh
# H3 881f993133fffff: 1 colonnine, 13.3 kWh coperti su 13.3 kWh
# H3 881f99315dfffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh
# H3 881f993117fffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh
# H3 881f993135fffff: 1 colonnine, 13.0 kWh coperti su 13.0 kWh
# H3 881f99311dfffff: 1 colonnine, 30.2 kWh coperti su 30.2 kWh
# H3 881f993153fffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh
# H3 881f993103fffff: 1 colonnine, 13.1 kWh coperti su 13.1 kWh
# H3 881f993027fffff: 1 colonnine, 14.9 kWh coperti su 14.9 kWh
# H3 881f993025fffff: 1 colonnine, 18.7 kWh coperti su 18.7 kWh
# H3 881f993137fffff: 1 colonnine, 13.5 kWh coperti su 13.5 kWh
# H3 881f993113fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh
# H3 881f993159fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f993139fffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh
# H3 881f993107fffff: 1 colonnine, 10.3 kWh coperti su 10.3 kWh
# H3 881f993111fffff: 1 colonnine, 18.1 kWh coperti su 18.1 kWh
# H3 881f993ad9fffff: 1 colonnine, 17.5 kWh coperti su 17.5 kWh
# H3 881f99313bfffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh
# H3 881f99310bfffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh
# H3 881f993155fffff: 1 colonnine, 25.3 kWh coperti su 25.3 kWh
# H3 881f9931edfffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh
# H3 881f99313dfffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh
# H3 881f993151fffff: 1 colonnine, 18.6 kWh coperti su 18.6 kWh
# H3 881f993119fffff: 1 colonnine, 14.5 kWh coperti su 14.5 kWh
# H3 881f993a6bfffff: 1 colonnine, 17.5 kWh coperti su 17.5 kWh
# H3 881f993a09fffff: 1 colonnine, 13.6 kWh coperti su 13.6 kWh
# H3 881f993165fffff: 1 colonnine, 14.6 kWh coperti su 14.6 kWh
# H3 881f993a4bfffff: 1 colonnine, 21.7 kWh coperti su 21.7 kWh
# H3 881f990483fffff: 1 colonnine, 12.1 kWh coperti su 12.1 kWh
# H3 881f993a5dfffff: 1 colonnine, 20.1 kWh coperti su 20.1 kWh
# H3 881f993169fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh
# H3 881f993a57fffff: 1 colonnine, 10.6 kWh coperti su 10.6 kWh
# H3 881f993a51fffff: 1 colonnine, 21.9 kWh coperti su 21.9 kWh
# H3 881f9904e3fffff: 1 colonnine, 13.9 kWh coperti su 13.9 kWh
# H3 881f9904b7fffff: 1 colonnine, 30.3 kWh coperti su 30.3 kWh
# H3 881f993a53fffff: 1 colonnine, 14.9 kWh coperti su 14.9 kWh
# H3 881f9904b5fffff: 1 colonnine, 15.8 kWh coperti su 15.8 kWh
# H3 881f990487fffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh
# H3 881f993a55fffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh
# H3 881f993a01fffff: 1 colonnine, 19.3 kWh coperti su 19.3 kWh
# H3 881f993a5bfffff: 1 colonnine, 13.2 kWh coperti su 13.2 kWh
# H3 881f993125fffff: 1 colonnine, 11.8 kWh coperti su 11.8 kWh
# H3 881f990495fffff: 1 colonnine, 14.7 kWh coperti su 14.7 kWh
# H3 881f993a43fffff: 1 colonnine, 12.7 kWh coperti su 12.7 kWh
# H3 881f9904abfffff: 1 colonnine, 9.9 kWh coperti su 9.9 kWh
# H3 881f993a0bfffff: 1 colonnine, 13.6 kWh coperti su 13.6 kWh
# H3 881f993a0dfffff: 1 colonnine, 15.1 kWh coperti su 15.1 kWh
# H3 881f993a49fffff: 1 colonnine, 16.0 kWh coperti su 16.0 kWh
# H3 881f993a4dfffff: 1 colonnine, 14.4 kWh coperti su 14.4 kWh
# H3 881f993a59fffff: 1 colonnine, 15.7 kWh coperti su 15.7 kWh
# H3 881f99316dfffff: 1 colonnine, 18.7 kWh coperti su 18.7 kWh
# H3 881f990497fffff: 1 colonnine, 14.2 kWh coperti su 14.2 kWh
# H3 881f993161fffff: 1 colonnine, 9.8 kWh coperti su 9.8 kWh
# H3 881f9904bbfffff: 1 colonnine, 16.1 kWh coperti su 16.1 kWh
# H3 881f993a69fffff: 1 colonnine, 13.7 kWh coperti su 13.7 kWh
# H3 881f9904b1fffff: 1 colonnine, 14.0 kWh coperti su 14.0 kWh
# H3 881f9904bdfffff: 1 colonnine, 18.5 kWh coperti su 18.5 kWh
# H3 881f990485fffff: 1 colonnine, 13.1 kWh coperti su 13.1 kWh
# H3 881f9904b3fffff: 1 colonnine, 30.2 kWh coperti su 30.2 kWh
# H3 881f9904b9fffff: 1 colonnine, 17.6 kWh coperti su 17.6 kWh
# H3 881f993a47fffff: 1 colonnine, 12.0 kWh coperti su 12.0 kWh
# H3 881f992565fffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh
# H3 881f992c09fffff: 1 colonnine, 7.9 kWh coperti su 7.9 kWh
# H3 881f992e09fffff: 1 colonnine, 7.1 kWh coperti su 7.1 kWh
# H3 881f992081fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh
# H3 881f992e5dfffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh
# H3 881f9920b5fffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh
# H3 881f992e41fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh
# H3 881f992c55fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh
# H3 881f992087fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh
# H3 881f992e4dfffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh
# H3 881f992e4bfffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh
# H3 881f992e15fffff: 1 colonnine, 11.7 kWh coperti su 11.7 kWh
# H3 881f992e47fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881f992e29fffff: 1 colonnine, 9.0 kWh coperti su 9.0 kWh
# H3 881f992e51fffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh
# H3 881f99256dfffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh
# H3 881f992e01fffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh
# H3 881f992e03fffff: 1 colonnine, 15.9 kWh coperti su 15.9 kWh
# H3 881f992e13fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh
# H3 881f992e07fffff: 1 colonnine, 7.9 kWh coperti su 7.9 kWh
# H3 881f992e0bfffff: 1 colonnine, 15.8 kWh coperti su 15.8 kWh
# H3 881f992e5bfffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh
# H3 881f992e63fffff: 1 colonnine, 9.5 kWh coperti su 9.5 kWh
# H3 881f992e43fffff: 1 colonnine, 12.1 kWh coperti su 12.1 kWh
# H3 881f992e39fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh
# H3 881f992e2bfffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh
# H3 881f9920b7fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh
# H3 881f992e55fffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh
# H3 881f992e0dfffff: 1 colonnine, 9.7 kWh coperti su 9.7 kWh
# H3 881f9920bdfffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh
# H3 881ea45acdfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881f9924ebfffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh
# H3 881f9924e3fffff: 1 colonnine, 9.0 kWh coperti su 9.0 kWh
# H3 881ea45a1dfffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh
# H3 881f9924b9fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh
# H3 881ea45a15fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh
# H3 881ea45a59fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh
# H3 881f992481fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh
# H3 881f9924b5fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh
# H3 881f992483fffff: 1 colonnine, 11.0 kWh coperti su 11.0 kWh
# H3 881f992487fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh
# H3 881f9924d9fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh
# H3 881f992495fffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh
# H3 881ea45a85fffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh
# H3 881f9924bdfffff: 1 colonnine, 10.0 kWh coperti su 10.0 kWh
# H3 881ea4516dfffff: 1 colonnine, 12.3 kWh coperti su 12.3 kWh
# H3 881f9924bbfffff: 1 colonnine, 10.8 kWh coperti su 10.8 kWh
# H3 881f9924b1fffff: 1 colonnine, 15.8 kWh coperti su 15.8 kWh
# H3 881f992485fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh
# H3 881ea45a19fffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh
# H3 881ea45a53fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh
# H3 881f99259bfffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh
# H3 881f9926b7fffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh
# H3 881ea45a13fffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh
# H3 881ea45aabfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f9930b3fffff: 1 colonnine, 17.6 kWh coperti su 17.6 kWh
# H3 881f993725fffff: 1 colonnine, 19.5 kWh coperti su 19.5 kWh
# H3 881f9930d7fffff: 1 colonnine, 7.7 kWh coperti su 7.7 kWh
# H3 881f9930b7fffff: 1 colonnine, 44.9 kWh coperti su 44.9 kWh
# H3 881f993767fffff: 1 colonnine, 17.0 kWh coperti su 17.0 kWh
# H3 881f993721fffff: 1 colonnine, 21.7 kWh coperti su 21.7 kWh
# H3 881f993091fffff: 1 colonnine, 28.8 kWh coperti su 28.8 kWh
# H3 881f99309dfffff: 1 colonnine, 13.6 kWh coperti su 13.6 kWh
# H3 881f993083fffff: 1 colonnine, 23.0 kWh coperti su 23.0 kWh
# H3 881f9930d9fffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh
# H3 881f99308bfffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh
# H3 881f99309bfffff: 1 colonnine, 25.4 kWh coperti su 25.4 kWh
# H3 881f993097fffff: 1 colonnine, 19.4 kWh coperti su 19.4 kWh
# H3 881f99376bfffff: 1 colonnine, 24.3 kWh coperti su 24.3 kWh
# H3 881f9930d1fffff: 1 colonnine, 27.0 kWh coperti su 27.0 kWh
# H3 881f9930bbfffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh
# H3 881f993765fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh
# H3 881f9930b9fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh
# H3 881f99370dfffff: 1 colonnine, 7.5 kWh coperti su 7.5 kWh
# H3 881f9930d3fffff: 1 colonnine, 22.6 kWh coperti su 22.6 kWh
# H3 881f993761fffff: 1 colonnine, 31.6 kWh coperti su 31.6 kWh
# H3 881f9930b1fffff: 1 colonnine, 23.0 kWh coperti su 23.0 kWh
# H3 881f99372dfffff: 1 colonnine, 35.2 kWh coperti su 35.2 kWh
# H3 881f993727fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh
# H3 881f993769fffff: 1 colonnine, 26.1 kWh coperti su 26.1 kWh
# H3 881f993763fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh
# H3 881f993729fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh
# H3 881f993095fffff: 1 colonnine, 16.9 kWh coperti su 16.9 kWh
# H3 881f9930dbfffff: 1 colonnine, 16.7 kWh coperti su 16.7 kWh
# H3 881f992259fffff: 1 colonnine, 38.8 kWh coperti su 38.8 kWh
# H3 881f993099fffff: 1 colonnine, 22.3 kWh coperti su 22.3 kWh
# H3 881f99356dfffff: 1 colonnine, 16.0 kWh coperti su 16.0 kWh
# H3 881f99373bfffff: 1 colonnine, 33.9 kWh coperti su 33.9 kWh
# H3 881f993627fffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh
# H3 881f993707fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f993445fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f993717fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881f993723fffff: 1 colonnine, 18.2 kWh coperti su 18.2 kWh
# H3 881f99346bfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f993711fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f99346dfffff: 1 colonnine, 25.2 kWh coperti su 25.2 kWh
# H3 881f99373dfffff: 1 colonnine, 23.8 kWh coperti su 23.8 kWh
# H3 881f993703fffff: 1 colonnine, 25.8 kWh coperti su 25.8 kWh
# H3 881f993713fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881f993465fffff: 1 colonnine, 27.6 kWh coperti su 27.6 kWh
# H3 881f993739fffff: 1 colonnine, 25.1 kWh coperti su 25.1 kWh
# H3 881f993733fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh
# H3 881f993735fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh
# H3 881f993731fffff: 1 colonnine, 15.4 kWh coperti su 15.4 kWh
# H3 881f993705fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f993715fffff: 1 colonnine, 17.4 kWh coperti su 17.4 kWh
# H3 881f993461fffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh
# H3 881f993441fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881f99355bfffff: 1 colonnine, 17.2 kWh coperti su 17.2 kWh
# H3 881f993469fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f99371bfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f993447fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f99372bfffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh
# H3 881f99344dfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881f99a449fffff: 1 colonnine, 9.7 kWh coperti su 9.7 kWh
# H3 881f99a707fffff: 1 colonnine, 13.1 kWh coperti su 13.1 kWh
# H3 881f99a625fffff: 1 colonnine, 14.9 kWh coperti su 14.9 kWh
# H3 881f99a715fffff: 1 colonnine, 18.3 kWh coperti su 18.3 kWh
# H3 881f99a713fffff: 1 colonnine, 7.5 kWh coperti su 7.5 kWh
# H3 881f99a44dfffff: 1 colonnine, 11.7 kWh coperti su 11.7 kWh
# H3 881f99a621fffff: 1 colonnine, 10.0 kWh coperti su 10.0 kWh
# H3 881f99a62bfffff: 1 colonnine, 10.5 kWh coperti su 10.5 kWh
# H3 881f99a711fffff: 1 colonnine, 20.2 kWh coperti su 20.2 kWh
# H3 881f99a757fffff: 1 colonnine, 11.0 kWh coperti su 11.0 kWh
# H3 881f99a719fffff: 1 colonnine, 20.8 kWh coperti su 20.8 kWh
# H3 881f99a739fffff: 1 colonnine, 18.1 kWh coperti su 18.1 kWh
# H3 881f99a71bfffff: 1 colonnine, 15.3 kWh coperti su 15.3 kWh
# H3 881f99a71dfffff: 1 colonnine, 12.7 kWh coperti su 12.7 kWh
# H3 881f99a627fffff: 1 colonnine, 9.5 kWh coperti su 9.5 kWh
# H3 881f99a703fffff: 1 colonnine, 10.4 kWh coperti su 10.4 kWh
# H3 881f99a73bfffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh
# H3 881f99a717fffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh
# H3 881f99319dfffff: 1 colonnine, 17.2 kWh coperti su 17.2 kWh
# H3 881f993199fffff: 1 colonnine, 17.2 kWh coperti su 17.2 kWh
# H3 881f9931d5fffff: 1 colonnine, 60.0 kWh coperti su 60.0 kWh
# H3 881f9931d7fffff: 1 colonnine, 53.8 kWh coperti su 53.8 kWh
# H3 881f99318bfffff: 1 colonnine, 59.4 kWh coperti su 59.4 kWh
# H3 881f9931d3fffff: 1 colonnine, 76.2 kWh coperti su 76.2 kWh
# H3 881f9931d1fffff: 1 colonnine, 67.1 kWh coperti su 67.1 kWh
# H3 881f993037fffff: 1 colonnine, 18.0 kWh coperti su 18.0 kWh
# H3 881f9931c3fffff: 1 colonnine, 35.0 kWh coperti su 35.0 kWh
# H3 881f9930a5fffff: 1 colonnine, 46.6 kWh coperti su 46.6 kWh
# H3 881f9931d9fffff: 1 colonnine, 51.6 kWh coperti su 51.6 kWh
# H3 881f993189fffff: 1 colonnine, 17.2 kWh coperti su 17.2 kWh
# H3 881f9931dbfffff: 1 colonnine, 22.3 kWh coperti su 22.3 kWh
# H3 881f9931ddfffff: 1 colonnine, 23.5 kWh coperti su 23.5 kWh
# H3 881f992f17fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh
# H3 881f992e2dfffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh
# H3 881f9921b1fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh
# H3 881f992f35fffff: 1 colonnine, 10.0 kWh coperti su 10.0 kWh
# H3 881f992f5bfffff: 1 colonnine, 10.2 kWh coperti su 10.2 kWh
# H3 881f992f15fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh
# H3 881f992f09fffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh
# H3 881f992d51fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh
# H3 881f992f41fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh
# H3 881f992f01fffff: 1 colonnine, 7.1 kWh coperti su 7.1 kWh
# H3 881f9921b9fffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh
# H3 881f992f0bfffff: 1 colonnine, 14.4 kWh coperti su 14.4 kWh
# H3 881f992c6bfffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh
# H3 881f992f21fffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh
# H3 881f992f69fffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh
# H3 881f992f57fffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh
# H3 881f992f47fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh
# H3 881f992f03fffff: 1 colonnine, 13.3 kWh coperti su 13.3 kWh
# H3 881f992f55fffff: 1 colonnine, 10.6 kWh coperti su 10.6 kWh
# H3 881f992c69fffff: 1 colonnine, 7.5 kWh coperti su 7.5 kWh
# H3 881f992f23fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh
# H3 881f992f39fffff: 1 colonnine, 10.2 kWh coperti su 10.2 kWh
# H3 881f992f51fffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh
# H3 881f9921b7fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh
# H3 881f992c2dfffff: 1 colonnine, 7.7 kWh coperti su 7.7 kWh
# H3 881f992d59fffff: 1 colonnine, 12.5 kWh coperti su 12.5 kWh
# H3 881f992f43fffff: 1 colonnine, 9.7 kWh coperti su 9.7 kWh
# H3 881f992f45fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh
# H3 881f992d49fffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh
# H3 881f992f5dfffff: 1 colonnine, 10.4 kWh coperti su 10.4 kWh
# H3 881f992e61fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh
# H3 881f992d5bfffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh
# H3 881f992f33fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh
# H3 881f99234bfffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh
# H3 881f992349fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh
# H3 881f9931b1fffff: 1 colonnine, 28.9 kWh coperti su 28.9 kWh
# H3 881f99226dfffff: 1 colonnine, 23.5 kWh coperti su 23.5 kWh
# H3 881f9931b7fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh
# H3 881f993185fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh
# H3 881f9931b5fffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh
# H3 881f993183fffff: 1 colonnine, 22.6 kWh coperti su 22.6 kWh
# H3 881f993195fffff: 1 colonnine, 22.2 kWh coperti su 22.2 kWh
# H3 881f9931bdfffff: 1 colonnine, 26.5 kWh coperti su 26.5 kWh
# H3 881f9931a3fffff: 1 colonnine, 30.7 kWh coperti su 30.7 kWh
# H3 881f9931b9fffff: 1 colonnine, 22.3 kWh coperti su 22.3 kWh
# H3 881f9931abfffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh
# H3 881f9931bbfffff: 1 colonnine, 33.2 kWh coperti su 33.2 kWh
# H3 881f993181fffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh
# H3 881f993187fffff: 1 colonnine, 9.7 kWh coperti su 9.7 kWh
# H3 881f99319bfffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh
# H3 881f9931a1fffff: 1 colonnine, 23.6 kWh coperti su 23.6 kWh
# H3 881f993197fffff: 1 colonnine, 30.2 kWh coperti su 30.2 kWh
# H3 881f9931b3fffff: 1 colonnine, 22.6 kWh coperti su 22.6 kWh
# H3 881f993191fffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh
# H3 881f993193fffff: 1 colonnine, 29.2 kWh coperti su 29.2 kWh
# H3 881f9931a9fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh
# H3 881f99235dfffff: 1 colonnine, 28.3 kWh coperti su 28.3 kWh
# H3 881f992719fffff: 1 colonnine, 17.9 kWh coperti su 17.9 kWh
# H3 881f992707fffff: 1 colonnine, 10.0 kWh coperti su 10.0 kWh
# H3 881f992703fffff: 1 colonnine, 14.6 kWh coperti su 14.6 kWh
# H3 881f99275dfffff: 1 colonnine, 9.3 kWh coperti su 9.3 kWh
# H3 881f992715fffff: 1 colonnine, 15.9 kWh coperti su 15.9 kWh
# H3 881f992709fffff: 1 colonnine, 15.0 kWh coperti su 15.0 kWh
# H3 881f992711fffff: 1 colonnine, 16.4 kWh coperti su 16.4 kWh
# H3 881f992705fffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh
# H3 881f992625fffff: 1 colonnine, 16.3 kWh coperti su 16.3 kWh
# H3 881f992753fffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh
# H3 881f992739fffff: 1 colonnine, 20.0 kWh coperti su 20.0 kWh
# H3 881f992743fffff: 1 colonnine, 21.3 kWh coperti su 21.3 kWh
# H3 881f99273dfffff: 1 colonnine, 14.8 kWh coperti su 14.8 kWh
# H3 881f99271dfffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh
# H3 881f992701fffff: 1 colonnine, 17.2 kWh coperti su 17.2 kWh
# H3 881f99270bfffff: 1 colonnine, 14.2 kWh coperti su 14.2 kWh
# H3 881f992757fffff: 1 colonnine, 14.6 kWh coperti su 14.6 kWh
# H3 881f992755fffff: 1 colonnine, 13.9 kWh coperti su 13.9 kWh
# H3 881f992a93fffff: 1 colonnine, 11.2 kWh coperti su 11.2 kWh
# H3 881f992a83fffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh
# H3 881f992a81fffff: 1 colonnine, 15.8 kWh coperti su 15.8 kWh
# H3 881f9928d1fffff: 1 colonnine, 9.4 kWh coperti su 9.4 kWh
# H3 881f992a87fffff: 1 colonnine, 11.7 kWh coperti su 11.7 kWh
# H3 881f992aabfffff: 1 colonnine, 12.6 kWh coperti su 12.6 kWh
# H3 881f992a91fffff: 1 colonnine, 10.5 kWh coperti su 10.5 kWh
# H3 881f9921a5fffff: 1 colonnine, 7.5 kWh coperti su 7.5 kWh
# H3 881f992a9dfffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh
# H3 881f9928d9fffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh
# H3 881f992abdfffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh
# H3 881f9928cbfffff: 1 colonnine, 10.0 kWh coperti su 10.0 kWh
# H3 881f992a85fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh
# H3 881f992ab5fffff: 1 colonnine, 12.5 kWh coperti su 12.5 kWh
# H3 881f992aa9fffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh
# H3 881f992a95fffff: 1 colonnine, 12.9 kWh coperti su 12.9 kWh
# H3 881f992ab7fffff: 1 colonnine, 15.8 kWh coperti su 15.8 kWh
# H3 881f992ab9fffff: 1 colonnine, 11.8 kWh coperti su 11.8 kWh
# H3 881f992aa3fffff: 1 colonnine, 10.2 kWh coperti su 10.2 kWh
# H3 881f992ab3fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh
# H3 881f992a97fffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh
# H3 881f992aa1fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh
# H3 881f9928c9fffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh
# H3 881f992a99fffff: 1 colonnine, 9.5 kWh coperti su 9.5 kWh
# H3 881f992abbfffff: 1 colonnine, 15.6 kWh coperti su 15.6 kWh
# H3 881f993665fffff: 1 colonnine, 12.6 kWh coperti su 12.6 kWh
# H3 881f99ad95fffff: 1 colonnine, 17.1 kWh coperti su 17.1 kWh
# H3 881f99366dfffff: 1 colonnine, 12.4 kWh coperti su 12.4 kWh
# H3 881f99375bfffff: 1 colonnine, 14.2 kWh coperti su 14.2 kWh
# H3 881f99ad87fffff: 1 colonnine, 9.4 kWh coperti su 9.4 kWh
# H3 881f993629fffff: 1 colonnine, 11.7 kWh coperti su 11.7 kWh
# H3 881f99ad83fffff: 1 colonnine, 11.4 kWh coperti su 11.4 kWh
# H3 881f99ad97fffff: 1 colonnine, 10.5 kWh coperti su 10.5 kWh
# H3 881f993667fffff: 1 colonnine, 11.0 kWh coperti su 11.0 kWh
# H3 881ea45b39fffff: 1 colonnine, 17.0 kWh coperti su 17.0 kWh
# H3 881ea45b3dfffff: 1 colonnine, 14.7 kWh coperti su 14.7 kWh
# H3 881ea45b3bfffff: 1 colonnine, 12.2 kWh coperti su 12.2 kWh
# H3 881ea4596bfffff: 1 colonnine, 9.5 kWh coperti su 9.5 kWh
# H3 881ea4594dfffff: 1 colonnine, 10.1 kWh coperti su 10.1 kWh
# H3 881ea45b05fffff: 1 colonnine, 14.4 kWh coperti su 14.4 kWh
# H3 881ea45b2bfffff: 1 colonnine, 26.9 kWh coperti su 26.9 kWh
# H3 881ea45b07fffff: 1 colonnine, 19.6 kWh coperti su 19.6 kWh
# H3 881ea45951fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea45949fffff: 1 colonnine, 17.4 kWh coperti su 17.4 kWh
# H3 881ea45941fffff: 1 colonnine, 19.2 kWh coperti su 19.2 kWh
# H3 881ea45b2dfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881ea45947fffff: 1 colonnine, 9.7 kWh coperti su 9.7 kWh
# H3 881ea45b25fffff: 1 colonnine, 13.4 kWh coperti su 13.4 kWh
# H3 881ea4590dfffff: 1 colonnine, 11.6 kWh coperti su 11.6 kWh
# H3 881ea45b35fffff: 1 colonnine, 21.2 kWh coperti su 21.2 kWh
# H3 881ea45b33fffff: 1 colonnine, 10.8 kWh coperti su 10.8 kWh
# H3 881ea45b27fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881f992c93fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea45b1dfffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh
# H3 881ea4594bfffff: 1 colonnine, 15.4 kWh coperti su 15.4 kWh
# H3 881ea45b31fffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh
# H3 881ea45969fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea45957fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea45943fffff: 1 colonnine, 9.7 kWh coperti su 9.7 kWh
# H3 881ea45b29fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh
# H3 881ea4595dfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881ea45b03fffff: 1 colonnine, 13.0 kWh coperti su 13.0 kWh
# H3 881ea45b21fffff: 1 colonnine, 15.6 kWh coperti su 15.6 kWh
# H3 881ea45945fffff: 1 colonnine, 15.5 kWh coperti su 15.5 kWh
# H3 881ea4590bfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f992c9bfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881ea45955fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea45b15fffff: 1 colonnine, 17.2 kWh coperti su 17.2 kWh
# H3 881ea45b37fffff: 1 colonnine, 16.5 kWh coperti su 16.5 kWh
# H3 881f992c97fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea45959fffff: 1 colonnine, 11.5 kWh coperti su 11.5 kWh
# H3 881ea45b23fffff: 1 colonnine, 18.6 kWh coperti su 18.6 kWh
# H3 881ea45909fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh
# H3 881f9925d5fffff: 1 colonnine, 11.7 kWh coperti su 11.7 kWh
# H3 881f9925cbfffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh
# H3 881f992405fffff: 1 colonnine, 13.6 kWh coperti su 13.6 kWh
# H3 881f992407fffff: 1 colonnine, 12.3 kWh coperti su 12.3 kWh
# H3 881f992595fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh
# H3 881f992439fffff: 1 colonnine, 15.0 kWh coperti su 15.0 kWh
# H3 881f992431fffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh
# H3 881f99242bfffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh
# H3 881f9925d1fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh
# H3 881f992427fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh
# H3 881f992423fffff: 1 colonnine, 10.4 kWh coperti su 10.4 kWh
# H3 881f9924e5fffff: 1 colonnine, 7.7 kWh coperti su 7.7 kWh
# H3 881f992591fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh
# H3 881f992467fffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh
# H3 881f992463fffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh
# H3 881f99259dfffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh
# H3 881f9925ddfffff: 1 colonnine, 12.4 kWh coperti su 12.4 kWh
# H3 881f9925c9fffff: 1 colonnine, 8.3 kWh coperti su 8.3 kWh
# H3 881f992435fffff: 1 colonnine, 10.3 kWh coperti su 10.3 kWh
# H3 881f992437fffff: 1 colonnine, 8.3 kWh coperti su 8.3 kWh
# H3 881f9924edfffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh
# H3 881f99243bfffff: 1 colonnine, 12.5 kWh coperti su 12.5 kWh
# H3 881f9925d9fffff: 1 colonnine, 12.6 kWh coperti su 12.6 kWh
# H3 881f992445fffff: 1 colonnine, 14.4 kWh coperti su 14.4 kWh
# H3 881f99246dfffff: 1 colonnine, 10.6 kWh coperti su 10.6 kWh
# H3 881f992733fffff: 1 colonnine, 22.2 kWh coperti su 22.2 kWh
# H3 881f992717fffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh
# H3 881f99244dfffff: 1 colonnine, 37.7 kWh coperti su 37.7 kWh
# H3 881f992469fffff: 1 colonnine, 22.1 kWh coperti su 22.1 kWh
# H3 881f992443fffff: 1 colonnine, 10.1 kWh coperti su 10.1 kWh
# H3 881f992621fffff: 1 colonnine, 28.1 kWh coperti su 28.1 kWh
# H3 881f992447fffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh
# H3 881f992461fffff: 1 colonnine, 10.0 kWh coperti su 10.0 kWh
# H3 881f99246bfffff: 1 colonnine, 28.9 kWh coperti su 28.9 kWh
# H3 881f992465fffff: 1 colonnine, 28.2 kWh coperti su 28.2 kWh
# H3 881f99273bfffff: 1 colonnine, 24.5 kWh coperti su 24.5 kWh
# H3 881f992623fffff: 1 colonnine, 31.9 kWh coperti su 31.9 kWh
# H3 881f992449fffff: 1 colonnine, 19.1 kWh coperti su 19.1 kWh
# H3 881f99271bfffff: 1 colonnine, 32.5 kWh coperti su 32.5 kWh
# H3 881f99240dfffff: 1 colonnine, 21.8 kWh coperti su 21.8 kWh
# H3 881f992627fffff: 1 colonnine, 43.9 kWh coperti su 43.9 kWh
# H3 881f992713fffff: 1 colonnine, 54.2 kWh coperti su 54.2 kWh
# H3 881f992441fffff: 1 colonnine, 29.0 kWh coperti su 29.0 kWh
# H3 881f992629fffff: 1 colonnine, 9.8 kWh coperti su 9.8 kWh
# H3 881f99218bfffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh
# H3 881f992199fffff: 1 colonnine, 7.9 kWh coperti su 7.9 kWh
# H3 881f9921a9fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh
# H3 881f9921adfffff: 1 colonnine, 7.1 kWh coperti su 7.1 kWh
# H3 881f992183fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh
# H3 881f9921d5fffff: 1 colonnine, 14.4 kWh coperti su 14.4 kWh
# H3 881f9921d7fffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh
# H3 881f992113fffff: 1 colonnine, 9.3 kWh coperti su 9.3 kWh
# H3 881f9921c1fffff: 1 colonnine, 14.1 kWh coperti su 14.1 kWh
# H3 881f9921ddfffff: 1 colonnine, 12.0 kWh coperti su 12.0 kWh
# H3 881f9921c3fffff: 1 colonnine, 12.8 kWh coperti su 12.8 kWh
# H3 881f9921cdfffff: 1 colonnine, 11.0 kWh coperti su 11.0 kWh
# H3 881f9921d9fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh
# H3 881f99219bfffff: 1 colonnine, 7.9 kWh coperti su 7.9 kWh
# H3 881f99218dfffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh
# H3 881f992189fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh
# H3 881f9921e3fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh
# H3 881f9920e7fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh
# H3 881f992027fffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh
# H3 881f993915fffff: 1 colonnine, 7.1 kWh coperti su 7.1 kWh
# H3 881f9939e7fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh
# H3 881f993913fffff: 1 colonnine, 12.2 kWh coperti su 12.2 kWh
# H3 881f9939e9fffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh
# H3 881f9939c1fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh
# H3 881f99391bfffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh
# H3 881f992a4dfffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh
# H3 881f993917fffff: 1 colonnine, 15.5 kWh coperti su 15.5 kWh
# H3 881f993983fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881f9939cdfffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh
# H3 881f9939adfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881f9939c9fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh
# H3 881ea4c939fffff: 1 colonnine, 16.9 kWh coperti su 16.9 kWh
# H3 881ea4c9c5fffff: 1 colonnine, 10.7 kWh coperti su 10.7 kWh
# H3 881ea4c911fffff: 1 colonnine, 18.2 kWh coperti su 18.2 kWh
# H3 881ea4c9e9fffff: 1 colonnine, 8.3 kWh coperti su 8.3 kWh
# H3 881ea4c90dfffff: 1 colonnine, 7.9 kWh coperti su 7.9 kWh
# H3 881ea4c9cdfffff: 1 colonnine, 9.9 kWh coperti su 9.9 kWh
# H3 881ea4c963fffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh
# H3 881ea4c91dfffff: 1 colonnine, 14.9 kWh coperti su 14.9 kWh
# H3 881ea4c943fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh
# H3 881ea4c9c9fffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh
# H3 881ea4c93dfffff: 1 colonnine, 7.1 kWh coperti su 7.1 kWh
# H3 881ea4c933fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh
# H3 881ea4c931fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh
# H3 881ea4c917fffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh
# H3 881ea4c915fffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh
# H3 881ea4c91bfffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh
# H3 881ea4c901fffff: 1 colonnine, 10.8 kWh coperti su 10.8 kWh
# H3 881ea4c9c1fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh
# H3 881ea4c913fffff: 1 colonnine, 11.8 kWh coperti su 11.8 kWh
# H3 881ea4c951fffff: 1 colonnine, 17.2 kWh coperti su 17.2 kWh
# H3 881ea4c93bfffff: 1 colonnine, 7.5 kWh coperti su 7.5 kWh
# H3 881ea4c903fffff: 1 colonnine, 18.5 kWh coperti su 18.5 kWh
# H3 881ea4c90bfffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh
# H3 881ea4c935fffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh
# H3 881ea4c95dfffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh
# H3 881ea4c955fffff: 1 colonnine, 11.9 kWh coperti su 11.9 kWh
# H3 881f992415fffff: 1 colonnine, 12.5 kWh coperti su 12.5 kWh
# H3 881f992403fffff: 1 colonnine, 9.4 kWh coperti su 9.4 kWh
# H3 881f992419fffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh
# H3 881f992401fffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh
# H3 881f9926b5fffff: 1 colonnine, 13.9 kWh coperti su 13.9 kWh
# H3 881f99241dfffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh
# H3 881f992455fffff: 1 colonnine, 6.8 kWh coperti su 6.8 kWh
# H3 881f992453fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh
# H3 881f992451fffff: 1 colonnine, 10.7 kWh coperti su 10.7 kWh
# H3 881f992417fffff: 1 colonnine, 9.8 kWh coperti su 9.8 kWh
# H3 881f9926a3fffff: 1 colonnine, 15.0 kWh coperti su 15.0 kWh
# H3 881f9926a9fffff: 1 colonnine, 13.1 kWh coperti su 13.1 kWh
# H3 881f99245dfffff: 1 colonnine, 13.2 kWh coperti su 13.2 kWh
# H3 881f9924c5fffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh
# H3 881f9924e9fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh
# H3 881f9926adfffff: 1 colonnine, 17.8 kWh coperti su 17.8 kWh
# H3 881f9924e1fffff: 1 colonnine, 17.2 kWh coperti su 17.2 kWh
# H3 881f9924c9fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh
# H3 881f9926abfffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh
# H3 881f99245bfffff: 1 colonnine, 12.9 kWh coperti su 12.9 kWh
# H3 881f9926a1fffff: 1 colonnine, 12.1 kWh coperti su 12.1 kWh
# H3 881f99240bfffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh
# H3 881f9920d1fffff: 1 colonnine, 13.1 kWh coperti su 13.1 kWh
# ...
# H3 881f992021fffff: 1 colonnine, 7.1 kWh coperti su 7.1 kWh
# H3 881f992069fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh
# H3 881f992065fffff: 1 colonnine, 13.0 kWh coperti su 13.0 kWh
# H3 881f992045fffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh
# H3 881f9920c9fffff: 1 colonnine, 147.1 kWh coperti su 147.1 kWh
# H3 881f992019fffff: 1 colonnine, 60.6 kWh coperti su 60.6 kWh
# H3 881f9922a7fffff: 1 colonnine, 140.8 kWh coperti su 140.8 kWh
# H3 881f992011fffff: 1 colonnine, 60.0 kWh coperti su 60.0 kWh
# H3 881f9922abfffff: 1 colonnine, 209.2 kWh coperti su 209.2 kWh
# H3 881f99201bfffff: 1 colonnine, 60.2 kWh coperti su 60.2 kWh
# H3 881f9922a1fffff: 1 colonnine, 263.4 kWh coperti su 263.4 kWh
# H3 881f9922a5fffff: 1 colonnine, 60.4 kWh coperti su 60.4 kWh
# H3 881f9922bdfffff: 1 colonnine, 215.6 kWh coperti su 215.6 kWh
# H3 881f9922a3fffff: 1 colonnine, 119.2 kWh coperti su 119.2 kWh
# H3 881f993289fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh
# H3 881f9932ddfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f9932c1fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f9932a9fffff: 1 colonnine, 23.0 kWh coperti su 23.0 kWh
# H3 881f993285fffff: 1 colonnine, 6.8 kWh coperti su 6.8 kWh
# H3 881f99328dfffff: 1 colonnine, 21.6 kWh coperti su 21.6 kWh
# H3 881f9932c3fffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh
# H3 881f9932abfffff: 1 colonnine, 21.6 kWh coperti su 21.6 kWh
# H3 881f993287fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh
# H3 881f9932d5fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881f99328bfffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh
# H3 881f993281fffff: 1 colonnine, 11.7 kWh coperti su 11.7 kWh
# H3 881ea6929bfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881f993543fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh
# H3 881f993559fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh
# H3 881f99355dfffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh
# H3 881f99350bfffff: 1 colonnine, 26.3 kWh coperti su 26.3 kWh
# H3 881f993737fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh
# H3 881f993555fffff: 1 colonnine, 9.7 kWh coperti su 9.7 kWh
# H3 881f993509fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh
# H3 881f993551fffff: 1 colonnine, 20.2 kWh coperti su 20.2 kWh
# H3 881f992a67fffff: 1 colonnine, 12.3 kWh coperti su 12.3 kWh
# H3 881f992a05fffff: 1 colonnine, 8.3 kWh coperti su 8.3 kWh
# H3 881f992b5bfffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh
# H3 881f992a07fffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh
# H3 881f992a47fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh
# H3 881f992a6bfffff: 1 colonnine, 13.6 kWh coperti su 13.6 kWh
# H3 881f992a01fffff: 1 colonnine, 10.1 kWh coperti su 10.1 kWh
# H3 881f992a2bfffff: 1 colonnine, 7.1 kWh coperti su 7.1 kWh
# H3 881f992a03fffff: 1 colonnine, 14.2 kWh coperti su 14.2 kWh
# H3 881f992b53fffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh
# H3 881f992a29fffff: 1 colonnine, 10.2 kWh coperti su 10.2 kWh
# H3 881f992a63fffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh
# H3 881f9939b3fffff: 1 colonnine, 9.0 kWh coperti su 9.0 kWh
# H3 881f992a0dfffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh
# H3 881f992a65fffff: 1 colonnine, 8.3 kWh coperti su 8.3 kWh
# H3 881f992a69fffff: 1 colonnine, 6.8 kWh coperti su 6.8 kWh
# H3 881f992a27fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh
# H3 881ea4c807fffff: 1 colonnine, 47.1 kWh coperti su 47.1 kWh
# H3 881ea4c811fffff: 1 colonnine, 10.2 kWh coperti su 10.2 kWh
# H3 881ea4c831fffff: 1 colonnine, 67.0 kWh coperti su 67.0 kWh
# H3 881ea4c823fffff: 1 colonnine, 65.6 kWh coperti su 65.6 kWh
# H3 881ea4c839fffff: 1 colonnine, 11.9 kWh coperti su 11.9 kWh
# H3 881ea4c83dfffff: 1 colonnine, 38.4 kWh coperti su 38.4 kWh
# H3 881ea4c815fffff: 1 colonnine, 12.8 kWh coperti su 12.8 kWh
# H3 881ea4c803fffff: 1 colonnine, 39.3 kWh coperti su 39.3 kWh
# H3 881ea4d8a1fffff: 1 colonnine, 10.0 kWh coperti su 10.0 kWh
# H3 881ea4d989fffff: 1 colonnine, 15.5 kWh coperti su 15.5 kWh
# H3 881ea4d8a5fffff: 1 colonnine, 19.5 kWh coperti su 19.5 kWh
# H3 881ea4d9d5fffff: 1 colonnine, 12.5 kWh coperti su 12.5 kWh
# H3 881ea4d9d3fffff: 1 colonnine, 16.6 kWh coperti su 16.6 kWh
# H3 881ea4d9d7fffff: 1 colonnine, 10.5 kWh coperti su 10.5 kWh
# H3 881ea4d9d1fffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh
# H3 881ea4d8adfffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh
# H3 881ea4d9d9fffff: 1 colonnine, 8.3 kWh coperti su 8.3 kWh
# H3 881ea4d8a9fffff: 1 colonnine, 8.8 kWh coperti su 8.8 kWh
# H3 881ea4d98bfffff: 1 colonnine, 9.8 kWh coperti su 9.8 kWh
# H3 881f993a35fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh
# H3 881f993859fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh
# H3 881f99385bfffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh
# H3 881f993a37fffff: 1 colonnine, 9.3 kWh coperti su 9.3 kWh
# H3 881f992d95fffff: 1 colonnine, 11.9 kWh coperti su 11.9 kWh
# H3 881f992ddbfffff: 1 colonnine, 8.3 kWh coperti su 8.3 kWh
# H3 881f992dd1fffff: 1 colonnine, 17.1 kWh coperti su 17.1 kWh
# H3 881f992dd5fffff: 1 colonnine, 14.1 kWh coperti su 14.1 kWh
# H3 881f992dd9fffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh
# H3 881f992dddfffff: 1 colonnine, 8.8 kWh coperti su 8.8 kWh
# H3 881f992dd3fffff: 1 colonnine, 10.7 kWh coperti su 10.7 kWh
# H3 881f992dc3fffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh
# H3 881f992d9dfffff: 1 colonnine, 7.7 kWh coperti su 7.7 kWh
# H3 881f992d83fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f992dd7fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh
# H3 881ea4cb59fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh
# H3 881ea4cb19fffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh
# H3 881ea4cb57fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh
# H3 881ea4cb1bfffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh
# H3 881ea4cb51fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh
# H3 881ea4cb53fffff: 1 colonnine, 7.9 kWh coperti su 7.9 kWh
# H3 881f992615fffff: 1 colonnine, 12.1 kWh coperti su 12.1 kWh
# H3 881f992611fffff: 1 colonnine, 21.0 kWh coperti su 21.0 kWh
# H3 881f992609fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh
# H3 881f992657fffff: 1 colonnine, 28.8 kWh coperti su 28.8 kWh
# H3 881f992619fffff: 1 colonnine, 22.7 kWh coperti su 22.7 kWh
# H3 881f99260bfffff: 1 colonnine, 6.3 kWh coperti su 6.3 kWh
# H3 881f992633fffff: 1 colonnine, 17.1 kWh coperti su 17.1 kWh
# H3 881f9926edfffff: 1 colonnine, 23.7 kWh coperti su 23.7 kWh
# H3 881f99263bfffff: 1 colonnine, 18.2 kWh coperti su 18.2 kWh
# H3 881f992617fffff: 1 colonnine, 10.3 kWh coperti su 10.3 kWh
# H3 881f99261dfffff: 1 colonnine, 17.1 kWh coperti su 17.1 kWh
# H3 881f992863fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh
# H3 881f992369fffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh
# H3 881f99236bfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f99059bfffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh
# H3 881f9905d3fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh
# H3 881f990599fffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh
# H3 881f990597fffff: 1 colonnine, 12.9 kWh coperti su 12.9 kWh
# H3 881f990591fffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh
# H3 881f9905dbfffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh
# H3 881f9938e1fffff: 1 colonnine, 9.3 kWh coperti su 9.3 kWh
# H3 881f9939d3fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f9926d5fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh
# H3 881f9926b9fffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh
# H3 881f992683fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f9926c3fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh
# H3 881f992681fffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh
# H3 881f9926bbfffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh
# H3 881f992689fffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh
# H3 881f9930e9fffff: 1 colonnine, 32.2 kWh coperti su 32.2 kWh
# H3 881f9930ebfffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh
# H3 881f993011fffff: 1 colonnine, 9.8 kWh coperti su 9.8 kWh
# H3 881f9930e1fffff: 1 colonnine, 20.7 kWh coperti su 20.7 kWh
# H3 881f993017fffff: 1 colonnine, 40.9 kWh coperti su 40.9 kWh
# H3 881f9930c5fffff: 1 colonnine, 66.6 kWh coperti su 66.6 kWh
# H3 881f9930edfffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh
# H3 881f993013fffff: 1 colonnine, 24.4 kWh coperti su 24.4 kWh
# H3 881f99a549fffff: 1 colonnine, 6.8 kWh coperti su 6.8 kWh
# H3 881f99a511fffff: 1 colonnine, 9.6 kWh coperti su 9.6 kWh
# H3 881f99a5cdfffff: 1 colonnine, 12.5 kWh coperti su 12.5 kWh
# H3 881f99a5c9fffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh
# H3 881f99a51bfffff: 1 colonnine, 13.6 kWh coperti su 13.6 kWh
# H3 881f99a51dfffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh
# H3 881f99214bfffff: 1 colonnine, 14.6 kWh coperti su 14.6 kWh
# H3 881f992149fffff: 1 colonnine, 16.4 kWh coperti su 16.4 kWh
# H3 881f99233dfffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh
# H3 881f992323fffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh
# H3 881f992335fffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh
# H3 881f992321fffff: 1 colonnine, 9.7 kWh coperti su 9.7 kWh
# H3 881f992143fffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh
# H3 881f99214dfffff: 1 colonnine, 14.3 kWh coperti su 14.3 kWh
# H3 881f992331fffff: 1 colonnine, 9.5 kWh coperti su 9.5 kWh
# H3 881f992327fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh
# H3 881f992329fffff: 1 colonnine, 9.8 kWh coperti su 9.8 kWh
# H3 881ea4c99bfffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh
# H3 881ea4c8a1fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea4c8a5fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh
# H3 881ea4c99dfffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh
# H3 881ea4c983fffff: 1 colonnine, 10.3 kWh coperti su 10.3 kWh
# H3 881ea4c981fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh
# H3 881ea4c987fffff: 1 colonnine, 10.8 kWh coperti su 10.8 kWh
# H3 881ea4c9abfffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh
# H3 881ea4c995fffff: 1 colonnine, 10.7 kWh coperti su 10.7 kWh
# H3 881ea4c9ebfffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh
# H3 881ea4c98bfffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh
# H3 881f992333fffff: 1 colonnine, 17.7 kWh coperti su 17.7 kWh
# H3 881f992317fffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh
# H3 881f992337fffff: 1 colonnine, 17.0 kWh coperti su 17.0 kWh
# H3 881f992159fffff: 1 colonnine, 15.7 kWh coperti su 15.7 kWh
# H3 881ea6962dfffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh
# H3 881f993295fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh
# H3 881f993293fffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh
# H3 881f9932b1fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh
# H3 881f9932bdfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881f99af13fffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh
# H3 881f9934b7fffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh
# H3 881f99265dfffff: 1 colonnine, 7.1 kWh coperti su 7.1 kWh
# H3 881ea692c5fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh
# H3 881ea692cdfffff: 1 colonnine, 7.5 kWh coperti su 7.5 kWh
# H3 881ea6921bfffff: 1 colonnine, 9.3 kWh coperti su 9.3 kWh
# H3 881f993a99fffff: 1 colonnine, 14.5 kWh coperti su 14.5 kWh
# H3 881f993a9bfffff: 1 colonnine, 20.0 kWh coperti su 20.0 kWh
# H3 881f9931adfffff: 1 colonnine, 20.0 kWh coperti su 20.0 kWh
# H3 881f993a91fffff: 1 colonnine, 10.7 kWh coperti su 10.7 kWh
# H3 881f993ad3fffff: 1 colonnine, 13.0 kWh coperti su 13.0 kWh
# H3 881f993a9dfffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh
# H3 881f9931a5fffff: 1 colonnine, 18.5 kWh coperti su 18.5 kWh
# H3 881ea4c9a3fffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh
# H3 881ea45349fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh
# H3 881ea4c9a7fffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh
# H3 881ea4c9b5fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh
# H3 881ea4c9e7fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh
# H3 881f9926dbfffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh
# H3 881ea4c9a5fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh
# H3 881ea4c9e5fffff: 1 colonnine, 6.3 kWh coperti su 6.3 kWh
# H3 881f9926d3fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh
# H3 881f9926d1fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh
# H3 881f992881fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh
# H3 881f992d6bfffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh
# H3 881f992d07fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh
# H3 881f992d05fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh
# H3 881f992d63fffff: 1 colonnine, 10.7 kWh coperti su 10.7 kWh
# H3 881f992d41fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f8a6925fffff: 1 colonnine, 20.3 kWh coperti su 20.3 kWh
# H3 881f99a61bfffff: 1 colonnine, 20.7 kWh coperti su 20.7 kWh
# H3 881f8a693dfffff: 1 colonnine, 33.6 kWh coperti su 33.6 kWh
# H3 881f8a6935fffff: 1 colonnine, 32.7 kWh coperti su 32.7 kWh
# H3 881f8a6927fffff: 1 colonnine, 18.0 kWh coperti su 18.0 kWh
# H3 881ea4c8c1fffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh
# H3 881ea4c8d5fffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh
# H3 881f99adadfffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh
# H3 881f9932dbfffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh
# H3 881f99ade7fffff: 1 colonnine, 7.7 kWh coperti su 7.7 kWh
# H3 881f9932d9fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh
# H3 881f99ad85fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh
# H3 881f9939cbfffff: 1 colonnine, 11.2 kWh coperti su 11.2 kWh
# H3 881f99398bfffff: 1 colonnine, 19.2 kWh coperti su 19.2 kWh
# H3 881f993989fffff: 1 colonnine, 14.1 kWh coperti su 14.1 kWh
# H3 881f9939ddfffff: 1 colonnine, 9.8 kWh coperti su 9.8 kWh
# H3 881f993837fffff: 1 colonnine, 14.2 kWh coperti su 14.2 kWh
# H3 881f9939d9fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh
# H3 881f9939c3fffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh
# H3 881f9928ebfffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh
# H3 881f9928e3fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f9928c7fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh
# H3 881f9928c5fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f9928e1fffff: 1 colonnine, 10.3 kWh coperti su 10.3 kWh
# H3 881f992a5dfffff: 1 colonnine, 9.6 kWh coperti su 9.6 kWh
# H3 881f9938b1fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f992a59fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f992a51fffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh
# H3 881f9938b5fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh
# H3 881f992a41fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh
# H3 881f992a4bfffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh
# H3 881f9938b7fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh
# H3 881f8a6859fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh
# H3 881f992653fffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh
# H3 881f99261bfffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh
# H3 881f9934d7fffff: 1 colonnine, 6.8 kWh coperti su 6.8 kWh
# H3 881ea69705fffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh
# H3 881f992ca5fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh
# H3 881f99ad1dfffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh
# H3 881f99ad11fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh
# H3 881f8a6923fffff: 1 colonnine, 10.8 kWh coperti su 10.8 kWh
# H3 881f8a692bfffff: 1 colonnine, 12.7 kWh coperti su 12.7 kWh
# H3 881f8a690dfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881ea45369fffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh
# H3 881ea4534bfffff: 1 colonnine, 13.4 kWh coperti su 13.4 kWh
# H3 881ea45341fffff: 1 colonnine, 12.0 kWh coperti su 12.0 kWh
# H3 881ea45345fffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh
# H3 881ea45347fffff: 1 colonnine, 11.2 kWh coperti su 11.2 kWh
# H3 881ea4cb67fffff: 1 colonnine, 9.6 kWh coperti su 9.6 kWh
# H3 881ea4cb47fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh
# H3 881ea4cb6bfffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh
# H3 881ea69219fffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh
# H3 881f9938d3fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh
# H3 881f993695fffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh
# H3 881ea6965bfffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh
# H3 881f8a6a5bfffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh
# H3 881f993a97fffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh
# H3 881f99236dfffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh
# H3 881ea4ca6dfffff: 1 colonnine, 49.8 kWh coperti su 49.8 kWh
# H3 881ea4d9bbfffff: 1 colonnine, 77.1 kWh coperti su 77.1 kWh
# H3 881ea4d983fffff: 1 colonnine, 33.1 kWh coperti su 33.1 kWh
# H3 881ea4d9b1fffff: 1 colonnine, 41.9 kWh coperti su 41.9 kWh
# H3 881ea4d995fffff: 1 colonnine, 12.8 kWh coperti su 12.8 kWh
# H3 881ea4d9b3fffff: 1 colonnine, 55.6 kWh coperti su 55.6 kWh
# H3 881f8a6a1bfffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh
# H3 881f8a6ae1fffff: 1 colonnine, 12.1 kWh coperti su 12.1 kWh
# H3 881f99ada5fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh
#
# Domanda totale coperta: 28010.36 kWh

# %% [markdown]
# ### Map visualisation

# %%
# Create and display the map based on hexagons
mappa = crea_mappa_colonnine_esagoni(gdf_risultati_base)
mappa
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Save the map as an HTML file
mappa.save("/content/drive/Shareddrives/OM in Business Analytics/OM in BA - Project/Codice/04 - Modello/log_heatmap_first_model_def.html")

# %% [markdown]
# ### Results

# %%
total_allocated_chargers = gdf_risultati_base["Colonnine allocate"].sum()
total_covered_demand = gdf_risultati_base["Domanda coperta (kWh)"].sum()
total_demand = gdf_risultati_base["Domanda Giornaliera Ponderata (kWh)"].sum()

print(f"Total allocated charging stations: {total_allocated_chargers}")
print(f"Total covered demand (kWh): {total_covered_demand:.2f}")
print(f"Total demand (kWh): {total_demand:.2f}")
# Out:
# Total allocated charging stations: 1623
# Total covered demand (kWh): 28010.36
# Total demand (kWh): 34500.45

# %% [markdown]
# ## SECOND MODEL
# ## Charging Station Allocation Model – Aggregated Neighborhood Demand (Hexagon-Based)
#
# ### Objective
# Allocate *n* charging stations among the hexagons in the province of Brescia to **maximize the coverage of local daily electricity demand**, allowing each hexagon to benefit from stations located in **neighboring hexagons** as well.
#
# ---
#
# ### Decision Variables
# - $ x_h \in \mathbb{Z}_{\geq 0} $: Number of charging stations installed in hexagon *h*
# - $ y_h \in [0, D_h] $: Amount of daily demand covered in hexagon *h*
#
# ---
#
# ### Parameters
# - $ D_h $: Daily electricity demand in hexagon *h*
# - $ \text{cap} = 555.43 $: Daily capacity of a single charging station (kWh/day)
# - $ p $: Maximum number of charging stations to be installed
# - $ \mathcal{N}(h) $: Set of neighbors of hexagon *h* (within k-ring 1)
#
# ---
#
# ### Constraints
#
# 1. **Total station limit**
#    $$
#    \sum_{h=1}^{n} x_h \leq p
#    $$
#
# 2. **Demand coverage cannot exceed actual local demand**
#    $$
#    y_h \leq D_h \quad \forall h
#    $$
#
# 3. **Coverage limited by capacity of stations in *h* and its neighbors**
#    $$
#    y_h \leq \text{cap} \cdot \left( x_h + \sum_{j \in \mathcal{N}(h)} x_j \right) \quad \forall h
#    $$
#
# ---
#
# ### Objective Function
#
# Maximize total local demand coverage:
# $$
# \max \sum_{h=1}^{n} y_h
# $$
#
# This model prioritizes local demand fulfillment while allowing neighboring station capacity to contribute, thereby improving spatial equity in charging infrastructure deployment.

# %%
# !pip install h3==3.*
# Out:
# Collecting h3==3.*
#   Downloading h3-3.7.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Downloading h3-3.7.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.0 MB/s eta 0:00:00
# Installing collected packages: h3
# Successfully installed h3-3.7.7

# %% [markdown]
# ### Neighbor list

# %%
import h3

# Get the unique list of hexagons in your GeoDataFrame (gdf)
h3_ids_present = set(gdf['h3_id'])

# Create a dictionary {index in gdf : list of neighboring indices}
h3_id_to_idx = {h3_id: idx for idx, h3_id in enumerate(gdf['h3_id'])}

neighbors_dict = {}

for idx, row in gdf.iterrows():
    h3_id = row['h3_id']
    # Get the neighboring H3 hexagons (k_ring with radius 1)
    neighbors_h3 = h3.k_ring(h3_id, 1)
    # Filter only those present in your dataframe
    present_neighbors = [h3_id_to_idx[v] for v in neighbors_h3 if v in h3_ids_present and v != h3_id]
    neighbors_dict[idx] = present_neighbors

print(f"Neighbor dictionary created with {len(neighbors_dict)} hexagons")
# Out:
# Neighbor dictionary created with 6495 hexagons

# %% [markdown]
# ### Model function

# %%
pip install pulp
# Out:
# Collecting pulp
#   Downloading pulp-3.1.1-py3-none-any.whl.metadata (1.3 kB)
# Downloading pulp-3.1.1-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 102.5 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-3.1.1

# %%
import pulp
import pandas as pd

def ottimizza_colonnine_con_domanda_aggregata(gdf_mappa, neighbours_dict= neighbors_dict, p_colonnine=30, cap=555.43, verbose=True ):
    """
    Risolve il problema di allocazione ottimale delle colonnine considerando la domanda aggregata nel vicinato.

    Parametri:
    - gdf_mappa: GeoDataFrame con 'h3_id' e 'Domanda Giornaliera Ponderata (kWh)'
    - neighbours_dict: dizionario {h3_id: lista di vicini h3_id}
    - p_colonnine: numero totale di colonnine disponibili
    - cap: capacità giornaliera di una colonnina (kWh)
    - verbose: se True, stampa i risultati

    Ritorna:
    - GeoDataFrame con colonne aggiuntive: 'Colonnine allocate', 'Domanda coperta (kWh)', 'Domanda aggregata (kWh)'
    """

    df = gdf_mappa.copy()
    h3_list = df['h3_id'].tolist()
    h3_to_idx = {h3_id: idx for idx, h3_id in enumerate(h3_list)}

    demand = df["Domanda Giornaliera Ponderata (kWh)"].tolist()
    n = len(demand)

    # Calculate aggregated demand (hexagon + neighbors)
    domanda_aggregata = []
    for h3_id in h3_list:
        idx = h3_to_idx[h3_id]
        vicini = neighbours_dict.get(h3_id, [])
        domanda_sum = demand[idx]  # local demand
        for vicino_id in vicini:
            if vicino_id in h3_to_idx:  # only consider if neighbor is in the dataset
                domanda_sum += demand[h3_to_idx[vicino_id]]
        domanda_aggregata.append(domanda_sum)
    df["Domanda aggregata (kWh)"] = domanda_aggregata

    # Model
    model = pulp.LpProblem("Colonnine_con_domanda_aggregata", pulp.LpMaximize)

    # Decision variables
    x = pulp.LpVariable.dicts("Colonnine", range(n), lowBound=0, cat="Integer")  # allocated stations
    y = pulp.LpVariable.dicts("DomandaCoperta", range(n), lowBound=0)            # covered demand

    # Objective: maximize total covered demand
    model += pulp.lpSum(y[i] for i in range(n))

    # Constraint: maximum total number of stations
    model += pulp.lpSum(x[i] for i in range(n)) <= p_colonnine

    # Constraints for each hexagon
    for i in range(n):
        h3_id = h3_list[i]
        vicini = neighbours_dict.get(h3_id, [])
        vicini_idx = [h3_to_idx[v] for v in vicini if v in h3_to_idx]

        # Vincolo: massimo 10 colonnine per esagono
        model += x[i] <= 10

        # Covered demand must be <= local demand
        model += y[i] <= demand[i]

        # Covered demand must be <= total capacity of stations allocated on hexagon + neighbors
        model += y[i] <= cap * (x[i] + pulp.lpSum(x[j] for j in vicini_idx))

    # Solve
    model.solve()

    # Extract results
    colonnine_allocate = [int(x[i].varValue) if x[i].varValue else 0 for i in range(n)]
    domanda_coperta = [y[i].varValue if y[i].varValue else 0.0 for i in range(n)]

    df["Colonnine allocate"] = colonnine_allocate
    df["Domanda coperta (kWh)"] = domanda_coperta

    if verbose:
        for i in range(n):
            if colonnine_allocate[i] > 0:
                print(f"H3 {df.iloc[i]['h3_id']}: {colonnine_allocate[i]} colonnine, "
                      f"{domanda_coperta[i]:.1f} kWh coperti su {demand[i]:.1f} kWh (Domanda agg: {domanda_aggregata[i]:.1f} kWh)")
        print(f"\nDomanda totale coperta: {pulp.value(model.objective):.2f} kWh")

    return df

# %% [markdown]
# ### Map function

# %%
import folium

def crea_mappa_colonnine_discrete(gdf,
                                  colonna_domanda="Domanda Giornaliera Ponderata (kWh)",
                                  colonna_coperta="Domanda coperta (kWh)",
                                  colonna_colonnine="Colonnine allocate",
                                  nome_mappa="Mappa Colonnine",
                                  location=[45.54, 10.22],
                                  zoom_start=10):
    """
    Creates a Folium map of H3 hexagons with discrete colors based on the NUMBER OF CHARGING STATIONS allocated:
    0 -> gray, 1 -> light blue, 2 -> bright blue, 3 -> light navy blue, 4 -> dark blue, 5+ -> purple.
    """

    # Check if the column exists
    if colonna_colonnine not in gdf.columns:
        raise ValueError(f"Column '{colonna_colonnine}' not found in the GeoDataFrame.")

    # Discrete color map
    def get_color(colonnine):
        if colonnine == 0:
            return "#B0B0B0"  # gray
        elif colonnine == 1:
            return "#ADD8E6"  # light blue
        elif colonnine == 2:
            return "#0096FF"  # bright blue
        elif colonnine == 3:
            return "#0000FF"  # light navy blue
        elif colonnine == 4:
            return "#00008B"  # dark blue
        else:
            return "#800080"  # purple (5 or more)

    # Create the map
    mappa = folium.Map(location=location, zoom_start=zoom_start, tiles="cartodbpositron")

    # Add polygons
    for _, row in gdf.iterrows():
        # Get the number of charging stations, use default if missing
        colonnine = int(row.get(colonna_colonnine, 0))

        # Do not modify the demand if there are 0 charging stations (avoid zeroing it)
        domanda = row.get(colonna_domanda, 0)
        if colonnine == 0 and domanda == 0:
            domanda = row.get(colonna_domanda, 0)  # Prevent zeroing if no stations

        coperta = row.get(colonna_coperta, 0)

        # Compute color based on the number of charging stations
        color = get_color(colonnine)

        # Create tooltip with details
        tooltip_text = (
            f"<b>H3 ID: {row.get('h3_id', 'N/A')}</b><br>"
            f"Demand: {domanda:.1f} kWh<br>"
            f"Covered: {coperta:.1f} kWh<br>"
            f"Allocated charging stations: {colonnine}"
        )

        # Add polygon to the map
        folium.GeoJson(
            row["geometry"],
            style_function=lambda feature, color=color: {
                "fillColor": color,
                "color": "black",
                "weight": 0.5,
                "fillOpacity": 0.7,
            },
            tooltip=folium.Tooltip(tooltip_text)
        ).add_to(mappa)

    # HTML per la legenda basata sui colori attuali
    legenda_html = """
     <div style="
         position: fixed;
         bottom: 50px; left: 50px; width: 220px; height: auto;
         background-color: white;
         border:2px solid grey;
         z-index:9999;
         font-size:14px;
         padding: 10px;
         box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
     ">
     <b>Legenda - Colonnine allocate</b><br>
     <i style="background:#B0B0B0;width:15px;height:15px;float:left;margin-right:5px;display:inline-block;"></i> 0 (nessuna)<br>
     <i style="background:#ADD8E6;width:15px;height:15px;float:left;margin-right:5px;display:inline-block;"></i> 1<br>
     <i style="background:#0096FF;width:15px;height:15px;float:left;margin-right:5px;display:inline-block;"></i> 2<br>
     <i style="background:#0000FF;width:15px;height:15px;float:left;margin-right:5px;display:inline-block;"></i> 3<br>
     <i style="background:#00008B;width:15px;height:15px;float:left;margin-right:5px;display:inline-block;"></i> 4<br>
     <i style="background:#800080;width:15px;height:15px;float:left;margin-right:5px;display:inline-block;"></i> 5 o più<br>
     </div>
    """

    mappa.get_root().html.add_child(folium.Element(legenda_html))

    return mappa

# %%
gdf_risultati = ottimizza_colonnine_con_domanda_aggregata(gdf_mappa = gdf, p_colonnine=1623)
# Out:
# H3 881f99274bfffff: 1 colonnine, 29.5 kWh coperti su 29.5 kWh (Domanda agg: 29.5 kWh)
# H3 881f992215fffff: 1 colonnine, 37.4 kWh coperti su 37.4 kWh (Domanda agg: 37.4 kWh)
# H3 881f992213fffff: 1 colonnine, 67.3 kWh coperti su 67.3 kWh (Domanda agg: 67.3 kWh)
# H3 881f9935c7fffff: 1 colonnine, 18.6 kWh coperti su 18.6 kWh (Domanda agg: 18.6 kWh)
# H3 881f9935a1fffff: 1 colonnine, 17.8 kWh coperti su 17.8 kWh (Domanda agg: 17.8 kWh)
# H3 881f9922ddfffff: 1 colonnine, 106.8 kWh coperti su 106.8 kWh (Domanda agg: 106.8 kWh)
# H3 881f992285fffff: 1 colonnine, 50.0 kWh coperti su 50.0 kWh (Domanda agg: 50.0 kWh)
# H3 881f9922e3fffff: 1 colonnine, 18.2 kWh coperti su 18.2 kWh (Domanda agg: 18.2 kWh)
# H3 881f992217fffff: 1 colonnine, 20.1 kWh coperti su 20.1 kWh (Domanda agg: 20.1 kWh)
# H3 881f993501fffff: 1 colonnine, 71.3 kWh coperti su 71.3 kWh (Domanda agg: 71.3 kWh)
# H3 881f99353bfffff: 1 colonnine, 108.0 kWh coperti su 108.0 kWh (Domanda agg: 108.0 kWh)
# H3 881f992295fffff: 1 colonnine, 51.4 kWh coperti su 51.4 kWh (Domanda agg: 51.4 kWh)
# H3 881f9922cdfffff: 1 colonnine, 76.6 kWh coperti su 76.6 kWh (Domanda agg: 76.6 kWh)
# H3 881f9920d9fffff: 1 colonnine, 44.7 kWh coperti su 44.7 kWh (Domanda agg: 44.7 kWh)
# H3 881f992745fffff: 1 colonnine, 46.8 kWh coperti su 46.8 kWh (Domanda agg: 46.8 kWh)
# H3 881f992291fffff: 1 colonnine, 70.6 kWh coperti su 70.6 kWh (Domanda agg: 70.6 kWh)
# H3 881f992233fffff: 1 colonnine, 67.0 kWh coperti su 67.0 kWh (Domanda agg: 67.0 kWh)
# H3 881f993537fffff: 1 colonnine, 31.5 kWh coperti su 31.5 kWh (Domanda agg: 31.5 kWh)
# H3 881f993531fffff: 1 colonnine, 84.1 kWh coperti su 84.1 kWh (Domanda agg: 84.1 kWh)
# H3 881f9922c9fffff: 1 colonnine, 85.3 kWh coperti su 85.3 kWh (Domanda agg: 85.3 kWh)
# H3 881f992741fffff: 1 colonnine, 67.4 kWh coperti su 67.4 kWh (Domanda agg: 67.4 kWh)
# H3 881f993511fffff: 1 colonnine, 78.1 kWh coperti su 78.1 kWh (Domanda agg: 78.1 kWh)
# H3 881f99270dfffff: 1 colonnine, 78.5 kWh coperti su 78.5 kWh (Domanda agg: 78.5 kWh)
# H3 881f992287fffff: 1 colonnine, 29.4 kWh coperti su 29.4 kWh (Domanda agg: 29.4 kWh)
# H3 881f992253fffff: 1 colonnine, 25.7 kWh coperti su 25.7 kWh (Domanda agg: 25.7 kWh)
# H3 881f992211fffff: 1 colonnine, 82.0 kWh coperti su 82.0 kWh (Domanda agg: 82.0 kWh)
# H3 881f992231fffff: 1 colonnine, 42.7 kWh coperti su 42.7 kWh (Domanda agg: 42.7 kWh)
# H3 881f9922d7fffff: 1 colonnine, 56.7 kWh coperti su 56.7 kWh (Domanda agg: 56.7 kWh)
# H3 881f9935a7fffff: 1 colonnine, 35.3 kWh coperti su 35.3 kWh (Domanda agg: 35.3 kWh)
# H3 881f99221bfffff: 1 colonnine, 56.2 kWh coperti su 56.2 kWh (Domanda agg: 56.2 kWh)
# H3 881f992239fffff: 1 colonnine, 19.7 kWh coperti su 19.7 kWh (Domanda agg: 19.7 kWh)
# H3 881f992761fffff: 1 colonnine, 70.0 kWh coperti su 70.0 kWh (Domanda agg: 70.0 kWh)
# H3 881f9935a5fffff: 1 colonnine, 65.7 kWh coperti su 65.7 kWh (Domanda agg: 65.7 kWh)
# H3 881f993557fffff: 1 colonnine, 77.3 kWh coperti su 77.3 kWh (Domanda agg: 77.3 kWh)
# H3 881f9935e1fffff: 1 colonnine, 19.0 kWh coperti su 19.0 kWh (Domanda agg: 19.0 kWh)
# H3 881f99358dfffff: 1 colonnine, 18.0 kWh coperti su 18.0 kWh (Domanda agg: 18.0 kWh)
# H3 881f9922b3fffff: 1 colonnine, 17.9 kWh coperti su 17.9 kWh (Domanda agg: 17.9 kWh)
# H3 881f9922edfffff: 1 colonnine, 51.3 kWh coperti su 51.3 kWh (Domanda agg: 51.3 kWh)
# H3 881f99223bfffff: 1 colonnine, 49.2 kWh coperti su 49.2 kWh (Domanda agg: 49.2 kWh)
# H3 881f992283fffff: 1 colonnine, 85.3 kWh coperti su 85.3 kWh (Domanda agg: 85.3 kWh)
# H3 881f993519fffff: 1 colonnine, 79.4 kWh coperti su 79.4 kWh (Domanda agg: 79.4 kWh)
# H3 881f993553fffff: 1 colonnine, 80.6 kWh coperti su 80.6 kWh (Domanda agg: 80.6 kWh)
# H3 881f993535fffff: 1 colonnine, 66.7 kWh coperti su 66.7 kWh (Domanda agg: 66.7 kWh)
# H3 881f993585fffff: 1 colonnine, 60.6 kWh coperti su 60.6 kWh (Domanda agg: 60.6 kWh)
# H3 881f993539fffff: 1 colonnine, 83.5 kWh coperti su 83.5 kWh (Domanda agg: 83.5 kWh)
# H3 881f992203fffff: 1 colonnine, 40.1 kWh coperti su 40.1 kWh (Domanda agg: 40.1 kWh)
# H3 881f9935e9fffff: 1 colonnine, 18.9 kWh coperti su 18.9 kWh (Domanda agg: 18.9 kWh)
# H3 881f992299fffff: 1 colonnine, 43.8 kWh coperti su 43.8 kWh (Domanda agg: 43.8 kWh)
# H3 881f9922d1fffff: 1 colonnine, 145.1 kWh coperti su 145.1 kWh (Domanda agg: 145.1 kWh)
# H3 881f992251fffff: 1 colonnine, 20.4 kWh coperti su 20.4 kWh (Domanda agg: 20.4 kWh)
# H3 881f993507fffff: 1 colonnine, 111.2 kWh coperti su 111.2 kWh (Domanda agg: 111.2 kWh)
# H3 881f9922a9fffff: 1 colonnine, 87.3 kWh coperti su 87.3 kWh (Domanda agg: 87.3 kWh)
# H3 881f992765fffff: 1 colonnine, 49.3 kWh coperti su 49.3 kWh (Domanda agg: 49.3 kWh)
# H3 881f99229bfffff: 1 colonnine, 95.6 kWh coperti su 95.6 kWh (Domanda agg: 95.6 kWh)
# H3 881f99276dfffff: 1 colonnine, 68.7 kWh coperti su 68.7 kWh (Domanda agg: 68.7 kWh)
# H3 881f99353dfffff: 1 colonnine, 90.5 kWh coperti su 90.5 kWh (Domanda agg: 90.5 kWh)
# H3 881f9922c7fffff: 1 colonnine, 74.4 kWh coperti su 74.4 kWh (Domanda agg: 74.4 kWh)
# H3 881f993563fffff: 1 colonnine, 43.1 kWh coperti su 43.1 kWh (Domanda agg: 43.1 kWh)
# H3 881f992293fffff: 1 colonnine, 20.2 kWh coperti su 20.2 kWh (Domanda agg: 20.2 kWh)
# H3 881f99352bfffff: 1 colonnine, 87.6 kWh coperti su 87.6 kWh (Domanda agg: 87.6 kWh)
# H3 881f9935cdfffff: 1 colonnine, 19.1 kWh coperti su 19.1 kWh (Domanda agg: 19.1 kWh)
# H3 881f993581fffff: 1 colonnine, 18.4 kWh coperti su 18.4 kWh (Domanda agg: 18.4 kWh)
# H3 881f99351bfffff: 1 colonnine, 24.3 kWh coperti su 24.3 kWh (Domanda agg: 24.3 kWh)
# H3 881f992297fffff: 1 colonnine, 50.5 kWh coperti su 50.5 kWh (Domanda agg: 50.5 kWh)
# H3 881f9922c5fffff: 1 colonnine, 134.7 kWh coperti su 134.7 kWh (Domanda agg: 134.7 kWh)
# H3 881f992769fffff: 1 colonnine, 61.7 kWh coperti su 61.7 kWh (Domanda agg: 61.7 kWh)
# H3 881f993425fffff: 1 colonnine, 56.7 kWh coperti su 56.7 kWh (Domanda agg: 56.7 kWh)
# H3 881f9935adfffff: 1 colonnine, 22.5 kWh coperti su 22.5 kWh (Domanda agg: 22.5 kWh)
# H3 881f992219fffff: 1 colonnine, 90.0 kWh coperti su 90.0 kWh (Domanda agg: 90.0 kWh)
# H3 881f99274dfffff: 1 colonnine, 86.5 kWh coperti su 86.5 kWh (Domanda agg: 86.5 kWh)
# H3 881f9922c1fffff: 1 colonnine, 118.2 kWh coperti su 118.2 kWh (Domanda agg: 118.2 kWh)
# H3 881f993427fffff: 1 colonnine, 27.8 kWh coperti su 27.8 kWh (Domanda agg: 27.8 kWh)
# H3 881f9922cbfffff: 1 colonnine, 86.3 kWh coperti su 86.3 kWh (Domanda agg: 86.3 kWh)
# H3 881f993503fffff: 1 colonnine, 74.0 kWh coperti su 74.0 kWh (Domanda agg: 74.0 kWh)
# H3 881f992237fffff: 1 colonnine, 72.6 kWh coperti su 72.6 kWh (Domanda agg: 72.6 kWh)
# H3 881f99205bfffff: 1 colonnine, 37.1 kWh coperti su 37.1 kWh (Domanda agg: 37.1 kWh)
# H3 881f9935a3fffff: 1 colonnine, 18.0 kWh coperti su 18.0 kWh (Domanda agg: 18.0 kWh)
# H3 881f99229dfffff: 1 colonnine, 60.8 kWh coperti su 60.8 kWh (Domanda agg: 60.8 kWh)
# H3 881f9935c5fffff: 1 colonnine, 18.8 kWh coperti su 18.8 kWh (Domanda agg: 18.8 kWh)
# H3 881f99351dfffff: 1 colonnine, 52.4 kWh coperti su 52.4 kWh (Domanda agg: 52.4 kWh)
# H3 881f993515fffff: 1 colonnine, 75.3 kWh coperti su 75.3 kWh (Domanda agg: 75.3 kWh)
# H3 881f992749fffff: 1 colonnine, 51.8 kWh coperti su 51.8 kWh (Domanda agg: 51.8 kWh)
# H3 881f9935e5fffff: 1 colonnine, 43.6 kWh coperti su 43.6 kWh (Domanda agg: 43.6 kWh)
# H3 881f9935ebfffff: 1 colonnine, 17.9 kWh coperti su 17.9 kWh (Domanda agg: 17.9 kWh)
# H3 881f99352dfffff: 1 colonnine, 61.4 kWh coperti su 61.4 kWh (Domanda agg: 61.4 kWh)
# H3 881f99228dfffff: 1 colonnine, 109.6 kWh coperti su 109.6 kWh (Domanda agg: 109.6 kWh)
# H3 881f9935e3fffff: 1 colonnine, 18.2 kWh coperti su 18.2 kWh (Domanda agg: 18.2 kWh)
# H3 881f993513fffff: 1 colonnine, 23.7 kWh coperti su 23.7 kWh (Domanda agg: 23.7 kWh)
# H3 881f993567fffff: 1 colonnine, 18.7 kWh coperti su 18.7 kWh (Domanda agg: 18.7 kWh)
# H3 881f9922adfffff: 1 colonnine, 33.7 kWh coperti su 33.7 kWh (Domanda agg: 33.7 kWh)
# H3 881f9935e7fffff: 1 colonnine, 84.6 kWh coperti su 84.6 kWh (Domanda agg: 84.6 kWh)
# H3 881f992747fffff: 1 colonnine, 18.5 kWh coperti su 18.5 kWh (Domanda agg: 18.5 kWh)
# H3 881f99276bfffff: 1 colonnine, 51.8 kWh coperti su 51.8 kWh (Domanda agg: 51.8 kWh)
# H3 881f993527fffff: 1 colonnine, 22.9 kWh coperti su 22.9 kWh (Domanda agg: 22.9 kWh)
# H3 881f993529fffff: 1 colonnine, 43.3 kWh coperti su 43.3 kWh (Domanda agg: 43.3 kWh)
# H3 881f992289fffff: 1 colonnine, 83.9 kWh coperti su 83.9 kWh (Domanda agg: 83.9 kWh)
# H3 881f9935edfffff: 1 colonnine, 22.5 kWh coperti su 22.5 kWh (Domanda agg: 22.5 kWh)
# H3 881f9922d9fffff: 1 colonnine, 166.2 kWh coperti su 166.2 kWh (Domanda agg: 166.2 kWh)
# H3 881f99350dfffff: 1 colonnine, 19.4 kWh coperti su 19.4 kWh (Domanda agg: 19.4 kWh)
# H3 881f992281fffff: 1 colonnine, 134.0 kWh coperti su 134.0 kWh (Domanda agg: 134.0 kWh)
# H3 881f99228bfffff: 1 colonnine, 59.4 kWh coperti su 59.4 kWh (Domanda agg: 59.4 kWh)
# H3 881f9922e1fffff: 1 colonnine, 67.5 kWh coperti su 67.5 kWh (Domanda agg: 67.5 kWh)
# H3 881f9922d5fffff: 1 colonnine, 72.1 kWh coperti su 72.1 kWh (Domanda agg: 72.1 kWh)
# H3 881f993505fffff: 1 colonnine, 65.5 kWh coperti su 65.5 kWh (Domanda agg: 65.5 kWh)
# H3 881f993517fffff: 1 colonnine, 52.0 kWh coperti su 52.0 kWh (Domanda agg: 52.0 kWh)
# H3 881f9935abfffff: 1 colonnine, 18.9 kWh coperti su 18.9 kWh (Domanda agg: 18.9 kWh)
# H3 881f9922bbfffff: 1 colonnine, 43.9 kWh coperti su 43.9 kWh (Domanda agg: 43.9 kWh)
# H3 881f9922d3fffff: 1 colonnine, 92.4 kWh coperti su 92.4 kWh (Domanda agg: 92.4 kWh)
# H3 881f993521fffff: 1 colonnine, 86.9 kWh coperti su 86.9 kWh (Domanda agg: 86.9 kWh)
# H3 881f9922ebfffff: 1 colonnine, 86.1 kWh coperti su 86.1 kWh (Domanda agg: 86.1 kWh)
# H3 881f9922e9fffff: 1 colonnine, 69.3 kWh coperti su 69.3 kWh (Domanda agg: 69.3 kWh)
# H3 881f993525fffff: 1 colonnine, 45.9 kWh coperti su 45.9 kWh (Domanda agg: 45.9 kWh)
# H3 881f9935b5fffff: 1 colonnine, 46.7 kWh coperti su 46.7 kWh (Domanda agg: 46.7 kWh)
# H3 881f9922c3fffff: 1 colonnine, 63.9 kWh coperti su 63.9 kWh (Domanda agg: 63.9 kWh)
# H3 881f9922e7fffff: 1 colonnine, 17.9 kWh coperti su 17.9 kWh (Domanda agg: 17.9 kWh)
# H3 881f9935a9fffff: 1 colonnine, 95.7 kWh coperti su 95.7 kWh (Domanda agg: 95.7 kWh)
# H3 881f99225bfffff: 1 colonnine, 59.4 kWh coperti su 59.4 kWh (Domanda agg: 59.4 kWh)
# H3 881f9922dbfffff: 1 colonnine, 22.0 kWh coperti su 22.0 kWh (Domanda agg: 22.0 kWh)
# H3 881f992059fffff: 1 colonnine, 19.0 kWh coperti su 19.0 kWh (Domanda agg: 19.0 kWh)
# H3 881f9922e5fffff: 1 colonnine, 43.5 kWh coperti su 43.5 kWh (Domanda agg: 43.5 kWh)
# H3 881f993523fffff: 1 colonnine, 58.3 kWh coperti su 58.3 kWh (Domanda agg: 58.3 kWh)
# H3 881f993533fffff: 1 colonnine, 69.8 kWh coperti su 69.8 kWh (Domanda agg: 69.8 kWh)
# H3 881f992497fffff: 1 colonnine, 10.6 kWh coperti su 10.6 kWh (Domanda agg: 10.6 kWh)
# H3 881ea45135fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea4510dfffff: 1 colonnine, 25.8 kWh coperti su 25.8 kWh (Domanda agg: 25.8 kWh)
# H3 881ea45ad1fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45addfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45149fffff: 1 colonnine, 14.5 kWh coperti su 14.5 kWh (Domanda agg: 14.5 kWh)
# H3 881ea4512dfffff: 1 colonnine, 10.6 kWh coperti su 10.6 kWh (Domanda agg: 10.6 kWh)
# H3 881ea45109fffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh (Domanda agg: 7.3 kWh)
# H3 881ea45a81fffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh (Domanda agg: 5.9 kWh)
# H3 881ea451e7fffff: 1 colonnine, 30.8 kWh coperti su 30.8 kWh (Domanda agg: 30.8 kWh)
# H3 881ea45161fffff: 1 colonnine, 22.0 kWh coperti su 22.0 kWh (Domanda agg: 22.0 kWh)
# H3 881ea45a83fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea451e3fffff: 1 colonnine, 13.1 kWh coperti su 13.1 kWh (Domanda agg: 13.1 kWh)
# H3 881ea45acbfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45a89fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea451e1fffff: 1 colonnine, 18.4 kWh coperti su 18.4 kWh (Domanda agg: 18.4 kWh)
# H3 881ea45025fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea45107fffff: 1 colonnine, 9.8 kWh coperti su 9.8 kWh (Domanda agg: 9.8 kWh)
# H3 881ea45ad7fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45ac3fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea451edfffff: 1 colonnine, 13.3 kWh coperti su 13.3 kWh (Domanda agg: 13.3 kWh)
# H3 881ea45133fffff: 1 colonnine, 14.5 kWh coperti su 14.5 kWh (Domanda agg: 14.5 kWh)
# H3 881ea45a99fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea4511dfffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea4513dfffff: 1 colonnine, 13.7 kWh coperti su 13.7 kWh (Domanda agg: 13.7 kWh)
# H3 881ea45103fffff: 1 colonnine, 24.0 kWh coperti su 24.0 kWh (Domanda agg: 24.0 kWh)
# H3 881ea451a1fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea45147fffff: 1 colonnine, 20.5 kWh coperti su 20.5 kWh (Domanda agg: 20.5 kWh)
# H3 881ea45067fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea45143fffff: 1 colonnine, 10.1 kWh coperti su 10.1 kWh (Domanda agg: 10.1 kWh)
# H3 881ea45ac9fffff: 1 colonnine, 12.6 kWh coperti su 12.6 kWh (Domanda agg: 12.6 kWh)
# H3 881ea45ab9fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea4514bfffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh (Domanda agg: 11.3 kWh)
# H3 881ea45061fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea4513bfffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881ea45a87fffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh (Domanda agg: 7.6 kWh)
# H3 881ea45ad9fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea45117fffff: 1 colonnine, 21.6 kWh coperti su 21.6 kWh (Domanda agg: 21.6 kWh)
# H3 881ea451abfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45119fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea451e5fffff: 1 colonnine, 14.8 kWh coperti su 14.8 kWh (Domanda agg: 14.8 kWh)
# H3 881ea45065fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea45129fffff: 1 colonnine, 19.1 kWh coperti su 19.1 kWh (Domanda agg: 19.1 kWh)
# H3 881ea451adfffff: 1 colonnine, 13.5 kWh coperti su 13.5 kWh (Domanda agg: 13.5 kWh)
# H3 881ea45115fffff: 1 colonnine, 21.6 kWh coperti su 21.6 kWh (Domanda agg: 21.6 kWh)
# H3 881ea45ad3fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45a8bfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45169fffff: 1 colonnine, 14.0 kWh coperti su 14.0 kWh (Domanda agg: 14.0 kWh)
# H3 881ea451e9fffff: 1 colonnine, 10.8 kWh coperti su 10.8 kWh (Domanda agg: 10.8 kWh)
# H3 881ea45337fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea4512bfffff: 1 colonnine, 18.7 kWh coperti su 18.7 kWh (Domanda agg: 18.7 kWh)
# H3 881ea4514dfffff: 1 colonnine, 13.0 kWh coperti su 13.0 kWh (Domanda agg: 13.0 kWh)
# H3 881ea45139fffff: 1 colonnine, 18.8 kWh coperti su 18.8 kWh (Domanda agg: 18.8 kWh)
# H3 881ea45adbfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881ea45145fffff: 1 colonnine, 10.9 kWh coperti su 10.9 kWh (Domanda agg: 10.9 kWh)
# H3 881ea45105fffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh (Domanda agg: 5.7 kWh)
# H3 881ea451a5fffff: 1 colonnine, 12.5 kWh coperti su 12.5 kWh (Domanda agg: 12.5 kWh)
# H3 881ea45141fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881ea45167fffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh (Domanda agg: 13.8 kWh)
# H3 881ea45ac1fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881ea45163fffff: 1 colonnine, 19.6 kWh coperti su 19.6 kWh (Domanda agg: 19.6 kWh)
# H3 881ea45113fffff: 1 colonnine, 16.1 kWh coperti su 16.1 kWh (Domanda agg: 16.1 kWh)
# H3 881ea45101fffff: 1 colonnine, 23.1 kWh coperti su 23.1 kWh (Domanda agg: 23.1 kWh)
# H3 881ea45ad5fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea451a9fffff: 1 colonnine, 11.8 kWh coperti su 11.8 kWh (Domanda agg: 11.8 kWh)
# H3 881ea45131fffff: 1 colonnine, 20.8 kWh coperti su 20.8 kWh (Domanda agg: 20.8 kWh)
# H3 881ea45123fffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh (Domanda agg: 11.1 kWh)
# H3 881ea4516bfffff: 1 colonnine, 25.5 kWh coperti su 25.5 kWh (Domanda agg: 25.5 kWh)
# H3 881ea451ebfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881ea4510bfffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea45137fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45121fffff: 1 colonnine, 9.5 kWh coperti su 9.5 kWh (Domanda agg: 9.5 kWh)
# H3 881ea45b53fffff: 1 colonnine, 7.1 kWh coperti su 7.1 kWh (Domanda agg: 7.1 kWh)
# H3 881f9925e7fffff: 1 colonnine, 9.0 kWh coperti su 9.0 kWh (Domanda agg: 9.0 kWh)
# H3 881f992e91fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f992ec5fffff: 1 colonnine, 8.8 kWh coperti su 8.8 kWh (Domanda agg: 8.8 kWh)
# H3 881f992583fffff: 1 colonnine, 8.3 kWh coperti su 8.3 kWh (Domanda agg: 8.3 kWh)
# H3 881f992515fffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh (Domanda agg: 6.7 kWh)
# H3 881f992ed3fffff: 1 colonnine, 8.8 kWh coperti su 8.8 kWh (Domanda agg: 8.8 kWh)
# H3 881f99250bfffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh (Domanda agg: 6.7 kWh)
# H3 881f992e9bfffff: 1 colonnine, 9.4 kWh coperti su 9.4 kWh (Domanda agg: 9.4 kWh)
# H3 881ea45b4dfffff: 1 colonnine, 12.3 kWh coperti su 12.3 kWh (Domanda agg: 12.3 kWh)
# H3 881f9925adfffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh (Domanda agg: 11.1 kWh)
# H3 881ea45b0dfffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881f9925edfffff: 1 colonnine, 11.2 kWh coperti su 11.2 kWh (Domanda agg: 11.2 kWh)
# H3 881ea45b0bfffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh (Domanda agg: 8.9 kWh)
# H3 881f992e8dfffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh (Domanda agg: 6.9 kWh)
# H3 881f9925a3fffff: 1 colonnine, 11.0 kWh coperti su 11.0 kWh (Domanda agg: 11.0 kWh)
# H3 881f9925abfffff: 1 colonnine, 15.1 kWh coperti su 15.1 kWh (Domanda agg: 15.1 kWh)
# H3 881f992e95fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f992587fffff: 1 colonnine, 8.8 kWh coperti su 8.8 kWh (Domanda agg: 8.8 kWh)
# H3 881f992ed5fffff: 1 colonnine, 10.2 kWh coperti su 10.2 kWh (Domanda agg: 10.2 kWh)
# H3 881f992e99fffff: 1 colonnine, 13.9 kWh coperti su 13.9 kWh (Domanda agg: 13.9 kWh)
# H3 881f9925a7fffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh (Domanda agg: 9.2 kWh)
# H3 881f9925b1fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh (Domanda agg: 7.4 kWh)
# H3 881ea45b4bfffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh (Domanda agg: 7.6 kWh)
# H3 881f992581fffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh (Domanda agg: 5.9 kWh)
# H3 881f992eddfffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh (Domanda agg: 5.7 kWh)
# H3 881f99252bfffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh (Domanda agg: 6.9 kWh)
# H3 881f9925a1fffff: 1 colonnine, 15.2 kWh coperti su 15.2 kWh (Domanda agg: 15.2 kWh)
# H3 881f992503fffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh (Domanda agg: 7.6 kWh)
# H3 881f992ec1fffff: 1 colonnine, 10.5 kWh coperti su 10.5 kWh (Domanda agg: 10.5 kWh)
# H3 881ea45b55fffff: 1 colonnine, 13.9 kWh coperti su 13.9 kWh (Domanda agg: 13.9 kWh)
# H3 881f992509fffff: 1 colonnine, 12.0 kWh coperti su 12.0 kWh (Domanda agg: 12.0 kWh)
# H3 881f992ec7fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881f992585fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881ea45b6bfffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh (Domanda agg: 6.9 kWh)
# H3 881ea45b49fffff: 1 colonnine, 9.0 kWh coperti su 9.0 kWh (Domanda agg: 9.0 kWh)
# H3 881f9925e5fffff: 1 colonnine, 19.6 kWh coperti su 19.6 kWh (Domanda agg: 19.6 kWh)
# H3 881f99253bfffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh (Domanda agg: 7.6 kWh)
# H3 881f992589fffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh (Domanda agg: 7.3 kWh)
# H3 881f9925a9fffff: 1 colonnine, 9.6 kWh coperti su 9.6 kWh (Domanda agg: 9.6 kWh)
# H3 881f992ec3fffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh (Domanda agg: 8.9 kWh)
# H3 881f992ed9fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881f992ec9fffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh (Domanda agg: 6.7 kWh)
# H3 881ea45b57fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh (Domanda agg: 7.4 kWh)
# H3 881f9925b7fffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh (Domanda agg: 7.6 kWh)
# H3 881f9925a5fffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh (Domanda agg: 11.1 kWh)
# H3 881ea45b51fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh (Domanda agg: 8.1 kWh)
# H3 881f992529fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881f992ed7fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f992523fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881ea45b43fffff: 1 colonnine, 12.4 kWh coperti su 12.4 kWh (Domanda agg: 12.4 kWh)
# H3 881ea45b59fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45b45fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881f992513fffff: 1 colonnine, 7.5 kWh coperti su 7.5 kWh (Domanda agg: 7.5 kWh)
# H3 881f9925b9fffff: 1 colonnine, 6.3 kWh coperti su 6.3 kWh (Domanda agg: 6.3 kWh)
# H3 881ea45b41fffff: 1 colonnine, 8.8 kWh coperti su 8.8 kWh (Domanda agg: 8.8 kWh)
# H3 881f9925b5fffff: 1 colonnine, 10.7 kWh coperti su 10.7 kWh (Domanda agg: 10.7 kWh)
# H3 881f992ebbfffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh (Domanda agg: 7.4 kWh)
# H3 881f992eb3fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881f992517fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881f992edbfffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881f992ed1fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f99362bfffff: 1 colonnine, 9.9 kWh coperti su 9.9 kWh (Domanda agg: 9.9 kWh)
# H3 881f993631fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f9936e9fffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh (Domanda agg: 9.2 kWh)
# H3 881f9936edfffff: 1 colonnine, 15.8 kWh coperti su 15.8 kWh (Domanda agg: 15.8 kWh)
# H3 881f9936e1fffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh (Domanda agg: 8.7 kWh)
# H3 881f993617fffff: 1 colonnine, 19.0 kWh coperti su 19.0 kWh (Domanda agg: 19.0 kWh)
# H3 881f99363dfffff: 1 colonnine, 16.3 kWh coperti su 16.3 kWh (Domanda agg: 16.3 kWh)
# H3 881f993605fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f993607fffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh (Domanda agg: 9.1 kWh)
# H3 881f993639fffff: 1 colonnine, 9.4 kWh coperti su 9.4 kWh (Domanda agg: 9.4 kWh)
# H3 881f9936e3fffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh (Domanda agg: 11.1 kWh)
# H3 881f99363bfffff: 1 colonnine, 20.3 kWh coperti su 20.3 kWh (Domanda agg: 20.3 kWh)
# H3 881f993685fffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh (Domanda agg: 8.4 kWh)
# H3 881f99069dfffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh (Domanda agg: 8.2 kWh)
# H3 881f9906b3fffff: 1 colonnine, 20.7 kWh coperti su 20.7 kWh (Domanda agg: 20.7 kWh)
# H3 881f9906a1fffff: 1 colonnine, 10.4 kWh coperti su 10.4 kWh (Domanda agg: 10.4 kWh)
# H3 881f9904cdfffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh (Domanda agg: 8.4 kWh)
# H3 881f99334dfffff: 1 colonnine, 14.1 kWh coperti su 14.1 kWh (Domanda agg: 14.1 kWh)
# H3 881f9904c3fffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh (Domanda agg: 8.4 kWh)
# H3 881f9906a3fffff: 1 colonnine, 45.5 kWh coperti su 45.5 kWh (Domanda agg: 45.5 kWh)
# H3 881f993369fffff: 1 colonnine, 35.0 kWh coperti su 35.0 kWh (Domanda agg: 35.0 kWh)
# H3 881f9904ddfffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh (Domanda agg: 8.4 kWh)
# H3 881f9906a5fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881f990695fffff: 1 colonnine, 33.5 kWh coperti su 33.5 kWh (Domanda agg: 33.5 kWh)
# H3 881f990693fffff: 1 colonnine, 34.4 kWh coperti su 34.4 kWh (Domanda agg: 34.4 kWh)
# H3 881f9906e7fffff: 1 colonnine, 13.9 kWh coperti su 13.9 kWh (Domanda agg: 13.9 kWh)
# H3 881f9906a9fffff: 1 colonnine, 31.1 kWh coperti su 31.1 kWh (Domanda agg: 31.1 kWh)
# H3 881f9904cbfffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881f990691fffff: 1 colonnine, 11.8 kWh coperti su 11.8 kWh (Domanda agg: 11.8 kWh)
# H3 881f9906a7fffff: 1 colonnine, 21.0 kWh coperti su 21.0 kWh (Domanda agg: 21.0 kWh)
# H3 881f9906b1fffff: 1 colonnine, 25.2 kWh coperti su 25.2 kWh (Domanda agg: 25.2 kWh)
# H3 881f9906adfffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh (Domanda agg: 8.1 kWh)
# H3 881f9904c1fffff: 1 colonnine, 8.3 kWh coperti su 8.3 kWh (Domanda agg: 8.3 kWh)
# H3 881f9906b9fffff: 1 colonnine, 30.9 kWh coperti su 30.9 kWh (Domanda agg: 30.9 kWh)
# H3 881f9904c7fffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh (Domanda agg: 8.4 kWh)
# H3 881f9906b7fffff: 1 colonnine, 24.1 kWh coperti su 24.1 kWh (Domanda agg: 24.1 kWh)
# H3 881f990699fffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh (Domanda agg: 8.2 kWh)
# H3 881f9904ebfffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh (Domanda agg: 8.7 kWh)
# H3 881f9906bdfffff: 1 colonnine, 53.5 kWh coperti su 53.5 kWh (Domanda agg: 53.5 kWh)
# H3 881f990685fffff: 1 colonnine, 24.0 kWh coperti su 24.0 kWh (Domanda agg: 24.0 kWh)
# H3 881f9906b5fffff: 1 colonnine, 29.0 kWh coperti su 29.0 kWh (Domanda agg: 29.0 kWh)
# H3 881f9906bbfffff: 1 colonnine, 29.6 kWh coperti su 29.6 kWh (Domanda agg: 29.6 kWh)
# H3 881f990687fffff: 1 colonnine, 40.2 kWh coperti su 40.2 kWh (Domanda agg: 40.2 kWh)
# H3 881f9906abfffff: 1 colonnine, 56.5 kWh coperti su 56.5 kWh (Domanda agg: 56.5 kWh)
# H3 881f990697fffff: 1 colonnine, 41.7 kWh coperti su 41.7 kWh (Domanda agg: 41.7 kWh)
# H3 881f9904c9fffff: 1 colonnine, 9.0 kWh coperti su 9.0 kWh (Domanda agg: 9.0 kWh)
# H3 881f99302dfffff: 1 colonnine, 13.3 kWh coperti su 13.3 kWh (Domanda agg: 13.3 kWh)
# H3 881f993157fffff: 1 colonnine, 19.3 kWh coperti su 19.3 kWh (Domanda agg: 19.3 kWh)
# H3 881f993adbfffff: 1 colonnine, 16.8 kWh coperti su 16.8 kWh (Domanda agg: 16.8 kWh)
# H3 881f99315bfffff: 1 colonnine, 23.4 kWh coperti su 23.4 kWh (Domanda agg: 23.4 kWh)
# H3 881f993133fffff: 1 colonnine, 13.3 kWh coperti su 13.3 kWh (Domanda agg: 13.3 kWh)
# H3 881f99315dfffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881f993117fffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh (Domanda agg: 9.1 kWh)
# H3 881f993135fffff: 1 colonnine, 13.0 kWh coperti su 13.0 kWh (Domanda agg: 13.0 kWh)
# H3 881f99311dfffff: 1 colonnine, 30.2 kWh coperti su 30.2 kWh (Domanda agg: 30.2 kWh)
# H3 881f993153fffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh (Domanda agg: 13.8 kWh)
# H3 881f993103fffff: 1 colonnine, 13.1 kWh coperti su 13.1 kWh (Domanda agg: 13.1 kWh)
# H3 881f993027fffff: 1 colonnine, 14.9 kWh coperti su 14.9 kWh (Domanda agg: 14.9 kWh)
# H3 881f993025fffff: 1 colonnine, 18.7 kWh coperti su 18.7 kWh (Domanda agg: 18.7 kWh)
# H3 881f993137fffff: 1 colonnine, 13.5 kWh coperti su 13.5 kWh (Domanda agg: 13.5 kWh)
# H3 881f993113fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881f993159fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f993139fffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh (Domanda agg: 11.1 kWh)
# H3 881f993107fffff: 1 colonnine, 10.3 kWh coperti su 10.3 kWh (Domanda agg: 10.3 kWh)
# H3 881f993111fffff: 1 colonnine, 18.1 kWh coperti su 18.1 kWh (Domanda agg: 18.1 kWh)
# H3 881f993ad9fffff: 1 colonnine, 17.5 kWh coperti su 17.5 kWh (Domanda agg: 17.5 kWh)
# H3 881f99313bfffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh (Domanda agg: 13.8 kWh)
# H3 881f99310bfffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh (Domanda agg: 13.8 kWh)
# H3 881f993155fffff: 1 colonnine, 25.3 kWh coperti su 25.3 kWh (Domanda agg: 25.3 kWh)
# H3 881f9931edfffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881f99313dfffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh (Domanda agg: 13.8 kWh)
# H3 881f993151fffff: 1 colonnine, 18.6 kWh coperti su 18.6 kWh (Domanda agg: 18.6 kWh)
# H3 881f993119fffff: 1 colonnine, 14.5 kWh coperti su 14.5 kWh (Domanda agg: 14.5 kWh)
# H3 881f993a6bfffff: 1 colonnine, 17.5 kWh coperti su 17.5 kWh (Domanda agg: 17.5 kWh)
# H3 881f993a09fffff: 1 colonnine, 13.6 kWh coperti su 13.6 kWh (Domanda agg: 13.6 kWh)
# H3 881f993165fffff: 1 colonnine, 14.6 kWh coperti su 14.6 kWh (Domanda agg: 14.6 kWh)
# H3 881f993a4bfffff: 1 colonnine, 21.7 kWh coperti su 21.7 kWh (Domanda agg: 21.7 kWh)
# H3 881f990483fffff: 1 colonnine, 12.1 kWh coperti su 12.1 kWh (Domanda agg: 12.1 kWh)
# H3 881f993a5dfffff: 1 colonnine, 20.1 kWh coperti su 20.1 kWh (Domanda agg: 20.1 kWh)
# H3 881f993169fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f993a57fffff: 1 colonnine, 10.6 kWh coperti su 10.6 kWh (Domanda agg: 10.6 kWh)
# H3 881f993a51fffff: 1 colonnine, 21.9 kWh coperti su 21.9 kWh (Domanda agg: 21.9 kWh)
# H3 881f9904e3fffff: 1 colonnine, 13.9 kWh coperti su 13.9 kWh (Domanda agg: 13.9 kWh)
# H3 881f9904b7fffff: 1 colonnine, 30.3 kWh coperti su 30.3 kWh (Domanda agg: 30.3 kWh)
# H3 881f993a53fffff: 1 colonnine, 14.9 kWh coperti su 14.9 kWh (Domanda agg: 14.9 kWh)
# H3 881f9904b5fffff: 1 colonnine, 15.8 kWh coperti su 15.8 kWh (Domanda agg: 15.8 kWh)
# H3 881f990487fffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh (Domanda agg: 6.6 kWh)
# H3 881f993a55fffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh (Domanda agg: 8.6 kWh)
# H3 881f993a01fffff: 1 colonnine, 19.3 kWh coperti su 19.3 kWh (Domanda agg: 19.3 kWh)
# H3 881f993a5bfffff: 1 colonnine, 13.2 kWh coperti su 13.2 kWh (Domanda agg: 13.2 kWh)
# H3 881f993125fffff: 1 colonnine, 11.8 kWh coperti su 11.8 kWh (Domanda agg: 11.8 kWh)
# H3 881f990495fffff: 1 colonnine, 14.7 kWh coperti su 14.7 kWh (Domanda agg: 14.7 kWh)
# H3 881f993a43fffff: 1 colonnine, 12.7 kWh coperti su 12.7 kWh (Domanda agg: 12.7 kWh)
# H3 881f9904abfffff: 1 colonnine, 9.9 kWh coperti su 9.9 kWh (Domanda agg: 9.9 kWh)
# H3 881f993a0bfffff: 1 colonnine, 13.6 kWh coperti su 13.6 kWh (Domanda agg: 13.6 kWh)
# H3 881f993a0dfffff: 1 colonnine, 15.1 kWh coperti su 15.1 kWh (Domanda agg: 15.1 kWh)
# H3 881f993a49fffff: 1 colonnine, 16.0 kWh coperti su 16.0 kWh (Domanda agg: 16.0 kWh)
# H3 881f993a4dfffff: 1 colonnine, 14.4 kWh coperti su 14.4 kWh (Domanda agg: 14.4 kWh)
# H3 881f993a59fffff: 1 colonnine, 15.7 kWh coperti su 15.7 kWh (Domanda agg: 15.7 kWh)
# H3 881f99316dfffff: 1 colonnine, 18.7 kWh coperti su 18.7 kWh (Domanda agg: 18.7 kWh)
# H3 881f990497fffff: 1 colonnine, 14.2 kWh coperti su 14.2 kWh (Domanda agg: 14.2 kWh)
# H3 881f993161fffff: 1 colonnine, 9.8 kWh coperti su 9.8 kWh (Domanda agg: 9.8 kWh)
# H3 881f9904bbfffff: 1 colonnine, 16.1 kWh coperti su 16.1 kWh (Domanda agg: 16.1 kWh)
# H3 881f993a69fffff: 1 colonnine, 13.7 kWh coperti su 13.7 kWh (Domanda agg: 13.7 kWh)
# H3 881f9904b1fffff: 1 colonnine, 14.0 kWh coperti su 14.0 kWh (Domanda agg: 14.0 kWh)
# H3 881f9904bdfffff: 1 colonnine, 18.5 kWh coperti su 18.5 kWh (Domanda agg: 18.5 kWh)
# H3 881f990485fffff: 1 colonnine, 13.1 kWh coperti su 13.1 kWh (Domanda agg: 13.1 kWh)
# H3 881f9904b3fffff: 1 colonnine, 30.2 kWh coperti su 30.2 kWh (Domanda agg: 30.2 kWh)
# H3 881f9904b9fffff: 1 colonnine, 17.6 kWh coperti su 17.6 kWh (Domanda agg: 17.6 kWh)
# H3 881f993a47fffff: 1 colonnine, 12.0 kWh coperti su 12.0 kWh (Domanda agg: 12.0 kWh)
# H3 881f992565fffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh (Domanda agg: 6.7 kWh)
# H3 881f992c09fffff: 1 colonnine, 7.9 kWh coperti su 7.9 kWh (Domanda agg: 7.9 kWh)
# H3 881f992e09fffff: 1 colonnine, 7.1 kWh coperti su 7.1 kWh (Domanda agg: 7.1 kWh)
# H3 881f992081fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881f992e5dfffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881f9920b5fffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh (Domanda agg: 8.0 kWh)
# H3 881f992e41fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881f992c55fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881f992087fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881f992e4dfffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881f992e4bfffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh (Domanda agg: 8.9 kWh)
# H3 881f992e15fffff: 1 colonnine, 11.7 kWh coperti su 11.7 kWh (Domanda agg: 11.7 kWh)
# H3 881f992e47fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f992e29fffff: 1 colonnine, 9.0 kWh coperti su 9.0 kWh (Domanda agg: 9.0 kWh)
# H3 881f992e51fffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh (Domanda agg: 8.9 kWh)
# H3 881f99256dfffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f992e01fffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh (Domanda agg: 11.3 kWh)
# H3 881f992e03fffff: 1 colonnine, 15.9 kWh coperti su 15.9 kWh (Domanda agg: 15.9 kWh)
# H3 881f992e13fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh (Domanda agg: 7.4 kWh)
# H3 881f992e07fffff: 1 colonnine, 7.9 kWh coperti su 7.9 kWh (Domanda agg: 7.9 kWh)
# H3 881f992e0bfffff: 1 colonnine, 15.8 kWh coperti su 15.8 kWh (Domanda agg: 15.8 kWh)
# H3 881f992e5bfffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881f992e63fffff: 1 colonnine, 9.5 kWh coperti su 9.5 kWh (Domanda agg: 9.5 kWh)
# H3 881f992e43fffff: 1 colonnine, 12.1 kWh coperti su 12.1 kWh (Domanda agg: 12.1 kWh)
# H3 881f992e39fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f992e2bfffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881f9920b7fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh (Domanda agg: 6.4 kWh)
# H3 881f992e55fffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh (Domanda agg: 8.7 kWh)
# H3 881f992e0dfffff: 1 colonnine, 9.7 kWh coperti su 9.7 kWh (Domanda agg: 9.7 kWh)
# H3 881f9920bdfffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh (Domanda agg: 6.7 kWh)
# H3 881ea45acdfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f9924ebfffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh (Domanda agg: 5.9 kWh)
# H3 881f9924e3fffff: 1 colonnine, 9.0 kWh coperti su 9.0 kWh (Domanda agg: 9.0 kWh)
# H3 881ea45a1dfffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh (Domanda agg: 7.3 kWh)
# H3 881f9924b9fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881ea45a15fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881ea45a59fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f992481fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh (Domanda agg: 8.1 kWh)
# H3 881f9924b5fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881f992483fffff: 1 colonnine, 11.0 kWh coperti su 11.0 kWh (Domanda agg: 11.0 kWh)
# H3 881f992487fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f9924d9fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f992495fffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh (Domanda agg: 8.7 kWh)
# H3 881ea45a85fffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh (Domanda agg: 5.7 kWh)
# H3 881f9924bdfffff: 1 colonnine, 10.0 kWh coperti su 10.0 kWh (Domanda agg: 10.0 kWh)
# H3 881ea4516dfffff: 1 colonnine, 12.3 kWh coperti su 12.3 kWh (Domanda agg: 12.3 kWh)
# H3 881f9924bbfffff: 1 colonnine, 10.8 kWh coperti su 10.8 kWh (Domanda agg: 10.8 kWh)
# H3 881f9924b1fffff: 1 colonnine, 15.8 kWh coperti su 15.8 kWh (Domanda agg: 15.8 kWh)
# H3 881f992485fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh (Domanda agg: 8.1 kWh)
# H3 881ea45a19fffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh (Domanda agg: 9.1 kWh)
# H3 881ea45a53fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881f99259bfffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh (Domanda agg: 5.9 kWh)
# H3 881f9926b7fffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh (Domanda agg: 8.6 kWh)
# H3 881ea45a13fffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh (Domanda agg: 6.9 kWh)
# H3 881ea45aabfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f9930b3fffff: 1 colonnine, 17.6 kWh coperti su 17.6 kWh (Domanda agg: 17.6 kWh)
# H3 881f993725fffff: 1 colonnine, 19.5 kWh coperti su 19.5 kWh (Domanda agg: 19.5 kWh)
# H3 881f9930d7fffff: 1 colonnine, 7.7 kWh coperti su 7.7 kWh (Domanda agg: 7.7 kWh)
# H3 881f9930b7fffff: 1 colonnine, 44.9 kWh coperti su 44.9 kWh (Domanda agg: 44.9 kWh)
# H3 881f993767fffff: 1 colonnine, 17.0 kWh coperti su 17.0 kWh (Domanda agg: 17.0 kWh)
# H3 881f993721fffff: 1 colonnine, 21.7 kWh coperti su 21.7 kWh (Domanda agg: 21.7 kWh)
# H3 881f993091fffff: 1 colonnine, 28.8 kWh coperti su 28.8 kWh (Domanda agg: 28.8 kWh)
# H3 881f99309dfffff: 1 colonnine, 13.6 kWh coperti su 13.6 kWh (Domanda agg: 13.6 kWh)
# H3 881f993083fffff: 1 colonnine, 23.0 kWh coperti su 23.0 kWh (Domanda agg: 23.0 kWh)
# H3 881f9930d9fffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh (Domanda agg: 7.6 kWh)
# H3 881f99308bfffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f99309bfffff: 1 colonnine, 25.4 kWh coperti su 25.4 kWh (Domanda agg: 25.4 kWh)
# H3 881f993097fffff: 1 colonnine, 19.4 kWh coperti su 19.4 kWh (Domanda agg: 19.4 kWh)
# H3 881f99376bfffff: 1 colonnine, 24.3 kWh coperti su 24.3 kWh (Domanda agg: 24.3 kWh)
# H3 881f9930d1fffff: 1 colonnine, 27.0 kWh coperti su 27.0 kWh (Domanda agg: 27.0 kWh)
# H3 881f9930bbfffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh (Domanda agg: 7.3 kWh)
# H3 881f993765fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f9930b9fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f99370dfffff: 1 colonnine, 7.5 kWh coperti su 7.5 kWh (Domanda agg: 7.5 kWh)
# H3 881f9930d3fffff: 1 colonnine, 22.6 kWh coperti su 22.6 kWh (Domanda agg: 22.6 kWh)
# H3 881f993761fffff: 1 colonnine, 31.6 kWh coperti su 31.6 kWh (Domanda agg: 31.6 kWh)
# H3 881f9930b1fffff: 1 colonnine, 23.0 kWh coperti su 23.0 kWh (Domanda agg: 23.0 kWh)
# H3 881f99372dfffff: 1 colonnine, 35.2 kWh coperti su 35.2 kWh (Domanda agg: 35.2 kWh)
# H3 881f993727fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881f993769fffff: 1 colonnine, 26.1 kWh coperti su 26.1 kWh (Domanda agg: 26.1 kWh)
# H3 881f993763fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh (Domanda agg: 7.4 kWh)
# H3 881f993729fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f993095fffff: 1 colonnine, 16.9 kWh coperti su 16.9 kWh (Domanda agg: 16.9 kWh)
# H3 881f9930dbfffff: 1 colonnine, 16.7 kWh coperti su 16.7 kWh (Domanda agg: 16.7 kWh)
# H3 881f992259fffff: 1 colonnine, 38.8 kWh coperti su 38.8 kWh (Domanda agg: 38.8 kWh)
# H3 881f993099fffff: 1 colonnine, 22.3 kWh coperti su 22.3 kWh (Domanda agg: 22.3 kWh)
# H3 881f99356dfffff: 1 colonnine, 16.0 kWh coperti su 16.0 kWh (Domanda agg: 16.0 kWh)
# H3 881f99373bfffff: 1 colonnine, 33.9 kWh coperti su 33.9 kWh (Domanda agg: 33.9 kWh)
# H3 881f993627fffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh (Domanda agg: 5.7 kWh)
# H3 881f993707fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f993445fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f993717fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f993723fffff: 1 colonnine, 18.2 kWh coperti su 18.2 kWh (Domanda agg: 18.2 kWh)
# H3 881f99346bfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f993711fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f99346dfffff: 1 colonnine, 25.2 kWh coperti su 25.2 kWh (Domanda agg: 25.2 kWh)
# H3 881f99373dfffff: 1 colonnine, 23.8 kWh coperti su 23.8 kWh (Domanda agg: 23.8 kWh)
# H3 881f993703fffff: 1 colonnine, 25.8 kWh coperti su 25.8 kWh (Domanda agg: 25.8 kWh)
# H3 881f993713fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f993465fffff: 1 colonnine, 27.6 kWh coperti su 27.6 kWh (Domanda agg: 27.6 kWh)
# H3 881f993739fffff: 1 colonnine, 25.1 kWh coperti su 25.1 kWh (Domanda agg: 25.1 kWh)
# H3 881f993733fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881f993735fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f993731fffff: 1 colonnine, 15.4 kWh coperti su 15.4 kWh (Domanda agg: 15.4 kWh)
# H3 881f993705fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f993715fffff: 1 colonnine, 17.4 kWh coperti su 17.4 kWh (Domanda agg: 17.4 kWh)
# H3 881f993461fffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh (Domanda agg: 6.9 kWh)
# H3 881f993441fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f99355bfffff: 1 colonnine, 17.2 kWh coperti su 17.2 kWh (Domanda agg: 17.2 kWh)
# H3 881f993469fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f99371bfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f993447fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f99372bfffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh (Domanda agg: 5.7 kWh)
# H3 881f99344dfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f99a449fffff: 1 colonnine, 9.7 kWh coperti su 9.7 kWh (Domanda agg: 9.7 kWh)
# H3 881f99a707fffff: 1 colonnine, 13.1 kWh coperti su 13.1 kWh (Domanda agg: 13.1 kWh)
# H3 881f99a625fffff: 1 colonnine, 14.9 kWh coperti su 14.9 kWh (Domanda agg: 14.9 kWh)
# H3 881f99a715fffff: 1 colonnine, 18.3 kWh coperti su 18.3 kWh (Domanda agg: 18.3 kWh)
# H3 881f99a713fffff: 1 colonnine, 7.5 kWh coperti su 7.5 kWh (Domanda agg: 7.5 kWh)
# H3 881f99a44dfffff: 1 colonnine, 11.7 kWh coperti su 11.7 kWh (Domanda agg: 11.7 kWh)
# H3 881f99a621fffff: 1 colonnine, 10.0 kWh coperti su 10.0 kWh (Domanda agg: 10.0 kWh)
# H3 881f99a62bfffff: 1 colonnine, 10.5 kWh coperti su 10.5 kWh (Domanda agg: 10.5 kWh)
# H3 881f99a711fffff: 1 colonnine, 20.2 kWh coperti su 20.2 kWh (Domanda agg: 20.2 kWh)
# H3 881f99a757fffff: 1 colonnine, 11.0 kWh coperti su 11.0 kWh (Domanda agg: 11.0 kWh)
# H3 881f99a719fffff: 1 colonnine, 20.8 kWh coperti su 20.8 kWh (Domanda agg: 20.8 kWh)
# H3 881f99a739fffff: 1 colonnine, 18.1 kWh coperti su 18.1 kWh (Domanda agg: 18.1 kWh)
# H3 881f99a71bfffff: 1 colonnine, 15.3 kWh coperti su 15.3 kWh (Domanda agg: 15.3 kWh)
# H3 881f99a71dfffff: 1 colonnine, 12.7 kWh coperti su 12.7 kWh (Domanda agg: 12.7 kWh)
# H3 881f99a627fffff: 1 colonnine, 9.5 kWh coperti su 9.5 kWh (Domanda agg: 9.5 kWh)
# H3 881f99a703fffff: 1 colonnine, 10.4 kWh coperti su 10.4 kWh (Domanda agg: 10.4 kWh)
# H3 881f99a73bfffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh (Domanda agg: 6.5 kWh)
# H3 881f99a717fffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh (Domanda agg: 9.2 kWh)
# H3 881f99319dfffff: 1 colonnine, 17.2 kWh coperti su 17.2 kWh (Domanda agg: 17.2 kWh)
# H3 881f993199fffff: 1 colonnine, 17.2 kWh coperti su 17.2 kWh (Domanda agg: 17.2 kWh)
# H3 881f9931d5fffff: 1 colonnine, 60.0 kWh coperti su 60.0 kWh (Domanda agg: 60.0 kWh)
# H3 881f9931d7fffff: 1 colonnine, 53.8 kWh coperti su 53.8 kWh (Domanda agg: 53.8 kWh)
# H3 881f99318bfffff: 1 colonnine, 59.4 kWh coperti su 59.4 kWh (Domanda agg: 59.4 kWh)
# H3 881f9931d3fffff: 1 colonnine, 76.2 kWh coperti su 76.2 kWh (Domanda agg: 76.2 kWh)
# H3 881f9931d1fffff: 1 colonnine, 67.1 kWh coperti su 67.1 kWh (Domanda agg: 67.1 kWh)
# H3 881f993037fffff: 1 colonnine, 18.0 kWh coperti su 18.0 kWh (Domanda agg: 18.0 kWh)
# H3 881f9931c3fffff: 1 colonnine, 35.0 kWh coperti su 35.0 kWh (Domanda agg: 35.0 kWh)
# H3 881f9930a5fffff: 1 colonnine, 46.6 kWh coperti su 46.6 kWh (Domanda agg: 46.6 kWh)
# H3 881f9931d9fffff: 1 colonnine, 51.6 kWh coperti su 51.6 kWh (Domanda agg: 51.6 kWh)
# H3 881f993189fffff: 1 colonnine, 17.2 kWh coperti su 17.2 kWh (Domanda agg: 17.2 kWh)
# H3 881f9931dbfffff: 1 colonnine, 22.3 kWh coperti su 22.3 kWh (Domanda agg: 22.3 kWh)
# H3 881f9931ddfffff: 1 colonnine, 23.5 kWh coperti su 23.5 kWh (Domanda agg: 23.5 kWh)
# H3 881f992f17fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f992e2dfffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh (Domanda agg: 7.4 kWh)
# H3 881f9921b1fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh (Domanda agg: 6.4 kWh)
# H3 881f992f35fffff: 1 colonnine, 10.0 kWh coperti su 10.0 kWh (Domanda agg: 10.0 kWh)
# H3 881f992f5bfffff: 1 colonnine, 10.2 kWh coperti su 10.2 kWh (Domanda agg: 10.2 kWh)
# H3 881f992f15fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881f992f09fffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh (Domanda agg: 13.8 kWh)
# H3 881f992d51fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh (Domanda agg: 6.5 kWh)
# H3 881f992f41fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881f992f01fffff: 1 colonnine, 7.1 kWh coperti su 7.1 kWh (Domanda agg: 7.1 kWh)
# H3 881f9921b9fffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh (Domanda agg: 6.6 kWh)
# H3 881f992f0bfffff: 1 colonnine, 14.4 kWh coperti su 14.4 kWh (Domanda agg: 14.4 kWh)
# H3 881f992c6bfffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh (Domanda agg: 6.9 kWh)
# H3 881f992f21fffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh (Domanda agg: 6.6 kWh)
# H3 881f992f69fffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh (Domanda agg: 8.4 kWh)
# H3 881f992f57fffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh (Domanda agg: 6.9 kWh)
# H3 881f992f47fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh (Domanda agg: 6.4 kWh)
# H3 881f992f03fffff: 1 colonnine, 13.3 kWh coperti su 13.3 kWh (Domanda agg: 13.3 kWh)
# H3 881f992f55fffff: 1 colonnine, 10.6 kWh coperti su 10.6 kWh (Domanda agg: 10.6 kWh)
# H3 881f992c69fffff: 1 colonnine, 7.5 kWh coperti su 7.5 kWh (Domanda agg: 7.5 kWh)
# H3 881f992f23fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881f992f39fffff: 1 colonnine, 10.2 kWh coperti su 10.2 kWh (Domanda agg: 10.2 kWh)
# H3 881f992f51fffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh (Domanda agg: 11.3 kWh)
# H3 881f9921b7fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh (Domanda agg: 6.4 kWh)
# H3 881f992c2dfffff: 1 colonnine, 7.7 kWh coperti su 7.7 kWh (Domanda agg: 7.7 kWh)
# H3 881f992d59fffff: 1 colonnine, 12.5 kWh coperti su 12.5 kWh (Domanda agg: 12.5 kWh)
# H3 881f992f43fffff: 1 colonnine, 9.7 kWh coperti su 9.7 kWh (Domanda agg: 9.7 kWh)
# H3 881f992f45fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh (Domanda agg: 8.1 kWh)
# H3 881f992d49fffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh (Domanda agg: 6.9 kWh)
# H3 881f992f5dfffff: 1 colonnine, 10.4 kWh coperti su 10.4 kWh (Domanda agg: 10.4 kWh)
# H3 881f992e61fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh (Domanda agg: 6.4 kWh)
# H3 881f992d5bfffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881f992f33fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881f99234bfffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh (Domanda agg: 8.6 kWh)
# H3 881f992349fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881f9931b1fffff: 1 colonnine, 28.9 kWh coperti su 28.9 kWh (Domanda agg: 28.9 kWh)
# H3 881f99226dfffff: 1 colonnine, 23.5 kWh coperti su 23.5 kWh (Domanda agg: 23.5 kWh)
# H3 881f9931b7fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881f993185fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881f9931b5fffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh (Domanda agg: 8.6 kWh)
# H3 881f993183fffff: 1 colonnine, 22.6 kWh coperti su 22.6 kWh (Domanda agg: 22.6 kWh)
# H3 881f993195fffff: 1 colonnine, 22.2 kWh coperti su 22.2 kWh (Domanda agg: 22.2 kWh)
# H3 881f9931bdfffff: 1 colonnine, 26.5 kWh coperti su 26.5 kWh (Domanda agg: 26.5 kWh)
# H3 881f9931a3fffff: 1 colonnine, 30.7 kWh coperti su 30.7 kWh (Domanda agg: 30.7 kWh)
# H3 881f9931b9fffff: 1 colonnine, 22.3 kWh coperti su 22.3 kWh (Domanda agg: 22.3 kWh)
# H3 881f9931abfffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh (Domanda agg: 8.6 kWh)
# H3 881f9931bbfffff: 1 colonnine, 33.2 kWh coperti su 33.2 kWh (Domanda agg: 33.2 kWh)
# H3 881f993181fffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh (Domanda agg: 8.6 kWh)
# H3 881f993187fffff: 1 colonnine, 9.7 kWh coperti su 9.7 kWh (Domanda agg: 9.7 kWh)
# H3 881f99319bfffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh (Domanda agg: 11.3 kWh)
# H3 881f9931a1fffff: 1 colonnine, 23.6 kWh coperti su 23.6 kWh (Domanda agg: 23.6 kWh)
# H3 881f993197fffff: 1 colonnine, 30.2 kWh coperti su 30.2 kWh (Domanda agg: 30.2 kWh)
# H3 881f9931b3fffff: 1 colonnine, 22.6 kWh coperti su 22.6 kWh (Domanda agg: 22.6 kWh)
# ...
# H3 881f993859fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f99385bfffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh (Domanda agg: 6.6 kWh)
# H3 881f993a37fffff: 1 colonnine, 9.3 kWh coperti su 9.3 kWh (Domanda agg: 9.3 kWh)
# H3 881f992d95fffff: 1 colonnine, 11.9 kWh coperti su 11.9 kWh (Domanda agg: 11.9 kWh)
# H3 881f992ddbfffff: 1 colonnine, 8.3 kWh coperti su 8.3 kWh (Domanda agg: 8.3 kWh)
# H3 881f992dd1fffff: 1 colonnine, 17.1 kWh coperti su 17.1 kWh (Domanda agg: 17.1 kWh)
# H3 881f992dd5fffff: 1 colonnine, 14.1 kWh coperti su 14.1 kWh (Domanda agg: 14.1 kWh)
# H3 881f992dd9fffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh (Domanda agg: 8.0 kWh)
# H3 881f992dddfffff: 1 colonnine, 8.8 kWh coperti su 8.8 kWh (Domanda agg: 8.8 kWh)
# H3 881f992dd3fffff: 1 colonnine, 10.7 kWh coperti su 10.7 kWh (Domanda agg: 10.7 kWh)
# H3 881f992dc3fffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh (Domanda agg: 7.6 kWh)
# H3 881f992d9dfffff: 1 colonnine, 7.7 kWh coperti su 7.7 kWh (Domanda agg: 7.7 kWh)
# H3 881f992d83fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f992dd7fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881ea4cb59fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh (Domanda agg: 8.1 kWh)
# H3 881ea4cb19fffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh (Domanda agg: 6.7 kWh)
# H3 881ea4cb57fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881ea4cb1bfffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881ea4cb51fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881ea4cb53fffff: 1 colonnine, 7.9 kWh coperti su 7.9 kWh (Domanda agg: 7.9 kWh)
# H3 881f992615fffff: 1 colonnine, 12.1 kWh coperti su 12.1 kWh (Domanda agg: 12.1 kWh)
# H3 881f992611fffff: 1 colonnine, 21.0 kWh coperti su 21.0 kWh (Domanda agg: 21.0 kWh)
# H3 881f992609fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881f992657fffff: 1 colonnine, 28.8 kWh coperti su 28.8 kWh (Domanda agg: 28.8 kWh)
# H3 881f992619fffff: 1 colonnine, 22.7 kWh coperti su 22.7 kWh (Domanda agg: 22.7 kWh)
# H3 881f99260bfffff: 1 colonnine, 6.3 kWh coperti su 6.3 kWh (Domanda agg: 6.3 kWh)
# H3 881f992633fffff: 1 colonnine, 17.1 kWh coperti su 17.1 kWh (Domanda agg: 17.1 kWh)
# H3 881f9926edfffff: 1 colonnine, 23.7 kWh coperti su 23.7 kWh (Domanda agg: 23.7 kWh)
# H3 881f99263bfffff: 1 colonnine, 18.2 kWh coperti su 18.2 kWh (Domanda agg: 18.2 kWh)
# H3 881f992617fffff: 1 colonnine, 10.3 kWh coperti su 10.3 kWh (Domanda agg: 10.3 kWh)
# H3 881f99261dfffff: 1 colonnine, 17.1 kWh coperti su 17.1 kWh (Domanda agg: 17.1 kWh)
# H3 881f992863fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881f992369fffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh (Domanda agg: 9.2 kWh)
# H3 881f99236bfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f99059bfffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh (Domanda agg: 6.5 kWh)
# H3 881f9905d3fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f990599fffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh (Domanda agg: 5.9 kWh)
# H3 881f990597fffff: 1 colonnine, 12.9 kWh coperti su 12.9 kWh (Domanda agg: 12.9 kWh)
# H3 881f990591fffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh (Domanda agg: 11.3 kWh)
# H3 881f9905dbfffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f9938e1fffff: 1 colonnine, 9.3 kWh coperti su 9.3 kWh (Domanda agg: 9.3 kWh)
# H3 881f9939d3fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f9926d5fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881f9926b9fffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh (Domanda agg: 8.2 kWh)
# H3 881f992683fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f9926c3fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh (Domanda agg: 8.1 kWh)
# H3 881f992681fffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh (Domanda agg: 8.0 kWh)
# H3 881f9926bbfffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881f992689fffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh (Domanda agg: 6.6 kWh)
# H3 881f9930e9fffff: 1 colonnine, 32.2 kWh coperti su 32.2 kWh (Domanda agg: 32.2 kWh)
# H3 881f9930ebfffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh (Domanda agg: 8.0 kWh)
# H3 881f993011fffff: 1 colonnine, 9.8 kWh coperti su 9.8 kWh (Domanda agg: 9.8 kWh)
# H3 881f9930e1fffff: 1 colonnine, 20.7 kWh coperti su 20.7 kWh (Domanda agg: 20.7 kWh)
# H3 881f993017fffff: 1 colonnine, 40.9 kWh coperti su 40.9 kWh (Domanda agg: 40.9 kWh)
# H3 881f9930c5fffff: 1 colonnine, 66.6 kWh coperti su 66.6 kWh (Domanda agg: 66.6 kWh)
# H3 881f9930edfffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh (Domanda agg: 8.0 kWh)
# H3 881f993013fffff: 1 colonnine, 24.4 kWh coperti su 24.4 kWh (Domanda agg: 24.4 kWh)
# H3 881f99a549fffff: 1 colonnine, 6.8 kWh coperti su 6.8 kWh (Domanda agg: 6.8 kWh)
# H3 881f99a511fffff: 1 colonnine, 9.6 kWh coperti su 9.6 kWh (Domanda agg: 9.6 kWh)
# H3 881f99a5cdfffff: 1 colonnine, 12.5 kWh coperti su 12.5 kWh (Domanda agg: 12.5 kWh)
# H3 881f99a5c9fffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh (Domanda agg: 6.6 kWh)
# H3 881f99a51bfffff: 1 colonnine, 13.6 kWh coperti su 13.6 kWh (Domanda agg: 13.6 kWh)
# H3 881f99a51dfffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f99214bfffff: 1 colonnine, 14.6 kWh coperti su 14.6 kWh (Domanda agg: 14.6 kWh)
# H3 881f992149fffff: 1 colonnine, 16.4 kWh coperti su 16.4 kWh (Domanda agg: 16.4 kWh)
# H3 881f99233dfffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh (Domanda agg: 9.2 kWh)
# H3 881f992323fffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh (Domanda agg: 8.9 kWh)
# H3 881f992335fffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh (Domanda agg: 6.7 kWh)
# H3 881f992321fffff: 1 colonnine, 9.7 kWh coperti su 9.7 kWh (Domanda agg: 9.7 kWh)
# H3 881f992143fffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh (Domanda agg: 8.2 kWh)
# H3 881f99214dfffff: 1 colonnine, 14.3 kWh coperti su 14.3 kWh (Domanda agg: 14.3 kWh)
# H3 881f992331fffff: 1 colonnine, 9.5 kWh coperti su 9.5 kWh (Domanda agg: 9.5 kWh)
# H3 881f992327fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881f992329fffff: 1 colonnine, 9.8 kWh coperti su 9.8 kWh (Domanda agg: 9.8 kWh)
# H3 881ea4c99bfffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881ea4c8a1fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea4c8a5fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881ea4c99dfffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh (Domanda agg: 9.2 kWh)
# H3 881ea4c983fffff: 1 colonnine, 10.3 kWh coperti su 10.3 kWh (Domanda agg: 10.3 kWh)
# H3 881ea4c981fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881ea4c987fffff: 1 colonnine, 10.8 kWh coperti su 10.8 kWh (Domanda agg: 10.8 kWh)
# H3 881ea4c9abfffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh (Domanda agg: 7.4 kWh)
# H3 881ea4c995fffff: 1 colonnine, 10.7 kWh coperti su 10.7 kWh (Domanda agg: 10.7 kWh)
# H3 881ea4c9ebfffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh (Domanda agg: 6.5 kWh)
# H3 881ea4c98bfffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh (Domanda agg: 7.4 kWh)
# H3 881f992333fffff: 1 colonnine, 17.7 kWh coperti su 17.7 kWh (Domanda agg: 17.7 kWh)
# H3 881f992317fffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh (Domanda agg: 8.9 kWh)
# H3 881f992337fffff: 1 colonnine, 17.0 kWh coperti su 17.0 kWh (Domanda agg: 17.0 kWh)
# H3 881f992159fffff: 1 colonnine, 15.7 kWh coperti su 15.7 kWh (Domanda agg: 15.7 kWh)
# H3 881ea6962dfffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f993295fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881f993293fffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh (Domanda agg: 7.3 kWh)
# H3 881f9932b1fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh (Domanda agg: 6.5 kWh)
# H3 881f9932bdfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f99af13fffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh (Domanda agg: 8.2 kWh)
# H3 881f9934b7fffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh (Domanda agg: 8.2 kWh)
# H3 881f99265dfffff: 1 colonnine, 7.1 kWh coperti su 7.1 kWh (Domanda agg: 7.1 kWh)
# H3 881ea692c5fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881ea692cdfffff: 1 colonnine, 7.5 kWh coperti su 7.5 kWh (Domanda agg: 7.5 kWh)
# H3 881ea6921bfffff: 1 colonnine, 9.3 kWh coperti su 9.3 kWh (Domanda agg: 9.3 kWh)
# H3 881f993a99fffff: 1 colonnine, 14.5 kWh coperti su 14.5 kWh (Domanda agg: 14.5 kWh)
# H3 881f993a9bfffff: 1 colonnine, 20.0 kWh coperti su 20.0 kWh (Domanda agg: 20.0 kWh)
# H3 881f9931adfffff: 1 colonnine, 20.0 kWh coperti su 20.0 kWh (Domanda agg: 20.0 kWh)
# H3 881f993a91fffff: 1 colonnine, 10.7 kWh coperti su 10.7 kWh (Domanda agg: 10.7 kWh)
# H3 881f993ad3fffff: 1 colonnine, 13.0 kWh coperti su 13.0 kWh (Domanda agg: 13.0 kWh)
# H3 881f993a9dfffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f9931a5fffff: 1 colonnine, 18.5 kWh coperti su 18.5 kWh (Domanda agg: 18.5 kWh)
# H3 881ea4c9a3fffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh (Domanda agg: 11.1 kWh)
# H3 881ea45349fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881ea4c9a7fffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh (Domanda agg: 6.7 kWh)
# H3 881ea4c9b5fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh (Domanda agg: 6.5 kWh)
# H3 881ea4c9e7fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f9926dbfffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh (Domanda agg: 6.4 kWh)
# H3 881ea4c9a5fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881ea4c9e5fffff: 1 colonnine, 6.3 kWh coperti su 6.3 kWh (Domanda agg: 6.3 kWh)
# H3 881f9926d3fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh (Domanda agg: 8.1 kWh)
# H3 881f9926d1fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f992881fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f992d6bfffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh (Domanda agg: 8.7 kWh)
# H3 881f992d07fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh (Domanda agg: 6.4 kWh)
# H3 881f992d05fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh (Domanda agg: 6.5 kWh)
# H3 881f992d63fffff: 1 colonnine, 10.7 kWh coperti su 10.7 kWh (Domanda agg: 10.7 kWh)
# H3 881f992d41fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f8a6925fffff: 1 colonnine, 20.3 kWh coperti su 20.3 kWh (Domanda agg: 20.3 kWh)
# H3 881f99a61bfffff: 1 colonnine, 20.7 kWh coperti su 20.7 kWh (Domanda agg: 20.7 kWh)
# H3 881f8a693dfffff: 1 colonnine, 33.6 kWh coperti su 33.6 kWh (Domanda agg: 33.6 kWh)
# H3 881f8a6935fffff: 1 colonnine, 32.7 kWh coperti su 32.7 kWh (Domanda agg: 32.7 kWh)
# H3 881f8a6927fffff: 1 colonnine, 18.0 kWh coperti su 18.0 kWh (Domanda agg: 18.0 kWh)
# H3 881ea4c8c1fffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh (Domanda agg: 5.7 kWh)
# H3 881ea4c8d5fffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh (Domanda agg: 7.6 kWh)
# H3 881f99adadfffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh (Domanda agg: 9.1 kWh)
# H3 881f9932dbfffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh (Domanda agg: 8.7 kWh)
# H3 881f99ade7fffff: 1 colonnine, 7.7 kWh coperti su 7.7 kWh (Domanda agg: 7.7 kWh)
# H3 881f9932d9fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881f99ad85fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881f9939cbfffff: 1 colonnine, 11.2 kWh coperti su 11.2 kWh (Domanda agg: 11.2 kWh)
# H3 881f99398bfffff: 1 colonnine, 19.2 kWh coperti su 19.2 kWh (Domanda agg: 19.2 kWh)
# H3 881f993989fffff: 1 colonnine, 14.1 kWh coperti su 14.1 kWh (Domanda agg: 14.1 kWh)
# H3 881f9939ddfffff: 1 colonnine, 9.8 kWh coperti su 9.8 kWh (Domanda agg: 9.8 kWh)
# H3 881f993837fffff: 1 colonnine, 14.2 kWh coperti su 14.2 kWh (Domanda agg: 14.2 kWh)
# H3 881f9939d9fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881f9939c3fffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh (Domanda agg: 8.7 kWh)
# H3 881f9928ebfffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh (Domanda agg: 6.5 kWh)
# H3 881f9928e3fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f9928c7fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881f9928c5fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f9928e1fffff: 1 colonnine, 10.3 kWh coperti su 10.3 kWh (Domanda agg: 10.3 kWh)
# H3 881f992a5dfffff: 1 colonnine, 9.6 kWh coperti su 9.6 kWh (Domanda agg: 9.6 kWh)
# H3 881f9938b1fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f992a59fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f992a51fffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh (Domanda agg: 6.9 kWh)
# H3 881f9938b5fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881f992a41fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh (Domanda agg: 7.4 kWh)
# H3 881f992a4bfffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881f9938b7fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh (Domanda agg: 6.5 kWh)
# H3 881f8a6859fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881f992653fffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh (Domanda agg: 8.6 kWh)
# H3 881f99261bfffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881f9934d7fffff: 1 colonnine, 6.8 kWh coperti su 6.8 kWh (Domanda agg: 6.8 kWh)
# H3 881ea69705fffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh (Domanda agg: 7.3 kWh)
# H3 881f992ca5fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f99ad1dfffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f99ad11fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881f8a6923fffff: 1 colonnine, 10.8 kWh coperti su 10.8 kWh (Domanda agg: 10.8 kWh)
# H3 881f8a692bfffff: 1 colonnine, 12.7 kWh coperti su 12.7 kWh (Domanda agg: 12.7 kWh)
# H3 881f8a690dfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45369fffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh (Domanda agg: 11.3 kWh)
# H3 881ea4534bfffff: 1 colonnine, 13.4 kWh coperti su 13.4 kWh (Domanda agg: 13.4 kWh)
# H3 881ea45341fffff: 1 colonnine, 12.0 kWh coperti su 12.0 kWh (Domanda agg: 12.0 kWh)
# H3 881ea45345fffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh (Domanda agg: 9.2 kWh)
# H3 881ea45347fffff: 1 colonnine, 11.2 kWh coperti su 11.2 kWh (Domanda agg: 11.2 kWh)
# H3 881ea4cb67fffff: 1 colonnine, 9.6 kWh coperti su 9.6 kWh (Domanda agg: 9.6 kWh)
# H3 881ea4cb47fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881ea4cb6bfffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881ea69219fffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh (Domanda agg: 9.2 kWh)
# H3 881f9938d3fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f993695fffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh (Domanda agg: 5.9 kWh)
# H3 881ea6965bfffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh (Domanda agg: 5.7 kWh)
# H3 881f8a6a5bfffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881f993a97fffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh (Domanda agg: 5.9 kWh)
# H3 881f99236dfffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881ea4ca6dfffff: 1 colonnine, 49.8 kWh coperti su 49.8 kWh (Domanda agg: 49.8 kWh)
# H3 881ea4d9bbfffff: 1 colonnine, 77.1 kWh coperti su 77.1 kWh (Domanda agg: 77.1 kWh)
# H3 881ea4d983fffff: 1 colonnine, 33.1 kWh coperti su 33.1 kWh (Domanda agg: 33.1 kWh)
# H3 881ea4d9b1fffff: 1 colonnine, 41.9 kWh coperti su 41.9 kWh (Domanda agg: 41.9 kWh)
# H3 881ea4d995fffff: 1 colonnine, 12.8 kWh coperti su 12.8 kWh (Domanda agg: 12.8 kWh)
# H3 881ea4d9b3fffff: 1 colonnine, 55.6 kWh coperti su 55.6 kWh (Domanda agg: 55.6 kWh)
# H3 881f8a6a1bfffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh (Domanda agg: 9.1 kWh)
# H3 881f8a6ae1fffff: 1 colonnine, 12.1 kWh coperti su 12.1 kWh (Domanda agg: 12.1 kWh)
# H3 881f99ada5fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
#
# Domanda totale coperta: 28010.36 kWh

# %% [markdown]
# ### Map visualisation

# %%
mappa = crea_mappa_colonnine_discrete(gdf_risultati, colonna_colonnine="Colonnine allocate")
mappa
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Save the map as an HTML file
mappa.save("/content/drive/Shareddrives/OM in Business Analytics/OM in BA - Project/Codice/04 - Modello/log_heatmap_second_model_def.html")

# %% [markdown]
# ### Results

# %%
total_allocated_chargers = gdf_risultati["Colonnine allocate"].sum()
total_covered_demand = gdf_risultati["Domanda coperta (kWh)"].sum()
total_demand = gdf_risultati["Domanda Giornaliera Ponderata (kWh)"].sum()

print(f"Total allocated charging stations: {total_allocated_chargers}")
print(f"Total covered demand (kWh): {total_covered_demand:.2f}")
print(f"Total demand (kWh): {total_demand:.2f}")
# Out:
# Total allocated charging stations: 1623
# Total covered demand (kWh): 28010.36
# Total demand (kWh): 34500.45

# %% [markdown]
# ## THIRD MODEL
# ## Charging Station Allocation Model – Aggregated Neighborhood Demand with Attenuation Factor
#
# ### Objective
# Allocate *p* charging stations among the hexagons in the province of Brescia to **maximize the total covered daily electricity demand**, accounting for local demand and **contributions from neighboring hexagons** attenuated by a coefficient *α*.
#
# ---
#
# ### Decision Variables
# - $ x_h \in \mathbb{Z}_{\geq 0} $: Number of charging stations installed in hexagon *h*
# - $ y_h \in [0, D_h] $: Amount of daily electricity demand covered in hexagon *h*
#
# ---
#
# ### Parameters
# - $ D_h $: Daily electricity demand in hexagon *h*
# - $ \text{cap} = 555.43 $: Daily capacity of a single charging station (kWh/day)
# - $ p $: Maximum number of charging stations to be installed
# - $ \mathcal{N}(h) $: Set of neighboring hexagons of *h* (within k-ring 1)
# - $ \alpha \in [0, 1] $: Attenuation factor for the contribution of neighboring stations
#
# ---
#
# ### Constraints
#
# 1. **Total station limit**
#    $$
#    \sum_{h=1}^{n} x_h \leq p
#    $$
#
# 2. **Local demand cannot be exceeded**
#    $$
#    y_h \leq D_h \quad \forall h
#    $$
#
# 3. **Demand covered is limited by capacity of local and neighboring stations**
#    $$
#    y_h \leq \text{cap} \cdot \left( x_h + \alpha \cdot \sum_{j \in \mathcal{N}(h)} x_j \right) \quad \forall h
#    $$
#
# ---
#
# ### Notes
# - The model assumes **partial contribution** from neighboring hexagons, modulated by *α*, to reflect diminishing accessibility or influence.
# - The objective promotes **equitable coverage** in areas with concentrated or clustered demand.

# %% [markdown]
# ### Model function

# %%
import pulp
import pandas as pd

def ottimizza_colonnine_con_alpha(gdf_mappa, neighbours_dict= neighbors_dict, p_colonnine=30, cap=555.43, verbose=True, alpha=0.5 ):
    """
    Risolve il problema di allocazione ottimale delle colonnine considerando la domanda aggregata nel vicinato.

    Parametri:
    - gdf_mappa: GeoDataFrame con 'h3_id' e 'Domanda Giornaliera Ponderata (kWh)'
    - neighbours_dict: dizionario {h3_id: lista di vicini h3_id}
    - p_colonnine: numero totale di colonnine disponibili
    - cap: capacità giornaliera di una colonnina (kWh)
    - verbose: se True, stampa i risultati

    Ritorna:
    - GeoDataFrame con colonne aggiuntive: 'Colonnine allocate', 'Domanda coperta (kWh)', 'Domanda aggregata (kWh)'
    """

    df = gdf_mappa.copy()
    h3_list = df['h3_id'].tolist()
    h3_to_idx = {h3_id: idx for idx, h3_id in enumerate(h3_list)}

    demand = df["Domanda Giornaliera Ponderata (kWh)"].tolist()
    n = len(demand)

    # Calcola domanda aggregata (esagono + vicini)
    domanda_aggregata = []
    for h3_id in h3_list:
        idx = h3_to_idx[h3_id]
        vicini = neighbours_dict.get(h3_id, [])
        domanda_sum = demand[idx]  # domanda locale
        for vicino_id in vicini:
            if vicino_id in h3_to_idx:  # considera solo se vicino presente nel dataset
                domanda_sum += demand[h3_to_idx[vicino_id]]
        domanda_aggregata.append(domanda_sum)
    df["Domanda aggregata (kWh)"] = domanda_aggregata

    # Modello
    model = pulp.LpProblem("Colonnine_con_domanda_aggregata", pulp.LpMaximize)

    # Variabili decisionali
    x = pulp.LpVariable.dicts("Colonnine", range(n), lowBound=0, cat="Integer")  # colonnine allocate
    y = pulp.LpVariable.dicts("DomandaCoperta", range(n), lowBound=0)            # domanda coperta

    # Obiettivo: massimizzare la domanda coperta totale
    model += pulp.lpSum(y[i] for i in range(n))

    # Vincolo: massimo numero di colonnine totali
    model += pulp.lpSum(x[i] for i in range(n)) <= p_colonnine

    # Vincoli per ogni esagono
    for i in range(n):
        h3_id = h3_list[i]
        vicini = neighbours_dict.get(h3_id, [])
        vicini_idx = [h3_to_idx[v] for v in vicini if v in h3_to_idx]

        # Vincolo: massimo 10 colonnine per esagono
        model += x[i] <= 10

        # Domanda coperta deve essere <= domanda locale
        model += y[i] <= demand[i]

        # Domanda coperta deve essere <= capacità totale delle colonnine allocate su esagono + vicini
        model += y[i] <= cap * (x[i] + alpha * pulp.lpSum(x[j] for j in vicini_idx))

    # Risolvi
    model.solve()

    # Estrai risultati
    colonnine_allocate = [int(x[i].varValue) if x[i].varValue else 0 for i in range(n)]
    domanda_coperta = [y[i].varValue if y[i].varValue else 0.0 for i in range(n)]

    df["Colonnine allocate"] = colonnine_allocate
    df["Domanda coperta (kWh)"] = domanda_coperta

    if verbose:
        for i in range(n):
            if colonnine_allocate[i] > 0:
                print(f"H3 {df.iloc[i]['h3_id']}: {colonnine_allocate[i]} colonnine, "
                      f"{domanda_coperta[i]:.1f} kWh coperti su {demand[i]:.1f} kWh (Domanda agg: {domanda_aggregata[i]:.1f} kWh)")
        print(f"\nDomanda totale coperta: {pulp.value(model.objective):.2f} kWh")

    return df

# %%
gdf_risultati_alpha = ottimizza_colonnine_con_alpha(gdf, p_colonnine=1623, alpha=0.167)
# Out:
# H3 881f99274bfffff: 1 colonnine, 29.5 kWh coperti su 29.5 kWh (Domanda agg: 29.5 kWh)
# H3 881f992215fffff: 1 colonnine, 37.4 kWh coperti su 37.4 kWh (Domanda agg: 37.4 kWh)
# H3 881f992213fffff: 1 colonnine, 67.3 kWh coperti su 67.3 kWh (Domanda agg: 67.3 kWh)
# H3 881f9935c7fffff: 1 colonnine, 18.6 kWh coperti su 18.6 kWh (Domanda agg: 18.6 kWh)
# H3 881f9935a1fffff: 1 colonnine, 17.8 kWh coperti su 17.8 kWh (Domanda agg: 17.8 kWh)
# H3 881f9922ddfffff: 1 colonnine, 106.8 kWh coperti su 106.8 kWh (Domanda agg: 106.8 kWh)
# H3 881f992285fffff: 1 colonnine, 50.0 kWh coperti su 50.0 kWh (Domanda agg: 50.0 kWh)
# H3 881f9922e3fffff: 1 colonnine, 18.2 kWh coperti su 18.2 kWh (Domanda agg: 18.2 kWh)
# H3 881f992217fffff: 1 colonnine, 20.1 kWh coperti su 20.1 kWh (Domanda agg: 20.1 kWh)
# H3 881f993501fffff: 1 colonnine, 71.3 kWh coperti su 71.3 kWh (Domanda agg: 71.3 kWh)
# H3 881f99353bfffff: 1 colonnine, 108.0 kWh coperti su 108.0 kWh (Domanda agg: 108.0 kWh)
# H3 881f992295fffff: 1 colonnine, 51.4 kWh coperti su 51.4 kWh (Domanda agg: 51.4 kWh)
# H3 881f9922cdfffff: 1 colonnine, 76.6 kWh coperti su 76.6 kWh (Domanda agg: 76.6 kWh)
# H3 881f9920d9fffff: 1 colonnine, 44.7 kWh coperti su 44.7 kWh (Domanda agg: 44.7 kWh)
# H3 881f992745fffff: 1 colonnine, 46.8 kWh coperti su 46.8 kWh (Domanda agg: 46.8 kWh)
# H3 881f992291fffff: 1 colonnine, 70.6 kWh coperti su 70.6 kWh (Domanda agg: 70.6 kWh)
# H3 881f992233fffff: 1 colonnine, 67.0 kWh coperti su 67.0 kWh (Domanda agg: 67.0 kWh)
# H3 881f993537fffff: 1 colonnine, 31.5 kWh coperti su 31.5 kWh (Domanda agg: 31.5 kWh)
# H3 881f993531fffff: 1 colonnine, 84.1 kWh coperti su 84.1 kWh (Domanda agg: 84.1 kWh)
# H3 881f9922c9fffff: 1 colonnine, 85.3 kWh coperti su 85.3 kWh (Domanda agg: 85.3 kWh)
# H3 881f992741fffff: 1 colonnine, 67.4 kWh coperti su 67.4 kWh (Domanda agg: 67.4 kWh)
# H3 881f993511fffff: 1 colonnine, 78.1 kWh coperti su 78.1 kWh (Domanda agg: 78.1 kWh)
# H3 881f99270dfffff: 1 colonnine, 78.5 kWh coperti su 78.5 kWh (Domanda agg: 78.5 kWh)
# H3 881f992287fffff: 1 colonnine, 29.4 kWh coperti su 29.4 kWh (Domanda agg: 29.4 kWh)
# H3 881f992253fffff: 1 colonnine, 25.7 kWh coperti su 25.7 kWh (Domanda agg: 25.7 kWh)
# H3 881f992211fffff: 1 colonnine, 82.0 kWh coperti su 82.0 kWh (Domanda agg: 82.0 kWh)
# H3 881f992231fffff: 1 colonnine, 42.7 kWh coperti su 42.7 kWh (Domanda agg: 42.7 kWh)
# H3 881f9922d7fffff: 1 colonnine, 56.7 kWh coperti su 56.7 kWh (Domanda agg: 56.7 kWh)
# H3 881f9935a7fffff: 1 colonnine, 35.3 kWh coperti su 35.3 kWh (Domanda agg: 35.3 kWh)
# H3 881f99221bfffff: 1 colonnine, 56.2 kWh coperti su 56.2 kWh (Domanda agg: 56.2 kWh)
# H3 881f992239fffff: 1 colonnine, 19.7 kWh coperti su 19.7 kWh (Domanda agg: 19.7 kWh)
# H3 881f992761fffff: 1 colonnine, 70.0 kWh coperti su 70.0 kWh (Domanda agg: 70.0 kWh)
# H3 881f9935a5fffff: 1 colonnine, 65.7 kWh coperti su 65.7 kWh (Domanda agg: 65.7 kWh)
# H3 881f993557fffff: 1 colonnine, 77.3 kWh coperti su 77.3 kWh (Domanda agg: 77.3 kWh)
# H3 881f9935e1fffff: 1 colonnine, 19.0 kWh coperti su 19.0 kWh (Domanda agg: 19.0 kWh)
# H3 881f99358dfffff: 1 colonnine, 18.0 kWh coperti su 18.0 kWh (Domanda agg: 18.0 kWh)
# H3 881f9922b3fffff: 1 colonnine, 17.9 kWh coperti su 17.9 kWh (Domanda agg: 17.9 kWh)
# H3 881f9922edfffff: 1 colonnine, 51.3 kWh coperti su 51.3 kWh (Domanda agg: 51.3 kWh)
# H3 881f99223bfffff: 1 colonnine, 49.2 kWh coperti su 49.2 kWh (Domanda agg: 49.2 kWh)
# H3 881f992283fffff: 1 colonnine, 85.3 kWh coperti su 85.3 kWh (Domanda agg: 85.3 kWh)
# H3 881f993519fffff: 1 colonnine, 79.4 kWh coperti su 79.4 kWh (Domanda agg: 79.4 kWh)
# H3 881f993553fffff: 1 colonnine, 80.6 kWh coperti su 80.6 kWh (Domanda agg: 80.6 kWh)
# H3 881f993535fffff: 1 colonnine, 66.7 kWh coperti su 66.7 kWh (Domanda agg: 66.7 kWh)
# H3 881f993585fffff: 1 colonnine, 60.6 kWh coperti su 60.6 kWh (Domanda agg: 60.6 kWh)
# H3 881f993539fffff: 1 colonnine, 83.5 kWh coperti su 83.5 kWh (Domanda agg: 83.5 kWh)
# H3 881f992203fffff: 1 colonnine, 40.1 kWh coperti su 40.1 kWh (Domanda agg: 40.1 kWh)
# H3 881f9935e9fffff: 1 colonnine, 18.9 kWh coperti su 18.9 kWh (Domanda agg: 18.9 kWh)
# H3 881f992299fffff: 1 colonnine, 43.8 kWh coperti su 43.8 kWh (Domanda agg: 43.8 kWh)
# H3 881f9922d1fffff: 1 colonnine, 145.1 kWh coperti su 145.1 kWh (Domanda agg: 145.1 kWh)
# H3 881f992251fffff: 1 colonnine, 20.4 kWh coperti su 20.4 kWh (Domanda agg: 20.4 kWh)
# H3 881f993507fffff: 1 colonnine, 111.2 kWh coperti su 111.2 kWh (Domanda agg: 111.2 kWh)
# H3 881f9922a9fffff: 1 colonnine, 87.3 kWh coperti su 87.3 kWh (Domanda agg: 87.3 kWh)
# H3 881f992765fffff: 1 colonnine, 49.3 kWh coperti su 49.3 kWh (Domanda agg: 49.3 kWh)
# H3 881f99229bfffff: 1 colonnine, 95.6 kWh coperti su 95.6 kWh (Domanda agg: 95.6 kWh)
# H3 881f99276dfffff: 1 colonnine, 68.7 kWh coperti su 68.7 kWh (Domanda agg: 68.7 kWh)
# H3 881f99353dfffff: 1 colonnine, 90.5 kWh coperti su 90.5 kWh (Domanda agg: 90.5 kWh)
# H3 881f9922c7fffff: 1 colonnine, 74.4 kWh coperti su 74.4 kWh (Domanda agg: 74.4 kWh)
# H3 881f993563fffff: 1 colonnine, 43.1 kWh coperti su 43.1 kWh (Domanda agg: 43.1 kWh)
# H3 881f992293fffff: 1 colonnine, 20.2 kWh coperti su 20.2 kWh (Domanda agg: 20.2 kWh)
# H3 881f99352bfffff: 1 colonnine, 87.6 kWh coperti su 87.6 kWh (Domanda agg: 87.6 kWh)
# H3 881f9935cdfffff: 1 colonnine, 19.1 kWh coperti su 19.1 kWh (Domanda agg: 19.1 kWh)
# H3 881f993581fffff: 1 colonnine, 18.4 kWh coperti su 18.4 kWh (Domanda agg: 18.4 kWh)
# H3 881f99351bfffff: 1 colonnine, 24.3 kWh coperti su 24.3 kWh (Domanda agg: 24.3 kWh)
# H3 881f992297fffff: 1 colonnine, 50.5 kWh coperti su 50.5 kWh (Domanda agg: 50.5 kWh)
# H3 881f9922c5fffff: 1 colonnine, 134.7 kWh coperti su 134.7 kWh (Domanda agg: 134.7 kWh)
# H3 881f992769fffff: 1 colonnine, 61.7 kWh coperti su 61.7 kWh (Domanda agg: 61.7 kWh)
# H3 881f993425fffff: 1 colonnine, 56.7 kWh coperti su 56.7 kWh (Domanda agg: 56.7 kWh)
# H3 881f9935adfffff: 1 colonnine, 22.5 kWh coperti su 22.5 kWh (Domanda agg: 22.5 kWh)
# H3 881f992219fffff: 1 colonnine, 90.0 kWh coperti su 90.0 kWh (Domanda agg: 90.0 kWh)
# H3 881f99274dfffff: 1 colonnine, 86.5 kWh coperti su 86.5 kWh (Domanda agg: 86.5 kWh)
# H3 881f9922c1fffff: 1 colonnine, 118.2 kWh coperti su 118.2 kWh (Domanda agg: 118.2 kWh)
# H3 881f993427fffff: 1 colonnine, 27.8 kWh coperti su 27.8 kWh (Domanda agg: 27.8 kWh)
# H3 881f9922cbfffff: 1 colonnine, 86.3 kWh coperti su 86.3 kWh (Domanda agg: 86.3 kWh)
# H3 881f993503fffff: 1 colonnine, 74.0 kWh coperti su 74.0 kWh (Domanda agg: 74.0 kWh)
# H3 881f992237fffff: 1 colonnine, 72.6 kWh coperti su 72.6 kWh (Domanda agg: 72.6 kWh)
# H3 881f99205bfffff: 1 colonnine, 37.1 kWh coperti su 37.1 kWh (Domanda agg: 37.1 kWh)
# H3 881f9935a3fffff: 1 colonnine, 18.0 kWh coperti su 18.0 kWh (Domanda agg: 18.0 kWh)
# H3 881f99229dfffff: 1 colonnine, 60.8 kWh coperti su 60.8 kWh (Domanda agg: 60.8 kWh)
# H3 881f9935c5fffff: 1 colonnine, 18.8 kWh coperti su 18.8 kWh (Domanda agg: 18.8 kWh)
# H3 881f99351dfffff: 1 colonnine, 52.4 kWh coperti su 52.4 kWh (Domanda agg: 52.4 kWh)
# H3 881f993515fffff: 1 colonnine, 75.3 kWh coperti su 75.3 kWh (Domanda agg: 75.3 kWh)
# H3 881f992749fffff: 1 colonnine, 51.8 kWh coperti su 51.8 kWh (Domanda agg: 51.8 kWh)
# H3 881f9935e5fffff: 1 colonnine, 43.6 kWh coperti su 43.6 kWh (Domanda agg: 43.6 kWh)
# H3 881f9935ebfffff: 1 colonnine, 17.9 kWh coperti su 17.9 kWh (Domanda agg: 17.9 kWh)
# H3 881f99352dfffff: 1 colonnine, 61.4 kWh coperti su 61.4 kWh (Domanda agg: 61.4 kWh)
# H3 881f99228dfffff: 1 colonnine, 109.6 kWh coperti su 109.6 kWh (Domanda agg: 109.6 kWh)
# H3 881f9935e3fffff: 1 colonnine, 18.2 kWh coperti su 18.2 kWh (Domanda agg: 18.2 kWh)
# H3 881f993513fffff: 1 colonnine, 23.7 kWh coperti su 23.7 kWh (Domanda agg: 23.7 kWh)
# H3 881f993567fffff: 1 colonnine, 18.7 kWh coperti su 18.7 kWh (Domanda agg: 18.7 kWh)
# H3 881f9922adfffff: 1 colonnine, 33.7 kWh coperti su 33.7 kWh (Domanda agg: 33.7 kWh)
# H3 881f9935e7fffff: 1 colonnine, 84.6 kWh coperti su 84.6 kWh (Domanda agg: 84.6 kWh)
# H3 881f992747fffff: 1 colonnine, 18.5 kWh coperti su 18.5 kWh (Domanda agg: 18.5 kWh)
# H3 881f99276bfffff: 1 colonnine, 51.8 kWh coperti su 51.8 kWh (Domanda agg: 51.8 kWh)
# H3 881f993527fffff: 1 colonnine, 22.9 kWh coperti su 22.9 kWh (Domanda agg: 22.9 kWh)
# H3 881f993529fffff: 1 colonnine, 43.3 kWh coperti su 43.3 kWh (Domanda agg: 43.3 kWh)
# H3 881f992289fffff: 1 colonnine, 83.9 kWh coperti su 83.9 kWh (Domanda agg: 83.9 kWh)
# H3 881f9935edfffff: 1 colonnine, 22.5 kWh coperti su 22.5 kWh (Domanda agg: 22.5 kWh)
# H3 881f9922d9fffff: 1 colonnine, 166.2 kWh coperti su 166.2 kWh (Domanda agg: 166.2 kWh)
# H3 881f99350dfffff: 1 colonnine, 19.4 kWh coperti su 19.4 kWh (Domanda agg: 19.4 kWh)
# H3 881f992281fffff: 1 colonnine, 134.0 kWh coperti su 134.0 kWh (Domanda agg: 134.0 kWh)
# H3 881f99228bfffff: 1 colonnine, 59.4 kWh coperti su 59.4 kWh (Domanda agg: 59.4 kWh)
# H3 881f9922e1fffff: 1 colonnine, 67.5 kWh coperti su 67.5 kWh (Domanda agg: 67.5 kWh)
# H3 881f9922d5fffff: 1 colonnine, 72.1 kWh coperti su 72.1 kWh (Domanda agg: 72.1 kWh)
# H3 881f993505fffff: 1 colonnine, 65.5 kWh coperti su 65.5 kWh (Domanda agg: 65.5 kWh)
# H3 881f993517fffff: 1 colonnine, 52.0 kWh coperti su 52.0 kWh (Domanda agg: 52.0 kWh)
# H3 881f9935abfffff: 1 colonnine, 18.9 kWh coperti su 18.9 kWh (Domanda agg: 18.9 kWh)
# H3 881f9922bbfffff: 1 colonnine, 43.9 kWh coperti su 43.9 kWh (Domanda agg: 43.9 kWh)
# H3 881f9922d3fffff: 1 colonnine, 92.4 kWh coperti su 92.4 kWh (Domanda agg: 92.4 kWh)
# H3 881f993521fffff: 1 colonnine, 86.9 kWh coperti su 86.9 kWh (Domanda agg: 86.9 kWh)
# H3 881f9922ebfffff: 1 colonnine, 86.1 kWh coperti su 86.1 kWh (Domanda agg: 86.1 kWh)
# H3 881f9922e9fffff: 1 colonnine, 69.3 kWh coperti su 69.3 kWh (Domanda agg: 69.3 kWh)
# H3 881f993525fffff: 1 colonnine, 45.9 kWh coperti su 45.9 kWh (Domanda agg: 45.9 kWh)
# H3 881f9935b5fffff: 1 colonnine, 46.7 kWh coperti su 46.7 kWh (Domanda agg: 46.7 kWh)
# H3 881f9922c3fffff: 1 colonnine, 63.9 kWh coperti su 63.9 kWh (Domanda agg: 63.9 kWh)
# H3 881f9922e7fffff: 1 colonnine, 17.9 kWh coperti su 17.9 kWh (Domanda agg: 17.9 kWh)
# H3 881f9935a9fffff: 1 colonnine, 95.7 kWh coperti su 95.7 kWh (Domanda agg: 95.7 kWh)
# H3 881f99225bfffff: 1 colonnine, 59.4 kWh coperti su 59.4 kWh (Domanda agg: 59.4 kWh)
# H3 881f9922dbfffff: 1 colonnine, 22.0 kWh coperti su 22.0 kWh (Domanda agg: 22.0 kWh)
# H3 881f992059fffff: 1 colonnine, 19.0 kWh coperti su 19.0 kWh (Domanda agg: 19.0 kWh)
# H3 881f9922e5fffff: 1 colonnine, 43.5 kWh coperti su 43.5 kWh (Domanda agg: 43.5 kWh)
# H3 881f993523fffff: 1 colonnine, 58.3 kWh coperti su 58.3 kWh (Domanda agg: 58.3 kWh)
# H3 881f993533fffff: 1 colonnine, 69.8 kWh coperti su 69.8 kWh (Domanda agg: 69.8 kWh)
# H3 881f992497fffff: 1 colonnine, 10.6 kWh coperti su 10.6 kWh (Domanda agg: 10.6 kWh)
# H3 881ea45135fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea4510dfffff: 1 colonnine, 25.8 kWh coperti su 25.8 kWh (Domanda agg: 25.8 kWh)
# H3 881ea45ad1fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45addfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45149fffff: 1 colonnine, 14.5 kWh coperti su 14.5 kWh (Domanda agg: 14.5 kWh)
# H3 881ea4512dfffff: 1 colonnine, 10.6 kWh coperti su 10.6 kWh (Domanda agg: 10.6 kWh)
# H3 881ea45109fffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh (Domanda agg: 7.3 kWh)
# H3 881ea45a81fffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh (Domanda agg: 5.9 kWh)
# H3 881ea451e7fffff: 1 colonnine, 30.8 kWh coperti su 30.8 kWh (Domanda agg: 30.8 kWh)
# H3 881ea45161fffff: 1 colonnine, 22.0 kWh coperti su 22.0 kWh (Domanda agg: 22.0 kWh)
# H3 881ea45a83fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea451e3fffff: 1 colonnine, 13.1 kWh coperti su 13.1 kWh (Domanda agg: 13.1 kWh)
# H3 881ea45acbfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45a89fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea451e1fffff: 1 colonnine, 18.4 kWh coperti su 18.4 kWh (Domanda agg: 18.4 kWh)
# H3 881ea45025fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea45107fffff: 1 colonnine, 9.8 kWh coperti su 9.8 kWh (Domanda agg: 9.8 kWh)
# H3 881ea45ad7fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45ac3fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea451edfffff: 1 colonnine, 13.3 kWh coperti su 13.3 kWh (Domanda agg: 13.3 kWh)
# H3 881ea45133fffff: 1 colonnine, 14.5 kWh coperti su 14.5 kWh (Domanda agg: 14.5 kWh)
# H3 881ea45a99fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea4511dfffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea4513dfffff: 1 colonnine, 13.7 kWh coperti su 13.7 kWh (Domanda agg: 13.7 kWh)
# H3 881ea45103fffff: 1 colonnine, 24.0 kWh coperti su 24.0 kWh (Domanda agg: 24.0 kWh)
# H3 881ea451a1fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea45147fffff: 1 colonnine, 20.5 kWh coperti su 20.5 kWh (Domanda agg: 20.5 kWh)
# H3 881ea45067fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea45143fffff: 1 colonnine, 10.1 kWh coperti su 10.1 kWh (Domanda agg: 10.1 kWh)
# H3 881ea45ac9fffff: 1 colonnine, 12.6 kWh coperti su 12.6 kWh (Domanda agg: 12.6 kWh)
# H3 881ea45ab9fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea4514bfffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh (Domanda agg: 11.3 kWh)
# H3 881ea45061fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea4513bfffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881ea45a87fffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh (Domanda agg: 7.6 kWh)
# H3 881ea45ad9fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea45117fffff: 1 colonnine, 21.6 kWh coperti su 21.6 kWh (Domanda agg: 21.6 kWh)
# H3 881ea451abfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45119fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea451e5fffff: 1 colonnine, 14.8 kWh coperti su 14.8 kWh (Domanda agg: 14.8 kWh)
# H3 881ea45065fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea45129fffff: 1 colonnine, 19.1 kWh coperti su 19.1 kWh (Domanda agg: 19.1 kWh)
# H3 881ea451adfffff: 1 colonnine, 13.5 kWh coperti su 13.5 kWh (Domanda agg: 13.5 kWh)
# H3 881ea45115fffff: 1 colonnine, 21.6 kWh coperti su 21.6 kWh (Domanda agg: 21.6 kWh)
# H3 881ea45ad3fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45a8bfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45169fffff: 1 colonnine, 14.0 kWh coperti su 14.0 kWh (Domanda agg: 14.0 kWh)
# H3 881ea451e9fffff: 1 colonnine, 10.8 kWh coperti su 10.8 kWh (Domanda agg: 10.8 kWh)
# H3 881ea45337fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea4512bfffff: 1 colonnine, 18.7 kWh coperti su 18.7 kWh (Domanda agg: 18.7 kWh)
# H3 881ea4514dfffff: 1 colonnine, 13.0 kWh coperti su 13.0 kWh (Domanda agg: 13.0 kWh)
# H3 881ea45139fffff: 1 colonnine, 18.8 kWh coperti su 18.8 kWh (Domanda agg: 18.8 kWh)
# H3 881ea45adbfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881ea45145fffff: 1 colonnine, 10.9 kWh coperti su 10.9 kWh (Domanda agg: 10.9 kWh)
# H3 881ea45105fffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh (Domanda agg: 5.7 kWh)
# H3 881ea451a5fffff: 1 colonnine, 12.5 kWh coperti su 12.5 kWh (Domanda agg: 12.5 kWh)
# H3 881ea45141fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881ea45167fffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh (Domanda agg: 13.8 kWh)
# H3 881ea45ac1fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881ea45163fffff: 1 colonnine, 19.6 kWh coperti su 19.6 kWh (Domanda agg: 19.6 kWh)
# H3 881ea45113fffff: 1 colonnine, 16.1 kWh coperti su 16.1 kWh (Domanda agg: 16.1 kWh)
# H3 881ea45101fffff: 1 colonnine, 23.1 kWh coperti su 23.1 kWh (Domanda agg: 23.1 kWh)
# H3 881ea45ad5fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea451a9fffff: 1 colonnine, 11.8 kWh coperti su 11.8 kWh (Domanda agg: 11.8 kWh)
# H3 881ea45131fffff: 1 colonnine, 20.8 kWh coperti su 20.8 kWh (Domanda agg: 20.8 kWh)
# H3 881ea45123fffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh (Domanda agg: 11.1 kWh)
# H3 881ea4516bfffff: 1 colonnine, 25.5 kWh coperti su 25.5 kWh (Domanda agg: 25.5 kWh)
# H3 881ea451ebfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881ea4510bfffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881ea45137fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45121fffff: 1 colonnine, 9.5 kWh coperti su 9.5 kWh (Domanda agg: 9.5 kWh)
# H3 881ea45b53fffff: 1 colonnine, 7.1 kWh coperti su 7.1 kWh (Domanda agg: 7.1 kWh)
# H3 881f9925e7fffff: 1 colonnine, 9.0 kWh coperti su 9.0 kWh (Domanda agg: 9.0 kWh)
# H3 881f992e91fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f992ec5fffff: 1 colonnine, 8.8 kWh coperti su 8.8 kWh (Domanda agg: 8.8 kWh)
# H3 881f992583fffff: 1 colonnine, 8.3 kWh coperti su 8.3 kWh (Domanda agg: 8.3 kWh)
# H3 881f992515fffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh (Domanda agg: 6.7 kWh)
# H3 881f992ed3fffff: 1 colonnine, 8.8 kWh coperti su 8.8 kWh (Domanda agg: 8.8 kWh)
# H3 881f99250bfffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh (Domanda agg: 6.7 kWh)
# H3 881f992e9bfffff: 1 colonnine, 9.4 kWh coperti su 9.4 kWh (Domanda agg: 9.4 kWh)
# H3 881ea45b4dfffff: 1 colonnine, 12.3 kWh coperti su 12.3 kWh (Domanda agg: 12.3 kWh)
# H3 881f9925adfffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh (Domanda agg: 11.1 kWh)
# H3 881ea45b0dfffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881f9925edfffff: 1 colonnine, 11.2 kWh coperti su 11.2 kWh (Domanda agg: 11.2 kWh)
# H3 881ea45b0bfffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh (Domanda agg: 8.9 kWh)
# H3 881f992e8dfffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh (Domanda agg: 6.9 kWh)
# H3 881f9925a3fffff: 1 colonnine, 11.0 kWh coperti su 11.0 kWh (Domanda agg: 11.0 kWh)
# H3 881f9925abfffff: 1 colonnine, 15.1 kWh coperti su 15.1 kWh (Domanda agg: 15.1 kWh)
# H3 881f992e95fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f992587fffff: 1 colonnine, 8.8 kWh coperti su 8.8 kWh (Domanda agg: 8.8 kWh)
# H3 881f992ed5fffff: 1 colonnine, 10.2 kWh coperti su 10.2 kWh (Domanda agg: 10.2 kWh)
# H3 881f992e99fffff: 1 colonnine, 13.9 kWh coperti su 13.9 kWh (Domanda agg: 13.9 kWh)
# H3 881f9925a7fffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh (Domanda agg: 9.2 kWh)
# H3 881f9925b1fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh (Domanda agg: 7.4 kWh)
# H3 881ea45b4bfffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh (Domanda agg: 7.6 kWh)
# H3 881f992581fffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh (Domanda agg: 5.9 kWh)
# H3 881f992eddfffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh (Domanda agg: 5.7 kWh)
# H3 881f99252bfffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh (Domanda agg: 6.9 kWh)
# H3 881f9925a1fffff: 1 colonnine, 15.2 kWh coperti su 15.2 kWh (Domanda agg: 15.2 kWh)
# H3 881f992503fffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh (Domanda agg: 7.6 kWh)
# H3 881f992ec1fffff: 1 colonnine, 10.5 kWh coperti su 10.5 kWh (Domanda agg: 10.5 kWh)
# H3 881ea45b55fffff: 1 colonnine, 13.9 kWh coperti su 13.9 kWh (Domanda agg: 13.9 kWh)
# H3 881f992509fffff: 1 colonnine, 12.0 kWh coperti su 12.0 kWh (Domanda agg: 12.0 kWh)
# H3 881f992ec7fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881f992585fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881ea45b6bfffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh (Domanda agg: 6.9 kWh)
# H3 881ea45b49fffff: 1 colonnine, 9.0 kWh coperti su 9.0 kWh (Domanda agg: 9.0 kWh)
# H3 881f9925e5fffff: 1 colonnine, 19.6 kWh coperti su 19.6 kWh (Domanda agg: 19.6 kWh)
# H3 881f99253bfffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh (Domanda agg: 7.6 kWh)
# H3 881f992589fffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh (Domanda agg: 7.3 kWh)
# H3 881f9925a9fffff: 1 colonnine, 9.6 kWh coperti su 9.6 kWh (Domanda agg: 9.6 kWh)
# H3 881f992ec3fffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh (Domanda agg: 8.9 kWh)
# H3 881f992ed9fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881f992ec9fffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh (Domanda agg: 6.7 kWh)
# H3 881ea45b57fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh (Domanda agg: 7.4 kWh)
# H3 881f9925b7fffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh (Domanda agg: 7.6 kWh)
# H3 881f9925a5fffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh (Domanda agg: 11.1 kWh)
# H3 881ea45b51fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh (Domanda agg: 8.1 kWh)
# H3 881f992529fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881f992ed7fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f992523fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881ea45b43fffff: 1 colonnine, 12.4 kWh coperti su 12.4 kWh (Domanda agg: 12.4 kWh)
# H3 881ea45b59fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45b45fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881f992513fffff: 1 colonnine, 7.5 kWh coperti su 7.5 kWh (Domanda agg: 7.5 kWh)
# H3 881f9925b9fffff: 1 colonnine, 6.3 kWh coperti su 6.3 kWh (Domanda agg: 6.3 kWh)
# H3 881ea45b41fffff: 1 colonnine, 8.8 kWh coperti su 8.8 kWh (Domanda agg: 8.8 kWh)
# H3 881f9925b5fffff: 1 colonnine, 10.7 kWh coperti su 10.7 kWh (Domanda agg: 10.7 kWh)
# H3 881f992ebbfffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh (Domanda agg: 7.4 kWh)
# H3 881f992eb3fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881f992517fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881f992edbfffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881f992ed1fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f99362bfffff: 1 colonnine, 9.9 kWh coperti su 9.9 kWh (Domanda agg: 9.9 kWh)
# H3 881f993631fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f9936e9fffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh (Domanda agg: 9.2 kWh)
# H3 881f9936edfffff: 1 colonnine, 15.8 kWh coperti su 15.8 kWh (Domanda agg: 15.8 kWh)
# H3 881f9936e1fffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh (Domanda agg: 8.7 kWh)
# H3 881f993617fffff: 1 colonnine, 19.0 kWh coperti su 19.0 kWh (Domanda agg: 19.0 kWh)
# H3 881f99363dfffff: 1 colonnine, 16.3 kWh coperti su 16.3 kWh (Domanda agg: 16.3 kWh)
# H3 881f993605fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f993607fffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh (Domanda agg: 9.1 kWh)
# H3 881f993639fffff: 1 colonnine, 9.4 kWh coperti su 9.4 kWh (Domanda agg: 9.4 kWh)
# H3 881f9936e3fffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh (Domanda agg: 11.1 kWh)
# H3 881f99363bfffff: 1 colonnine, 20.3 kWh coperti su 20.3 kWh (Domanda agg: 20.3 kWh)
# H3 881f993685fffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh (Domanda agg: 8.4 kWh)
# H3 881f99069dfffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh (Domanda agg: 8.2 kWh)
# H3 881f9906b3fffff: 1 colonnine, 20.7 kWh coperti su 20.7 kWh (Domanda agg: 20.7 kWh)
# H3 881f9906a1fffff: 1 colonnine, 10.4 kWh coperti su 10.4 kWh (Domanda agg: 10.4 kWh)
# H3 881f9904cdfffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh (Domanda agg: 8.4 kWh)
# H3 881f99334dfffff: 1 colonnine, 14.1 kWh coperti su 14.1 kWh (Domanda agg: 14.1 kWh)
# H3 881f9904c3fffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh (Domanda agg: 8.4 kWh)
# H3 881f9906a3fffff: 1 colonnine, 45.5 kWh coperti su 45.5 kWh (Domanda agg: 45.5 kWh)
# H3 881f993369fffff: 1 colonnine, 35.0 kWh coperti su 35.0 kWh (Domanda agg: 35.0 kWh)
# H3 881f9904ddfffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh (Domanda agg: 8.4 kWh)
# H3 881f9906a5fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881f990695fffff: 1 colonnine, 33.5 kWh coperti su 33.5 kWh (Domanda agg: 33.5 kWh)
# H3 881f990693fffff: 1 colonnine, 34.4 kWh coperti su 34.4 kWh (Domanda agg: 34.4 kWh)
# H3 881f9906e7fffff: 1 colonnine, 13.9 kWh coperti su 13.9 kWh (Domanda agg: 13.9 kWh)
# H3 881f9906a9fffff: 1 colonnine, 31.1 kWh coperti su 31.1 kWh (Domanda agg: 31.1 kWh)
# H3 881f9904cbfffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881f990691fffff: 1 colonnine, 11.8 kWh coperti su 11.8 kWh (Domanda agg: 11.8 kWh)
# H3 881f9906a7fffff: 1 colonnine, 21.0 kWh coperti su 21.0 kWh (Domanda agg: 21.0 kWh)
# H3 881f9906b1fffff: 1 colonnine, 25.2 kWh coperti su 25.2 kWh (Domanda agg: 25.2 kWh)
# H3 881f9906adfffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh (Domanda agg: 8.1 kWh)
# H3 881f9904c1fffff: 1 colonnine, 8.3 kWh coperti su 8.3 kWh (Domanda agg: 8.3 kWh)
# H3 881f9906b9fffff: 1 colonnine, 30.9 kWh coperti su 30.9 kWh (Domanda agg: 30.9 kWh)
# H3 881f9904c7fffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh (Domanda agg: 8.4 kWh)
# H3 881f9906b7fffff: 1 colonnine, 24.1 kWh coperti su 24.1 kWh (Domanda agg: 24.1 kWh)
# H3 881f990699fffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh (Domanda agg: 8.2 kWh)
# H3 881f9904ebfffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh (Domanda agg: 8.7 kWh)
# H3 881f9906bdfffff: 1 colonnine, 53.5 kWh coperti su 53.5 kWh (Domanda agg: 53.5 kWh)
# H3 881f990685fffff: 1 colonnine, 24.0 kWh coperti su 24.0 kWh (Domanda agg: 24.0 kWh)
# H3 881f9906b5fffff: 1 colonnine, 29.0 kWh coperti su 29.0 kWh (Domanda agg: 29.0 kWh)
# H3 881f9906bbfffff: 1 colonnine, 29.6 kWh coperti su 29.6 kWh (Domanda agg: 29.6 kWh)
# H3 881f990687fffff: 1 colonnine, 40.2 kWh coperti su 40.2 kWh (Domanda agg: 40.2 kWh)
# H3 881f9906abfffff: 1 colonnine, 56.5 kWh coperti su 56.5 kWh (Domanda agg: 56.5 kWh)
# H3 881f990697fffff: 1 colonnine, 41.7 kWh coperti su 41.7 kWh (Domanda agg: 41.7 kWh)
# H3 881f9904c9fffff: 1 colonnine, 9.0 kWh coperti su 9.0 kWh (Domanda agg: 9.0 kWh)
# H3 881f99302dfffff: 1 colonnine, 13.3 kWh coperti su 13.3 kWh (Domanda agg: 13.3 kWh)
# H3 881f993157fffff: 1 colonnine, 19.3 kWh coperti su 19.3 kWh (Domanda agg: 19.3 kWh)
# H3 881f993adbfffff: 1 colonnine, 16.8 kWh coperti su 16.8 kWh (Domanda agg: 16.8 kWh)
# H3 881f99315bfffff: 1 colonnine, 23.4 kWh coperti su 23.4 kWh (Domanda agg: 23.4 kWh)
# H3 881f993133fffff: 1 colonnine, 13.3 kWh coperti su 13.3 kWh (Domanda agg: 13.3 kWh)
# H3 881f99315dfffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881f993117fffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh (Domanda agg: 9.1 kWh)
# H3 881f993135fffff: 1 colonnine, 13.0 kWh coperti su 13.0 kWh (Domanda agg: 13.0 kWh)
# H3 881f99311dfffff: 1 colonnine, 30.2 kWh coperti su 30.2 kWh (Domanda agg: 30.2 kWh)
# H3 881f993153fffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh (Domanda agg: 13.8 kWh)
# H3 881f993103fffff: 1 colonnine, 13.1 kWh coperti su 13.1 kWh (Domanda agg: 13.1 kWh)
# H3 881f993027fffff: 1 colonnine, 14.9 kWh coperti su 14.9 kWh (Domanda agg: 14.9 kWh)
# H3 881f993025fffff: 1 colonnine, 18.7 kWh coperti su 18.7 kWh (Domanda agg: 18.7 kWh)
# H3 881f993137fffff: 1 colonnine, 13.5 kWh coperti su 13.5 kWh (Domanda agg: 13.5 kWh)
# H3 881f993113fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881f993159fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f993139fffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh (Domanda agg: 11.1 kWh)
# H3 881f993107fffff: 1 colonnine, 10.3 kWh coperti su 10.3 kWh (Domanda agg: 10.3 kWh)
# H3 881f993111fffff: 1 colonnine, 18.1 kWh coperti su 18.1 kWh (Domanda agg: 18.1 kWh)
# H3 881f993ad9fffff: 1 colonnine, 17.5 kWh coperti su 17.5 kWh (Domanda agg: 17.5 kWh)
# H3 881f99313bfffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh (Domanda agg: 13.8 kWh)
# H3 881f99310bfffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh (Domanda agg: 13.8 kWh)
# H3 881f993155fffff: 1 colonnine, 25.3 kWh coperti su 25.3 kWh (Domanda agg: 25.3 kWh)
# H3 881f9931edfffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881f99313dfffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh (Domanda agg: 13.8 kWh)
# H3 881f993151fffff: 1 colonnine, 18.6 kWh coperti su 18.6 kWh (Domanda agg: 18.6 kWh)
# H3 881f993119fffff: 1 colonnine, 14.5 kWh coperti su 14.5 kWh (Domanda agg: 14.5 kWh)
# H3 881f993a6bfffff: 1 colonnine, 17.5 kWh coperti su 17.5 kWh (Domanda agg: 17.5 kWh)
# H3 881f993a09fffff: 1 colonnine, 13.6 kWh coperti su 13.6 kWh (Domanda agg: 13.6 kWh)
# H3 881f993165fffff: 1 colonnine, 14.6 kWh coperti su 14.6 kWh (Domanda agg: 14.6 kWh)
# H3 881f993a4bfffff: 1 colonnine, 21.7 kWh coperti su 21.7 kWh (Domanda agg: 21.7 kWh)
# H3 881f990483fffff: 1 colonnine, 12.1 kWh coperti su 12.1 kWh (Domanda agg: 12.1 kWh)
# H3 881f993a5dfffff: 1 colonnine, 20.1 kWh coperti su 20.1 kWh (Domanda agg: 20.1 kWh)
# H3 881f993169fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f993a57fffff: 1 colonnine, 10.6 kWh coperti su 10.6 kWh (Domanda agg: 10.6 kWh)
# H3 881f993a51fffff: 1 colonnine, 21.9 kWh coperti su 21.9 kWh (Domanda agg: 21.9 kWh)
# H3 881f9904e3fffff: 1 colonnine, 13.9 kWh coperti su 13.9 kWh (Domanda agg: 13.9 kWh)
# H3 881f9904b7fffff: 1 colonnine, 30.3 kWh coperti su 30.3 kWh (Domanda agg: 30.3 kWh)
# H3 881f993a53fffff: 1 colonnine, 14.9 kWh coperti su 14.9 kWh (Domanda agg: 14.9 kWh)
# H3 881f9904b5fffff: 1 colonnine, 15.8 kWh coperti su 15.8 kWh (Domanda agg: 15.8 kWh)
# H3 881f990487fffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh (Domanda agg: 6.6 kWh)
# H3 881f993a55fffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh (Domanda agg: 8.6 kWh)
# H3 881f993a01fffff: 1 colonnine, 19.3 kWh coperti su 19.3 kWh (Domanda agg: 19.3 kWh)
# H3 881f993a5bfffff: 1 colonnine, 13.2 kWh coperti su 13.2 kWh (Domanda agg: 13.2 kWh)
# H3 881f993125fffff: 1 colonnine, 11.8 kWh coperti su 11.8 kWh (Domanda agg: 11.8 kWh)
# H3 881f990495fffff: 1 colonnine, 14.7 kWh coperti su 14.7 kWh (Domanda agg: 14.7 kWh)
# H3 881f993a43fffff: 1 colonnine, 12.7 kWh coperti su 12.7 kWh (Domanda agg: 12.7 kWh)
# H3 881f9904abfffff: 1 colonnine, 9.9 kWh coperti su 9.9 kWh (Domanda agg: 9.9 kWh)
# H3 881f993a0bfffff: 1 colonnine, 13.6 kWh coperti su 13.6 kWh (Domanda agg: 13.6 kWh)
# H3 881f993a0dfffff: 1 colonnine, 15.1 kWh coperti su 15.1 kWh (Domanda agg: 15.1 kWh)
# H3 881f993a49fffff: 1 colonnine, 16.0 kWh coperti su 16.0 kWh (Domanda agg: 16.0 kWh)
# H3 881f993a4dfffff: 1 colonnine, 14.4 kWh coperti su 14.4 kWh (Domanda agg: 14.4 kWh)
# H3 881f993a59fffff: 1 colonnine, 15.7 kWh coperti su 15.7 kWh (Domanda agg: 15.7 kWh)
# H3 881f99316dfffff: 1 colonnine, 18.7 kWh coperti su 18.7 kWh (Domanda agg: 18.7 kWh)
# H3 881f990497fffff: 1 colonnine, 14.2 kWh coperti su 14.2 kWh (Domanda agg: 14.2 kWh)
# H3 881f993161fffff: 1 colonnine, 9.8 kWh coperti su 9.8 kWh (Domanda agg: 9.8 kWh)
# H3 881f9904bbfffff: 1 colonnine, 16.1 kWh coperti su 16.1 kWh (Domanda agg: 16.1 kWh)
# H3 881f993a69fffff: 1 colonnine, 13.7 kWh coperti su 13.7 kWh (Domanda agg: 13.7 kWh)
# H3 881f9904b1fffff: 1 colonnine, 14.0 kWh coperti su 14.0 kWh (Domanda agg: 14.0 kWh)
# H3 881f9904bdfffff: 1 colonnine, 18.5 kWh coperti su 18.5 kWh (Domanda agg: 18.5 kWh)
# H3 881f990485fffff: 1 colonnine, 13.1 kWh coperti su 13.1 kWh (Domanda agg: 13.1 kWh)
# H3 881f9904b3fffff: 1 colonnine, 30.2 kWh coperti su 30.2 kWh (Domanda agg: 30.2 kWh)
# H3 881f9904b9fffff: 1 colonnine, 17.6 kWh coperti su 17.6 kWh (Domanda agg: 17.6 kWh)
# H3 881f993a47fffff: 1 colonnine, 12.0 kWh coperti su 12.0 kWh (Domanda agg: 12.0 kWh)
# H3 881f992565fffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh (Domanda agg: 6.7 kWh)
# H3 881f992c09fffff: 1 colonnine, 7.9 kWh coperti su 7.9 kWh (Domanda agg: 7.9 kWh)
# H3 881f992e09fffff: 1 colonnine, 7.1 kWh coperti su 7.1 kWh (Domanda agg: 7.1 kWh)
# H3 881f992081fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881f992e5dfffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881f9920b5fffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh (Domanda agg: 8.0 kWh)
# H3 881f992e41fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881f992c55fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881f992087fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881f992e4dfffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881f992e4bfffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh (Domanda agg: 8.9 kWh)
# H3 881f992e15fffff: 1 colonnine, 11.7 kWh coperti su 11.7 kWh (Domanda agg: 11.7 kWh)
# H3 881f992e47fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f992e29fffff: 1 colonnine, 9.0 kWh coperti su 9.0 kWh (Domanda agg: 9.0 kWh)
# H3 881f992e51fffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh (Domanda agg: 8.9 kWh)
# H3 881f99256dfffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f992e01fffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh (Domanda agg: 11.3 kWh)
# H3 881f992e03fffff: 1 colonnine, 15.9 kWh coperti su 15.9 kWh (Domanda agg: 15.9 kWh)
# H3 881f992e13fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh (Domanda agg: 7.4 kWh)
# H3 881f992e07fffff: 1 colonnine, 7.9 kWh coperti su 7.9 kWh (Domanda agg: 7.9 kWh)
# H3 881f992e0bfffff: 1 colonnine, 15.8 kWh coperti su 15.8 kWh (Domanda agg: 15.8 kWh)
# H3 881f992e5bfffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881f992e63fffff: 1 colonnine, 9.5 kWh coperti su 9.5 kWh (Domanda agg: 9.5 kWh)
# H3 881f992e43fffff: 1 colonnine, 12.1 kWh coperti su 12.1 kWh (Domanda agg: 12.1 kWh)
# H3 881f992e39fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f992e2bfffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881f9920b7fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh (Domanda agg: 6.4 kWh)
# H3 881f992e55fffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh (Domanda agg: 8.7 kWh)
# H3 881f992e0dfffff: 1 colonnine, 9.7 kWh coperti su 9.7 kWh (Domanda agg: 9.7 kWh)
# H3 881f9920bdfffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh (Domanda agg: 6.7 kWh)
# H3 881ea45acdfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f9924ebfffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh (Domanda agg: 5.9 kWh)
# H3 881f9924e3fffff: 1 colonnine, 9.0 kWh coperti su 9.0 kWh (Domanda agg: 9.0 kWh)
# H3 881ea45a1dfffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh (Domanda agg: 7.3 kWh)
# H3 881f9924b9fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881ea45a15fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881ea45a59fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f992481fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh (Domanda agg: 8.1 kWh)
# H3 881f9924b5fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881f992483fffff: 1 colonnine, 11.0 kWh coperti su 11.0 kWh (Domanda agg: 11.0 kWh)
# H3 881f992487fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f9924d9fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f992495fffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh (Domanda agg: 8.7 kWh)
# H3 881ea45a85fffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh (Domanda agg: 5.7 kWh)
# H3 881f9924bdfffff: 1 colonnine, 10.0 kWh coperti su 10.0 kWh (Domanda agg: 10.0 kWh)
# H3 881ea4516dfffff: 1 colonnine, 12.3 kWh coperti su 12.3 kWh (Domanda agg: 12.3 kWh)
# H3 881f9924bbfffff: 1 colonnine, 10.8 kWh coperti su 10.8 kWh (Domanda agg: 10.8 kWh)
# H3 881f9924b1fffff: 1 colonnine, 15.8 kWh coperti su 15.8 kWh (Domanda agg: 15.8 kWh)
# H3 881f992485fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh (Domanda agg: 8.1 kWh)
# H3 881ea45a19fffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh (Domanda agg: 9.1 kWh)
# H3 881ea45a53fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881f99259bfffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh (Domanda agg: 5.9 kWh)
# H3 881f9926b7fffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh (Domanda agg: 8.6 kWh)
# H3 881ea45a13fffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh (Domanda agg: 6.9 kWh)
# H3 881ea45aabfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f9930b3fffff: 1 colonnine, 17.6 kWh coperti su 17.6 kWh (Domanda agg: 17.6 kWh)
# H3 881f993725fffff: 1 colonnine, 19.5 kWh coperti su 19.5 kWh (Domanda agg: 19.5 kWh)
# H3 881f9930d7fffff: 1 colonnine, 7.7 kWh coperti su 7.7 kWh (Domanda agg: 7.7 kWh)
# H3 881f9930b7fffff: 1 colonnine, 44.9 kWh coperti su 44.9 kWh (Domanda agg: 44.9 kWh)
# H3 881f993767fffff: 1 colonnine, 17.0 kWh coperti su 17.0 kWh (Domanda agg: 17.0 kWh)
# H3 881f993721fffff: 1 colonnine, 21.7 kWh coperti su 21.7 kWh (Domanda agg: 21.7 kWh)
# H3 881f993091fffff: 1 colonnine, 28.8 kWh coperti su 28.8 kWh (Domanda agg: 28.8 kWh)
# H3 881f99309dfffff: 1 colonnine, 13.6 kWh coperti su 13.6 kWh (Domanda agg: 13.6 kWh)
# H3 881f993083fffff: 1 colonnine, 23.0 kWh coperti su 23.0 kWh (Domanda agg: 23.0 kWh)
# H3 881f9930d9fffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh (Domanda agg: 7.6 kWh)
# H3 881f99308bfffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f99309bfffff: 1 colonnine, 25.4 kWh coperti su 25.4 kWh (Domanda agg: 25.4 kWh)
# H3 881f993097fffff: 1 colonnine, 19.4 kWh coperti su 19.4 kWh (Domanda agg: 19.4 kWh)
# H3 881f99376bfffff: 1 colonnine, 24.3 kWh coperti su 24.3 kWh (Domanda agg: 24.3 kWh)
# H3 881f9930d1fffff: 1 colonnine, 27.0 kWh coperti su 27.0 kWh (Domanda agg: 27.0 kWh)
# H3 881f9930bbfffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh (Domanda agg: 7.3 kWh)
# H3 881f993765fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f9930b9fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f99370dfffff: 1 colonnine, 7.5 kWh coperti su 7.5 kWh (Domanda agg: 7.5 kWh)
# H3 881f9930d3fffff: 1 colonnine, 22.6 kWh coperti su 22.6 kWh (Domanda agg: 22.6 kWh)
# H3 881f993761fffff: 1 colonnine, 31.6 kWh coperti su 31.6 kWh (Domanda agg: 31.6 kWh)
# H3 881f9930b1fffff: 1 colonnine, 23.0 kWh coperti su 23.0 kWh (Domanda agg: 23.0 kWh)
# H3 881f99372dfffff: 1 colonnine, 35.2 kWh coperti su 35.2 kWh (Domanda agg: 35.2 kWh)
# H3 881f993727fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881f993769fffff: 1 colonnine, 26.1 kWh coperti su 26.1 kWh (Domanda agg: 26.1 kWh)
# H3 881f993763fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh (Domanda agg: 7.4 kWh)
# H3 881f993729fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f993095fffff: 1 colonnine, 16.9 kWh coperti su 16.9 kWh (Domanda agg: 16.9 kWh)
# H3 881f9930dbfffff: 1 colonnine, 16.7 kWh coperti su 16.7 kWh (Domanda agg: 16.7 kWh)
# H3 881f992259fffff: 1 colonnine, 38.8 kWh coperti su 38.8 kWh (Domanda agg: 38.8 kWh)
# H3 881f993099fffff: 1 colonnine, 22.3 kWh coperti su 22.3 kWh (Domanda agg: 22.3 kWh)
# H3 881f99356dfffff: 1 colonnine, 16.0 kWh coperti su 16.0 kWh (Domanda agg: 16.0 kWh)
# H3 881f99373bfffff: 1 colonnine, 33.9 kWh coperti su 33.9 kWh (Domanda agg: 33.9 kWh)
# H3 881f993627fffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh (Domanda agg: 5.7 kWh)
# H3 881f993707fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f993445fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f993717fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f993723fffff: 1 colonnine, 18.2 kWh coperti su 18.2 kWh (Domanda agg: 18.2 kWh)
# H3 881f99346bfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f993711fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f99346dfffff: 1 colonnine, 25.2 kWh coperti su 25.2 kWh (Domanda agg: 25.2 kWh)
# H3 881f99373dfffff: 1 colonnine, 23.8 kWh coperti su 23.8 kWh (Domanda agg: 23.8 kWh)
# H3 881f993703fffff: 1 colonnine, 25.8 kWh coperti su 25.8 kWh (Domanda agg: 25.8 kWh)
# H3 881f993713fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f993465fffff: 1 colonnine, 27.6 kWh coperti su 27.6 kWh (Domanda agg: 27.6 kWh)
# H3 881f993739fffff: 1 colonnine, 25.1 kWh coperti su 25.1 kWh (Domanda agg: 25.1 kWh)
# H3 881f993733fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881f993735fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f993731fffff: 1 colonnine, 15.4 kWh coperti su 15.4 kWh (Domanda agg: 15.4 kWh)
# H3 881f993705fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f993715fffff: 1 colonnine, 17.4 kWh coperti su 17.4 kWh (Domanda agg: 17.4 kWh)
# H3 881f993461fffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh (Domanda agg: 6.9 kWh)
# H3 881f993441fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f99355bfffff: 1 colonnine, 17.2 kWh coperti su 17.2 kWh (Domanda agg: 17.2 kWh)
# H3 881f993469fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f99371bfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f993447fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f99372bfffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh (Domanda agg: 5.7 kWh)
# H3 881f99344dfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f99a449fffff: 1 colonnine, 9.7 kWh coperti su 9.7 kWh (Domanda agg: 9.7 kWh)
# H3 881f99a707fffff: 1 colonnine, 13.1 kWh coperti su 13.1 kWh (Domanda agg: 13.1 kWh)
# H3 881f99a625fffff: 1 colonnine, 14.9 kWh coperti su 14.9 kWh (Domanda agg: 14.9 kWh)
# H3 881f99a715fffff: 1 colonnine, 18.3 kWh coperti su 18.3 kWh (Domanda agg: 18.3 kWh)
# H3 881f99a713fffff: 1 colonnine, 7.5 kWh coperti su 7.5 kWh (Domanda agg: 7.5 kWh)
# H3 881f99a44dfffff: 1 colonnine, 11.7 kWh coperti su 11.7 kWh (Domanda agg: 11.7 kWh)
# H3 881f99a621fffff: 1 colonnine, 10.0 kWh coperti su 10.0 kWh (Domanda agg: 10.0 kWh)
# H3 881f99a62bfffff: 1 colonnine, 10.5 kWh coperti su 10.5 kWh (Domanda agg: 10.5 kWh)
# H3 881f99a711fffff: 1 colonnine, 20.2 kWh coperti su 20.2 kWh (Domanda agg: 20.2 kWh)
# H3 881f99a757fffff: 1 colonnine, 11.0 kWh coperti su 11.0 kWh (Domanda agg: 11.0 kWh)
# H3 881f99a719fffff: 1 colonnine, 20.8 kWh coperti su 20.8 kWh (Domanda agg: 20.8 kWh)
# H3 881f99a739fffff: 1 colonnine, 18.1 kWh coperti su 18.1 kWh (Domanda agg: 18.1 kWh)
# H3 881f99a71bfffff: 1 colonnine, 15.3 kWh coperti su 15.3 kWh (Domanda agg: 15.3 kWh)
# H3 881f99a71dfffff: 1 colonnine, 12.7 kWh coperti su 12.7 kWh (Domanda agg: 12.7 kWh)
# H3 881f99a627fffff: 1 colonnine, 9.5 kWh coperti su 9.5 kWh (Domanda agg: 9.5 kWh)
# H3 881f99a703fffff: 1 colonnine, 10.4 kWh coperti su 10.4 kWh (Domanda agg: 10.4 kWh)
# H3 881f99a73bfffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh (Domanda agg: 6.5 kWh)
# H3 881f99a717fffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh (Domanda agg: 9.2 kWh)
# H3 881f99319dfffff: 1 colonnine, 17.2 kWh coperti su 17.2 kWh (Domanda agg: 17.2 kWh)
# H3 881f993199fffff: 1 colonnine, 17.2 kWh coperti su 17.2 kWh (Domanda agg: 17.2 kWh)
# H3 881f9931d5fffff: 1 colonnine, 60.0 kWh coperti su 60.0 kWh (Domanda agg: 60.0 kWh)
# H3 881f9931d7fffff: 1 colonnine, 53.8 kWh coperti su 53.8 kWh (Domanda agg: 53.8 kWh)
# H3 881f99318bfffff: 1 colonnine, 59.4 kWh coperti su 59.4 kWh (Domanda agg: 59.4 kWh)
# H3 881f9931d3fffff: 1 colonnine, 76.2 kWh coperti su 76.2 kWh (Domanda agg: 76.2 kWh)
# H3 881f9931d1fffff: 1 colonnine, 67.1 kWh coperti su 67.1 kWh (Domanda agg: 67.1 kWh)
# H3 881f993037fffff: 1 colonnine, 18.0 kWh coperti su 18.0 kWh (Domanda agg: 18.0 kWh)
# H3 881f9931c3fffff: 1 colonnine, 35.0 kWh coperti su 35.0 kWh (Domanda agg: 35.0 kWh)
# H3 881f9930a5fffff: 1 colonnine, 46.6 kWh coperti su 46.6 kWh (Domanda agg: 46.6 kWh)
# H3 881f9931d9fffff: 1 colonnine, 51.6 kWh coperti su 51.6 kWh (Domanda agg: 51.6 kWh)
# H3 881f993189fffff: 1 colonnine, 17.2 kWh coperti su 17.2 kWh (Domanda agg: 17.2 kWh)
# H3 881f9931dbfffff: 1 colonnine, 22.3 kWh coperti su 22.3 kWh (Domanda agg: 22.3 kWh)
# H3 881f9931ddfffff: 1 colonnine, 23.5 kWh coperti su 23.5 kWh (Domanda agg: 23.5 kWh)
# H3 881f992f17fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f992e2dfffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh (Domanda agg: 7.4 kWh)
# H3 881f9921b1fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh (Domanda agg: 6.4 kWh)
# H3 881f992f35fffff: 1 colonnine, 10.0 kWh coperti su 10.0 kWh (Domanda agg: 10.0 kWh)
# H3 881f992f5bfffff: 1 colonnine, 10.2 kWh coperti su 10.2 kWh (Domanda agg: 10.2 kWh)
# H3 881f992f15fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881f992f09fffff: 1 colonnine, 13.8 kWh coperti su 13.8 kWh (Domanda agg: 13.8 kWh)
# H3 881f992d51fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh (Domanda agg: 6.5 kWh)
# H3 881f992f41fffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881f992f01fffff: 1 colonnine, 7.1 kWh coperti su 7.1 kWh (Domanda agg: 7.1 kWh)
# H3 881f9921b9fffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh (Domanda agg: 6.6 kWh)
# H3 881f992f0bfffff: 1 colonnine, 14.4 kWh coperti su 14.4 kWh (Domanda agg: 14.4 kWh)
# H3 881f992c6bfffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh (Domanda agg: 6.9 kWh)
# H3 881f992f21fffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh (Domanda agg: 6.6 kWh)
# H3 881f992f69fffff: 1 colonnine, 8.4 kWh coperti su 8.4 kWh (Domanda agg: 8.4 kWh)
# H3 881f992f57fffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh (Domanda agg: 6.9 kWh)
# H3 881f992f47fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh (Domanda agg: 6.4 kWh)
# H3 881f992f03fffff: 1 colonnine, 13.3 kWh coperti su 13.3 kWh (Domanda agg: 13.3 kWh)
# H3 881f992f55fffff: 1 colonnine, 10.6 kWh coperti su 10.6 kWh (Domanda agg: 10.6 kWh)
# H3 881f992c69fffff: 1 colonnine, 7.5 kWh coperti su 7.5 kWh (Domanda agg: 7.5 kWh)
# H3 881f992f23fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881f992f39fffff: 1 colonnine, 10.2 kWh coperti su 10.2 kWh (Domanda agg: 10.2 kWh)
# H3 881f992f51fffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh (Domanda agg: 11.3 kWh)
# H3 881f9921b7fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh (Domanda agg: 6.4 kWh)
# H3 881f992c2dfffff: 1 colonnine, 7.7 kWh coperti su 7.7 kWh (Domanda agg: 7.7 kWh)
# H3 881f992d59fffff: 1 colonnine, 12.5 kWh coperti su 12.5 kWh (Domanda agg: 12.5 kWh)
# H3 881f992f43fffff: 1 colonnine, 9.7 kWh coperti su 9.7 kWh (Domanda agg: 9.7 kWh)
# H3 881f992f45fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh (Domanda agg: 8.1 kWh)
# H3 881f992d49fffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh (Domanda agg: 6.9 kWh)
# H3 881f992f5dfffff: 1 colonnine, 10.4 kWh coperti su 10.4 kWh (Domanda agg: 10.4 kWh)
# H3 881f992e61fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh (Domanda agg: 6.4 kWh)
# H3 881f992d5bfffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881f992f33fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881f99234bfffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh (Domanda agg: 8.6 kWh)
# H3 881f992349fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881f9931b1fffff: 1 colonnine, 28.9 kWh coperti su 28.9 kWh (Domanda agg: 28.9 kWh)
# H3 881f99226dfffff: 1 colonnine, 23.5 kWh coperti su 23.5 kWh (Domanda agg: 23.5 kWh)
# H3 881f9931b7fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881f993185fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881f9931b5fffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh (Domanda agg: 8.6 kWh)
# H3 881f993183fffff: 1 colonnine, 22.6 kWh coperti su 22.6 kWh (Domanda agg: 22.6 kWh)
# H3 881f993195fffff: 1 colonnine, 22.2 kWh coperti su 22.2 kWh (Domanda agg: 22.2 kWh)
# H3 881f9931bdfffff: 1 colonnine, 26.5 kWh coperti su 26.5 kWh (Domanda agg: 26.5 kWh)
# H3 881f9931a3fffff: 1 colonnine, 30.7 kWh coperti su 30.7 kWh (Domanda agg: 30.7 kWh)
# H3 881f9931b9fffff: 1 colonnine, 22.3 kWh coperti su 22.3 kWh (Domanda agg: 22.3 kWh)
# H3 881f9931abfffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh (Domanda agg: 8.6 kWh)
# H3 881f9931bbfffff: 1 colonnine, 33.2 kWh coperti su 33.2 kWh (Domanda agg: 33.2 kWh)
# H3 881f993181fffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh (Domanda agg: 8.6 kWh)
# H3 881f993187fffff: 1 colonnine, 9.7 kWh coperti su 9.7 kWh (Domanda agg: 9.7 kWh)
# H3 881f99319bfffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh (Domanda agg: 11.3 kWh)
# H3 881f9931a1fffff: 1 colonnine, 23.6 kWh coperti su 23.6 kWh (Domanda agg: 23.6 kWh)
# H3 881f993197fffff: 1 colonnine, 30.2 kWh coperti su 30.2 kWh (Domanda agg: 30.2 kWh)
# H3 881f9931b3fffff: 1 colonnine, 22.6 kWh coperti su 22.6 kWh (Domanda agg: 22.6 kWh)
# ...
# H3 881f993859fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f99385bfffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh (Domanda agg: 6.6 kWh)
# H3 881f993a37fffff: 1 colonnine, 9.3 kWh coperti su 9.3 kWh (Domanda agg: 9.3 kWh)
# H3 881f992d95fffff: 1 colonnine, 11.9 kWh coperti su 11.9 kWh (Domanda agg: 11.9 kWh)
# H3 881f992ddbfffff: 1 colonnine, 8.3 kWh coperti su 8.3 kWh (Domanda agg: 8.3 kWh)
# H3 881f992dd1fffff: 1 colonnine, 17.1 kWh coperti su 17.1 kWh (Domanda agg: 17.1 kWh)
# H3 881f992dd5fffff: 1 colonnine, 14.1 kWh coperti su 14.1 kWh (Domanda agg: 14.1 kWh)
# H3 881f992dd9fffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh (Domanda agg: 8.0 kWh)
# H3 881f992dddfffff: 1 colonnine, 8.8 kWh coperti su 8.8 kWh (Domanda agg: 8.8 kWh)
# H3 881f992dd3fffff: 1 colonnine, 10.7 kWh coperti su 10.7 kWh (Domanda agg: 10.7 kWh)
# H3 881f992dc3fffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh (Domanda agg: 7.6 kWh)
# H3 881f992d9dfffff: 1 colonnine, 7.7 kWh coperti su 7.7 kWh (Domanda agg: 7.7 kWh)
# H3 881f992d83fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f992dd7fffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881ea4cb59fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh (Domanda agg: 8.1 kWh)
# H3 881ea4cb19fffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh (Domanda agg: 6.7 kWh)
# H3 881ea4cb57fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881ea4cb1bfffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881ea4cb51fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881ea4cb53fffff: 1 colonnine, 7.9 kWh coperti su 7.9 kWh (Domanda agg: 7.9 kWh)
# H3 881f992615fffff: 1 colonnine, 12.1 kWh coperti su 12.1 kWh (Domanda agg: 12.1 kWh)
# H3 881f992611fffff: 1 colonnine, 21.0 kWh coperti su 21.0 kWh (Domanda agg: 21.0 kWh)
# H3 881f992609fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881f992657fffff: 1 colonnine, 28.8 kWh coperti su 28.8 kWh (Domanda agg: 28.8 kWh)
# H3 881f992619fffff: 1 colonnine, 22.7 kWh coperti su 22.7 kWh (Domanda agg: 22.7 kWh)
# H3 881f99260bfffff: 1 colonnine, 6.3 kWh coperti su 6.3 kWh (Domanda agg: 6.3 kWh)
# H3 881f992633fffff: 1 colonnine, 17.1 kWh coperti su 17.1 kWh (Domanda agg: 17.1 kWh)
# H3 881f9926edfffff: 1 colonnine, 23.7 kWh coperti su 23.7 kWh (Domanda agg: 23.7 kWh)
# H3 881f99263bfffff: 1 colonnine, 18.2 kWh coperti su 18.2 kWh (Domanda agg: 18.2 kWh)
# H3 881f992617fffff: 1 colonnine, 10.3 kWh coperti su 10.3 kWh (Domanda agg: 10.3 kWh)
# H3 881f99261dfffff: 1 colonnine, 17.1 kWh coperti su 17.1 kWh (Domanda agg: 17.1 kWh)
# H3 881f992863fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881f992369fffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh (Domanda agg: 9.2 kWh)
# H3 881f99236bfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f99059bfffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh (Domanda agg: 6.5 kWh)
# H3 881f9905d3fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f990599fffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh (Domanda agg: 5.9 kWh)
# H3 881f990597fffff: 1 colonnine, 12.9 kWh coperti su 12.9 kWh (Domanda agg: 12.9 kWh)
# H3 881f990591fffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh (Domanda agg: 11.3 kWh)
# H3 881f9905dbfffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f9938e1fffff: 1 colonnine, 9.3 kWh coperti su 9.3 kWh (Domanda agg: 9.3 kWh)
# H3 881f9939d3fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f9926d5fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881f9926b9fffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh (Domanda agg: 8.2 kWh)
# H3 881f992683fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f9926c3fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh (Domanda agg: 8.1 kWh)
# H3 881f992681fffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh (Domanda agg: 8.0 kWh)
# H3 881f9926bbfffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881f992689fffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh (Domanda agg: 6.6 kWh)
# H3 881f9930e9fffff: 1 colonnine, 32.2 kWh coperti su 32.2 kWh (Domanda agg: 32.2 kWh)
# H3 881f9930ebfffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh (Domanda agg: 8.0 kWh)
# H3 881f993011fffff: 1 colonnine, 9.8 kWh coperti su 9.8 kWh (Domanda agg: 9.8 kWh)
# H3 881f9930e1fffff: 1 colonnine, 20.7 kWh coperti su 20.7 kWh (Domanda agg: 20.7 kWh)
# H3 881f993017fffff: 1 colonnine, 40.9 kWh coperti su 40.9 kWh (Domanda agg: 40.9 kWh)
# H3 881f9930c5fffff: 1 colonnine, 66.6 kWh coperti su 66.6 kWh (Domanda agg: 66.6 kWh)
# H3 881f9930edfffff: 1 colonnine, 8.0 kWh coperti su 8.0 kWh (Domanda agg: 8.0 kWh)
# H3 881f993013fffff: 1 colonnine, 24.4 kWh coperti su 24.4 kWh (Domanda agg: 24.4 kWh)
# H3 881f99a549fffff: 1 colonnine, 6.8 kWh coperti su 6.8 kWh (Domanda agg: 6.8 kWh)
# H3 881f99a511fffff: 1 colonnine, 9.6 kWh coperti su 9.6 kWh (Domanda agg: 9.6 kWh)
# H3 881f99a5cdfffff: 1 colonnine, 12.5 kWh coperti su 12.5 kWh (Domanda agg: 12.5 kWh)
# H3 881f99a5c9fffff: 1 colonnine, 6.6 kWh coperti su 6.6 kWh (Domanda agg: 6.6 kWh)
# H3 881f99a51bfffff: 1 colonnine, 13.6 kWh coperti su 13.6 kWh (Domanda agg: 13.6 kWh)
# H3 881f99a51dfffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f99214bfffff: 1 colonnine, 14.6 kWh coperti su 14.6 kWh (Domanda agg: 14.6 kWh)
# H3 881f992149fffff: 1 colonnine, 16.4 kWh coperti su 16.4 kWh (Domanda agg: 16.4 kWh)
# H3 881f99233dfffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh (Domanda agg: 9.2 kWh)
# H3 881f992323fffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh (Domanda agg: 8.9 kWh)
# H3 881f992335fffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh (Domanda agg: 6.7 kWh)
# H3 881f992321fffff: 1 colonnine, 9.7 kWh coperti su 9.7 kWh (Domanda agg: 9.7 kWh)
# H3 881f992143fffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh (Domanda agg: 8.2 kWh)
# H3 881f99214dfffff: 1 colonnine, 14.3 kWh coperti su 14.3 kWh (Domanda agg: 14.3 kWh)
# H3 881f992331fffff: 1 colonnine, 9.5 kWh coperti su 9.5 kWh (Domanda agg: 9.5 kWh)
# H3 881f992327fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881f992329fffff: 1 colonnine, 9.8 kWh coperti su 9.8 kWh (Domanda agg: 9.8 kWh)
# H3 881ea4c99bfffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881ea4c8a1fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea4c8a5fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881ea4c99dfffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh (Domanda agg: 9.2 kWh)
# H3 881ea4c983fffff: 1 colonnine, 10.3 kWh coperti su 10.3 kWh (Domanda agg: 10.3 kWh)
# H3 881ea4c981fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881ea4c987fffff: 1 colonnine, 10.8 kWh coperti su 10.8 kWh (Domanda agg: 10.8 kWh)
# H3 881ea4c9abfffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh (Domanda agg: 7.4 kWh)
# H3 881ea4c995fffff: 1 colonnine, 10.7 kWh coperti su 10.7 kWh (Domanda agg: 10.7 kWh)
# H3 881ea4c9ebfffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh (Domanda agg: 6.5 kWh)
# H3 881ea4c98bfffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh (Domanda agg: 7.4 kWh)
# H3 881f992333fffff: 1 colonnine, 17.7 kWh coperti su 17.7 kWh (Domanda agg: 17.7 kWh)
# H3 881f992317fffff: 1 colonnine, 8.9 kWh coperti su 8.9 kWh (Domanda agg: 8.9 kWh)
# H3 881f992337fffff: 1 colonnine, 17.0 kWh coperti su 17.0 kWh (Domanda agg: 17.0 kWh)
# H3 881f992159fffff: 1 colonnine, 15.7 kWh coperti su 15.7 kWh (Domanda agg: 15.7 kWh)
# H3 881ea6962dfffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f993295fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881f993293fffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh (Domanda agg: 7.3 kWh)
# H3 881f9932b1fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh (Domanda agg: 6.5 kWh)
# H3 881f9932bdfffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f99af13fffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh (Domanda agg: 8.2 kWh)
# H3 881f9934b7fffff: 1 colonnine, 8.2 kWh coperti su 8.2 kWh (Domanda agg: 8.2 kWh)
# H3 881f99265dfffff: 1 colonnine, 7.1 kWh coperti su 7.1 kWh (Domanda agg: 7.1 kWh)
# H3 881ea692c5fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881ea692cdfffff: 1 colonnine, 7.5 kWh coperti su 7.5 kWh (Domanda agg: 7.5 kWh)
# H3 881ea6921bfffff: 1 colonnine, 9.3 kWh coperti su 9.3 kWh (Domanda agg: 9.3 kWh)
# H3 881f993a99fffff: 1 colonnine, 14.5 kWh coperti su 14.5 kWh (Domanda agg: 14.5 kWh)
# H3 881f993a9bfffff: 1 colonnine, 20.0 kWh coperti su 20.0 kWh (Domanda agg: 20.0 kWh)
# H3 881f9931adfffff: 1 colonnine, 20.0 kWh coperti su 20.0 kWh (Domanda agg: 20.0 kWh)
# H3 881f993a91fffff: 1 colonnine, 10.7 kWh coperti su 10.7 kWh (Domanda agg: 10.7 kWh)
# H3 881f993ad3fffff: 1 colonnine, 13.0 kWh coperti su 13.0 kWh (Domanda agg: 13.0 kWh)
# H3 881f993a9dfffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f9931a5fffff: 1 colonnine, 18.5 kWh coperti su 18.5 kWh (Domanda agg: 18.5 kWh)
# H3 881ea4c9a3fffff: 1 colonnine, 11.1 kWh coperti su 11.1 kWh (Domanda agg: 11.1 kWh)
# H3 881ea45349fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881ea4c9a7fffff: 1 colonnine, 6.7 kWh coperti su 6.7 kWh (Domanda agg: 6.7 kWh)
# H3 881ea4c9b5fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh (Domanda agg: 6.5 kWh)
# H3 881ea4c9e7fffff: 1 colonnine, 7.2 kWh coperti su 7.2 kWh (Domanda agg: 7.2 kWh)
# H3 881f9926dbfffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh (Domanda agg: 6.4 kWh)
# H3 881ea4c9a5fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881ea4c9e5fffff: 1 colonnine, 6.3 kWh coperti su 6.3 kWh (Domanda agg: 6.3 kWh)
# H3 881f9926d3fffff: 1 colonnine, 8.1 kWh coperti su 8.1 kWh (Domanda agg: 8.1 kWh)
# H3 881f9926d1fffff: 1 colonnine, 5.6 kWh coperti su 5.6 kWh (Domanda agg: 5.6 kWh)
# H3 881f992881fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f992d6bfffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh (Domanda agg: 8.7 kWh)
# H3 881f992d07fffff: 1 colonnine, 6.4 kWh coperti su 6.4 kWh (Domanda agg: 6.4 kWh)
# H3 881f992d05fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh (Domanda agg: 6.5 kWh)
# H3 881f992d63fffff: 1 colonnine, 10.7 kWh coperti su 10.7 kWh (Domanda agg: 10.7 kWh)
# H3 881f992d41fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f8a6925fffff: 1 colonnine, 20.3 kWh coperti su 20.3 kWh (Domanda agg: 20.3 kWh)
# H3 881f99a61bfffff: 1 colonnine, 20.7 kWh coperti su 20.7 kWh (Domanda agg: 20.7 kWh)
# H3 881f8a693dfffff: 1 colonnine, 33.6 kWh coperti su 33.6 kWh (Domanda agg: 33.6 kWh)
# H3 881f8a6935fffff: 1 colonnine, 32.7 kWh coperti su 32.7 kWh (Domanda agg: 32.7 kWh)
# H3 881f8a6927fffff: 1 colonnine, 18.0 kWh coperti su 18.0 kWh (Domanda agg: 18.0 kWh)
# H3 881ea4c8c1fffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh (Domanda agg: 5.7 kWh)
# H3 881ea4c8d5fffff: 1 colonnine, 7.6 kWh coperti su 7.6 kWh (Domanda agg: 7.6 kWh)
# H3 881f99adadfffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh (Domanda agg: 9.1 kWh)
# H3 881f9932dbfffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh (Domanda agg: 8.7 kWh)
# H3 881f99ade7fffff: 1 colonnine, 7.7 kWh coperti su 7.7 kWh (Domanda agg: 7.7 kWh)
# H3 881f9932d9fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881f99ad85fffff: 1 colonnine, 7.0 kWh coperti su 7.0 kWh (Domanda agg: 7.0 kWh)
# H3 881f9939cbfffff: 1 colonnine, 11.2 kWh coperti su 11.2 kWh (Domanda agg: 11.2 kWh)
# H3 881f99398bfffff: 1 colonnine, 19.2 kWh coperti su 19.2 kWh (Domanda agg: 19.2 kWh)
# H3 881f993989fffff: 1 colonnine, 14.1 kWh coperti su 14.1 kWh (Domanda agg: 14.1 kWh)
# H3 881f9939ddfffff: 1 colonnine, 9.8 kWh coperti su 9.8 kWh (Domanda agg: 9.8 kWh)
# H3 881f993837fffff: 1 colonnine, 14.2 kWh coperti su 14.2 kWh (Domanda agg: 14.2 kWh)
# H3 881f9939d9fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881f9939c3fffff: 1 colonnine, 8.7 kWh coperti su 8.7 kWh (Domanda agg: 8.7 kWh)
# H3 881f9928ebfffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh (Domanda agg: 6.5 kWh)
# H3 881f9928e3fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f9928c7fffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881f9928c5fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f9928e1fffff: 1 colonnine, 10.3 kWh coperti su 10.3 kWh (Domanda agg: 10.3 kWh)
# H3 881f992a5dfffff: 1 colonnine, 9.6 kWh coperti su 9.6 kWh (Domanda agg: 9.6 kWh)
# H3 881f9938b1fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f992a59fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f992a51fffff: 1 colonnine, 6.9 kWh coperti su 6.9 kWh (Domanda agg: 6.9 kWh)
# H3 881f9938b5fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881f992a41fffff: 1 colonnine, 7.4 kWh coperti su 7.4 kWh (Domanda agg: 7.4 kWh)
# H3 881f992a4bfffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881f9938b7fffff: 1 colonnine, 6.5 kWh coperti su 6.5 kWh (Domanda agg: 6.5 kWh)
# H3 881f8a6859fffff: 1 colonnine, 5.4 kWh coperti su 5.4 kWh (Domanda agg: 5.4 kWh)
# H3 881f992653fffff: 1 colonnine, 8.6 kWh coperti su 8.6 kWh (Domanda agg: 8.6 kWh)
# H3 881f99261bfffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881f9934d7fffff: 1 colonnine, 6.8 kWh coperti su 6.8 kWh (Domanda agg: 6.8 kWh)
# H3 881ea69705fffff: 1 colonnine, 7.3 kWh coperti su 7.3 kWh (Domanda agg: 7.3 kWh)
# H3 881f992ca5fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f99ad1dfffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
# H3 881f99ad11fffff: 1 colonnine, 6.0 kWh coperti su 6.0 kWh (Domanda agg: 6.0 kWh)
# H3 881f8a6923fffff: 1 colonnine, 10.8 kWh coperti su 10.8 kWh (Domanda agg: 10.8 kWh)
# H3 881f8a692bfffff: 1 colonnine, 12.7 kWh coperti su 12.7 kWh (Domanda agg: 12.7 kWh)
# H3 881f8a690dfffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881ea45369fffff: 1 colonnine, 11.3 kWh coperti su 11.3 kWh (Domanda agg: 11.3 kWh)
# H3 881ea4534bfffff: 1 colonnine, 13.4 kWh coperti su 13.4 kWh (Domanda agg: 13.4 kWh)
# H3 881ea45341fffff: 1 colonnine, 12.0 kWh coperti su 12.0 kWh (Domanda agg: 12.0 kWh)
# H3 881ea45345fffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh (Domanda agg: 9.2 kWh)
# H3 881ea45347fffff: 1 colonnine, 11.2 kWh coperti su 11.2 kWh (Domanda agg: 11.2 kWh)
# H3 881ea4cb67fffff: 1 colonnine, 9.6 kWh coperti su 9.6 kWh (Domanda agg: 9.6 kWh)
# H3 881ea4cb47fffff: 1 colonnine, 6.2 kWh coperti su 6.2 kWh (Domanda agg: 6.2 kWh)
# H3 881ea4cb6bfffff: 1 colonnine, 6.1 kWh coperti su 6.1 kWh (Domanda agg: 6.1 kWh)
# H3 881ea69219fffff: 1 colonnine, 9.2 kWh coperti su 9.2 kWh (Domanda agg: 9.2 kWh)
# H3 881f9938d3fffff: 1 colonnine, 5.5 kWh coperti su 5.5 kWh (Domanda agg: 5.5 kWh)
# H3 881f993695fffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh (Domanda agg: 5.9 kWh)
# H3 881ea6965bfffff: 1 colonnine, 5.7 kWh coperti su 5.7 kWh (Domanda agg: 5.7 kWh)
# H3 881f8a6a5bfffff: 1 colonnine, 7.8 kWh coperti su 7.8 kWh (Domanda agg: 7.8 kWh)
# H3 881f993a97fffff: 1 colonnine, 5.9 kWh coperti su 5.9 kWh (Domanda agg: 5.9 kWh)
# H3 881f99236dfffff: 1 colonnine, 8.5 kWh coperti su 8.5 kWh (Domanda agg: 8.5 kWh)
# H3 881ea4ca6dfffff: 1 colonnine, 49.8 kWh coperti su 49.8 kWh (Domanda agg: 49.8 kWh)
# H3 881ea4d9bbfffff: 1 colonnine, 77.1 kWh coperti su 77.1 kWh (Domanda agg: 77.1 kWh)
# H3 881ea4d983fffff: 1 colonnine, 33.1 kWh coperti su 33.1 kWh (Domanda agg: 33.1 kWh)
# H3 881ea4d9b1fffff: 1 colonnine, 41.9 kWh coperti su 41.9 kWh (Domanda agg: 41.9 kWh)
# H3 881ea4d995fffff: 1 colonnine, 12.8 kWh coperti su 12.8 kWh (Domanda agg: 12.8 kWh)
# H3 881ea4d9b3fffff: 1 colonnine, 55.6 kWh coperti su 55.6 kWh (Domanda agg: 55.6 kWh)
# H3 881f8a6a1bfffff: 1 colonnine, 9.1 kWh coperti su 9.1 kWh (Domanda agg: 9.1 kWh)
# H3 881f8a6ae1fffff: 1 colonnine, 12.1 kWh coperti su 12.1 kWh (Domanda agg: 12.1 kWh)
# H3 881f99ada5fffff: 1 colonnine, 5.8 kWh coperti su 5.8 kWh (Domanda agg: 5.8 kWh)
#
# Domanda totale coperta: 28010.36 kWh

# %% [markdown]
# ### Map visualisation

# %%
mappa = crea_mappa_colonnine_discrete(gdf_risultati_alpha, colonna_colonnine="Colonnine allocate")
mappa
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Save the map as an HTML file
mappa.save("/content/drive/Shareddrives/OM in Business Analytics/OM in BA - Project/Codice/04 - Modello/log_heatmap_third_model_def.html")

# %% [markdown]
# ### Results

# %%
total_allocated_chargers = gdf_risultati_alpha["Colonnine allocate"].sum()
total_covered_demand = gdf_risultati_alpha["Domanda coperta (kWh)"].sum()
total_demand = gdf_risultati_alpha["Domanda Giornaliera Ponderata (kWh)"].sum()

print(f"Total allocated charging stations: {total_allocated_chargers}")
print(f"Total covered demand (kWh): {total_covered_demand:.2f}")
print(f"Total demand (kWh): {total_demand:.2f}")
# Out:
# Total allocated charging stations: 1623
# Total covered demand (kWh): 28010.36
# Total demand (kWh): 34500.45

# %% [markdown]
# # 2030 MODELS

# %% [markdown]
# ## FOURTH MODEL
# ## Charging Station Allocation Model – 2030 Conservative Scenario
# This model estimates the allocation of 4,039 charging stations under a conservative 2030 scenario. It assumes increased energy demand and enforces a maximum of 10 stations per hexagon. The building index has been excluded, as estimating future building locations and counts would require a separate, dedicated analysis.

# %%
# !pip install h3==3.*
# Out:
# Requirement already satisfied: h3==3.* in /usr/local/lib/python3.11/dist-packages (3.7.7)

# %% [markdown]
# ### Neighbor list

# %%
import h3

# Get the unique list of hexagons in your GeoDataFrame
h3_ids_presenti = set(gdf_conservativo['h3_id'])

# Create a dictionary {index in gdf : list of neighboring indices}
h3_id_to_idx = {h3_id: idx for idx, h3_id in enumerate(gdf_conservativo['h3_id'])}

neighbors_dict = {}

for idx, row in gdf_conservativo.iterrows():
    h3_id = row['h3_id']
    # Get H3 neighbors (k_ring with radius 1)
    vicini_h3 = h3.k_ring(h3_id, 1)
    # Filter only those present in your dataframe
    vicini_presenti = [h3_id_to_idx[v] for v in vicini_h3 if v in h3_ids_presenti and v != h3_id]
    neighbors_dict[idx] = vicini_presenti

print(f"Neighbor dictionary created with {len(neighbors_dict)} hexagons")
# Out:
# Neighbor dictionary created with 6495 hexagons

# %%
gdf_risultati_cons2030 = ottimizza_colonnine_con_domanda_aggregata(gdf_conservativo, p_colonnine=4039)
# Out:
# H3 881f99274bfffff: 10 colonnine, 5554.3 kWh coperti su 22330.9 kWh (Domanda agg: 22330.9 kWh)
# H3 881f992215fffff: 10 colonnine, 5554.3 kWh coperti su 28225.8 kWh (Domanda agg: 28225.8 kWh)
# H3 881f992213fffff: 10 colonnine, 5554.3 kWh coperti su 46257.9 kWh (Domanda agg: 46257.9 kWh)
# H3 881f9935c7fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f9935a1fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f9922ddfffff: 10 colonnine, 5554.3 kWh coperti su 75974.8 kWh (Domanda agg: 75974.8 kWh)
# H3 881f992285fffff: 10 colonnine, 5554.3 kWh coperti su 37835.5 kWh (Domanda agg: 37835.5 kWh)
# H3 881f9922e3fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f992217fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f993501fffff: 10 colonnine, 5554.3 kWh coperti su 48814.8 kWh (Domanda agg: 48814.8 kWh)
# H3 881f99353bfffff: 10 colonnine, 5554.3 kWh coperti su 79049.0 kWh (Domanda agg: 79049.0 kWh)
# H3 881f992295fffff: 10 colonnine, 5554.3 kWh coperti su 39223.8 kWh (Domanda agg: 39223.8 kWh)
# H3 881f9922cdfffff: 10 colonnine, 5554.3 kWh coperti su 57252.3 kWh (Domanda agg: 57252.3 kWh)
# H3 881f9920d9fffff: 10 colonnine, 5554.3 kWh coperti su 34265.4 kWh (Domanda agg: 34265.4 kWh)
# H3 881f992745fffff: 10 colonnine, 5554.3 kWh coperti su 35158.2 kWh (Domanda agg: 35158.2 kWh)
# H3 881f992291fffff: 10 colonnine, 5554.3 kWh coperti su 51503.7 kWh (Domanda agg: 51503.7 kWh)
# H3 881f992233fffff: 10 colonnine, 5554.3 kWh coperti su 48982.2 kWh (Domanda agg: 48982.2 kWh)
# H3 881f993537fffff: 10 colonnine, 5554.3 kWh coperti su 15131.1 kWh (Domanda agg: 15131.1 kWh)
# H3 881f993531fffff: 10 colonnine, 5554.3 kWh coperti su 57187.7 kWh (Domanda agg: 57187.7 kWh)
# H3 881f9922c9fffff: 10 colonnine, 5554.3 kWh coperti su 61610.4 kWh (Domanda agg: 61610.4 kWh)
# H3 881f992741fffff: 10 colonnine, 5554.3 kWh coperti su 51040.0 kWh (Domanda agg: 51040.0 kWh)
# H3 881f993511fffff: 10 colonnine, 5554.3 kWh coperti su 55197.7 kWh (Domanda agg: 55197.7 kWh)
# H3 881f99270dfffff: 10 colonnine, 5554.3 kWh coperti su 61119.5 kWh (Domanda agg: 61119.5 kWh)
# H3 881f992287fffff: 10 colonnine, 5554.3 kWh coperti su 22271.5 kWh (Domanda agg: 22271.5 kWh)
# H3 881f992253fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f992211fffff: 10 colonnine, 5554.3 kWh coperti su 62349.8 kWh (Domanda agg: 62349.8 kWh)
# H3 881f992231fffff: 10 colonnine, 5554.3 kWh coperti su 32097.7 kWh (Domanda agg: 32097.7 kWh)
# H3 881f9922d7fffff: 10 colonnine, 5554.3 kWh coperti su 42282.2 kWh (Domanda agg: 42282.2 kWh)
# H3 881f9935a7fffff: 10 colonnine, 5554.3 kWh coperti su 20346.9 kWh (Domanda agg: 20346.9 kWh)
# H3 881f99221bfffff: 10 colonnine, 5554.3 kWh coperti su 41326.1 kWh (Domanda agg: 41326.1 kWh)
# H3 881f992239fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f992761fffff: 10 colonnine, 5554.3 kWh coperti su 50170.5 kWh (Domanda agg: 50170.5 kWh)
# H3 881f9935a5fffff: 10 colonnine, 5554.3 kWh coperti su 49117.2 kWh (Domanda agg: 49117.2 kWh)
# H3 881f993557fffff: 10 colonnine, 5554.3 kWh coperti su 57997.5 kWh (Domanda agg: 57997.5 kWh)
# H3 881f9935e1fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f99358dfffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f9922b3fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f9922edfffff: 10 colonnine, 5554.3 kWh coperti su 36174.4 kWh (Domanda agg: 36174.4 kWh)
# H3 881f99223bfffff: 10 colonnine, 5554.3 kWh coperti su 37792.3 kWh (Domanda agg: 37792.3 kWh)
# H3 881f992283fffff: 10 colonnine, 5554.3 kWh coperti su 65894.3 kWh (Domanda agg: 65894.3 kWh)
# H3 881f993519fffff: 10 colonnine, 5554.3 kWh coperti su 57001.5 kWh (Domanda agg: 57001.5 kWh)
# H3 881f993553fffff: 10 colonnine, 5554.3 kWh coperti su 54146.6 kWh (Domanda agg: 54146.6 kWh)
# H3 881f993535fffff: 10 colonnine, 5554.3 kWh coperti su 45354.5 kWh (Domanda agg: 45354.5 kWh)
# H3 881f993585fffff: 10 colonnine, 5554.3 kWh coperti su 46692.9 kWh (Domanda agg: 46692.9 kWh)
# H3 881f993539fffff: 10 colonnine, 5554.3 kWh coperti su 59158.2 kWh (Domanda agg: 59158.2 kWh)
# H3 881f992203fffff: 10 colonnine, 5554.3 kWh coperti su 28519.0 kWh (Domanda agg: 28519.0 kWh)
# H3 881f9935e9fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f992299fffff: 10 colonnine, 5554.3 kWh coperti su 31154.5 kWh (Domanda agg: 31154.5 kWh)
# H3 881f9922d1fffff: 10 colonnine, 5554.3 kWh coperti su 106683.2 kWh (Domanda agg: 106683.2 kWh)
# H3 881f992251fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f993507fffff: 10 colonnine, 5554.3 kWh coperti su 84160.6 kWh (Domanda agg: 84160.6 kWh)
# H3 881f9922a9fffff: 10 colonnine, 5554.3 kWh coperti su 65120.1 kWh (Domanda agg: 65120.1 kWh)
# H3 881f992765fffff: 10 colonnine, 5554.3 kWh coperti su 36535.3 kWh (Domanda agg: 36535.3 kWh)
# H3 881f99229bfffff: 10 colonnine, 5554.3 kWh coperti su 71251.6 kWh (Domanda agg: 71251.6 kWh)
# H3 881f99276dfffff: 10 colonnine, 5554.3 kWh coperti su 52827.3 kWh (Domanda agg: 52827.3 kWh)
# H3 881f99353dfffff: 10 colonnine, 5554.3 kWh coperti su 66364.0 kWh (Domanda agg: 66364.0 kWh)
# H3 881f9922c7fffff: 10 colonnine, 5554.3 kWh coperti su 54608.6 kWh (Domanda agg: 54608.6 kWh)
# H3 881f993563fffff: 10 colonnine, 5554.3 kWh coperti su 32187.2 kWh (Domanda agg: 32187.2 kWh)
# H3 881f992293fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f99352bfffff: 10 colonnine, 5554.3 kWh coperti su 63888.0 kWh (Domanda agg: 63888.0 kWh)
# H3 881f9935cdfffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f993581fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f99351bfffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f992297fffff: 10 colonnine, 5554.3 kWh coperti su 35094.3 kWh (Domanda agg: 35094.3 kWh)
# H3 881f9922c5fffff: 10 colonnine, 5554.3 kWh coperti su 102115.3 kWh (Domanda agg: 102115.3 kWh)
# H3 881f992769fffff: 10 colonnine, 5554.3 kWh coperti su 47811.2 kWh (Domanda agg: 47811.2 kWh)
# H3 881f993425fffff: 10 colonnine, 5554.3 kWh coperti su 38847.3 kWh (Domanda agg: 38847.3 kWh)
# H3 881f9935adfffff: 10 colonnine, 5554.3 kWh coperti su 15614.0 kWh (Domanda agg: 15614.0 kWh)
# H3 881f992219fffff: 10 colonnine, 5554.3 kWh coperti su 69837.6 kWh (Domanda agg: 69837.6 kWh)
# H3 881f99274dfffff: 10 colonnine, 5554.3 kWh coperti su 64131.6 kWh (Domanda agg: 64131.6 kWh)
# H3 881f9922c1fffff: 10 colonnine, 5554.3 kWh coperti su 87208.4 kWh (Domanda agg: 87208.4 kWh)
# H3 881f993427fffff: 10 colonnine, 5554.3 kWh coperti su 21023.6 kWh (Domanda agg: 21023.6 kWh)
# H3 881f9922cbfffff: 10 colonnine, 5554.3 kWh coperti su 59957.8 kWh (Domanda agg: 59957.8 kWh)
# H3 881f993503fffff: 10 colonnine, 5554.3 kWh coperti su 55220.0 kWh (Domanda agg: 55220.0 kWh)
# H3 881f992237fffff: 10 colonnine, 5554.3 kWh coperti su 51989.0 kWh (Domanda agg: 51989.0 kWh)
# H3 881f99205bfffff: 10 colonnine, 5554.3 kWh coperti su 27888.4 kWh (Domanda agg: 27888.4 kWh)
# H3 881f9935a3fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f99229dfffff: 10 colonnine, 5554.3 kWh coperti su 45431.7 kWh (Domanda agg: 45431.7 kWh)
# H3 881f9935c5fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f99351dfffff: 10 colonnine, 5554.3 kWh coperti su 35097.8 kWh (Domanda agg: 35097.8 kWh)
# H3 881f993515fffff: 10 colonnine, 5554.3 kWh coperti su 53890.0 kWh (Domanda agg: 53890.0 kWh)
# H3 881f992749fffff: 10 colonnine, 5554.3 kWh coperti su 35891.4 kWh (Domanda agg: 35891.4 kWh)
# H3 881f9935e5fffff: 10 colonnine, 5554.3 kWh coperti su 33268.4 kWh (Domanda agg: 33268.4 kWh)
# H3 881f9935ebfffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f99352dfffff: 10 colonnine, 5554.3 kWh coperti su 41808.9 kWh (Domanda agg: 41808.9 kWh)
# H3 881f99228dfffff: 10 colonnine, 5554.3 kWh coperti su 83931.5 kWh (Domanda agg: 83931.5 kWh)
# H3 881f9935e3fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f993513fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f993567fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f9922adfffff: 10 colonnine, 5554.3 kWh coperti su 24606.0 kWh (Domanda agg: 24606.0 kWh)
# H3 881f9935e7fffff: 10 colonnine, 5554.3 kWh coperti su 65426.2 kWh (Domanda agg: 65426.2 kWh)
# H3 881f992747fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f99276bfffff: 10 colonnine, 5554.3 kWh coperti su 39810.2 kWh (Domanda agg: 39810.2 kWh)
# H3 881f993527fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f993529fffff: 10 colonnine, 5554.3 kWh coperti su 26637.1 kWh (Domanda agg: 26637.1 kWh)
# H3 881f992289fffff: 10 colonnine, 5554.3 kWh coperti su 59736.5 kWh (Domanda agg: 59736.5 kWh)
# H3 881f9935edfffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f9922d9fffff: 10 colonnine, 5554.3 kWh coperti su 122987.1 kWh (Domanda agg: 122987.1 kWh)
# H3 881f99350dfffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f992281fffff: 10 colonnine, 5554.3 kWh coperti su 101725.1 kWh (Domanda agg: 101725.1 kWh)
# H3 881f99228bfffff: 10 colonnine, 5554.3 kWh coperti su 44882.1 kWh (Domanda agg: 44882.1 kWh)
# H3 881f9922e1fffff: 10 colonnine, 5554.3 kWh coperti su 48331.2 kWh (Domanda agg: 48331.2 kWh)
# H3 881f9922d5fffff: 10 colonnine, 5554.3 kWh coperti su 51294.2 kWh (Domanda agg: 51294.2 kWh)
# H3 881f993505fffff: 10 colonnine, 5554.3 kWh coperti su 39951.3 kWh (Domanda agg: 39951.3 kWh)
# H3 881f993517fffff: 10 colonnine, 5554.3 kWh coperti su 35738.0 kWh (Domanda agg: 35738.0 kWh)
# H3 881f9935abfffff: 10 colonnine, 5554.3 kWh coperti su 14670.9 kWh (Domanda agg: 14670.9 kWh)
# H3 881f9922bbfffff: 10 colonnine, 5554.3 kWh coperti su 33010.9 kWh (Domanda agg: 33010.9 kWh)
# H3 881f9922d3fffff: 10 colonnine, 5554.3 kWh coperti su 67129.3 kWh (Domanda agg: 67129.3 kWh)
# H3 881f993521fffff: 10 colonnine, 5554.3 kWh coperti su 62718.3 kWh (Domanda agg: 62718.3 kWh)
# H3 881f9922ebfffff: 10 colonnine, 5554.3 kWh coperti su 66644.9 kWh (Domanda agg: 66644.9 kWh)
# H3 881f9922e9fffff: 10 colonnine, 5554.3 kWh coperti su 48411.5 kWh (Domanda agg: 48411.5 kWh)
# H3 881f993525fffff: 10 colonnine, 5554.3 kWh coperti su 35130.0 kWh (Domanda agg: 35130.0 kWh)
# H3 881f9935b5fffff: 10 colonnine, 5554.3 kWh coperti su 33723.8 kWh (Domanda agg: 33723.8 kWh)
# H3 881f9922c3fffff: 10 colonnine, 5554.3 kWh coperti su 46291.5 kWh (Domanda agg: 46291.5 kWh)
# H3 881f9922e7fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f9935a9fffff: 10 colonnine, 5554.3 kWh coperti su 74557.1 kWh (Domanda agg: 74557.1 kWh)
# H3 881f99225bfffff: 10 colonnine, 5554.3 kWh coperti su 40501.0 kWh (Domanda agg: 40501.0 kWh)
# H3 881f9922dbfffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f992059fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f9922e5fffff: 10 colonnine, 5554.3 kWh coperti su 33339.3 kWh (Domanda agg: 33339.3 kWh)
# H3 881f993523fffff: 10 colonnine, 5554.3 kWh coperti su 39311.8 kWh (Domanda agg: 39311.8 kWh)
# H3 881f993533fffff: 10 colonnine, 5554.3 kWh coperti su 49971.3 kWh (Domanda agg: 49971.3 kWh)
# H3 881ea45157fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881f992497fffff: 8 colonnine, 4443.4 kWh coperti su 4722.2 kWh (Domanda agg: 4722.2 kWh)
# H3 881ea45135fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45333fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea4510dfffff: 10 colonnine, 5554.3 kWh coperti su 10048.3 kWh (Domanda agg: 10048.3 kWh)
# H3 881ea45ad1fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45149fffff: 10 colonnine, 5554.3 kWh coperti su 6430.7 kWh (Domanda agg: 6430.7 kWh)
# H3 881ea4512dfffff: 8 colonnine, 4443.4 kWh coperti su 4557.1 kWh (Domanda agg: 4557.1 kWh)
# H3 881ea45109fffff: 5 colonnine, 2777.2 kWh coperti su 3175.5 kWh (Domanda agg: 3175.5 kWh)
# H3 881ea45a81fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea451e7fffff: 10 colonnine, 5554.3 kWh coperti su 13135.3 kWh (Domanda agg: 13135.3 kWh)
# H3 881ea45161fffff: 10 colonnine, 5554.3 kWh coperti su 9873.3 kWh (Domanda agg: 9873.3 kWh)
# H3 881ea451e3fffff: 10 colonnine, 5554.3 kWh coperti su 5900.2 kWh (Domanda agg: 5900.2 kWh)
# H3 881ea451e1fffff: 10 colonnine, 5554.3 kWh coperti su 8211.7 kWh (Domanda agg: 8211.7 kWh)
# H3 881ea45025fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45107fffff: 7 colonnine, 3888.0 kWh coperti su 4085.2 kWh (Domanda agg: 4085.2 kWh)
# H3 881ea4515dfffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45ad7fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea451edfffff: 10 colonnine, 5554.3 kWh coperti su 5742.8 kWh (Domanda agg: 5742.8 kWh)
# H3 881ea45133fffff: 10 colonnine, 5554.3 kWh coperti su 6439.4 kWh (Domanda agg: 6439.4 kWh)
# H3 881ea45a99fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea4511dfffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea4513dfffff: 10 colonnine, 5554.3 kWh coperti su 6153.7 kWh (Domanda agg: 6153.7 kWh)
# H3 881ea45103fffff: 10 colonnine, 5554.3 kWh coperti su 10061.9 kWh (Domanda agg: 10061.9 kWh)
# H3 881ea451a1fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45151fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45147fffff: 10 colonnine, 5554.3 kWh coperti su 7880.7 kWh (Domanda agg: 7880.7 kWh)
# H3 881ea4511bfffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45143fffff: 7 colonnine, 3888.0 kWh coperti su 4421.5 kWh (Domanda agg: 4421.5 kWh)
# H3 881ea45ac9fffff: 10 colonnine, 5554.3 kWh coperti su 5667.9 kWh (Domanda agg: 5667.9 kWh)
# H3 881ea4514bfffff: 9 colonnine, 4998.9 kWh coperti su 5006.0 kWh (Domanda agg: 5006.0 kWh)
# H3 881ea45a87fffff: 6 colonnine, 3332.6 kWh coperti su 3418.7 kWh (Domanda agg: 3418.7 kWh)
# H3 881ea4515bfffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45ad9fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45117fffff: 10 colonnine, 5554.3 kWh coperti su 9157.8 kWh (Domanda agg: 9157.8 kWh)
# H3 881ea451abfffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea451e5fffff: 10 colonnine, 5554.3 kWh coperti su 6543.8 kWh (Domanda agg: 6543.8 kWh)
# H3 881ea45065fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45129fffff: 10 colonnine, 5554.3 kWh coperti su 8419.3 kWh (Domanda agg: 8419.3 kWh)
# H3 881ea451adfffff: 10 colonnine, 5554.3 kWh coperti su 5837.6 kWh (Domanda agg: 5837.6 kWh)
# H3 881ea45115fffff: 10 colonnine, 5554.3 kWh coperti su 8971.1 kWh (Domanda agg: 8971.1 kWh)
# H3 881ea45ad3fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45111fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45169fffff: 10 colonnine, 5554.3 kWh coperti su 6259.6 kWh (Domanda agg: 6259.6 kWh)
# H3 881ea451e9fffff: 8 colonnine, 4443.4 kWh coperti su 4808.3 kWh (Domanda agg: 4808.3 kWh)
# H3 881ea45337fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea4512bfffff: 10 colonnine, 5554.3 kWh coperti su 8339.4 kWh (Domanda agg: 8339.4 kWh)
# H3 881ea4514dfffff: 10 colonnine, 5554.3 kWh coperti su 5769.0 kWh (Domanda agg: 5769.0 kWh)
# H3 881ea45139fffff: 10 colonnine, 5554.3 kWh coperti su 7289.7 kWh (Domanda agg: 7289.7 kWh)
# H3 881ea45adbfffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45145fffff: 8 colonnine, 4443.4 kWh coperti su 4692.4 kWh (Domanda agg: 4692.4 kWh)
# H3 881ea45167fffff: 10 colonnine, 5554.3 kWh coperti su 6069.0 kWh (Domanda agg: 6069.0 kWh)
# H3 881ea45ac1fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45163fffff: 10 colonnine, 5554.3 kWh coperti su 8279.8 kWh (Domanda agg: 8279.8 kWh)
# H3 881ea45113fffff: 10 colonnine, 5554.3 kWh coperti su 6193.3 kWh (Domanda agg: 6193.3 kWh)
# H3 881ea45101fffff: 10 colonnine, 5554.3 kWh coperti su 9307.1 kWh (Domanda agg: 9307.1 kWh)
# H3 881ea45131fffff: 10 colonnine, 5554.3 kWh coperti su 9175.6 kWh (Domanda agg: 9175.6 kWh)
# H3 881ea45123fffff: 8 colonnine, 4443.4 kWh coperti su 4958.1 kWh (Domanda agg: 4958.1 kWh)
# H3 881ea4516bfffff: 10 colonnine, 5554.3 kWh coperti su 10775.3 kWh (Domanda agg: 10775.3 kWh)
# H3 881ea451ebfffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea4510bfffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45137fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45b53fffff: 8 colonnine, 4443.4 kWh coperti su 4486.8 kWh (Domanda agg: 4486.8 kWh)
# H3 881f9925e7fffff: 10 colonnine, 5554.3 kWh coperti su 5647.0 kWh (Domanda agg: 5647.0 kWh)
# H3 881f992ec5fffff: 10 colonnine, 5554.3 kWh coperti su 5575.0 kWh (Domanda agg: 5575.0 kWh)
# H3 881f992583fffff: 9 colonnine, 4998.9 kWh coperti su 5303.1 kWh (Domanda agg: 5303.1 kWh)
# H3 881f992515fffff: 7 colonnine, 3888.0 kWh coperti su 4278.0 kWh (Domanda agg: 4278.0 kWh)
# H3 881f992ed3fffff: 10 colonnine, 5554.3 kWh coperti su 5648.8 kWh (Domanda agg: 5648.8 kWh)
# H3 881f992e9bfffff: 10 colonnine, 5554.3 kWh coperti su 5879.6 kWh (Domanda agg: 5879.6 kWh)
# H3 881ea45b65fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881ea45b09fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f992527fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881ea45b4dfffff: 10 colonnine, 5554.3 kWh coperti su 7778.4 kWh (Domanda agg: 7778.4 kWh)
# H3 881f9925adfffff: 10 colonnine, 5554.3 kWh coperti su 6288.0 kWh (Domanda agg: 6288.0 kWh)
# H3 881f992505fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f9925edfffff: 10 colonnine, 5554.3 kWh coperti su 6785.3 kWh (Domanda agg: 6785.3 kWh)
# H3 881f9925a3fffff: 10 colonnine, 5554.3 kWh coperti su 6471.5 kWh (Domanda agg: 6471.5 kWh)
# H3 881ea45b67fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f9925e1fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f9925abfffff: 10 colonnine, 5554.3 kWh coperti su 8957.2 kWh (Domanda agg: 8957.2 kWh)
# H3 881f992587fffff: 9 colonnine, 4998.9 kWh coperti su 5272.8 kWh (Domanda agg: 5272.8 kWh)
# H3 881f992ed5fffff: 10 colonnine, 5554.3 kWh coperti su 6222.2 kWh (Domanda agg: 6222.2 kWh)
# H3 881f992e99fffff: 10 colonnine, 5554.3 kWh coperti su 8834.3 kWh (Domanda agg: 8834.3 kWh)
# H3 881f9925a7fffff: 10 colonnine, 5554.3 kWh coperti su 5558.2 kWh (Domanda agg: 5558.2 kWh)
# H3 881f992e83fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f9925b3fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f992eb9fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881ea45b4bfffff: 8 colonnine, 4443.4 kWh coperti su 4791.4 kWh (Domanda agg: 4791.4 kWh)
# H3 881f992581fffff: 6 colonnine, 3332.6 kWh coperti su 3675.8 kWh (Domanda agg: 3675.8 kWh)
# H3 881f9925bdfffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881ea45b01fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f992eddfffff: 6 colonnine, 3332.6 kWh coperti su 3460.7 kWh (Domanda agg: 3460.7 kWh)
# H3 881f9925ebfffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881ea45b63fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f9925a1fffff: 10 colonnine, 5554.3 kWh coperti su 8130.6 kWh (Domanda agg: 8130.6 kWh)
# H3 881f992503fffff: 8 colonnine, 4443.4 kWh coperti su 4822.6 kWh (Domanda agg: 4822.6 kWh)
# H3 881f992ec1fffff: 10 colonnine, 5554.3 kWh coperti su 6668.5 kWh (Domanda agg: 6668.5 kWh)
# H3 881ea45a2dfffff: 4 colonnine, 2221.7 kWh coperti su 2472.0 kWh (Domanda agg: 2472.0 kWh)
# H3 881ea45b6dfffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881ea45b55fffff: 10 colonnine, 5554.3 kWh coperti su 8450.4 kWh (Domanda agg: 8450.4 kWh)
# H3 881f992509fffff: 10 colonnine, 5554.3 kWh coperti su 7581.2 kWh (Domanda agg: 7581.2 kWh)
# H3 881f992ec7fffff: 7 colonnine, 3888.0 kWh coperti su 4430.3 kWh (Domanda agg: 4430.3 kWh)
# H3 881f992585fffff: 8 colonnine, 4443.4 kWh coperti su 4886.8 kWh (Domanda agg: 4886.8 kWh)
# H3 881ea45b6bfffff: 7 colonnine, 3888.0 kWh coperti su 4431.2 kWh (Domanda agg: 4431.2 kWh)
# H3 881f9925e5fffff: 10 colonnine, 5554.3 kWh coperti su 12361.1 kWh (Domanda agg: 12361.1 kWh)
# H3 881f992589fffff: 8 colonnine, 4443.4 kWh coperti su 4641.0 kWh (Domanda agg: 4641.0 kWh)
# H3 881f992ec3fffff: 10 colonnine, 5554.3 kWh coperti su 5645.1 kWh (Domanda agg: 5645.1 kWh)
# H3 881f992521fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f992ec9fffff: 7 colonnine, 3888.0 kWh coperti su 4295.1 kWh (Domanda agg: 4295.1 kWh)
# H3 881ea45b57fffff: 8 colonnine, 4443.4 kWh coperti su 4686.3 kWh (Domanda agg: 4686.3 kWh)
# H3 881f9925a5fffff: 10 colonnine, 5554.3 kWh coperti su 6410.5 kWh (Domanda agg: 6410.5 kWh)
# H3 881ea45b51fffff: 8 colonnine, 4443.4 kWh coperti su 4881.5 kWh (Domanda agg: 4881.5 kWh)
# H3 881f992529fffff: 8 colonnine, 4443.4 kWh coperti su 4998.0 kWh (Domanda agg: 4998.0 kWh)
# H3 881f992e81fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f992523fffff: 8 colonnine, 4443.4 kWh coperti su 4928.8 kWh (Domanda agg: 4928.8 kWh)
# H3 881ea45b43fffff: 10 colonnine, 5554.3 kWh coperti su 7863.9 kWh (Domanda agg: 7863.9 kWh)
# H3 881f99253dfffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f992ecbfffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881ea45b41fffff: 10 colonnine, 5554.3 kWh coperti su 5572.5 kWh (Domanda agg: 5572.5 kWh)
# H3 881f99251dfffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f9925e9fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f9925b5fffff: 10 colonnine, 5554.3 kWh coperti su 6788.9 kWh (Domanda agg: 6788.9 kWh)
# H3 881f992eb3fffff: 6 colonnine, 3332.6 kWh coperti su 3878.4 kWh (Domanda agg: 3878.4 kWh)
# H3 881f992edbfffff: 7 colonnine, 3888.0 kWh coperti su 4427.0 kWh (Domanda agg: 4427.0 kWh)
# H3 881f992ed1fffff: 6 colonnine, 3332.6 kWh coperti su 3461.8 kWh (Domanda agg: 3461.8 kWh)
# H3 881f99362bfffff: 5 colonnine, 2777.2 kWh coperti su 2857.3 kWh (Domanda agg: 2857.3 kWh)
# H3 881f9936e9fffff: 4 colonnine, 2221.7 kWh coperti su 2670.1 kWh (Domanda agg: 2670.1 kWh)
# H3 881f9936edfffff: 6 colonnine, 3332.6 kWh coperti su 3510.0 kWh (Domanda agg: 3510.0 kWh)
# H3 881f993639fffff: 3 colonnine, 1666.3 kWh coperti su 2009.2 kWh (Domanda agg: 2009.2 kWh)
# H3 881f99363bfffff: 9 colonnine, 4998.9 kWh coperti su 5030.7 kWh (Domanda agg: 5030.7 kWh)
# H3 881f993685fffff: 4 colonnine, 2221.7 kWh coperti su 2558.6 kWh (Domanda agg: 2558.6 kWh)
# H3 881f99069dfffff: 2 colonnine, 1110.9 kWh coperti su 1367.2 kWh (Domanda agg: 1367.2 kWh)
# H3 881f9904c3fffff: 2 colonnine, 1110.9 kWh coperti su 1367.2 kWh (Domanda agg: 1367.2 kWh)
# H3 881f9906a3fffff: 10 colonnine, 5554.3 kWh coperti su 7337.0 kWh (Domanda agg: 7337.0 kWh)
# H3 881f993369fffff: 10 colonnine, 5554.3 kWh coperti su 5751.8 kWh (Domanda agg: 5751.8 kWh)
# H3 881f9906bdfffff: 10 colonnine, 5554.3 kWh coperti su 7895.7 kWh (Domanda agg: 7895.7 kWh)
# H3 881f990687fffff: 10 colonnine, 5554.3 kWh coperti su 6133.4 kWh (Domanda agg: 6133.4 kWh)
# H3 881f9906abfffff: 10 colonnine, 5554.3 kWh coperti su 8791.6 kWh (Domanda agg: 8791.6 kWh)
# H3 881f990697fffff: 10 colonnine, 5554.3 kWh coperti su 6744.0 kWh (Domanda agg: 6744.0 kWh)
# H3 881f993133fffff: 6 colonnine, 3332.6 kWh coperti su 3386.7 kWh (Domanda agg: 3386.7 kWh)
# H3 881f99311dfffff: 10 colonnine, 5554.3 kWh coperti su 7662.3 kWh (Domanda agg: 7662.3 kWh)
# H3 881f99311bfffff: 2 colonnine, 1110.9 kWh coperti su 1233.9 kWh (Domanda agg: 1233.9 kWh)
# H3 881f993155fffff: 10 colonnine, 5554.3 kWh coperti su 6329.9 kWh (Domanda agg: 6329.9 kWh)
# H3 881f9931cdfffff: 2 colonnine, 1110.9 kWh coperti su 1233.9 kWh (Domanda agg: 1233.9 kWh)
# H3 881f993a4bfffff: 10 colonnine, 5554.3 kWh coperti su 6100.4 kWh (Domanda agg: 6100.4 kWh)
# H3 881f993a5dfffff: 10 colonnine, 5554.3 kWh coperti su 5716.7 kWh (Domanda agg: 5716.7 kWh)
# H3 881f993a51fffff: 10 colonnine, 5554.3 kWh coperti su 6195.9 kWh (Domanda agg: 6195.9 kWh)
# H3 881f9904b7fffff: 10 colonnine, 5554.3 kWh coperti su 7776.3 kWh (Domanda agg: 7776.3 kWh)
# H3 881f993161fffff: 4 colonnine, 2221.7 kWh coperti su 2732.9 kWh (Domanda agg: 2732.9 kWh)
# H3 881f9904b3fffff: 10 colonnine, 5554.3 kWh coperti su 7158.4 kWh (Domanda agg: 7158.4 kWh)
# H3 881f992e31fffff: 4 colonnine, 2221.7 kWh coperti su 2415.0 kWh (Domanda agg: 2415.0 kWh)
# H3 881f9920b3fffff: 2 colonnine, 1110.9 kWh coperti su 1495.7 kWh (Domanda agg: 1495.7 kWh)
# H3 881f992c43fffff: 2 colonnine, 1110.9 kWh coperti su 1495.7 kWh (Domanda agg: 1495.7 kWh)
# H3 881f9920b1fffff: 2 colonnine, 1110.9 kWh coperti su 1495.7 kWh (Domanda agg: 1495.7 kWh)
# H3 881f992c4dfffff: 2 colonnine, 1110.9 kWh coperti su 1495.7 kWh (Domanda agg: 1495.7 kWh)
# H3 881f992087fffff: 5 colonnine, 2777.2 kWh coperti su 3298.0 kWh (Domanda agg: 3298.0 kWh)
# H3 881f992e15fffff: 10 colonnine, 5554.3 kWh coperti su 6154.2 kWh (Domanda agg: 6154.2 kWh)
# H3 881f992e29fffff: 8 colonnine, 4443.4 kWh coperti su 4943.4 kWh (Domanda agg: 4943.4 kWh)
# H3 881f992c59fffff: 4 colonnine, 2221.7 kWh coperti su 2380.9 kWh (Domanda agg: 2380.9 kWh)
# H3 881f992e03fffff: 10 colonnine, 5554.3 kWh coperti su 7463.2 kWh (Domanda agg: 7463.2 kWh)
# H3 881f992e0bfffff: 10 colonnine, 5554.3 kWh coperti su 7470.1 kWh (Domanda agg: 7470.1 kWh)
# H3 881f992e43fffff: 10 colonnine, 5554.3 kWh coperti su 6629.7 kWh (Domanda agg: 6629.7 kWh)
# H3 881f992e1dfffff: 4 colonnine, 2221.7 kWh coperti su 2550.3 kWh (Domanda agg: 2550.3 kWh)
# H3 881f992567fffff: 2 colonnine, 1110.9 kWh coperti su 1495.7 kWh (Domanda agg: 1495.7 kWh)
# H3 881ea45a03fffff: 1 colonnine, 555.4 kWh coperti su 1088.7 kWh (Domanda agg: 1088.7 kWh)
# H3 881f9924cbfffff: 2 colonnine, 1110.9 kWh coperti su 1253.1 kWh (Domanda agg: 1253.1 kWh)
# H3 881f992483fffff: 10 colonnine, 5554.3 kWh coperti su 6151.0 kWh (Domanda agg: 6151.0 kWh)
# H3 881ea45ab5fffff: 1 colonnine, 555.4 kWh coperti su 1088.7 kWh (Domanda agg: 1088.7 kWh)
# H3 881ea45125fffff: 1 colonnine, 555.4 kWh coperti su 1088.7 kWh (Domanda agg: 1088.7 kWh)
# H3 881ea45a47fffff: 5 colonnine, 2777.2 kWh coperti su 2862.3 kWh (Domanda agg: 2862.3 kWh)
# H3 881ea4516dfffff: 10 colonnine, 5554.3 kWh coperti su 6974.5 kWh (Domanda agg: 6974.5 kWh)
# H3 881f9924bbfffff: 10 colonnine, 5554.3 kWh coperti su 6052.2 kWh (Domanda agg: 6052.2 kWh)
# H3 881f9924a1fffff: 1 colonnine, 555.4 kWh coperti su 1088.7 kWh (Domanda agg: 1088.7 kWh)
# H3 881f9924b1fffff: 10 colonnine, 5554.3 kWh coperti su 8054.7 kWh (Domanda agg: 8054.7 kWh)
# H3 881f992493fffff: 1 colonnine, 555.4 kWh coperti su 1088.7 kWh (Domanda agg: 1088.7 kWh)
# H3 881f9930b7fffff: 10 colonnine, 5554.3 kWh coperti su 6678.7 kWh (Domanda agg: 6678.7 kWh)
# H3 881f99308bfffff: 1 colonnine, 555.4 kWh coperti su 1070.9 kWh (Domanda agg: 1070.9 kWh)
# H3 881f9930bbfffff: 1 colonnine, 555.4 kWh coperti su 1070.9 kWh (Domanda agg: 1070.9 kWh)
# H3 881f99356dfffff: 4 colonnine, 2221.7 kWh coperti su 2290.9 kWh (Domanda agg: 2290.9 kWh)
# H3 881f993445fffff: 1 colonnine, 555.4 kWh coperti su 939.9 kWh (Domanda agg: 939.9 kWh)
# H3 881f99346bfffff: 1 colonnine, 555.4 kWh coperti su 939.9 kWh (Domanda agg: 939.9 kWh)
# H3 881f993713fffff: 1 colonnine, 555.4 kWh coperti su 939.9 kWh (Domanda agg: 939.9 kWh)
# H3 881f993447fffff: 1 colonnine, 555.4 kWh coperti su 939.9 kWh (Domanda agg: 939.9 kWh)
# H3 881f99a409fffff: 1 colonnine, 555.4 kWh coperti su 932.4 kWh (Domanda agg: 932.4 kWh)
# H3 881f99a621fffff: 4 colonnine, 2221.7 kWh coperti su 2711.8 kWh (Domanda agg: 2711.8 kWh)
# H3 881f99a719fffff: 10 colonnine, 5554.3 kWh coperti su 5625.5 kWh (Domanda agg: 5625.5 kWh)
# H3 881f99a71dfffff: 5 colonnine, 2777.2 kWh coperti su 3236.9 kWh (Domanda agg: 3236.9 kWh)
# H3 881f99a403fffff: 1 colonnine, 555.4 kWh coperti su 932.4 kWh (Domanda agg: 932.4 kWh)
# H3 881f99a663fffff: 1 colonnine, 555.4 kWh coperti su 932.4 kWh (Domanda agg: 932.4 kWh)
# H3 881f99a73bfffff: 2 colonnine, 1110.9 kWh coperti su 1623.2 kWh (Domanda agg: 1623.2 kWh)
# H3 881f993037fffff: 1 colonnine, 555.4 kWh coperti su 1027.8 kWh (Domanda agg: 1027.8 kWh)
# H3 881f992f27fffff: 2 colonnine, 1110.9 kWh coperti su 1203.4 kWh (Domanda agg: 1203.4 kWh)
# H3 881f9921b1fffff: 4 colonnine, 2221.7 kWh coperti su 2554.4 kWh (Domanda agg: 2554.4 kWh)
# H3 881f992f1bfffff: 2 colonnine, 1110.9 kWh coperti su 1203.4 kWh (Domanda agg: 1203.4 kWh)
# H3 881f992f01fffff: 5 colonnine, 2777.2 kWh coperti su 2790.5 kWh (Domanda agg: 2790.5 kWh)
# H3 881f992f31fffff: 3 colonnine, 1666.3 kWh coperti su 1787.7 kWh (Domanda agg: 1787.7 kWh)
# H3 881f992f29fffff: 2 colonnine, 1110.9 kWh coperti su 1203.4 kWh (Domanda agg: 1203.4 kWh)
# H3 881f992c69fffff: 5 colonnine, 2777.2 kWh coperti su 2995.3 kWh (Domanda agg: 2995.3 kWh)
# H3 881f9921b7fffff: 4 colonnine, 2221.7 kWh coperti su 2551.4 kWh (Domanda agg: 2551.4 kWh)
# H3 881f992f43fffff: 6 colonnine, 3332.6 kWh coperti su 3840.8 kWh (Domanda agg: 3840.8 kWh)
# H3 881f9921a3fffff: 2 colonnine, 1110.9 kWh coperti su 1203.4 kWh (Domanda agg: 1203.4 kWh)
# H3 881f992f45fffff: 5 colonnine, 2777.2 kWh coperti su 3251.5 kWh (Domanda agg: 3251.5 kWh)
# H3 881f9921bbfffff: 2 colonnine, 1110.9 kWh coperti su 1203.4 kWh (Domanda agg: 1203.4 kWh)
# H3 881f992703fffff: 6 colonnine, 3332.6 kWh coperti su 3418.3 kWh (Domanda agg: 3418.3 kWh)
# H3 881f992667fffff: 1 colonnine, 555.4 kWh coperti su 947.2 kWh (Domanda agg: 947.2 kWh)
# H3 881f992759fffff: 1 colonnine, 555.4 kWh coperti su 947.2 kWh (Domanda agg: 947.2 kWh)
# H3 881f99375bfffff: 4 colonnine, 2221.7 kWh coperti su 2615.7 kWh (Domanda agg: 2615.7 kWh)
# H3 881f99362dfffff: 1 colonnine, 555.4 kWh coperti su 669.1 kWh (Domanda agg: 669.1 kWh)
# H3 881f99ad81fffff: 1 colonnine, 555.4 kWh coperti su 669.1 kWh (Domanda agg: 669.1 kWh)
# H3 881ea45b3dfffff: 3 colonnine, 1666.3 kWh coperti su 2029.1 kWh (Domanda agg: 2029.1 kWh)
# H3 881ea45b3bfffff: 4 colonnine, 2221.7 kWh coperti su 2329.9 kWh (Domanda agg: 2329.9 kWh)
# H3 881ea4596bfffff: 3 colonnine, 1666.3 kWh coperti su 1825.7 kWh (Domanda agg: 1825.7 kWh)
# H3 881ea45b35fffff: 7 colonnine, 3888.0 kWh coperti su 3925.5 kWh (Domanda agg: 3925.5 kWh)
# H3 881ea45955fffff: 1 colonnine, 555.4 kWh coperti su 1062.1 kWh (Domanda agg: 1062.1 kWh)
# H3 881ea45b15fffff: 5 colonnine, 2777.2 kWh coperti su 3283.4 kWh (Domanda agg: 3283.4 kWh)
# H3 881ea45b37fffff: 5 colonnine, 2777.2 kWh coperti su 3147.6 kWh (Domanda agg: 3147.6 kWh)
# H3 881f992c97fffff: 1 colonnine, 555.4 kWh coperti su 1062.1 kWh (Domanda agg: 1062.1 kWh)
# H3 881ea45b23fffff: 5 colonnine, 2777.2 kWh coperti su 3055.8 kWh (Domanda agg: 3055.8 kWh)
# H3 881ea45909fffff: 2 colonnine, 1110.9 kWh coperti su 1180.3 kWh (Domanda agg: 1180.3 kWh)
# H3 881f9925d5fffff: 6 colonnine, 3332.6 kWh coperti su 3534.6 kWh (Domanda agg: 3534.6 kWh)
# H3 881f992407fffff: 6 colonnine, 3332.6 kWh coperti su 3734.0 kWh (Domanda agg: 3734.0 kWh)
# H3 881f992595fffff: 3 colonnine, 1666.3 kWh coperti su 2003.7 kWh (Domanda agg: 2003.7 kWh)
# H3 881ea45a6dfffff: 1 colonnine, 555.4 kWh coperti su 864.2 kWh (Domanda agg: 864.2 kWh)
# H3 881f992431fffff: 4 colonnine, 2221.7 kWh coperti su 2376.0 kWh (Domanda agg: 2376.0 kWh)
# H3 881f9925c3fffff: 1 colonnine, 555.4 kWh coperti su 864.2 kWh (Domanda agg: 864.2 kWh)
# H3 881f99255bfffff: 1 colonnine, 555.4 kWh coperti su 864.2 kWh (Domanda agg: 864.2 kWh)
# H3 881f99242bfffff: 3 colonnine, 1666.3 kWh coperti su 2177.1 kWh (Domanda agg: 2177.1 kWh)
# H3 881f9925d1fffff: 4 colonnine, 2221.7 kWh coperti su 2391.0 kWh (Domanda agg: 2391.0 kWh)
# H3 881f992599fffff: 1 colonnine, 555.4 kWh coperti su 864.2 kWh (Domanda agg: 864.2 kWh)
# H3 881f992427fffff: 3 colonnine, 1666.3 kWh coperti su 2013.4 kWh (Domanda agg: 2013.4 kWh)
# H3 881f9924e5fffff: 4 colonnine, 2221.7 kWh coperti su 2351.1 kWh (Domanda agg: 2351.1 kWh)
# H3 881f992591fffff: 4 colonnine, 2221.7 kWh coperti su 2231.3 kWh (Domanda agg: 2231.3 kWh)
# H3 881f992467fffff: 3 colonnine, 1666.3 kWh coperti su 2146.8 kWh (Domanda agg: 2146.8 kWh)
# H3 881f9925ddfffff: 5 colonnine, 2777.2 kWh coperti su 3314.9 kWh (Domanda agg: 3314.9 kWh)
# H3 881f992553fffff: 1 colonnine, 555.4 kWh coperti su 864.2 kWh (Domanda agg: 864.2 kWh)
# H3 881f9925dbfffff: 1 colonnine, 555.4 kWh coperti su 864.2 kWh (Domanda agg: 864.2 kWh)
# H3 881f9925c9fffff: 4 colonnine, 2221.7 kWh coperti su 2485.1 kWh (Domanda agg: 2485.1 kWh)
# H3 881f9925cdfffff: 2 colonnine, 1110.9 kWh coperti su 1651.5 kWh (Domanda agg: 1651.5 kWh)
# H3 881f99243bfffff: 6 colonnine, 3332.6 kWh coperti su 3552.5 kWh (Domanda agg: 3552.5 kWh)
# H3 881f9925c7fffff: 1 colonnine, 555.4 kWh coperti su 864.2 kWh (Domanda agg: 864.2 kWh)
# H3 881f992433fffff: 2 colonnine, 1110.9 kWh coperti su 1284.5 kWh (Domanda agg: 1284.5 kWh)
# H3 881f99246dfffff: 1 colonnine, 555.4 kWh coperti su 878.1 kWh (Domanda agg: 878.1 kWh)
# H3 881f992733fffff: 3 colonnine, 1666.3 kWh coperti su 1993.5 kWh (Domanda agg: 1993.5 kWh)
# H3 881f99244dfffff: 5 colonnine, 2777.2 kWh coperti su 3124.8 kWh (Domanda agg: 3124.8 kWh)
# H3 881f992443fffff: 1 colonnine, 555.4 kWh coperti su 878.1 kWh (Domanda agg: 878.1 kWh)
# H3 881f992621fffff: 4 colonnine, 2221.7 kWh coperti su 2274.8 kWh (Domanda agg: 2274.8 kWh)
# H3 881f992447fffff: 1 colonnine, 555.4 kWh coperti su 878.1 kWh (Domanda agg: 878.1 kWh)
# H3 881f992465fffff: 4 colonnine, 2221.7 kWh coperti su 2535.7 kWh (Domanda agg: 2535.7 kWh)
# H3 881f992623fffff: 4 colonnine, 2221.7 kWh coperti su 2740.5 kWh (Domanda agg: 2740.5 kWh)
# H3 881f99271bfffff: 5 colonnine, 2777.2 kWh coperti su 2902.9 kWh (Domanda agg: 2902.9 kWh)
# H3 881f99240dfffff: 3 colonnine, 1666.3 kWh coperti su 1937.4 kWh (Domanda agg: 1937.4 kWh)
# H3 881f992627fffff: 6 colonnine, 3332.6 kWh coperti su 3786.9 kWh (Domanda agg: 3786.9 kWh)
# H3 881f992713fffff: 8 colonnine, 4443.4 kWh coperti su 4569.9 kWh (Domanda agg: 4569.9 kWh)
# H3 881f992441fffff: 4 colonnine, 2221.7 kWh coperti su 2279.9 kWh (Domanda agg: 2279.9 kWh)
# H3 881f992629fffff: 1 colonnine, 555.4 kWh coperti su 878.1 kWh (Domanda agg: 878.1 kWh)
# H3 881f99218bfffff: 4 colonnine, 2221.7 kWh coperti su 2239.6 kWh (Domanda agg: 2239.6 kWh)
# H3 881f9921c5fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f9921e9fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f992199fffff: 4 colonnine, 2221.7 kWh coperti su 2421.7 kWh (Domanda agg: 2421.7 kWh)
# H3 881f9921ebfffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f9920e5fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f9921d3fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f992183fffff: 3 colonnine, 1666.3 kWh coperti su 2164.6 kWh (Domanda agg: 2164.6 kWh)
# H3 881f9921d1fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f992185fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f992113fffff: 5 colonnine, 2777.2 kWh coperti su 2870.3 kWh (Domanda agg: 2870.3 kWh)
# H3 881f9921ddfffff: 5 colonnine, 2777.2 kWh coperti su 3206.0 kWh (Domanda agg: 3206.0 kWh)
# H3 881f9921c3fffff: 5 colonnine, 2777.2 kWh coperti su 3235.5 kWh (Domanda agg: 3235.5 kWh)
# H3 881f9921c9fffff: 2 colonnine, 1110.9 kWh coperti su 1460.8 kWh (Domanda agg: 1460.8 kWh)
# H3 881f992adbfffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f99219bfffff: 4 colonnine, 2221.7 kWh coperti su 2433.0 kWh (Domanda agg: 2433.0 kWh)
# H3 881f9921abfffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f99218dfffff: 4 colonnine, 2221.7 kWh coperti su 2449.1 kWh (Domanda agg: 2449.1 kWh)
# H3 881f992181fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f9921a1fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f992187fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f992189fffff: 3 colonnine, 1666.3 kWh coperti su 2059.4 kWh (Domanda agg: 2059.4 kWh)
# H3 881f9921cbfffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f9921e5fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f9921edfffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f9921dbfffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f99219dfffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f992027fffff: 3 colonnine, 1666.3 kWh coperti su 1847.4 kWh (Domanda agg: 1847.4 kWh)
# H3 881f993937fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f9976c1fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993915fffff: 4 colonnine, 2221.7 kWh coperti su 2732.1 kWh (Domanda agg: 2732.1 kWh)
# H3 881f9939a3fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993821fffff: 3 colonnine, 1666.3 kWh coperti su 1718.6 kWh (Domanda agg: 1718.6 kWh)
# H3 881f9939c5fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993919fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f9939e9fffff: 5 colonnine, 2777.2 kWh coperti su 3126.1 kWh (Domanda agg: 3126.1 kWh)
# H3 881f993985fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f9939a5fffff: 3 colonnine, 1666.3 kWh coperti su 2082.6 kWh (Domanda agg: 2082.6 kWh)
# H3 881f993951fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f9939c1fffff: 4 colonnine, 2221.7 kWh coperti su 2571.2 kWh (Domanda agg: 2571.2 kWh)
# H3 881f993865fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f99390bfffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f992a4dfffff: 4 colonnine, 2221.7 kWh coperti su 2666.4 kWh (Domanda agg: 2666.4 kWh)
# H3 881f99382dfffff: 2 colonnine, 1110.9 kWh coperti su 1366.9 kWh (Domanda agg: 1366.9 kWh)
# H3 881f9976cbfffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f9939a7fffff: 3 colonnine, 1666.3 kWh coperti su 1885.7 kWh (Domanda agg: 1885.7 kWh)
# H3 881f993955fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993959fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f9939bdfffff: 2 colonnine, 1110.9 kWh coperti su 1662.8 kWh (Domanda agg: 1662.8 kWh)
# H3 881f993827fffff: 2 colonnine, 1110.9 kWh coperti su 1587.2 kWh (Domanda agg: 1587.2 kWh)
# H3 881f993935fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993957fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993823fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f99395bfffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993917fffff: 9 colonnine, 4998.9 kWh coperti su 5484.5 kWh (Domanda agg: 5484.5 kWh)
# H3 881f993903fffff: 3 colonnine, 1666.3 kWh coperti su 1951.4 kWh (Domanda agg: 1951.4 kWh)
# H3 881f9939bbfffff: 2 colonnine, 1110.9 kWh coperti su 1602.9 kWh (Domanda agg: 1602.9 kWh)
# H3 881f9939e3fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993953fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f9939adfffff: 4 colonnine, 2221.7 kWh coperti su 2284.1 kWh (Domanda agg: 2284.1 kWh)
# H3 881f99393bfffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993825fffff: 3 colonnine, 1666.3 kWh coperti su 1805.3 kWh (Domanda agg: 1805.3 kWh)
# H3 881f9939c9fffff: 4 colonnine, 2221.7 kWh coperti su 2502.1 kWh (Domanda agg: 2502.1 kWh)
# H3 881f993911fffff: 2 colonnine, 1110.9 kWh coperti su 1444.1 kWh (Domanda agg: 1444.1 kWh)
# H3 881f99398dfffff: 3 colonnine, 1666.3 kWh coperti su 2056.7 kWh (Domanda agg: 2056.7 kWh)
# H3 881f993993fffff: 3 colonnine, 1666.3 kWh coperti su 2037.8 kWh (Domanda agg: 2037.8 kWh)
# H3 881f993987fffff: 2 colonnine, 1110.9 kWh coperti su 1267.1 kWh (Domanda agg: 1267.1 kWh)
# H3 881f9939abfffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993933fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f99391dfffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f9939c7fffff: 3 colonnine, 1666.3 kWh coperti su 1696.3 kWh (Domanda agg: 1696.3 kWh)
# H3 881f993939fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881ea4c911fffff: 8 colonnine, 4443.4 kWh coperti su 4982.3 kWh (Domanda agg: 4982.3 kWh)
# H3 881ea4c907fffff: 1 colonnine, 555.4 kWh coperti su 768.9 kWh (Domanda agg: 768.9 kWh)
# H3 881ea4c9cdfffff: 4 colonnine, 2221.7 kWh coperti su 2677.2 kWh (Domanda agg: 2677.2 kWh)
# H3 881ea4cb31fffff: 1 colonnine, 555.4 kWh coperti su 768.9 kWh (Domanda agg: 768.9 kWh)
# H3 881ea4c91dfffff: 6 colonnine, 3332.6 kWh coperti su 3653.8 kWh (Domanda agg: 3653.8 kWh)
# H3 881ea4c943fffff: 3 colonnine, 1666.3 kWh coperti su 1850.0 kWh (Domanda agg: 1850.0 kWh)
# H3 881ea4c9c9fffff: 4 colonnine, 2221.7 kWh coperti su 2221.8 kWh (Domanda agg: 2221.8 kWh)
# H3 881ea4c93dfffff: 3 colonnine, 1666.3 kWh coperti su 1941.2 kWh (Domanda agg: 1941.2 kWh)
# H3 881ea4c933fffff: 3 colonnine, 1666.3 kWh coperti su 1883.1 kWh (Domanda agg: 1883.1 kWh)
# H3 881ea4c931fffff: 3 colonnine, 1666.3 kWh coperti su 1934.7 kWh (Domanda agg: 1934.7 kWh)
# H3 881ea4c909fffff: 1 colonnine, 555.4 kWh coperti su 768.9 kWh (Domanda agg: 768.9 kWh)
# H3 881ea4c915fffff: 3 colonnine, 1666.3 kWh coperti su 2217.4 kWh (Domanda agg: 2217.4 kWh)
# H3 881ea4c91bfffff: 4 colonnine, 2221.7 kWh coperti su 2356.4 kWh (Domanda agg: 2356.4 kWh)
# H3 881ea4c901fffff: 5 colonnine, 2777.2 kWh coperti su 3019.4 kWh (Domanda agg: 3019.4 kWh)
# H3 881ea4c951fffff: 8 colonnine, 4443.4 kWh coperti su 4709.2 kWh (Domanda agg: 4709.2 kWh)
# H3 881ea4c93bfffff: 3 colonnine, 1666.3 kWh coperti su 2093.7 kWh (Domanda agg: 2093.7 kWh)
# H3 881ea4c903fffff: 8 colonnine, 4443.4 kWh coperti su 4581.0 kWh (Domanda agg: 4581.0 kWh)
# H3 881ea4c90bfffff: 2 colonnine, 1110.9 kWh coperti su 1467.0 kWh (Domanda agg: 1467.0 kWh)
# H3 881ea4c905fffff: 1 colonnine, 555.4 kWh coperti su 768.9 kWh (Domanda agg: 768.9 kWh)
# H3 881ea4c92bfffff: 1 colonnine, 555.4 kWh coperti su 768.9 kWh (Domanda agg: 768.9 kWh)
# H3 881ea4c95bfffff: 1 colonnine, 555.4 kWh coperti su 768.9 kWh (Domanda agg: 768.9 kWh)
# H3 881ea4c955fffff: 5 colonnine, 2777.2 kWh coperti su 3275.4 kWh (Domanda agg: 3275.4 kWh)
# H3 881f992415fffff: 5 colonnine, 2777.2 kWh coperti su 2954.1 kWh (Domanda agg: 2954.1 kWh)
# H3 881f9926e3fffff: 1 colonnine, 555.4 kWh coperti su 795.3 kWh (Domanda agg: 795.3 kWh)
# H3 881f992403fffff: 4 colonnine, 2221.7 kWh coperti su 2350.4 kWh (Domanda agg: 2350.4 kWh)
# H3 881f992457fffff: 1 colonnine, 555.4 kWh coperti su 795.3 kWh (Domanda agg: 795.3 kWh)
# H3 881f992419fffff: 4 colonnine, 2221.7 kWh coperti su 2222.5 kWh (Domanda agg: 2222.5 kWh)
# H3 881f992401fffff: 3 colonnine, 1666.3 kWh coperti su 2140.3 kWh (Domanda agg: 2140.3 kWh)
# H3 881f9926b5fffff: 6 colonnine, 3332.6 kWh coperti su 3454.2 kWh (Domanda agg: 3454.2 kWh)
# H3 881f992411fffff: 1 colonnine, 555.4 kWh coperti su 795.3 kWh (Domanda agg: 795.3 kWh)
# H3 881f9924cdfffff: 1 colonnine, 555.4 kWh coperti su 795.3 kWh (Domanda agg: 795.3 kWh)
# H3 881f99241dfffff: 3 colonnine, 1666.3 kWh coperti su 1986.8 kWh (Domanda agg: 1986.8 kWh)
# H3 881f992455fffff: 2 colonnine, 1110.9 kWh coperti su 1663.4 kWh (Domanda agg: 1663.4 kWh)
# H3 881f992453fffff: 2 colonnine, 1110.9 kWh coperti su 1499.1 kWh (Domanda agg: 1499.1 kWh)
# H3 881f992451fffff: 4 colonnine, 2221.7 kWh coperti su 2633.8 kWh (Domanda agg: 2633.8 kWh)
# H3 881f992417fffff: 4 colonnine, 2221.7 kWh coperti su 2399.1 kWh (Domanda agg: 2399.1 kWh)
# H3 881f9926a3fffff: 6 colonnine, 3332.6 kWh coperti su 3639.6 kWh (Domanda agg: 3639.6 kWh)
# H3 881f9926e7fffff: 1 colonnine, 555.4 kWh coperti su 1016.5 kWh (Domanda agg: 1016.5 kWh)
# H3 881f99245dfffff: 5 colonnine, 2777.2 kWh coperti su 3259.7 kWh (Domanda agg: 3259.7 kWh)
# H3 881f9926a7fffff: 1 colonnine, 555.4 kWh coperti su 795.3 kWh (Domanda agg: 795.3 kWh)
# H3 881f9924c5fffff: 3 colonnine, 1666.3 kWh coperti su 1835.6 kWh (Domanda agg: 1835.6 kWh)
# H3 881f9924e9fffff: 3 colonnine, 1666.3 kWh coperti su 2118.7 kWh (Domanda agg: 2118.7 kWh)
# H3 881f99241bfffff: 1 colonnine, 555.4 kWh coperti su 795.3 kWh (Domanda agg: 795.3 kWh)
# H3 881f9926adfffff: 7 colonnine, 3888.0 kWh coperti su 4042.8 kWh (Domanda agg: 4042.8 kWh)
# H3 881f992413fffff: 1 colonnine, 555.4 kWh coperti su 795.3 kWh (Domanda agg: 795.3 kWh)
# H3 881f9924e1fffff: 7 colonnine, 3888.0 kWh coperti su 4296.4 kWh (Domanda agg: 4296.4 kWh)
# H3 881f9926abfffff: 3 colonnine, 1666.3 kWh coperti su 1971.4 kWh (Domanda agg: 1971.4 kWh)
# H3 881f9926a5fffff: 1 colonnine, 555.4 kWh coperti su 1021.2 kWh (Domanda agg: 1021.2 kWh)
# H3 881f9920d1fffff: 4 colonnine, 2221.7 kWh coperti su 2537.6 kWh (Domanda agg: 2537.6 kWh)
# H3 881f992549fffff: 3 colonnine, 1666.3 kWh coperti su 2015.5 kWh (Domanda agg: 2015.5 kWh)
# H3 881f992541fffff: 3 colonnine, 1666.3 kWh coperti su 2093.5 kWh (Domanda agg: 2093.5 kWh)
# H3 881f992731fffff: 2 colonnine, 1110.9 kWh coperti su 1654.4 kWh (Domanda agg: 1654.4 kWh)
# H3 881f992721fffff: 6 colonnine, 3332.6 kWh coperti su 3834.9 kWh (Domanda agg: 3834.9 kWh)
# H3 881f992767fffff: 3 colonnine, 1666.3 kWh coperti su 2196.1 kWh (Domanda agg: 2196.1 kWh)
# H3 881f992559fffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f99209bfffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f99208bfffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f992545fffff: 2 colonnine, 1110.9 kWh coperti su 1253.6 kWh (Domanda agg: 1253.6 kWh)
# H3 881f99256bfffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f99255dfffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f992099fffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f992725fffff: 3 colonnine, 1666.3 kWh coperti su 1796.5 kWh (Domanda agg: 1796.5 kWh)
# H3 881f99254dfffff: 3 colonnine, 1666.3 kWh coperti su 1957.8 kWh (Domanda agg: 1957.8 kWh)
# H3 881f992551fffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f99209dfffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f992095fffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f9920d3fffff: 4 colonnine, 2221.7 kWh coperti su 2253.0 kWh (Domanda agg: 2253.0 kWh)
# H3 881f9920dbfffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f992727fffff: 3 colonnine, 1666.3 kWh coperti su 1943.8 kWh (Domanda agg: 1943.8 kWh)
# H3 881f99272dfffff: 3 colonnine, 1666.3 kWh coperti su 1721.8 kWh (Domanda agg: 1721.8 kWh)
# ...
# H3 881ea4c829fffff: 2 colonnine, 1110.9 kWh coperti su 1252.1 kWh (Domanda agg: 1252.1 kWh)
# H3 881ea4c953fffff: 1 colonnine, 555.4 kWh coperti su 1105.2 kWh (Domanda agg: 1105.2 kWh)
# H3 881ea4c957fffff: 3 colonnine, 1666.3 kWh coperti su 1736.4 kWh (Domanda agg: 1736.4 kWh)
# H3 881ea4c801fffff: 1 colonnine, 555.4 kWh coperti su 813.4 kWh (Domanda agg: 813.4 kWh)
# H3 881ea4c825fffff: 2 colonnine, 1110.9 kWh coperti su 1649.3 kWh (Domanda agg: 1649.3 kWh)
# H3 881f992123fffff: 1 colonnine, 555.4 kWh coperti su 1006.4 kWh (Domanda agg: 1006.4 kWh)
# H3 881f992161fffff: 2 colonnine, 1110.9 kWh coperti su 1403.3 kWh (Domanda agg: 1403.3 kWh)
# H3 881f992a5bfffff: 1 colonnine, 555.4 kWh coperti su 799.7 kWh (Domanda agg: 799.7 kWh)
# H3 881f992a53fffff: 2 colonnine, 1110.9 kWh coperti su 1284.0 kWh (Domanda agg: 1284.0 kWh)
# H3 881f992101fffff: 2 colonnine, 1110.9 kWh coperti su 1185.5 kWh (Domanda agg: 1185.5 kWh)
# H3 881f992167fffff: 1 colonnine, 555.4 kWh coperti su 1059.0 kWh (Domanda agg: 1059.0 kWh)
# H3 881f992163fffff: 2 colonnine, 1110.9 kWh coperti su 1638.0 kWh (Domanda agg: 1638.0 kWh)
# H3 881f99210dfffff: 2 colonnine, 1110.9 kWh coperti su 1402.2 kWh (Domanda agg: 1402.2 kWh)
# H3 881f99216dfffff: 1 colonnine, 555.4 kWh coperti su 999.3 kWh (Domanda agg: 999.3 kWh)
# H3 881f992103fffff: 2 colonnine, 1110.9 kWh coperti su 1191.5 kWh (Domanda agg: 1191.5 kWh)
# H3 881f993aa9fffff: 1 colonnine, 555.4 kWh coperti su 644.0 kWh (Domanda agg: 644.0 kWh)
# H3 881f993ab3fffff: 1 colonnine, 555.4 kWh coperti su 1036.6 kWh (Domanda agg: 1036.6 kWh)
# H3 881f993aadfffff: 2 colonnine, 1110.9 kWh coperti su 1616.7 kWh (Domanda agg: 1616.7 kWh)
# H3 881f993aabfffff: 2 colonnine, 1110.9 kWh coperti su 1155.4 kWh (Domanda agg: 1155.4 kWh)
# H3 881f993a87fffff: 1 colonnine, 555.4 kWh coperti su 715.9 kWh (Domanda agg: 715.9 kWh)
# H3 881f993aa1fffff: 1 colonnine, 555.4 kWh coperti su 816.2 kWh (Domanda agg: 816.2 kWh)
# H3 881f993a8bfffff: 1 colonnine, 555.4 kWh coperti su 925.6 kWh (Domanda agg: 925.6 kWh)
# H3 881f992b57fffff: 1 colonnine, 555.4 kWh coperti su 778.8 kWh (Domanda agg: 778.8 kWh)
# H3 881f992b59fffff: 1 colonnine, 555.4 kWh coperti su 1000.5 kWh (Domanda agg: 1000.5 kWh)
# H3 881f992b0bfffff: 1 colonnine, 555.4 kWh coperti su 644.7 kWh (Domanda agg: 644.7 kWh)
# H3 881f997693fffff: 1 colonnine, 555.4 kWh coperti su 731.3 kWh (Domanda agg: 731.3 kWh)
# H3 881f992b45fffff: 1 colonnine, 555.4 kWh coperti su 583.3 kWh (Domanda agg: 583.3 kWh)
# H3 881f9939b1fffff: 1 colonnine, 555.4 kWh coperti su 864.4 kWh (Domanda agg: 864.4 kWh)
# H3 881f992b01fffff: 1 colonnine, 555.4 kWh coperti su 923.4 kWh (Domanda agg: 923.4 kWh)
# H3 881f992b03fffff: 1 colonnine, 555.4 kWh coperti su 993.6 kWh (Domanda agg: 993.6 kWh)
# H3 881f992b47fffff: 2 colonnine, 1110.9 kWh coperti su 1139.5 kWh (Domanda agg: 1139.5 kWh)
# H3 881f992b41fffff: 1 colonnine, 555.4 kWh coperti su 852.1 kWh (Domanda agg: 852.1 kWh)
# H3 881f992b6bfffff: 2 colonnine, 1110.9 kWh coperti su 1300.0 kWh (Domanda agg: 1300.0 kWh)
# H3 881f992b17fffff: 2 colonnine, 1110.9 kWh coperti su 1622.6 kWh (Domanda agg: 1622.6 kWh)
# H3 881f992b1dfffff: 2 colonnine, 1110.9 kWh coperti su 1428.4 kWh (Domanda agg: 1428.4 kWh)
# H3 881f9939b7fffff: 1 colonnine, 555.4 kWh coperti su 1084.9 kWh (Domanda agg: 1084.9 kWh)
# H3 881f992b0dfffff: 3 colonnine, 1666.3 kWh coperti su 1855.1 kWh (Domanda agg: 1855.1 kWh)
# H3 881f992b1bfffff: 1 colonnine, 555.4 kWh coperti su 860.3 kWh (Domanda agg: 860.3 kWh)
# H3 881f992b05fffff: 1 colonnine, 555.4 kWh coperti su 1069.0 kWh (Domanda agg: 1069.0 kWh)
# H3 881ea4c997fffff: 2 colonnine, 1110.9 kWh coperti su 1355.4 kWh (Domanda agg: 1355.4 kWh)
# H3 881ea45265fffff: 2 colonnine, 1110.9 kWh coperti su 1179.5 kWh (Domanda agg: 1179.5 kWh)
# H3 881ea4c993fffff: 1 colonnine, 555.4 kWh coperti su 1081.8 kWh (Domanda agg: 1081.8 kWh)
# H3 881f992017fffff: 1 colonnine, 555.4 kWh coperti su 753.8 kWh (Domanda agg: 753.8 kWh)
# H3 881f992007fffff: 1 colonnine, 555.4 kWh coperti su 971.7 kWh (Domanda agg: 971.7 kWh)
# H3 881f992039fffff: 1 colonnine, 555.4 kWh coperti su 1089.5 kWh (Domanda agg: 1089.5 kWh)
# H3 881f99208dfffff: 1 colonnine, 555.4 kWh coperti su 943.6 kWh (Domanda agg: 943.6 kWh)
# H3 881f9920a3fffff: 1 colonnine, 555.4 kWh coperti su 922.2 kWh (Domanda agg: 922.2 kWh)
# H3 881f9920a1fffff: 1 colonnine, 555.4 kWh coperti su 801.7 kWh (Domanda agg: 801.7 kWh)
# H3 881f9920e3fffff: 2 colonnine, 1110.9 kWh coperti su 1189.7 kWh (Domanda agg: 1189.7 kWh)
# H3 881f99a611fffff: 2 colonnine, 1110.9 kWh coperti su 1153.4 kWh (Domanda agg: 1153.4 kWh)
# H3 881f99a615fffff: 1 colonnine, 555.4 kWh coperti su 1040.3 kWh (Domanda agg: 1040.3 kWh)
# H3 881ea692dbfffff: 1 colonnine, 555.4 kWh coperti su 933.9 kWh (Domanda agg: 933.9 kWh)
# H3 881f992d57fffff: 1 colonnine, 555.4 kWh coperti su 918.0 kWh (Domanda agg: 918.0 kWh)
# H3 881f992d39fffff: 1 colonnine, 555.4 kWh coperti su 1058.4 kWh (Domanda agg: 1058.4 kWh)
# H3 881f992d33fffff: 2 colonnine, 1110.9 kWh coperti su 1555.1 kWh (Domanda agg: 1555.1 kWh)
# H3 881f992c27fffff: 1 colonnine, 555.4 kWh coperti su 735.5 kWh (Domanda agg: 735.5 kWh)
# H3 881f992d3bfffff: 1 colonnine, 555.4 kWh coperti su 886.5 kWh (Domanda agg: 886.5 kWh)
# H3 881f992c01fffff: 1 colonnine, 555.4 kWh coperti su 826.1 kWh (Domanda agg: 826.1 kWh)
# H3 881f992d15fffff: 1 colonnine, 555.4 kWh coperti su 565.8 kWh (Domanda agg: 565.8 kWh)
# H3 881f992c0dfffff: 1 colonnine, 555.4 kWh coperti su 800.7 kWh (Domanda agg: 800.7 kWh)
# H3 881f992dc7fffff: 1 colonnine, 555.4 kWh coperti su 1073.7 kWh (Domanda agg: 1073.7 kWh)
# H3 881f992dcdfffff: 1 colonnine, 555.4 kWh coperti su 937.2 kWh (Domanda agg: 937.2 kWh)
# H3 881f992c05fffff: 1 colonnine, 555.4 kWh coperti su 772.6 kWh (Domanda agg: 772.6 kWh)
# H3 881f992d17fffff: 2 colonnine, 1110.9 kWh coperti su 1483.7 kWh (Domanda agg: 1483.7 kWh)
# H3 881f992dedfffff: 2 colonnine, 1110.9 kWh coperti su 1541.4 kWh (Domanda agg: 1541.4 kWh)
# H3 881f992c2bfffff: 1 colonnine, 555.4 kWh coperti su 898.4 kWh (Domanda agg: 898.4 kWh)
# H3 881f99a991fffff: 1 colonnine, 555.4 kWh coperti su 807.5 kWh (Domanda agg: 807.5 kWh)
# H3 881f993849fffff: 1 colonnine, 555.4 kWh coperti su 597.2 kWh (Domanda agg: 597.2 kWh)
# H3 881f993b1bfffff: 1 colonnine, 555.4 kWh coperti su 902.9 kWh (Domanda agg: 902.9 kWh)
# H3 881f993a2bfffff: 1 colonnine, 555.4 kWh coperti su 833.9 kWh (Domanda agg: 833.9 kWh)
# H3 881f993829fffff: 1 colonnine, 555.4 kWh coperti su 709.6 kWh (Domanda agg: 709.6 kWh)
# H3 881f99354dfffff: 1 colonnine, 555.4 kWh coperti su 864.3 kWh (Domanda agg: 864.3 kWh)
# H3 881f99356bfffff: 1 colonnine, 555.4 kWh coperti su 785.4 kWh (Domanda agg: 785.4 kWh)
# H3 881f993545fffff: 1 colonnine, 555.4 kWh coperti su 807.4 kWh (Domanda agg: 807.4 kWh)
# H3 881ea45305fffff: 1 colonnine, 555.4 kWh coperti su 925.3 kWh (Domanda agg: 925.3 kWh)
# H3 881ea4532dfffff: 2 colonnine, 1110.9 kWh coperti su 1514.5 kWh (Domanda agg: 1514.5 kWh)
# H3 881ea45363fffff: 1 colonnine, 555.4 kWh coperti su 1049.6 kWh (Domanda agg: 1049.6 kWh)
# H3 881ea45321fffff: 1 colonnine, 555.4 kWh coperti su 949.7 kWh (Domanda agg: 949.7 kWh)
# H3 881f99a619fffff: 1 colonnine, 555.4 kWh coperti su 839.8 kWh (Domanda agg: 839.8 kWh)
# H3 881f99a603fffff: 1 colonnine, 555.4 kWh coperti su 882.4 kWh (Domanda agg: 882.4 kWh)
# H3 881f99a607fffff: 1 colonnine, 555.4 kWh coperti su 866.4 kWh (Domanda agg: 866.4 kWh)
# H3 881f99a09bfffff: 1 colonnine, 555.4 kWh coperti su 660.8 kWh (Domanda agg: 660.8 kWh)
# H3 881f99a54dfffff: 2 colonnine, 1110.9 kWh coperti su 1540.9 kWh (Domanda agg: 1540.9 kWh)
# H3 881f99a503fffff: 1 colonnine, 555.4 kWh coperti su 688.7 kWh (Domanda agg: 688.7 kWh)
# H3 881f992637fffff: 2 colonnine, 1110.9 kWh coperti su 1569.1 kWh (Domanda agg: 1569.1 kWh)
# H3 881f992631fffff: 2 colonnine, 1110.9 kWh coperti su 1356.6 kWh (Domanda agg: 1356.6 kWh)
# H3 881f99215bfffff: 1 colonnine, 555.4 kWh coperti su 990.8 kWh (Domanda agg: 990.8 kWh)
# H3 881f992021fffff: 1 colonnine, 555.4 kWh coperti su 981.2 kWh (Domanda agg: 981.2 kWh)
# H3 881ea4d351fffff: 2 colonnine, 1110.9 kWh coperti su 1658.4 kWh (Domanda agg: 1658.4 kWh)
# H3 881f8a69a5fffff: 2 colonnine, 1110.9 kWh coperti su 1356.9 kWh (Domanda agg: 1356.9 kWh)
# H3 881f8a693bfffff: 3 colonnine, 1666.3 kWh coperti su 1885.4 kWh (Domanda agg: 1885.4 kWh)
# H3 881f8a6939fffff: 3 colonnine, 1666.3 kWh coperti su 1768.9 kWh (Domanda agg: 1768.9 kWh)
# H3 881ea4d237fffff: 1 colonnine, 555.4 kWh coperti su 788.0 kWh (Domanda agg: 788.0 kWh)
# H3 881f8a6917fffff: 2 colonnine, 1110.9 kWh coperti su 1258.3 kWh (Domanda agg: 1258.3 kWh)
# H3 881f99a6dbfffff: 1 colonnine, 555.4 kWh coperti su 866.4 kWh (Domanda agg: 866.4 kWh)
# H3 881ea4d231fffff: 1 colonnine, 555.4 kWh coperti su 572.4 kWh (Domanda agg: 572.4 kWh)
# H3 881ea4d235fffff: 1 colonnine, 555.4 kWh coperti su 909.5 kWh (Domanda agg: 909.5 kWh)
# H3 881f8a6915fffff: 1 colonnine, 555.4 kWh coperti su 687.7 kWh (Domanda agg: 687.7 kWh)
# H3 881ea4d049fffff: 2 colonnine, 1110.9 kWh coperti su 1364.2 kWh (Domanda agg: 1364.2 kWh)
# H3 881ea69761fffff: 1 colonnine, 555.4 kWh coperti su 916.4 kWh (Domanda agg: 916.4 kWh)
# H3 881ea69749fffff: 1 colonnine, 555.4 kWh coperti su 805.8 kWh (Domanda agg: 805.8 kWh)
# H3 881ea69759fffff: 1 colonnine, 555.4 kWh coperti su 885.3 kWh (Domanda agg: 885.3 kWh)
# H3 881ea69299fffff: 2 colonnine, 1110.9 kWh coperti su 1262.3 kWh (Domanda agg: 1262.3 kWh)
# H3 881ea69291fffff: 2 colonnine, 1110.9 kWh coperti su 1277.5 kWh (Domanda agg: 1277.5 kWh)
# H3 881ea69745fffff: 1 colonnine, 555.4 kWh coperti su 870.2 kWh (Domanda agg: 870.2 kWh)
# H3 881ea692bbfffff: 1 colonnine, 555.4 kWh coperti su 790.9 kWh (Domanda agg: 790.9 kWh)
# H3 881ea69751fffff: 1 colonnine, 555.4 kWh coperti su 781.2 kWh (Domanda agg: 781.2 kWh)
# H3 881f992da5fffff: 1 colonnine, 555.4 kWh coperti su 899.3 kWh (Domanda agg: 899.3 kWh)
# H3 881ea69293fffff: 2 colonnine, 1110.9 kWh coperti su 1225.9 kWh (Domanda agg: 1225.9 kWh)
# H3 881ea6929dfffff: 1 colonnine, 555.4 kWh coperti su 1039.0 kWh (Domanda agg: 1039.0 kWh)
# H3 881ea692d3fffff: 1 colonnine, 555.4 kWh coperti su 765.0 kWh (Domanda agg: 765.0 kWh)
# H3 881ea69741fffff: 2 colonnine, 1110.9 kWh coperti su 1312.6 kWh (Domanda agg: 1312.6 kWh)
# H3 881f992a67fffff: 2 colonnine, 1110.9 kWh coperti su 1394.6 kWh (Domanda agg: 1394.6 kWh)
# H3 881f992a05fffff: 1 colonnine, 555.4 kWh coperti su 942.2 kWh (Domanda agg: 942.2 kWh)
# H3 881f992a03fffff: 2 colonnine, 1110.9 kWh coperti su 1621.2 kWh (Domanda agg: 1621.2 kWh)
# H3 881f992a29fffff: 2 colonnine, 1110.9 kWh coperti su 1159.0 kWh (Domanda agg: 1159.0 kWh)
# H3 881f992a63fffff: 2 colonnine, 1110.9 kWh coperti su 1290.5 kWh (Domanda agg: 1290.5 kWh)
# H3 881f8a634dfffff: 1 colonnine, 555.4 kWh coperti su 984.1 kWh (Domanda agg: 984.1 kWh)
# H3 881f99ac8bfffff: 1 colonnine, 555.4 kWh coperti su 815.4 kWh (Domanda agg: 815.4 kWh)
# H3 881f99ac83fffff: 1 colonnine, 555.4 kWh coperti su 583.7 kWh (Domanda agg: 583.7 kWh)
# H3 881f99acabfffff: 1 colonnine, 555.4 kWh coperti su 613.5 kWh (Domanda agg: 613.5 kWh)
# H3 881ea4d8a5fffff: 2 colonnine, 1110.9 kWh coperti su 1512.7 kWh (Domanda agg: 1512.7 kWh)
# H3 881ea4d9d7fffff: 1 colonnine, 555.4 kWh coperti su 730.9 kWh (Domanda agg: 730.9 kWh)
# H3 881ea4d8adfffff: 1 colonnine, 555.4 kWh coperti su 673.7 kWh (Domanda agg: 673.7 kWh)
# H3 881f99385bfffff: 1 colonnine, 555.4 kWh coperti su 868.3 kWh (Domanda agg: 868.3 kWh)
# H3 881f992ae9fffff: 1 colonnine, 555.4 kWh coperti su 699.1 kWh (Domanda agg: 699.1 kWh)
# H3 881f992ae1fffff: 1 colonnine, 555.4 kWh coperti su 848.3 kWh (Domanda agg: 848.3 kWh)
# H3 881f992ae7fffff: 1 colonnine, 555.4 kWh coperti su 675.8 kWh (Domanda agg: 675.8 kWh)
# H3 881f992a17fffff: 1 colonnine, 555.4 kWh coperti su 833.3 kWh (Domanda agg: 833.3 kWh)
# H3 881f992a1dfffff: 1 colonnine, 555.4 kWh coperti su 641.6 kWh (Domanda agg: 641.6 kWh)
# H3 881f992dd1fffff: 2 colonnine, 1110.9 kWh coperti su 1331.8 kWh (Domanda agg: 1331.8 kWh)
# H3 881f992dd5fffff: 2 colonnine, 1110.9 kWh coperti su 1175.8 kWh (Domanda agg: 1175.8 kWh)
# H3 881f992dd9fffff: 1 colonnine, 555.4 kWh coperti su 712.8 kWh (Domanda agg: 712.8 kWh)
# H3 881f992d9dfffff: 1 colonnine, 555.4 kWh coperti su 680.1 kWh (Domanda agg: 680.1 kWh)
# H3 881ea4cb55fffff: 1 colonnine, 555.4 kWh coperti su 641.1 kWh (Domanda agg: 641.1 kWh)
# H3 881ea4cb59fffff: 2 colonnine, 1110.9 kWh coperti su 1123.8 kWh (Domanda agg: 1123.8 kWh)
# H3 881ea4cb51fffff: 1 colonnine, 555.4 kWh coperti su 711.1 kWh (Domanda agg: 711.1 kWh)
# H3 881f9926edfffff: 1 colonnine, 555.4 kWh coperti su 951.5 kWh (Domanda agg: 951.5 kWh)
# H3 881f992825fffff: 1 colonnine, 555.4 kWh coperti su 747.2 kWh (Domanda agg: 747.2 kWh)
# H3 881f992829fffff: 1 colonnine, 555.4 kWh coperti su 591.8 kWh (Domanda agg: 591.8 kWh)
# H3 881f992911fffff: 1 colonnine, 555.4 kWh coperti su 822.6 kWh (Domanda agg: 822.6 kWh)
# H3 881f99a6cbfffff: 1 colonnine, 555.4 kWh coperti su 703.2 kWh (Domanda agg: 703.2 kWh)
# H3 881ea4d335fffff: 1 colonnine, 555.4 kWh coperti su 750.7 kWh (Domanda agg: 750.7 kWh)
# H3 881f99a6d1fffff: 1 colonnine, 555.4 kWh coperti su 792.3 kWh (Domanda agg: 792.3 kWh)
# H3 881ea4c26dfffff: 1 colonnine, 555.4 kWh coperti su 992.8 kWh (Domanda agg: 992.8 kWh)
# H3 881ea4d005fffff: 1 colonnine, 555.4 kWh coperti su 577.6 kWh (Domanda agg: 577.6 kWh)
# H3 881ea4d131fffff: 2 colonnine, 1110.9 kWh coperti su 1132.5 kWh (Domanda agg: 1132.5 kWh)
# H3 881f992345fffff: 1 colonnine, 555.4 kWh coperti su 654.8 kWh (Domanda agg: 654.8 kWh)
# H3 881f992369fffff: 2 colonnine, 1110.9 kWh coperti su 1323.0 kWh (Domanda agg: 1323.0 kWh)
# H3 881f992363fffff: 1 colonnine, 555.4 kWh coperti su 603.1 kWh (Domanda agg: 603.1 kWh)
# H3 881f9931a7fffff: 1 colonnine, 555.4 kWh coperti su 666.3 kWh (Domanda agg: 666.3 kWh)
# H3 881f992343fffff: 1 colonnine, 555.4 kWh coperti su 783.5 kWh (Domanda agg: 783.5 kWh)
# H3 881f99399bfffff: 1 colonnine, 555.4 kWh coperti su 732.3 kWh (Domanda agg: 732.3 kWh)
# H3 881f992689fffff: 1 colonnine, 555.4 kWh coperti su 697.7 kWh (Domanda agg: 697.7 kWh)
# H3 881f9930e1fffff: 1 colonnine, 555.4 kWh coperti su 616.9 kWh (Domanda agg: 616.9 kWh)
# H3 881f993017fffff: 2 colonnine, 1110.9 kWh coperti su 1139.6 kWh (Domanda agg: 1139.6 kWh)
# H3 881f9930c5fffff: 3 colonnine, 1666.3 kWh coperti su 1974.3 kWh (Domanda agg: 1974.3 kWh)
# H3 881ea4430dfffff: 1 colonnine, 555.4 kWh coperti su 788.5 kWh (Domanda agg: 788.5 kWh)
# H3 881ea44347fffff: 1 colonnine, 555.4 kWh coperti su 608.7 kWh (Domanda agg: 608.7 kWh)
# H3 881f99a511fffff: 1 colonnine, 555.4 kWh coperti su 804.4 kWh (Domanda agg: 804.4 kWh)
# H3 881ea4c99bfffff: 1 colonnine, 555.4 kWh coperti su 807.3 kWh (Domanda agg: 807.3 kWh)
# H3 881ea4c8adfffff: 1 colonnine, 555.4 kWh coperti su 787.7 kWh (Domanda agg: 787.7 kWh)
# H3 881ea4c8a5fffff: 1 colonnine, 555.4 kWh coperti su 801.6 kWh (Domanda agg: 801.6 kWh)
# H3 881ea4c9abfffff: 1 colonnine, 555.4 kWh coperti su 611.6 kWh (Domanda agg: 611.6 kWh)
# H3 881ea4c995fffff: 1 colonnine, 555.4 kWh coperti su 846.7 kWh (Domanda agg: 846.7 kWh)
# H3 881f992159fffff: 1 colonnine, 555.4 kWh coperti su 884.0 kWh (Domanda agg: 884.0 kWh)
# H3 881ea6966bfffff: 1 colonnine, 555.4 kWh coperti su 595.4 kWh (Domanda agg: 595.4 kWh)
# H3 881f99af17fffff: 1 colonnine, 555.4 kWh coperti su 789.4 kWh (Domanda agg: 789.4 kWh)
# H3 881f99af19fffff: 1 colonnine, 555.4 kWh coperti su 861.5 kWh (Domanda agg: 861.5 kWh)
# H3 881f8a78b7fffff: 1 colonnine, 555.4 kWh coperti su 1020.9 kWh (Domanda agg: 1020.9 kWh)
# H3 881ea6928bfffff: 1 colonnine, 555.4 kWh coperti su 604.6 kWh (Domanda agg: 604.6 kWh)
# H3 881ea4ce2dfffff: 1 colonnine, 555.4 kWh coperti su 645.9 kWh (Domanda agg: 645.9 kWh)
# H3 881ea4ce65fffff: 1 colonnine, 555.4 kWh coperti su 685.5 kWh (Domanda agg: 685.5 kWh)
# H3 881f8a693dfffff: 1 colonnine, 555.4 kWh coperti su 746.0 kWh (Domanda agg: 746.0 kWh)
# H3 881f99a709fffff: 1 colonnine, 555.4 kWh coperti su 698.0 kWh (Domanda agg: 698.0 kWh)
# H3 881f8a692bfffff: 1 colonnine, 555.4 kWh coperti su 774.0 kWh (Domanda agg: 774.0 kWh)
# H3 881ea4cb67fffff: 1 colonnine, 555.4 kWh coperti su 570.3 kWh (Domanda agg: 570.3 kWh)
#
# Domanda totale coperta: 2243381.77 kWh

# %% [markdown]
# ### Map visualisation

# %%
mappa = crea_mappa_colonnine_discrete(gdf_risultati_cons2030)
mappa
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Save the map as an HTML file
mappa.save("/content/drive/Shareddrives/OM in Business Analytics/OM in BA - Project/Codice/04 - Modello/log_heatmap_fourth_model_def.html")

# %% [markdown]
# ### Results

# %%
total_allocated_chargers = gdf_risultati_cons2030["Colonnine allocate"].sum()
total_covered_demand = gdf_risultati_cons2030["Domanda coperta (kWh)"].sum()
total_demand = gdf_risultati_cons2030["Domanda Giornaliera Ponderata (kWh)"].sum()

print(f"Total allocated charging stations: {total_allocated_chargers}")
print(f"Total covered demand (kWh): {total_covered_demand:.2f}")
print(f"Total demand (kWh): {total_demand:.2f}")
# Out:
# Total allocated charging stations: 4039
# Total covered demand (kWh): 2243381.77
# Total demand (kWh): 10009341.21

# %% [markdown]
# ## FIFTH MODEL
# ## Charging Station Allocation Model Alpha – 2030 Conservative Scenario

# %%
gdf_risultati_cons2030_alpha = ottimizza_colonnine_con_alpha(gdf_conservativo, p_colonnine=4039, alpha=0.167)
# Out:
# H3 881f99274bfffff: 10 colonnine, 5554.3 kWh coperti su 22330.9 kWh (Domanda agg: 22330.9 kWh)
# H3 881f992215fffff: 10 colonnine, 5554.3 kWh coperti su 28225.8 kWh (Domanda agg: 28225.8 kWh)
# H3 881f992213fffff: 10 colonnine, 5554.3 kWh coperti su 46257.9 kWh (Domanda agg: 46257.9 kWh)
# H3 881f9935c7fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f9935a1fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f9922ddfffff: 10 colonnine, 5554.3 kWh coperti su 75974.8 kWh (Domanda agg: 75974.8 kWh)
# H3 881f992285fffff: 10 colonnine, 5554.3 kWh coperti su 37835.5 kWh (Domanda agg: 37835.5 kWh)
# H3 881f9922e3fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f992217fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f993501fffff: 10 colonnine, 5554.3 kWh coperti su 48814.8 kWh (Domanda agg: 48814.8 kWh)
# H3 881f99353bfffff: 10 colonnine, 5554.3 kWh coperti su 79049.0 kWh (Domanda agg: 79049.0 kWh)
# H3 881f992295fffff: 10 colonnine, 5554.3 kWh coperti su 39223.8 kWh (Domanda agg: 39223.8 kWh)
# H3 881f9922cdfffff: 10 colonnine, 5554.3 kWh coperti su 57252.3 kWh (Domanda agg: 57252.3 kWh)
# H3 881f9920d9fffff: 10 colonnine, 5554.3 kWh coperti su 34265.4 kWh (Domanda agg: 34265.4 kWh)
# H3 881f992745fffff: 10 colonnine, 5554.3 kWh coperti su 35158.2 kWh (Domanda agg: 35158.2 kWh)
# H3 881f992291fffff: 10 colonnine, 5554.3 kWh coperti su 51503.7 kWh (Domanda agg: 51503.7 kWh)
# H3 881f992233fffff: 10 colonnine, 5554.3 kWh coperti su 48982.2 kWh (Domanda agg: 48982.2 kWh)
# H3 881f993537fffff: 10 colonnine, 5554.3 kWh coperti su 15131.1 kWh (Domanda agg: 15131.1 kWh)
# H3 881f993531fffff: 10 colonnine, 5554.3 kWh coperti su 57187.7 kWh (Domanda agg: 57187.7 kWh)
# H3 881f9922c9fffff: 10 colonnine, 5554.3 kWh coperti su 61610.4 kWh (Domanda agg: 61610.4 kWh)
# H3 881f992741fffff: 10 colonnine, 5554.3 kWh coperti su 51040.0 kWh (Domanda agg: 51040.0 kWh)
# H3 881f993511fffff: 10 colonnine, 5554.3 kWh coperti su 55197.7 kWh (Domanda agg: 55197.7 kWh)
# H3 881f99270dfffff: 10 colonnine, 5554.3 kWh coperti su 61119.5 kWh (Domanda agg: 61119.5 kWh)
# H3 881f992287fffff: 10 colonnine, 5554.3 kWh coperti su 22271.5 kWh (Domanda agg: 22271.5 kWh)
# H3 881f992253fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f992211fffff: 10 colonnine, 5554.3 kWh coperti su 62349.8 kWh (Domanda agg: 62349.8 kWh)
# H3 881f992231fffff: 10 colonnine, 5554.3 kWh coperti su 32097.7 kWh (Domanda agg: 32097.7 kWh)
# H3 881f9922d7fffff: 10 colonnine, 5554.3 kWh coperti su 42282.2 kWh (Domanda agg: 42282.2 kWh)
# H3 881f9935a7fffff: 10 colonnine, 5554.3 kWh coperti su 20346.9 kWh (Domanda agg: 20346.9 kWh)
# H3 881f99221bfffff: 10 colonnine, 5554.3 kWh coperti su 41326.1 kWh (Domanda agg: 41326.1 kWh)
# H3 881f992239fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f992761fffff: 10 colonnine, 5554.3 kWh coperti su 50170.5 kWh (Domanda agg: 50170.5 kWh)
# H3 881f9935a5fffff: 10 colonnine, 5554.3 kWh coperti su 49117.2 kWh (Domanda agg: 49117.2 kWh)
# H3 881f993557fffff: 10 colonnine, 5554.3 kWh coperti su 57997.5 kWh (Domanda agg: 57997.5 kWh)
# H3 881f9935e1fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f99358dfffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f9922b3fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f9922edfffff: 10 colonnine, 5554.3 kWh coperti su 36174.4 kWh (Domanda agg: 36174.4 kWh)
# H3 881f99223bfffff: 10 colonnine, 5554.3 kWh coperti su 37792.3 kWh (Domanda agg: 37792.3 kWh)
# H3 881f992283fffff: 10 colonnine, 5554.3 kWh coperti su 65894.3 kWh (Domanda agg: 65894.3 kWh)
# H3 881f993519fffff: 10 colonnine, 5554.3 kWh coperti su 57001.5 kWh (Domanda agg: 57001.5 kWh)
# H3 881f993553fffff: 10 colonnine, 5554.3 kWh coperti su 54146.6 kWh (Domanda agg: 54146.6 kWh)
# H3 881f993535fffff: 10 colonnine, 5554.3 kWh coperti su 45354.5 kWh (Domanda agg: 45354.5 kWh)
# H3 881f993585fffff: 10 colonnine, 5554.3 kWh coperti su 46692.9 kWh (Domanda agg: 46692.9 kWh)
# H3 881f993539fffff: 10 colonnine, 5554.3 kWh coperti su 59158.2 kWh (Domanda agg: 59158.2 kWh)
# H3 881f992203fffff: 10 colonnine, 5554.3 kWh coperti su 28519.0 kWh (Domanda agg: 28519.0 kWh)
# H3 881f9935e9fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f992299fffff: 10 colonnine, 5554.3 kWh coperti su 31154.5 kWh (Domanda agg: 31154.5 kWh)
# H3 881f9922d1fffff: 10 colonnine, 5554.3 kWh coperti su 106683.2 kWh (Domanda agg: 106683.2 kWh)
# H3 881f992251fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f993507fffff: 10 colonnine, 5554.3 kWh coperti su 84160.6 kWh (Domanda agg: 84160.6 kWh)
# H3 881f9922a9fffff: 10 colonnine, 5554.3 kWh coperti su 65120.1 kWh (Domanda agg: 65120.1 kWh)
# H3 881f992765fffff: 10 colonnine, 5554.3 kWh coperti su 36535.3 kWh (Domanda agg: 36535.3 kWh)
# H3 881f99229bfffff: 10 colonnine, 5554.3 kWh coperti su 71251.6 kWh (Domanda agg: 71251.6 kWh)
# H3 881f99276dfffff: 10 colonnine, 5554.3 kWh coperti su 52827.3 kWh (Domanda agg: 52827.3 kWh)
# H3 881f99353dfffff: 10 colonnine, 5554.3 kWh coperti su 66364.0 kWh (Domanda agg: 66364.0 kWh)
# H3 881f9922c7fffff: 10 colonnine, 5554.3 kWh coperti su 54608.6 kWh (Domanda agg: 54608.6 kWh)
# H3 881f993563fffff: 10 colonnine, 5554.3 kWh coperti su 32187.2 kWh (Domanda agg: 32187.2 kWh)
# H3 881f992293fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f99352bfffff: 10 colonnine, 5554.3 kWh coperti su 63888.0 kWh (Domanda agg: 63888.0 kWh)
# H3 881f9935cdfffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f993581fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f99351bfffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f992297fffff: 10 colonnine, 5554.3 kWh coperti su 35094.3 kWh (Domanda agg: 35094.3 kWh)
# H3 881f9922c5fffff: 10 colonnine, 5554.3 kWh coperti su 102115.3 kWh (Domanda agg: 102115.3 kWh)
# H3 881f992769fffff: 10 colonnine, 5554.3 kWh coperti su 47811.2 kWh (Domanda agg: 47811.2 kWh)
# H3 881f993425fffff: 10 colonnine, 5554.3 kWh coperti su 38847.3 kWh (Domanda agg: 38847.3 kWh)
# H3 881f9935adfffff: 10 colonnine, 5554.3 kWh coperti su 15614.0 kWh (Domanda agg: 15614.0 kWh)
# H3 881f992219fffff: 10 colonnine, 5554.3 kWh coperti su 69837.6 kWh (Domanda agg: 69837.6 kWh)
# H3 881f99274dfffff: 10 colonnine, 5554.3 kWh coperti su 64131.6 kWh (Domanda agg: 64131.6 kWh)
# H3 881f9922c1fffff: 10 colonnine, 5554.3 kWh coperti su 87208.4 kWh (Domanda agg: 87208.4 kWh)
# H3 881f993427fffff: 10 colonnine, 5554.3 kWh coperti su 21023.6 kWh (Domanda agg: 21023.6 kWh)
# H3 881f9922cbfffff: 10 colonnine, 5554.3 kWh coperti su 59957.8 kWh (Domanda agg: 59957.8 kWh)
# H3 881f993503fffff: 10 colonnine, 5554.3 kWh coperti su 55220.0 kWh (Domanda agg: 55220.0 kWh)
# H3 881f992237fffff: 10 colonnine, 5554.3 kWh coperti su 51989.0 kWh (Domanda agg: 51989.0 kWh)
# H3 881f99205bfffff: 10 colonnine, 5554.3 kWh coperti su 27888.4 kWh (Domanda agg: 27888.4 kWh)
# H3 881f9935a3fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f99229dfffff: 10 colonnine, 5554.3 kWh coperti su 45431.7 kWh (Domanda agg: 45431.7 kWh)
# H3 881f9935c5fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f99351dfffff: 10 colonnine, 5554.3 kWh coperti su 35097.8 kWh (Domanda agg: 35097.8 kWh)
# H3 881f993515fffff: 10 colonnine, 5554.3 kWh coperti su 53890.0 kWh (Domanda agg: 53890.0 kWh)
# H3 881f992749fffff: 10 colonnine, 5554.3 kWh coperti su 35891.4 kWh (Domanda agg: 35891.4 kWh)
# H3 881f9935e5fffff: 10 colonnine, 5554.3 kWh coperti su 33268.4 kWh (Domanda agg: 33268.4 kWh)
# H3 881f9935ebfffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f99352dfffff: 10 colonnine, 5554.3 kWh coperti su 41808.9 kWh (Domanda agg: 41808.9 kWh)
# H3 881f99228dfffff: 10 colonnine, 5554.3 kWh coperti su 83931.5 kWh (Domanda agg: 83931.5 kWh)
# H3 881f9935e3fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f993513fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f993567fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f9922adfffff: 10 colonnine, 5554.3 kWh coperti su 24606.0 kWh (Domanda agg: 24606.0 kWh)
# H3 881f9935e7fffff: 10 colonnine, 5554.3 kWh coperti su 65426.2 kWh (Domanda agg: 65426.2 kWh)
# H3 881f992747fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f99276bfffff: 10 colonnine, 5554.3 kWh coperti su 39810.2 kWh (Domanda agg: 39810.2 kWh)
# H3 881f993527fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f993529fffff: 10 colonnine, 5554.3 kWh coperti su 26637.1 kWh (Domanda agg: 26637.1 kWh)
# H3 881f992289fffff: 10 colonnine, 5554.3 kWh coperti su 59736.5 kWh (Domanda agg: 59736.5 kWh)
# H3 881f9935edfffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f9922d9fffff: 10 colonnine, 5554.3 kWh coperti su 122987.1 kWh (Domanda agg: 122987.1 kWh)
# H3 881f99350dfffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f992281fffff: 10 colonnine, 5554.3 kWh coperti su 101725.1 kWh (Domanda agg: 101725.1 kWh)
# H3 881f99228bfffff: 10 colonnine, 5554.3 kWh coperti su 44882.1 kWh (Domanda agg: 44882.1 kWh)
# H3 881f9922e1fffff: 10 colonnine, 5554.3 kWh coperti su 48331.2 kWh (Domanda agg: 48331.2 kWh)
# H3 881f9922d5fffff: 10 colonnine, 5554.3 kWh coperti su 51294.2 kWh (Domanda agg: 51294.2 kWh)
# H3 881f993505fffff: 10 colonnine, 5554.3 kWh coperti su 39951.3 kWh (Domanda agg: 39951.3 kWh)
# H3 881f993517fffff: 10 colonnine, 5554.3 kWh coperti su 35738.0 kWh (Domanda agg: 35738.0 kWh)
# H3 881f9935abfffff: 10 colonnine, 5554.3 kWh coperti su 14670.9 kWh (Domanda agg: 14670.9 kWh)
# H3 881f9922bbfffff: 10 colonnine, 5554.3 kWh coperti su 33010.9 kWh (Domanda agg: 33010.9 kWh)
# H3 881f9922d3fffff: 10 colonnine, 5554.3 kWh coperti su 67129.3 kWh (Domanda agg: 67129.3 kWh)
# H3 881f993521fffff: 10 colonnine, 5554.3 kWh coperti su 62718.3 kWh (Domanda agg: 62718.3 kWh)
# H3 881f9922ebfffff: 10 colonnine, 5554.3 kWh coperti su 66644.9 kWh (Domanda agg: 66644.9 kWh)
# H3 881f9922e9fffff: 10 colonnine, 5554.3 kWh coperti su 48411.5 kWh (Domanda agg: 48411.5 kWh)
# H3 881f993525fffff: 10 colonnine, 5554.3 kWh coperti su 35130.0 kWh (Domanda agg: 35130.0 kWh)
# H3 881f9935b5fffff: 10 colonnine, 5554.3 kWh coperti su 33723.8 kWh (Domanda agg: 33723.8 kWh)
# H3 881f9922c3fffff: 10 colonnine, 5554.3 kWh coperti su 46291.5 kWh (Domanda agg: 46291.5 kWh)
# H3 881f9922e7fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f9935a9fffff: 10 colonnine, 5554.3 kWh coperti su 74557.1 kWh (Domanda agg: 74557.1 kWh)
# H3 881f99225bfffff: 10 colonnine, 5554.3 kWh coperti su 40501.0 kWh (Domanda agg: 40501.0 kWh)
# H3 881f9922dbfffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f992059fffff: 10 colonnine, 5554.3 kWh coperti su 13905.7 kWh (Domanda agg: 13905.7 kWh)
# H3 881f9922e5fffff: 10 colonnine, 5554.3 kWh coperti su 33339.3 kWh (Domanda agg: 33339.3 kWh)
# H3 881f993523fffff: 10 colonnine, 5554.3 kWh coperti su 39311.8 kWh (Domanda agg: 39311.8 kWh)
# H3 881f993533fffff: 10 colonnine, 5554.3 kWh coperti su 49971.3 kWh (Domanda agg: 49971.3 kWh)
# H3 881ea45157fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881f992497fffff: 8 colonnine, 4443.4 kWh coperti su 4722.2 kWh (Domanda agg: 4722.2 kWh)
# H3 881ea45135fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45333fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea4510dfffff: 10 colonnine, 5554.3 kWh coperti su 10048.3 kWh (Domanda agg: 10048.3 kWh)
# H3 881ea45ad1fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45149fffff: 10 colonnine, 5554.3 kWh coperti su 6430.7 kWh (Domanda agg: 6430.7 kWh)
# H3 881ea4512dfffff: 8 colonnine, 4443.4 kWh coperti su 4557.1 kWh (Domanda agg: 4557.1 kWh)
# H3 881ea45109fffff: 5 colonnine, 2777.2 kWh coperti su 3175.5 kWh (Domanda agg: 3175.5 kWh)
# H3 881ea45a81fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea451e7fffff: 10 colonnine, 5554.3 kWh coperti su 13135.3 kWh (Domanda agg: 13135.3 kWh)
# H3 881ea45161fffff: 10 colonnine, 5554.3 kWh coperti su 9873.3 kWh (Domanda agg: 9873.3 kWh)
# H3 881ea451e3fffff: 10 colonnine, 5554.3 kWh coperti su 5900.2 kWh (Domanda agg: 5900.2 kWh)
# H3 881ea451e1fffff: 10 colonnine, 5554.3 kWh coperti su 8211.7 kWh (Domanda agg: 8211.7 kWh)
# H3 881ea45025fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45107fffff: 7 colonnine, 3888.0 kWh coperti su 4085.2 kWh (Domanda agg: 4085.2 kWh)
# H3 881ea4515dfffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45ad7fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea451edfffff: 10 colonnine, 5554.3 kWh coperti su 5742.8 kWh (Domanda agg: 5742.8 kWh)
# H3 881ea45133fffff: 10 colonnine, 5554.3 kWh coperti su 6439.4 kWh (Domanda agg: 6439.4 kWh)
# H3 881ea45a99fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea4511dfffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea4513dfffff: 10 colonnine, 5554.3 kWh coperti su 6153.7 kWh (Domanda agg: 6153.7 kWh)
# H3 881ea45103fffff: 10 colonnine, 5554.3 kWh coperti su 10061.9 kWh (Domanda agg: 10061.9 kWh)
# H3 881ea451a1fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45151fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45147fffff: 10 colonnine, 5554.3 kWh coperti su 7880.7 kWh (Domanda agg: 7880.7 kWh)
# H3 881ea4511bfffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45143fffff: 7 colonnine, 3888.0 kWh coperti su 4421.5 kWh (Domanda agg: 4421.5 kWh)
# H3 881ea45ac9fffff: 10 colonnine, 5554.3 kWh coperti su 5667.9 kWh (Domanda agg: 5667.9 kWh)
# H3 881ea4514bfffff: 9 colonnine, 4998.9 kWh coperti su 5006.0 kWh (Domanda agg: 5006.0 kWh)
# H3 881ea45a87fffff: 6 colonnine, 3332.6 kWh coperti su 3418.7 kWh (Domanda agg: 3418.7 kWh)
# H3 881ea4515bfffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45ad9fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45117fffff: 10 colonnine, 5554.3 kWh coperti su 9157.8 kWh (Domanda agg: 9157.8 kWh)
# H3 881ea451abfffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea451e5fffff: 10 colonnine, 5554.3 kWh coperti su 6543.8 kWh (Domanda agg: 6543.8 kWh)
# H3 881ea45065fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45129fffff: 10 colonnine, 5554.3 kWh coperti su 8419.3 kWh (Domanda agg: 8419.3 kWh)
# H3 881ea451adfffff: 10 colonnine, 5554.3 kWh coperti su 5837.6 kWh (Domanda agg: 5837.6 kWh)
# H3 881ea45115fffff: 10 colonnine, 5554.3 kWh coperti su 8971.1 kWh (Domanda agg: 8971.1 kWh)
# H3 881ea45ad3fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45111fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45169fffff: 10 colonnine, 5554.3 kWh coperti su 6259.6 kWh (Domanda agg: 6259.6 kWh)
# H3 881ea451e9fffff: 8 colonnine, 4443.4 kWh coperti su 4808.3 kWh (Domanda agg: 4808.3 kWh)
# H3 881ea45337fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea4512bfffff: 10 colonnine, 5554.3 kWh coperti su 8339.4 kWh (Domanda agg: 8339.4 kWh)
# H3 881ea4514dfffff: 10 colonnine, 5554.3 kWh coperti su 5769.0 kWh (Domanda agg: 5769.0 kWh)
# H3 881ea45139fffff: 10 colonnine, 5554.3 kWh coperti su 7289.7 kWh (Domanda agg: 7289.7 kWh)
# H3 881ea45adbfffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45145fffff: 8 colonnine, 4443.4 kWh coperti su 4692.4 kWh (Domanda agg: 4692.4 kWh)
# H3 881ea45167fffff: 10 colonnine, 5554.3 kWh coperti su 6069.0 kWh (Domanda agg: 6069.0 kWh)
# H3 881ea45ac1fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45163fffff: 10 colonnine, 5554.3 kWh coperti su 8279.8 kWh (Domanda agg: 8279.8 kWh)
# H3 881ea45113fffff: 10 colonnine, 5554.3 kWh coperti su 6193.3 kWh (Domanda agg: 6193.3 kWh)
# H3 881ea45101fffff: 10 colonnine, 5554.3 kWh coperti su 9307.1 kWh (Domanda agg: 9307.1 kWh)
# H3 881ea45131fffff: 10 colonnine, 5554.3 kWh coperti su 9175.6 kWh (Domanda agg: 9175.6 kWh)
# H3 881ea45123fffff: 8 colonnine, 4443.4 kWh coperti su 4958.1 kWh (Domanda agg: 4958.1 kWh)
# H3 881ea4516bfffff: 10 colonnine, 5554.3 kWh coperti su 10775.3 kWh (Domanda agg: 10775.3 kWh)
# H3 881ea451ebfffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea4510bfffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45137fffff: 4 colonnine, 2221.7 kWh coperti su 2438.2 kWh (Domanda agg: 2438.2 kWh)
# H3 881ea45b53fffff: 8 colonnine, 4443.4 kWh coperti su 4486.8 kWh (Domanda agg: 4486.8 kWh)
# H3 881f9925e7fffff: 10 colonnine, 5554.3 kWh coperti su 5647.0 kWh (Domanda agg: 5647.0 kWh)
# H3 881f992ec5fffff: 10 colonnine, 5554.3 kWh coperti su 5575.0 kWh (Domanda agg: 5575.0 kWh)
# H3 881f992583fffff: 9 colonnine, 4998.9 kWh coperti su 5303.1 kWh (Domanda agg: 5303.1 kWh)
# H3 881f992515fffff: 7 colonnine, 3888.0 kWh coperti su 4278.0 kWh (Domanda agg: 4278.0 kWh)
# H3 881f992ed3fffff: 10 colonnine, 5554.3 kWh coperti su 5648.8 kWh (Domanda agg: 5648.8 kWh)
# H3 881f992e9bfffff: 10 colonnine, 5554.3 kWh coperti su 5879.6 kWh (Domanda agg: 5879.6 kWh)
# H3 881ea45b65fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881ea45b09fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f992527fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881ea45b4dfffff: 10 colonnine, 5554.3 kWh coperti su 7778.4 kWh (Domanda agg: 7778.4 kWh)
# H3 881f9925adfffff: 10 colonnine, 5554.3 kWh coperti su 6288.0 kWh (Domanda agg: 6288.0 kWh)
# H3 881f992505fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f9925edfffff: 10 colonnine, 5554.3 kWh coperti su 6785.3 kWh (Domanda agg: 6785.3 kWh)
# H3 881f9925a3fffff: 10 colonnine, 5554.3 kWh coperti su 6471.5 kWh (Domanda agg: 6471.5 kWh)
# H3 881ea45b67fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f9925e1fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f9925abfffff: 10 colonnine, 5554.3 kWh coperti su 8957.2 kWh (Domanda agg: 8957.2 kWh)
# H3 881f992587fffff: 9 colonnine, 4998.9 kWh coperti su 5272.8 kWh (Domanda agg: 5272.8 kWh)
# H3 881f992ed5fffff: 10 colonnine, 5554.3 kWh coperti su 6222.2 kWh (Domanda agg: 6222.2 kWh)
# H3 881f992e99fffff: 10 colonnine, 5554.3 kWh coperti su 8834.3 kWh (Domanda agg: 8834.3 kWh)
# H3 881f9925a7fffff: 10 colonnine, 5554.3 kWh coperti su 5558.2 kWh (Domanda agg: 5558.2 kWh)
# H3 881f992e83fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f9925b3fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f992eb9fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881ea45b4bfffff: 8 colonnine, 4443.4 kWh coperti su 4791.4 kWh (Domanda agg: 4791.4 kWh)
# H3 881f992581fffff: 6 colonnine, 3332.6 kWh coperti su 3675.8 kWh (Domanda agg: 3675.8 kWh)
# H3 881f9925bdfffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881ea45b01fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f992eddfffff: 6 colonnine, 3332.6 kWh coperti su 3460.7 kWh (Domanda agg: 3460.7 kWh)
# H3 881f9925ebfffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881ea45b63fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f9925a1fffff: 10 colonnine, 5554.3 kWh coperti su 8130.6 kWh (Domanda agg: 8130.6 kWh)
# H3 881f992503fffff: 8 colonnine, 4443.4 kWh coperti su 4822.6 kWh (Domanda agg: 4822.6 kWh)
# H3 881f992ec1fffff: 10 colonnine, 5554.3 kWh coperti su 6668.5 kWh (Domanda agg: 6668.5 kWh)
# H3 881ea45a2dfffff: 4 colonnine, 2221.7 kWh coperti su 2472.0 kWh (Domanda agg: 2472.0 kWh)
# H3 881ea45b6dfffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881ea45b55fffff: 10 colonnine, 5554.3 kWh coperti su 8450.4 kWh (Domanda agg: 8450.4 kWh)
# H3 881f992509fffff: 10 colonnine, 5554.3 kWh coperti su 7581.2 kWh (Domanda agg: 7581.2 kWh)
# H3 881f992ec7fffff: 7 colonnine, 3888.0 kWh coperti su 4430.3 kWh (Domanda agg: 4430.3 kWh)
# H3 881f992585fffff: 8 colonnine, 4443.4 kWh coperti su 4886.8 kWh (Domanda agg: 4886.8 kWh)
# H3 881ea45b6bfffff: 7 colonnine, 3888.0 kWh coperti su 4431.2 kWh (Domanda agg: 4431.2 kWh)
# H3 881f9925e5fffff: 10 colonnine, 5554.3 kWh coperti su 12361.1 kWh (Domanda agg: 12361.1 kWh)
# H3 881f992589fffff: 8 colonnine, 4443.4 kWh coperti su 4641.0 kWh (Domanda agg: 4641.0 kWh)
# H3 881f992ec3fffff: 10 colonnine, 5554.3 kWh coperti su 5645.1 kWh (Domanda agg: 5645.1 kWh)
# H3 881f992521fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f992ec9fffff: 7 colonnine, 3888.0 kWh coperti su 4295.1 kWh (Domanda agg: 4295.1 kWh)
# H3 881ea45b57fffff: 8 colonnine, 4443.4 kWh coperti su 4686.3 kWh (Domanda agg: 4686.3 kWh)
# H3 881f9925a5fffff: 10 colonnine, 5554.3 kWh coperti su 6410.5 kWh (Domanda agg: 6410.5 kWh)
# H3 881ea45b51fffff: 8 colonnine, 4443.4 kWh coperti su 4881.5 kWh (Domanda agg: 4881.5 kWh)
# H3 881f992529fffff: 8 colonnine, 4443.4 kWh coperti su 4998.0 kWh (Domanda agg: 4998.0 kWh)
# H3 881f992e81fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f992523fffff: 8 colonnine, 4443.4 kWh coperti su 4928.8 kWh (Domanda agg: 4928.8 kWh)
# H3 881ea45b43fffff: 10 colonnine, 5554.3 kWh coperti su 7863.9 kWh (Domanda agg: 7863.9 kWh)
# H3 881f99253dfffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f992ecbfffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881ea45b41fffff: 10 colonnine, 5554.3 kWh coperti su 5572.5 kWh (Domanda agg: 5572.5 kWh)
# H3 881f99251dfffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f9925e9fffff: 3 colonnine, 1666.3 kWh coperti su 2032.6 kWh (Domanda agg: 2032.6 kWh)
# H3 881f9925b5fffff: 10 colonnine, 5554.3 kWh coperti su 6788.9 kWh (Domanda agg: 6788.9 kWh)
# H3 881f992eb3fffff: 6 colonnine, 3332.6 kWh coperti su 3878.4 kWh (Domanda agg: 3878.4 kWh)
# H3 881f992edbfffff: 7 colonnine, 3888.0 kWh coperti su 4427.0 kWh (Domanda agg: 4427.0 kWh)
# H3 881f992ed1fffff: 6 colonnine, 3332.6 kWh coperti su 3461.8 kWh (Domanda agg: 3461.8 kWh)
# H3 881f99362bfffff: 5 colonnine, 2777.2 kWh coperti su 2857.3 kWh (Domanda agg: 2857.3 kWh)
# H3 881f9936e9fffff: 4 colonnine, 2221.7 kWh coperti su 2670.1 kWh (Domanda agg: 2670.1 kWh)
# H3 881f9936edfffff: 6 colonnine, 3332.6 kWh coperti su 3510.0 kWh (Domanda agg: 3510.0 kWh)
# H3 881f993639fffff: 3 colonnine, 1666.3 kWh coperti su 2009.2 kWh (Domanda agg: 2009.2 kWh)
# H3 881f99363bfffff: 9 colonnine, 4998.9 kWh coperti su 5030.7 kWh (Domanda agg: 5030.7 kWh)
# H3 881f993685fffff: 4 colonnine, 2221.7 kWh coperti su 2558.6 kWh (Domanda agg: 2558.6 kWh)
# H3 881f99069dfffff: 2 colonnine, 1110.9 kWh coperti su 1367.2 kWh (Domanda agg: 1367.2 kWh)
# H3 881f9904c3fffff: 2 colonnine, 1110.9 kWh coperti su 1367.2 kWh (Domanda agg: 1367.2 kWh)
# H3 881f9906a3fffff: 10 colonnine, 5554.3 kWh coperti su 7337.0 kWh (Domanda agg: 7337.0 kWh)
# H3 881f993369fffff: 10 colonnine, 5554.3 kWh coperti su 5751.8 kWh (Domanda agg: 5751.8 kWh)
# H3 881f9906bdfffff: 10 colonnine, 5554.3 kWh coperti su 7895.7 kWh (Domanda agg: 7895.7 kWh)
# H3 881f990687fffff: 10 colonnine, 5554.3 kWh coperti su 6133.4 kWh (Domanda agg: 6133.4 kWh)
# H3 881f9906abfffff: 10 colonnine, 5554.3 kWh coperti su 8791.6 kWh (Domanda agg: 8791.6 kWh)
# H3 881f990697fffff: 10 colonnine, 5554.3 kWh coperti su 6744.0 kWh (Domanda agg: 6744.0 kWh)
# H3 881f993133fffff: 6 colonnine, 3332.6 kWh coperti su 3386.7 kWh (Domanda agg: 3386.7 kWh)
# H3 881f99311dfffff: 10 colonnine, 5554.3 kWh coperti su 7662.3 kWh (Domanda agg: 7662.3 kWh)
# H3 881f99311bfffff: 2 colonnine, 1110.9 kWh coperti su 1233.9 kWh (Domanda agg: 1233.9 kWh)
# H3 881f993155fffff: 10 colonnine, 5554.3 kWh coperti su 6329.9 kWh (Domanda agg: 6329.9 kWh)
# H3 881f9931cdfffff: 2 colonnine, 1110.9 kWh coperti su 1233.9 kWh (Domanda agg: 1233.9 kWh)
# H3 881f993a4bfffff: 10 colonnine, 5554.3 kWh coperti su 6100.4 kWh (Domanda agg: 6100.4 kWh)
# H3 881f993a5dfffff: 10 colonnine, 5554.3 kWh coperti su 5716.7 kWh (Domanda agg: 5716.7 kWh)
# H3 881f993a51fffff: 10 colonnine, 5554.3 kWh coperti su 6195.9 kWh (Domanda agg: 6195.9 kWh)
# H3 881f9904b7fffff: 10 colonnine, 5554.3 kWh coperti su 7776.3 kWh (Domanda agg: 7776.3 kWh)
# H3 881f993161fffff: 4 colonnine, 2221.7 kWh coperti su 2732.9 kWh (Domanda agg: 2732.9 kWh)
# H3 881f9904b3fffff: 10 colonnine, 5554.3 kWh coperti su 7158.4 kWh (Domanda agg: 7158.4 kWh)
# H3 881f992e31fffff: 4 colonnine, 2221.7 kWh coperti su 2415.0 kWh (Domanda agg: 2415.0 kWh)
# H3 881f9920b3fffff: 2 colonnine, 1110.9 kWh coperti su 1495.7 kWh (Domanda agg: 1495.7 kWh)
# H3 881f992c43fffff: 2 colonnine, 1110.9 kWh coperti su 1495.7 kWh (Domanda agg: 1495.7 kWh)
# H3 881f9920b1fffff: 2 colonnine, 1110.9 kWh coperti su 1495.7 kWh (Domanda agg: 1495.7 kWh)
# H3 881f992c4dfffff: 2 colonnine, 1110.9 kWh coperti su 1495.7 kWh (Domanda agg: 1495.7 kWh)
# H3 881f992087fffff: 5 colonnine, 2777.2 kWh coperti su 3298.0 kWh (Domanda agg: 3298.0 kWh)
# H3 881f992e15fffff: 10 colonnine, 5554.3 kWh coperti su 6154.2 kWh (Domanda agg: 6154.2 kWh)
# H3 881f992e29fffff: 8 colonnine, 4443.4 kWh coperti su 4943.4 kWh (Domanda agg: 4943.4 kWh)
# H3 881f992c59fffff: 4 colonnine, 2221.7 kWh coperti su 2380.9 kWh (Domanda agg: 2380.9 kWh)
# H3 881f992e03fffff: 10 colonnine, 5554.3 kWh coperti su 7463.2 kWh (Domanda agg: 7463.2 kWh)
# H3 881f992e0bfffff: 10 colonnine, 5554.3 kWh coperti su 7470.1 kWh (Domanda agg: 7470.1 kWh)
# H3 881f992e43fffff: 10 colonnine, 5554.3 kWh coperti su 6629.7 kWh (Domanda agg: 6629.7 kWh)
# H3 881f992e1dfffff: 4 colonnine, 2221.7 kWh coperti su 2550.3 kWh (Domanda agg: 2550.3 kWh)
# H3 881f992567fffff: 2 colonnine, 1110.9 kWh coperti su 1495.7 kWh (Domanda agg: 1495.7 kWh)
# H3 881ea45a03fffff: 1 colonnine, 555.4 kWh coperti su 1088.7 kWh (Domanda agg: 1088.7 kWh)
# H3 881f9924cbfffff: 2 colonnine, 1110.9 kWh coperti su 1253.1 kWh (Domanda agg: 1253.1 kWh)
# H3 881f992483fffff: 10 colonnine, 5554.3 kWh coperti su 6151.0 kWh (Domanda agg: 6151.0 kWh)
# H3 881ea45ab5fffff: 1 colonnine, 555.4 kWh coperti su 1088.7 kWh (Domanda agg: 1088.7 kWh)
# H3 881ea45125fffff: 1 colonnine, 555.4 kWh coperti su 1088.7 kWh (Domanda agg: 1088.7 kWh)
# H3 881ea45a47fffff: 5 colonnine, 2777.2 kWh coperti su 2862.3 kWh (Domanda agg: 2862.3 kWh)
# H3 881ea4516dfffff: 10 colonnine, 5554.3 kWh coperti su 6974.5 kWh (Domanda agg: 6974.5 kWh)
# H3 881f9924bbfffff: 10 colonnine, 5554.3 kWh coperti su 6052.2 kWh (Domanda agg: 6052.2 kWh)
# H3 881f9924a1fffff: 1 colonnine, 555.4 kWh coperti su 1088.7 kWh (Domanda agg: 1088.7 kWh)
# H3 881f9924b1fffff: 10 colonnine, 5554.3 kWh coperti su 8054.7 kWh (Domanda agg: 8054.7 kWh)
# H3 881f992493fffff: 1 colonnine, 555.4 kWh coperti su 1088.7 kWh (Domanda agg: 1088.7 kWh)
# H3 881f9930b7fffff: 10 colonnine, 5554.3 kWh coperti su 6678.7 kWh (Domanda agg: 6678.7 kWh)
# H3 881f99308bfffff: 1 colonnine, 555.4 kWh coperti su 1070.9 kWh (Domanda agg: 1070.9 kWh)
# H3 881f9930bbfffff: 1 colonnine, 555.4 kWh coperti su 1070.9 kWh (Domanda agg: 1070.9 kWh)
# H3 881f99356dfffff: 4 colonnine, 2221.7 kWh coperti su 2290.9 kWh (Domanda agg: 2290.9 kWh)
# H3 881f993445fffff: 1 colonnine, 555.4 kWh coperti su 939.9 kWh (Domanda agg: 939.9 kWh)
# H3 881f99346bfffff: 1 colonnine, 555.4 kWh coperti su 939.9 kWh (Domanda agg: 939.9 kWh)
# H3 881f993713fffff: 1 colonnine, 555.4 kWh coperti su 939.9 kWh (Domanda agg: 939.9 kWh)
# H3 881f993447fffff: 1 colonnine, 555.4 kWh coperti su 939.9 kWh (Domanda agg: 939.9 kWh)
# H3 881f99a409fffff: 1 colonnine, 555.4 kWh coperti su 932.4 kWh (Domanda agg: 932.4 kWh)
# H3 881f99a621fffff: 4 colonnine, 2221.7 kWh coperti su 2711.8 kWh (Domanda agg: 2711.8 kWh)
# H3 881f99a719fffff: 10 colonnine, 5554.3 kWh coperti su 5625.5 kWh (Domanda agg: 5625.5 kWh)
# H3 881f99a71dfffff: 5 colonnine, 2777.2 kWh coperti su 3236.9 kWh (Domanda agg: 3236.9 kWh)
# H3 881f99a403fffff: 1 colonnine, 555.4 kWh coperti su 932.4 kWh (Domanda agg: 932.4 kWh)
# H3 881f99a663fffff: 1 colonnine, 555.4 kWh coperti su 932.4 kWh (Domanda agg: 932.4 kWh)
# H3 881f99a73bfffff: 2 colonnine, 1110.9 kWh coperti su 1623.2 kWh (Domanda agg: 1623.2 kWh)
# H3 881f993037fffff: 1 colonnine, 555.4 kWh coperti su 1027.8 kWh (Domanda agg: 1027.8 kWh)
# H3 881f992f27fffff: 2 colonnine, 1110.9 kWh coperti su 1203.4 kWh (Domanda agg: 1203.4 kWh)
# H3 881f9921b1fffff: 4 colonnine, 2221.7 kWh coperti su 2554.4 kWh (Domanda agg: 2554.4 kWh)
# H3 881f992f1bfffff: 2 colonnine, 1110.9 kWh coperti su 1203.4 kWh (Domanda agg: 1203.4 kWh)
# H3 881f992f01fffff: 5 colonnine, 2777.2 kWh coperti su 2790.5 kWh (Domanda agg: 2790.5 kWh)
# H3 881f992f31fffff: 3 colonnine, 1666.3 kWh coperti su 1787.7 kWh (Domanda agg: 1787.7 kWh)
# H3 881f992f29fffff: 2 colonnine, 1110.9 kWh coperti su 1203.4 kWh (Domanda agg: 1203.4 kWh)
# H3 881f992c69fffff: 5 colonnine, 2777.2 kWh coperti su 2995.3 kWh (Domanda agg: 2995.3 kWh)
# H3 881f9921b7fffff: 4 colonnine, 2221.7 kWh coperti su 2551.4 kWh (Domanda agg: 2551.4 kWh)
# H3 881f992f43fffff: 6 colonnine, 3332.6 kWh coperti su 3840.8 kWh (Domanda agg: 3840.8 kWh)
# H3 881f9921a3fffff: 2 colonnine, 1110.9 kWh coperti su 1203.4 kWh (Domanda agg: 1203.4 kWh)
# H3 881f992f45fffff: 5 colonnine, 2777.2 kWh coperti su 3251.5 kWh (Domanda agg: 3251.5 kWh)
# H3 881f9921bbfffff: 2 colonnine, 1110.9 kWh coperti su 1203.4 kWh (Domanda agg: 1203.4 kWh)
# H3 881f992703fffff: 6 colonnine, 3332.6 kWh coperti su 3418.3 kWh (Domanda agg: 3418.3 kWh)
# H3 881f992667fffff: 1 colonnine, 555.4 kWh coperti su 947.2 kWh (Domanda agg: 947.2 kWh)
# H3 881f992759fffff: 1 colonnine, 555.4 kWh coperti su 947.2 kWh (Domanda agg: 947.2 kWh)
# H3 881f99375bfffff: 4 colonnine, 2221.7 kWh coperti su 2615.7 kWh (Domanda agg: 2615.7 kWh)
# H3 881f99362dfffff: 1 colonnine, 555.4 kWh coperti su 669.1 kWh (Domanda agg: 669.1 kWh)
# H3 881f99ad81fffff: 1 colonnine, 555.4 kWh coperti su 669.1 kWh (Domanda agg: 669.1 kWh)
# H3 881ea45b3dfffff: 3 colonnine, 1666.3 kWh coperti su 2029.1 kWh (Domanda agg: 2029.1 kWh)
# H3 881ea45b3bfffff: 4 colonnine, 2221.7 kWh coperti su 2329.9 kWh (Domanda agg: 2329.9 kWh)
# H3 881ea4596bfffff: 3 colonnine, 1666.3 kWh coperti su 1825.7 kWh (Domanda agg: 1825.7 kWh)
# H3 881ea45b35fffff: 7 colonnine, 3888.0 kWh coperti su 3925.5 kWh (Domanda agg: 3925.5 kWh)
# H3 881ea45955fffff: 1 colonnine, 555.4 kWh coperti su 1062.1 kWh (Domanda agg: 1062.1 kWh)
# H3 881ea45b15fffff: 5 colonnine, 2777.2 kWh coperti su 3283.4 kWh (Domanda agg: 3283.4 kWh)
# H3 881ea45b37fffff: 5 colonnine, 2777.2 kWh coperti su 3147.6 kWh (Domanda agg: 3147.6 kWh)
# H3 881f992c97fffff: 1 colonnine, 555.4 kWh coperti su 1062.1 kWh (Domanda agg: 1062.1 kWh)
# H3 881ea45b23fffff: 5 colonnine, 2777.2 kWh coperti su 3055.8 kWh (Domanda agg: 3055.8 kWh)
# H3 881ea45909fffff: 2 colonnine, 1110.9 kWh coperti su 1180.3 kWh (Domanda agg: 1180.3 kWh)
# H3 881f9925d5fffff: 6 colonnine, 3332.6 kWh coperti su 3534.6 kWh (Domanda agg: 3534.6 kWh)
# H3 881f992407fffff: 6 colonnine, 3332.6 kWh coperti su 3734.0 kWh (Domanda agg: 3734.0 kWh)
# H3 881f992595fffff: 3 colonnine, 1666.3 kWh coperti su 2003.7 kWh (Domanda agg: 2003.7 kWh)
# H3 881ea45a6dfffff: 1 colonnine, 555.4 kWh coperti su 864.2 kWh (Domanda agg: 864.2 kWh)
# H3 881f992431fffff: 4 colonnine, 2221.7 kWh coperti su 2376.0 kWh (Domanda agg: 2376.0 kWh)
# H3 881f9925c3fffff: 1 colonnine, 555.4 kWh coperti su 864.2 kWh (Domanda agg: 864.2 kWh)
# H3 881f99255bfffff: 1 colonnine, 555.4 kWh coperti su 864.2 kWh (Domanda agg: 864.2 kWh)
# H3 881f99242bfffff: 3 colonnine, 1666.3 kWh coperti su 2177.1 kWh (Domanda agg: 2177.1 kWh)
# H3 881f9925d1fffff: 4 colonnine, 2221.7 kWh coperti su 2391.0 kWh (Domanda agg: 2391.0 kWh)
# H3 881f992599fffff: 1 colonnine, 555.4 kWh coperti su 864.2 kWh (Domanda agg: 864.2 kWh)
# H3 881f992427fffff: 3 colonnine, 1666.3 kWh coperti su 2013.4 kWh (Domanda agg: 2013.4 kWh)
# H3 881f9924e5fffff: 4 colonnine, 2221.7 kWh coperti su 2351.1 kWh (Domanda agg: 2351.1 kWh)
# H3 881f992591fffff: 4 colonnine, 2221.7 kWh coperti su 2231.3 kWh (Domanda agg: 2231.3 kWh)
# H3 881f992467fffff: 3 colonnine, 1666.3 kWh coperti su 2146.8 kWh (Domanda agg: 2146.8 kWh)
# H3 881f9925ddfffff: 5 colonnine, 2777.2 kWh coperti su 3314.9 kWh (Domanda agg: 3314.9 kWh)
# H3 881f992553fffff: 1 colonnine, 555.4 kWh coperti su 864.2 kWh (Domanda agg: 864.2 kWh)
# H3 881f9925dbfffff: 1 colonnine, 555.4 kWh coperti su 864.2 kWh (Domanda agg: 864.2 kWh)
# H3 881f9925c9fffff: 4 colonnine, 2221.7 kWh coperti su 2485.1 kWh (Domanda agg: 2485.1 kWh)
# H3 881f9925cdfffff: 2 colonnine, 1110.9 kWh coperti su 1651.5 kWh (Domanda agg: 1651.5 kWh)
# H3 881f99243bfffff: 6 colonnine, 3332.6 kWh coperti su 3552.5 kWh (Domanda agg: 3552.5 kWh)
# H3 881f9925c7fffff: 1 colonnine, 555.4 kWh coperti su 864.2 kWh (Domanda agg: 864.2 kWh)
# H3 881f992433fffff: 2 colonnine, 1110.9 kWh coperti su 1284.5 kWh (Domanda agg: 1284.5 kWh)
# H3 881f99246dfffff: 1 colonnine, 555.4 kWh coperti su 878.1 kWh (Domanda agg: 878.1 kWh)
# H3 881f992733fffff: 3 colonnine, 1666.3 kWh coperti su 1993.5 kWh (Domanda agg: 1993.5 kWh)
# H3 881f99244dfffff: 5 colonnine, 2777.2 kWh coperti su 3124.8 kWh (Domanda agg: 3124.8 kWh)
# H3 881f992443fffff: 1 colonnine, 555.4 kWh coperti su 878.1 kWh (Domanda agg: 878.1 kWh)
# H3 881f992621fffff: 4 colonnine, 2221.7 kWh coperti su 2274.8 kWh (Domanda agg: 2274.8 kWh)
# H3 881f992447fffff: 1 colonnine, 555.4 kWh coperti su 878.1 kWh (Domanda agg: 878.1 kWh)
# H3 881f992465fffff: 4 colonnine, 2221.7 kWh coperti su 2535.7 kWh (Domanda agg: 2535.7 kWh)
# H3 881f992623fffff: 4 colonnine, 2221.7 kWh coperti su 2740.5 kWh (Domanda agg: 2740.5 kWh)
# H3 881f99271bfffff: 5 colonnine, 2777.2 kWh coperti su 2902.9 kWh (Domanda agg: 2902.9 kWh)
# H3 881f99240dfffff: 3 colonnine, 1666.3 kWh coperti su 1937.4 kWh (Domanda agg: 1937.4 kWh)
# H3 881f992627fffff: 6 colonnine, 3332.6 kWh coperti su 3786.9 kWh (Domanda agg: 3786.9 kWh)
# H3 881f992713fffff: 8 colonnine, 4443.4 kWh coperti su 4569.9 kWh (Domanda agg: 4569.9 kWh)
# H3 881f992441fffff: 4 colonnine, 2221.7 kWh coperti su 2279.9 kWh (Domanda agg: 2279.9 kWh)
# H3 881f992629fffff: 1 colonnine, 555.4 kWh coperti su 878.1 kWh (Domanda agg: 878.1 kWh)
# H3 881f99218bfffff: 4 colonnine, 2221.7 kWh coperti su 2239.6 kWh (Domanda agg: 2239.6 kWh)
# H3 881f9921c5fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f9921e9fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f992199fffff: 4 colonnine, 2221.7 kWh coperti su 2421.7 kWh (Domanda agg: 2421.7 kWh)
# H3 881f9921ebfffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f9920e5fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f9921d3fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f992183fffff: 3 colonnine, 1666.3 kWh coperti su 2164.6 kWh (Domanda agg: 2164.6 kWh)
# H3 881f9921d1fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f992185fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f992113fffff: 5 colonnine, 2777.2 kWh coperti su 2870.3 kWh (Domanda agg: 2870.3 kWh)
# H3 881f9921ddfffff: 5 colonnine, 2777.2 kWh coperti su 3206.0 kWh (Domanda agg: 3206.0 kWh)
# H3 881f9921c3fffff: 5 colonnine, 2777.2 kWh coperti su 3235.5 kWh (Domanda agg: 3235.5 kWh)
# H3 881f9921c9fffff: 2 colonnine, 1110.9 kWh coperti su 1460.8 kWh (Domanda agg: 1460.8 kWh)
# H3 881f992adbfffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f99219bfffff: 4 colonnine, 2221.7 kWh coperti su 2433.0 kWh (Domanda agg: 2433.0 kWh)
# H3 881f9921abfffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f99218dfffff: 4 colonnine, 2221.7 kWh coperti su 2449.1 kWh (Domanda agg: 2449.1 kWh)
# H3 881f992181fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f9921a1fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f992187fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f992189fffff: 3 colonnine, 1666.3 kWh coperti su 2059.4 kWh (Domanda agg: 2059.4 kWh)
# H3 881f9921cbfffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f9921e5fffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f9921edfffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f9921dbfffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f99219dfffff: 1 colonnine, 555.4 kWh coperti su 1007.1 kWh (Domanda agg: 1007.1 kWh)
# H3 881f992027fffff: 3 colonnine, 1666.3 kWh coperti su 1847.4 kWh (Domanda agg: 1847.4 kWh)
# H3 881f993937fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f9976c1fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993915fffff: 4 colonnine, 2221.7 kWh coperti su 2732.1 kWh (Domanda agg: 2732.1 kWh)
# H3 881f9939a3fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993821fffff: 3 colonnine, 1666.3 kWh coperti su 1718.6 kWh (Domanda agg: 1718.6 kWh)
# H3 881f9939c5fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993919fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f9939e9fffff: 5 colonnine, 2777.2 kWh coperti su 3126.1 kWh (Domanda agg: 3126.1 kWh)
# H3 881f993985fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f9939a5fffff: 3 colonnine, 1666.3 kWh coperti su 2082.6 kWh (Domanda agg: 2082.6 kWh)
# H3 881f993951fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f9939c1fffff: 4 colonnine, 2221.7 kWh coperti su 2571.2 kWh (Domanda agg: 2571.2 kWh)
# H3 881f993865fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f99390bfffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f992a4dfffff: 4 colonnine, 2221.7 kWh coperti su 2666.4 kWh (Domanda agg: 2666.4 kWh)
# H3 881f99382dfffff: 2 colonnine, 1110.9 kWh coperti su 1366.9 kWh (Domanda agg: 1366.9 kWh)
# H3 881f9976cbfffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f9939a7fffff: 3 colonnine, 1666.3 kWh coperti su 1885.7 kWh (Domanda agg: 1885.7 kWh)
# H3 881f993955fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993959fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f9939bdfffff: 2 colonnine, 1110.9 kWh coperti su 1662.8 kWh (Domanda agg: 1662.8 kWh)
# H3 881f993827fffff: 2 colonnine, 1110.9 kWh coperti su 1587.2 kWh (Domanda agg: 1587.2 kWh)
# H3 881f993935fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993957fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993823fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f99395bfffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993917fffff: 9 colonnine, 4998.9 kWh coperti su 5484.5 kWh (Domanda agg: 5484.5 kWh)
# H3 881f993903fffff: 3 colonnine, 1666.3 kWh coperti su 1951.4 kWh (Domanda agg: 1951.4 kWh)
# H3 881f9939bbfffff: 2 colonnine, 1110.9 kWh coperti su 1602.9 kWh (Domanda agg: 1602.9 kWh)
# H3 881f9939e3fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993953fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f9939adfffff: 4 colonnine, 2221.7 kWh coperti su 2284.1 kWh (Domanda agg: 2284.1 kWh)
# H3 881f99393bfffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993825fffff: 3 colonnine, 1666.3 kWh coperti su 1805.3 kWh (Domanda agg: 1805.3 kWh)
# H3 881f9939c9fffff: 4 colonnine, 2221.7 kWh coperti su 2502.1 kWh (Domanda agg: 2502.1 kWh)
# H3 881f993911fffff: 2 colonnine, 1110.9 kWh coperti su 1444.1 kWh (Domanda agg: 1444.1 kWh)
# H3 881f99398dfffff: 3 colonnine, 1666.3 kWh coperti su 2056.7 kWh (Domanda agg: 2056.7 kWh)
# H3 881f993993fffff: 3 colonnine, 1666.3 kWh coperti su 2037.8 kWh (Domanda agg: 2037.8 kWh)
# H3 881f993987fffff: 2 colonnine, 1110.9 kWh coperti su 1267.1 kWh (Domanda agg: 1267.1 kWh)
# H3 881f9939abfffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f993933fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f99391dfffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881f9939c7fffff: 3 colonnine, 1666.3 kWh coperti su 1696.3 kWh (Domanda agg: 1696.3 kWh)
# H3 881f993939fffff: 1 colonnine, 555.4 kWh coperti su 997.5 kWh (Domanda agg: 997.5 kWh)
# H3 881ea4c911fffff: 8 colonnine, 4443.4 kWh coperti su 4982.3 kWh (Domanda agg: 4982.3 kWh)
# H3 881ea4c907fffff: 1 colonnine, 555.4 kWh coperti su 768.9 kWh (Domanda agg: 768.9 kWh)
# H3 881ea4c9cdfffff: 4 colonnine, 2221.7 kWh coperti su 2677.2 kWh (Domanda agg: 2677.2 kWh)
# H3 881ea4cb31fffff: 1 colonnine, 555.4 kWh coperti su 768.9 kWh (Domanda agg: 768.9 kWh)
# H3 881ea4c91dfffff: 6 colonnine, 3332.6 kWh coperti su 3653.8 kWh (Domanda agg: 3653.8 kWh)
# H3 881ea4c943fffff: 3 colonnine, 1666.3 kWh coperti su 1850.0 kWh (Domanda agg: 1850.0 kWh)
# H3 881ea4c9c9fffff: 4 colonnine, 2221.7 kWh coperti su 2221.8 kWh (Domanda agg: 2221.8 kWh)
# H3 881ea4c93dfffff: 3 colonnine, 1666.3 kWh coperti su 1941.2 kWh (Domanda agg: 1941.2 kWh)
# H3 881ea4c933fffff: 3 colonnine, 1666.3 kWh coperti su 1883.1 kWh (Domanda agg: 1883.1 kWh)
# H3 881ea4c931fffff: 3 colonnine, 1666.3 kWh coperti su 1934.7 kWh (Domanda agg: 1934.7 kWh)
# H3 881ea4c909fffff: 1 colonnine, 555.4 kWh coperti su 768.9 kWh (Domanda agg: 768.9 kWh)
# H3 881ea4c915fffff: 3 colonnine, 1666.3 kWh coperti su 2217.4 kWh (Domanda agg: 2217.4 kWh)
# H3 881ea4c91bfffff: 4 colonnine, 2221.7 kWh coperti su 2356.4 kWh (Domanda agg: 2356.4 kWh)
# H3 881ea4c901fffff: 5 colonnine, 2777.2 kWh coperti su 3019.4 kWh (Domanda agg: 3019.4 kWh)
# H3 881ea4c951fffff: 8 colonnine, 4443.4 kWh coperti su 4709.2 kWh (Domanda agg: 4709.2 kWh)
# H3 881ea4c93bfffff: 3 colonnine, 1666.3 kWh coperti su 2093.7 kWh (Domanda agg: 2093.7 kWh)
# H3 881ea4c903fffff: 8 colonnine, 4443.4 kWh coperti su 4581.0 kWh (Domanda agg: 4581.0 kWh)
# H3 881ea4c90bfffff: 2 colonnine, 1110.9 kWh coperti su 1467.0 kWh (Domanda agg: 1467.0 kWh)
# H3 881ea4c905fffff: 1 colonnine, 555.4 kWh coperti su 768.9 kWh (Domanda agg: 768.9 kWh)
# H3 881ea4c92bfffff: 1 colonnine, 555.4 kWh coperti su 768.9 kWh (Domanda agg: 768.9 kWh)
# H3 881ea4c95bfffff: 1 colonnine, 555.4 kWh coperti su 768.9 kWh (Domanda agg: 768.9 kWh)
# H3 881ea4c955fffff: 5 colonnine, 2777.2 kWh coperti su 3275.4 kWh (Domanda agg: 3275.4 kWh)
# H3 881f992415fffff: 5 colonnine, 2777.2 kWh coperti su 2954.1 kWh (Domanda agg: 2954.1 kWh)
# H3 881f9926e3fffff: 1 colonnine, 555.4 kWh coperti su 795.3 kWh (Domanda agg: 795.3 kWh)
# H3 881f992403fffff: 4 colonnine, 2221.7 kWh coperti su 2350.4 kWh (Domanda agg: 2350.4 kWh)
# H3 881f992457fffff: 1 colonnine, 555.4 kWh coperti su 795.3 kWh (Domanda agg: 795.3 kWh)
# H3 881f992419fffff: 4 colonnine, 2221.7 kWh coperti su 2222.5 kWh (Domanda agg: 2222.5 kWh)
# H3 881f992401fffff: 3 colonnine, 1666.3 kWh coperti su 2140.3 kWh (Domanda agg: 2140.3 kWh)
# H3 881f9926b5fffff: 6 colonnine, 3332.6 kWh coperti su 3454.2 kWh (Domanda agg: 3454.2 kWh)
# H3 881f992411fffff: 1 colonnine, 555.4 kWh coperti su 795.3 kWh (Domanda agg: 795.3 kWh)
# H3 881f9924cdfffff: 1 colonnine, 555.4 kWh coperti su 795.3 kWh (Domanda agg: 795.3 kWh)
# H3 881f99241dfffff: 3 colonnine, 1666.3 kWh coperti su 1986.8 kWh (Domanda agg: 1986.8 kWh)
# H3 881f992455fffff: 2 colonnine, 1110.9 kWh coperti su 1663.4 kWh (Domanda agg: 1663.4 kWh)
# H3 881f992453fffff: 2 colonnine, 1110.9 kWh coperti su 1499.1 kWh (Domanda agg: 1499.1 kWh)
# H3 881f992451fffff: 4 colonnine, 2221.7 kWh coperti su 2633.8 kWh (Domanda agg: 2633.8 kWh)
# H3 881f992417fffff: 4 colonnine, 2221.7 kWh coperti su 2399.1 kWh (Domanda agg: 2399.1 kWh)
# H3 881f9926a3fffff: 6 colonnine, 3332.6 kWh coperti su 3639.6 kWh (Domanda agg: 3639.6 kWh)
# H3 881f9926e7fffff: 1 colonnine, 555.4 kWh coperti su 1016.5 kWh (Domanda agg: 1016.5 kWh)
# H3 881f99245dfffff: 5 colonnine, 2777.2 kWh coperti su 3259.7 kWh (Domanda agg: 3259.7 kWh)
# H3 881f9926a7fffff: 1 colonnine, 555.4 kWh coperti su 795.3 kWh (Domanda agg: 795.3 kWh)
# H3 881f9924c5fffff: 3 colonnine, 1666.3 kWh coperti su 1835.6 kWh (Domanda agg: 1835.6 kWh)
# H3 881f9924e9fffff: 3 colonnine, 1666.3 kWh coperti su 2118.7 kWh (Domanda agg: 2118.7 kWh)
# H3 881f99241bfffff: 1 colonnine, 555.4 kWh coperti su 795.3 kWh (Domanda agg: 795.3 kWh)
# H3 881f9926adfffff: 7 colonnine, 3888.0 kWh coperti su 4042.8 kWh (Domanda agg: 4042.8 kWh)
# H3 881f992413fffff: 1 colonnine, 555.4 kWh coperti su 795.3 kWh (Domanda agg: 795.3 kWh)
# H3 881f9924e1fffff: 7 colonnine, 3888.0 kWh coperti su 4296.4 kWh (Domanda agg: 4296.4 kWh)
# H3 881f9926abfffff: 3 colonnine, 1666.3 kWh coperti su 1971.4 kWh (Domanda agg: 1971.4 kWh)
# H3 881f9926a5fffff: 1 colonnine, 555.4 kWh coperti su 1021.2 kWh (Domanda agg: 1021.2 kWh)
# H3 881f9920d1fffff: 4 colonnine, 2221.7 kWh coperti su 2537.6 kWh (Domanda agg: 2537.6 kWh)
# H3 881f992549fffff: 3 colonnine, 1666.3 kWh coperti su 2015.5 kWh (Domanda agg: 2015.5 kWh)
# H3 881f992541fffff: 3 colonnine, 1666.3 kWh coperti su 2093.5 kWh (Domanda agg: 2093.5 kWh)
# H3 881f992731fffff: 2 colonnine, 1110.9 kWh coperti su 1654.4 kWh (Domanda agg: 1654.4 kWh)
# H3 881f992721fffff: 6 colonnine, 3332.6 kWh coperti su 3834.9 kWh (Domanda agg: 3834.9 kWh)
# H3 881f992767fffff: 3 colonnine, 1666.3 kWh coperti su 2196.1 kWh (Domanda agg: 2196.1 kWh)
# H3 881f992559fffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f99209bfffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f99208bfffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f992545fffff: 2 colonnine, 1110.9 kWh coperti su 1253.6 kWh (Domanda agg: 1253.6 kWh)
# H3 881f99256bfffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f99255dfffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f992099fffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f992725fffff: 3 colonnine, 1666.3 kWh coperti su 1796.5 kWh (Domanda agg: 1796.5 kWh)
# H3 881f99254dfffff: 3 colonnine, 1666.3 kWh coperti su 1957.8 kWh (Domanda agg: 1957.8 kWh)
# H3 881f992551fffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f99209dfffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f992095fffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f9920d3fffff: 4 colonnine, 2221.7 kWh coperti su 2253.0 kWh (Domanda agg: 2253.0 kWh)
# H3 881f9920dbfffff: 1 colonnine, 555.4 kWh coperti su 812.0 kWh (Domanda agg: 812.0 kWh)
# H3 881f992727fffff: 3 colonnine, 1666.3 kWh coperti su 1943.8 kWh (Domanda agg: 1943.8 kWh)
# H3 881f99272dfffff: 3 colonnine, 1666.3 kWh coperti su 1721.8 kWh (Domanda agg: 1721.8 kWh)
# ...
# H3 881ea4c829fffff: 2 colonnine, 1110.9 kWh coperti su 1252.1 kWh (Domanda agg: 1252.1 kWh)
# H3 881ea4c953fffff: 1 colonnine, 555.4 kWh coperti su 1105.2 kWh (Domanda agg: 1105.2 kWh)
# H3 881ea4c957fffff: 3 colonnine, 1666.3 kWh coperti su 1736.4 kWh (Domanda agg: 1736.4 kWh)
# H3 881ea4c801fffff: 1 colonnine, 555.4 kWh coperti su 813.4 kWh (Domanda agg: 813.4 kWh)
# H3 881ea4c825fffff: 2 colonnine, 1110.9 kWh coperti su 1649.3 kWh (Domanda agg: 1649.3 kWh)
# H3 881f992123fffff: 1 colonnine, 555.4 kWh coperti su 1006.4 kWh (Domanda agg: 1006.4 kWh)
# H3 881f992161fffff: 2 colonnine, 1110.9 kWh coperti su 1403.3 kWh (Domanda agg: 1403.3 kWh)
# H3 881f992a5bfffff: 1 colonnine, 555.4 kWh coperti su 799.7 kWh (Domanda agg: 799.7 kWh)
# H3 881f992a53fffff: 2 colonnine, 1110.9 kWh coperti su 1284.0 kWh (Domanda agg: 1284.0 kWh)
# H3 881f992101fffff: 2 colonnine, 1110.9 kWh coperti su 1185.5 kWh (Domanda agg: 1185.5 kWh)
# H3 881f992167fffff: 1 colonnine, 555.4 kWh coperti su 1059.0 kWh (Domanda agg: 1059.0 kWh)
# H3 881f992163fffff: 2 colonnine, 1110.9 kWh coperti su 1638.0 kWh (Domanda agg: 1638.0 kWh)
# H3 881f99210dfffff: 2 colonnine, 1110.9 kWh coperti su 1402.2 kWh (Domanda agg: 1402.2 kWh)
# H3 881f99216dfffff: 1 colonnine, 555.4 kWh coperti su 999.3 kWh (Domanda agg: 999.3 kWh)
# H3 881f992103fffff: 2 colonnine, 1110.9 kWh coperti su 1191.5 kWh (Domanda agg: 1191.5 kWh)
# H3 881f993aa9fffff: 1 colonnine, 555.4 kWh coperti su 644.0 kWh (Domanda agg: 644.0 kWh)
# H3 881f993ab3fffff: 1 colonnine, 555.4 kWh coperti su 1036.6 kWh (Domanda agg: 1036.6 kWh)
# H3 881f993aadfffff: 2 colonnine, 1110.9 kWh coperti su 1616.7 kWh (Domanda agg: 1616.7 kWh)
# H3 881f993aabfffff: 2 colonnine, 1110.9 kWh coperti su 1155.4 kWh (Domanda agg: 1155.4 kWh)
# H3 881f993a87fffff: 1 colonnine, 555.4 kWh coperti su 715.9 kWh (Domanda agg: 715.9 kWh)
# H3 881f993aa1fffff: 1 colonnine, 555.4 kWh coperti su 816.2 kWh (Domanda agg: 816.2 kWh)
# H3 881f993a8bfffff: 1 colonnine, 555.4 kWh coperti su 925.6 kWh (Domanda agg: 925.6 kWh)
# H3 881f992b57fffff: 1 colonnine, 555.4 kWh coperti su 778.8 kWh (Domanda agg: 778.8 kWh)
# H3 881f992b59fffff: 1 colonnine, 555.4 kWh coperti su 1000.5 kWh (Domanda agg: 1000.5 kWh)
# H3 881f992b0bfffff: 1 colonnine, 555.4 kWh coperti su 644.7 kWh (Domanda agg: 644.7 kWh)
# H3 881f997693fffff: 1 colonnine, 555.4 kWh coperti su 731.3 kWh (Domanda agg: 731.3 kWh)
# H3 881f992b45fffff: 1 colonnine, 555.4 kWh coperti su 583.3 kWh (Domanda agg: 583.3 kWh)
# H3 881f9939b1fffff: 1 colonnine, 555.4 kWh coperti su 864.4 kWh (Domanda agg: 864.4 kWh)
# H3 881f992b01fffff: 1 colonnine, 555.4 kWh coperti su 923.4 kWh (Domanda agg: 923.4 kWh)
# H3 881f992b03fffff: 1 colonnine, 555.4 kWh coperti su 993.6 kWh (Domanda agg: 993.6 kWh)
# H3 881f992b47fffff: 2 colonnine, 1110.9 kWh coperti su 1139.5 kWh (Domanda agg: 1139.5 kWh)
# H3 881f992b41fffff: 1 colonnine, 555.4 kWh coperti su 852.1 kWh (Domanda agg: 852.1 kWh)
# H3 881f992b6bfffff: 2 colonnine, 1110.9 kWh coperti su 1300.0 kWh (Domanda agg: 1300.0 kWh)
# H3 881f992b17fffff: 2 colonnine, 1110.9 kWh coperti su 1622.6 kWh (Domanda agg: 1622.6 kWh)
# H3 881f992b1dfffff: 2 colonnine, 1110.9 kWh coperti su 1428.4 kWh (Domanda agg: 1428.4 kWh)
# H3 881f9939b7fffff: 1 colonnine, 555.4 kWh coperti su 1084.9 kWh (Domanda agg: 1084.9 kWh)
# H3 881f992b0dfffff: 3 colonnine, 1666.3 kWh coperti su 1855.1 kWh (Domanda agg: 1855.1 kWh)
# H3 881f992b1bfffff: 1 colonnine, 555.4 kWh coperti su 860.3 kWh (Domanda agg: 860.3 kWh)
# H3 881f992b05fffff: 1 colonnine, 555.4 kWh coperti su 1069.0 kWh (Domanda agg: 1069.0 kWh)
# H3 881ea4c997fffff: 2 colonnine, 1110.9 kWh coperti su 1355.4 kWh (Domanda agg: 1355.4 kWh)
# H3 881ea45265fffff: 2 colonnine, 1110.9 kWh coperti su 1179.5 kWh (Domanda agg: 1179.5 kWh)
# H3 881ea4c993fffff: 1 colonnine, 555.4 kWh coperti su 1081.8 kWh (Domanda agg: 1081.8 kWh)
# H3 881f992017fffff: 1 colonnine, 555.4 kWh coperti su 753.8 kWh (Domanda agg: 753.8 kWh)
# H3 881f992007fffff: 1 colonnine, 555.4 kWh coperti su 971.7 kWh (Domanda agg: 971.7 kWh)
# H3 881f992039fffff: 1 colonnine, 555.4 kWh coperti su 1089.5 kWh (Domanda agg: 1089.5 kWh)
# H3 881f99208dfffff: 1 colonnine, 555.4 kWh coperti su 943.6 kWh (Domanda agg: 943.6 kWh)
# H3 881f9920a3fffff: 1 colonnine, 555.4 kWh coperti su 922.2 kWh (Domanda agg: 922.2 kWh)
# H3 881f9920a1fffff: 1 colonnine, 555.4 kWh coperti su 801.7 kWh (Domanda agg: 801.7 kWh)
# H3 881f9920e3fffff: 2 colonnine, 1110.9 kWh coperti su 1189.7 kWh (Domanda agg: 1189.7 kWh)
# H3 881f99a611fffff: 2 colonnine, 1110.9 kWh coperti su 1153.4 kWh (Domanda agg: 1153.4 kWh)
# H3 881f99a615fffff: 1 colonnine, 555.4 kWh coperti su 1040.3 kWh (Domanda agg: 1040.3 kWh)
# H3 881ea692dbfffff: 1 colonnine, 555.4 kWh coperti su 933.9 kWh (Domanda agg: 933.9 kWh)
# H3 881f992d57fffff: 1 colonnine, 555.4 kWh coperti su 918.0 kWh (Domanda agg: 918.0 kWh)
# H3 881f992d39fffff: 1 colonnine, 555.4 kWh coperti su 1058.4 kWh (Domanda agg: 1058.4 kWh)
# H3 881f992d33fffff: 2 colonnine, 1110.9 kWh coperti su 1555.1 kWh (Domanda agg: 1555.1 kWh)
# H3 881f992c27fffff: 1 colonnine, 555.4 kWh coperti su 735.5 kWh (Domanda agg: 735.5 kWh)
# H3 881f992d3bfffff: 1 colonnine, 555.4 kWh coperti su 886.5 kWh (Domanda agg: 886.5 kWh)
# H3 881f992c01fffff: 1 colonnine, 555.4 kWh coperti su 826.1 kWh (Domanda agg: 826.1 kWh)
# H3 881f992d15fffff: 1 colonnine, 555.4 kWh coperti su 565.8 kWh (Domanda agg: 565.8 kWh)
# H3 881f992c0dfffff: 1 colonnine, 555.4 kWh coperti su 800.7 kWh (Domanda agg: 800.7 kWh)
# H3 881f992dc7fffff: 1 colonnine, 555.4 kWh coperti su 1073.7 kWh (Domanda agg: 1073.7 kWh)
# H3 881f992dcdfffff: 1 colonnine, 555.4 kWh coperti su 937.2 kWh (Domanda agg: 937.2 kWh)
# H3 881f992c05fffff: 1 colonnine, 555.4 kWh coperti su 772.6 kWh (Domanda agg: 772.6 kWh)
# H3 881f992d17fffff: 2 colonnine, 1110.9 kWh coperti su 1483.7 kWh (Domanda agg: 1483.7 kWh)
# H3 881f992dedfffff: 2 colonnine, 1110.9 kWh coperti su 1541.4 kWh (Domanda agg: 1541.4 kWh)
# H3 881f992c2bfffff: 1 colonnine, 555.4 kWh coperti su 898.4 kWh (Domanda agg: 898.4 kWh)
# H3 881f99a991fffff: 1 colonnine, 555.4 kWh coperti su 807.5 kWh (Domanda agg: 807.5 kWh)
# H3 881f993849fffff: 1 colonnine, 555.4 kWh coperti su 597.2 kWh (Domanda agg: 597.2 kWh)
# H3 881f993b1bfffff: 1 colonnine, 555.4 kWh coperti su 902.9 kWh (Domanda agg: 902.9 kWh)
# H3 881f993a2bfffff: 1 colonnine, 555.4 kWh coperti su 833.9 kWh (Domanda agg: 833.9 kWh)
# H3 881f993829fffff: 1 colonnine, 555.4 kWh coperti su 709.6 kWh (Domanda agg: 709.6 kWh)
# H3 881f99354dfffff: 1 colonnine, 555.4 kWh coperti su 864.3 kWh (Domanda agg: 864.3 kWh)
# H3 881f99356bfffff: 1 colonnine, 555.4 kWh coperti su 785.4 kWh (Domanda agg: 785.4 kWh)
# H3 881f993545fffff: 1 colonnine, 555.4 kWh coperti su 807.4 kWh (Domanda agg: 807.4 kWh)
# H3 881ea45305fffff: 1 colonnine, 555.4 kWh coperti su 925.3 kWh (Domanda agg: 925.3 kWh)
# H3 881ea4532dfffff: 2 colonnine, 1110.9 kWh coperti su 1514.5 kWh (Domanda agg: 1514.5 kWh)
# H3 881ea45363fffff: 1 colonnine, 555.4 kWh coperti su 1049.6 kWh (Domanda agg: 1049.6 kWh)
# H3 881ea45321fffff: 1 colonnine, 555.4 kWh coperti su 949.7 kWh (Domanda agg: 949.7 kWh)
# H3 881f99a619fffff: 1 colonnine, 555.4 kWh coperti su 839.8 kWh (Domanda agg: 839.8 kWh)
# H3 881f99a603fffff: 1 colonnine, 555.4 kWh coperti su 882.4 kWh (Domanda agg: 882.4 kWh)
# H3 881f99a607fffff: 1 colonnine, 555.4 kWh coperti su 866.4 kWh (Domanda agg: 866.4 kWh)
# H3 881f99a09bfffff: 1 colonnine, 555.4 kWh coperti su 660.8 kWh (Domanda agg: 660.8 kWh)
# H3 881f99a54dfffff: 2 colonnine, 1110.9 kWh coperti su 1540.9 kWh (Domanda agg: 1540.9 kWh)
# H3 881f99a503fffff: 1 colonnine, 555.4 kWh coperti su 688.7 kWh (Domanda agg: 688.7 kWh)
# H3 881f992637fffff: 2 colonnine, 1110.9 kWh coperti su 1569.1 kWh (Domanda agg: 1569.1 kWh)
# H3 881f992631fffff: 2 colonnine, 1110.9 kWh coperti su 1356.6 kWh (Domanda agg: 1356.6 kWh)
# H3 881f99215bfffff: 1 colonnine, 555.4 kWh coperti su 990.8 kWh (Domanda agg: 990.8 kWh)
# H3 881f992021fffff: 1 colonnine, 555.4 kWh coperti su 981.2 kWh (Domanda agg: 981.2 kWh)
# H3 881ea4d351fffff: 2 colonnine, 1110.9 kWh coperti su 1658.4 kWh (Domanda agg: 1658.4 kWh)
# H3 881f8a69a5fffff: 2 colonnine, 1110.9 kWh coperti su 1356.9 kWh (Domanda agg: 1356.9 kWh)
# H3 881f8a693bfffff: 3 colonnine, 1666.3 kWh coperti su 1885.4 kWh (Domanda agg: 1885.4 kWh)
# H3 881f8a6939fffff: 3 colonnine, 1666.3 kWh coperti su 1768.9 kWh (Domanda agg: 1768.9 kWh)
# H3 881ea4d237fffff: 1 colonnine, 555.4 kWh coperti su 788.0 kWh (Domanda agg: 788.0 kWh)
# H3 881f8a6917fffff: 2 colonnine, 1110.9 kWh coperti su 1258.3 kWh (Domanda agg: 1258.3 kWh)
# H3 881f99a6dbfffff: 1 colonnine, 555.4 kWh coperti su 866.4 kWh (Domanda agg: 866.4 kWh)
# H3 881ea4d231fffff: 1 colonnine, 555.4 kWh coperti su 572.4 kWh (Domanda agg: 572.4 kWh)
# H3 881ea4d235fffff: 1 colonnine, 555.4 kWh coperti su 909.5 kWh (Domanda agg: 909.5 kWh)
# H3 881f8a6915fffff: 1 colonnine, 555.4 kWh coperti su 687.7 kWh (Domanda agg: 687.7 kWh)
# H3 881ea4d049fffff: 2 colonnine, 1110.9 kWh coperti su 1364.2 kWh (Domanda agg: 1364.2 kWh)
# H3 881ea69761fffff: 1 colonnine, 555.4 kWh coperti su 916.4 kWh (Domanda agg: 916.4 kWh)
# H3 881ea69749fffff: 1 colonnine, 555.4 kWh coperti su 805.8 kWh (Domanda agg: 805.8 kWh)
# H3 881ea69759fffff: 1 colonnine, 555.4 kWh coperti su 885.3 kWh (Domanda agg: 885.3 kWh)
# H3 881ea69299fffff: 2 colonnine, 1110.9 kWh coperti su 1262.3 kWh (Domanda agg: 1262.3 kWh)
# H3 881ea69291fffff: 2 colonnine, 1110.9 kWh coperti su 1277.5 kWh (Domanda agg: 1277.5 kWh)
# H3 881ea69745fffff: 1 colonnine, 555.4 kWh coperti su 870.2 kWh (Domanda agg: 870.2 kWh)
# H3 881ea692bbfffff: 1 colonnine, 555.4 kWh coperti su 790.9 kWh (Domanda agg: 790.9 kWh)
# H3 881ea69751fffff: 1 colonnine, 555.4 kWh coperti su 781.2 kWh (Domanda agg: 781.2 kWh)
# H3 881f992da5fffff: 1 colonnine, 555.4 kWh coperti su 899.3 kWh (Domanda agg: 899.3 kWh)
# H3 881ea69293fffff: 2 colonnine, 1110.9 kWh coperti su 1225.9 kWh (Domanda agg: 1225.9 kWh)
# H3 881ea6929dfffff: 1 colonnine, 555.4 kWh coperti su 1039.0 kWh (Domanda agg: 1039.0 kWh)
# H3 881ea692d3fffff: 1 colonnine, 555.4 kWh coperti su 765.0 kWh (Domanda agg: 765.0 kWh)
# H3 881ea69741fffff: 2 colonnine, 1110.9 kWh coperti su 1312.6 kWh (Domanda agg: 1312.6 kWh)
# H3 881f992a67fffff: 2 colonnine, 1110.9 kWh coperti su 1394.6 kWh (Domanda agg: 1394.6 kWh)
# H3 881f992a05fffff: 1 colonnine, 555.4 kWh coperti su 942.2 kWh (Domanda agg: 942.2 kWh)
# H3 881f992a03fffff: 2 colonnine, 1110.9 kWh coperti su 1621.2 kWh (Domanda agg: 1621.2 kWh)
# H3 881f992a29fffff: 2 colonnine, 1110.9 kWh coperti su 1159.0 kWh (Domanda agg: 1159.0 kWh)
# H3 881f992a63fffff: 2 colonnine, 1110.9 kWh coperti su 1290.5 kWh (Domanda agg: 1290.5 kWh)
# H3 881f8a634dfffff: 1 colonnine, 555.4 kWh coperti su 984.1 kWh (Domanda agg: 984.1 kWh)
# H3 881f99ac8bfffff: 1 colonnine, 555.4 kWh coperti su 815.4 kWh (Domanda agg: 815.4 kWh)
# H3 881f99ac83fffff: 1 colonnine, 555.4 kWh coperti su 583.7 kWh (Domanda agg: 583.7 kWh)
# H3 881f99acabfffff: 1 colonnine, 555.4 kWh coperti su 613.5 kWh (Domanda agg: 613.5 kWh)
# H3 881ea4d8a5fffff: 2 colonnine, 1110.9 kWh coperti su 1512.7 kWh (Domanda agg: 1512.7 kWh)
# H3 881ea4d9d7fffff: 1 colonnine, 555.4 kWh coperti su 730.9 kWh (Domanda agg: 730.9 kWh)
# H3 881ea4d8adfffff: 1 colonnine, 555.4 kWh coperti su 673.7 kWh (Domanda agg: 673.7 kWh)
# H3 881f99385bfffff: 1 colonnine, 555.4 kWh coperti su 868.3 kWh (Domanda agg: 868.3 kWh)
# H3 881f992ae9fffff: 1 colonnine, 555.4 kWh coperti su 699.1 kWh (Domanda agg: 699.1 kWh)
# H3 881f992ae1fffff: 1 colonnine, 555.4 kWh coperti su 848.3 kWh (Domanda agg: 848.3 kWh)
# H3 881f992ae7fffff: 1 colonnine, 555.4 kWh coperti su 675.8 kWh (Domanda agg: 675.8 kWh)
# H3 881f992a17fffff: 1 colonnine, 555.4 kWh coperti su 833.3 kWh (Domanda agg: 833.3 kWh)
# H3 881f992a1dfffff: 1 colonnine, 555.4 kWh coperti su 641.6 kWh (Domanda agg: 641.6 kWh)
# H3 881f992dd1fffff: 2 colonnine, 1110.9 kWh coperti su 1331.8 kWh (Domanda agg: 1331.8 kWh)
# H3 881f992dd5fffff: 2 colonnine, 1110.9 kWh coperti su 1175.8 kWh (Domanda agg: 1175.8 kWh)
# H3 881f992dd9fffff: 1 colonnine, 555.4 kWh coperti su 712.8 kWh (Domanda agg: 712.8 kWh)
# H3 881f992d9dfffff: 1 colonnine, 555.4 kWh coperti su 680.1 kWh (Domanda agg: 680.1 kWh)
# H3 881ea4cb55fffff: 1 colonnine, 555.4 kWh coperti su 641.1 kWh (Domanda agg: 641.1 kWh)
# H3 881ea4cb59fffff: 2 colonnine, 1110.9 kWh coperti su 1123.8 kWh (Domanda agg: 1123.8 kWh)
# H3 881ea4cb51fffff: 1 colonnine, 555.4 kWh coperti su 711.1 kWh (Domanda agg: 711.1 kWh)
# H3 881f9926edfffff: 1 colonnine, 555.4 kWh coperti su 951.5 kWh (Domanda agg: 951.5 kWh)
# H3 881f992825fffff: 1 colonnine, 555.4 kWh coperti su 747.2 kWh (Domanda agg: 747.2 kWh)
# H3 881f992829fffff: 1 colonnine, 555.4 kWh coperti su 591.8 kWh (Domanda agg: 591.8 kWh)
# H3 881f992911fffff: 1 colonnine, 555.4 kWh coperti su 822.6 kWh (Domanda agg: 822.6 kWh)
# H3 881f99a6cbfffff: 1 colonnine, 555.4 kWh coperti su 703.2 kWh (Domanda agg: 703.2 kWh)
# H3 881ea4d335fffff: 1 colonnine, 555.4 kWh coperti su 750.7 kWh (Domanda agg: 750.7 kWh)
# H3 881f99a6d1fffff: 1 colonnine, 555.4 kWh coperti su 792.3 kWh (Domanda agg: 792.3 kWh)
# H3 881ea4c26dfffff: 1 colonnine, 555.4 kWh coperti su 992.8 kWh (Domanda agg: 992.8 kWh)
# H3 881ea4d005fffff: 1 colonnine, 555.4 kWh coperti su 577.6 kWh (Domanda agg: 577.6 kWh)
# H3 881ea4d131fffff: 2 colonnine, 1110.9 kWh coperti su 1132.5 kWh (Domanda agg: 1132.5 kWh)
# H3 881f992345fffff: 1 colonnine, 555.4 kWh coperti su 654.8 kWh (Domanda agg: 654.8 kWh)
# H3 881f992369fffff: 2 colonnine, 1110.9 kWh coperti su 1323.0 kWh (Domanda agg: 1323.0 kWh)
# H3 881f992363fffff: 1 colonnine, 555.4 kWh coperti su 603.1 kWh (Domanda agg: 603.1 kWh)
# H3 881f9931a7fffff: 1 colonnine, 555.4 kWh coperti su 666.3 kWh (Domanda agg: 666.3 kWh)
# H3 881f992343fffff: 1 colonnine, 555.4 kWh coperti su 783.5 kWh (Domanda agg: 783.5 kWh)
# H3 881f99399bfffff: 1 colonnine, 555.4 kWh coperti su 732.3 kWh (Domanda agg: 732.3 kWh)
# H3 881f992689fffff: 1 colonnine, 555.4 kWh coperti su 697.7 kWh (Domanda agg: 697.7 kWh)
# H3 881f9930e1fffff: 1 colonnine, 555.4 kWh coperti su 616.9 kWh (Domanda agg: 616.9 kWh)
# H3 881f993017fffff: 2 colonnine, 1110.9 kWh coperti su 1139.6 kWh (Domanda agg: 1139.6 kWh)
# H3 881f9930c5fffff: 3 colonnine, 1666.3 kWh coperti su 1974.3 kWh (Domanda agg: 1974.3 kWh)
# H3 881ea4430dfffff: 1 colonnine, 555.4 kWh coperti su 788.5 kWh (Domanda agg: 788.5 kWh)
# H3 881ea44347fffff: 1 colonnine, 555.4 kWh coperti su 608.7 kWh (Domanda agg: 608.7 kWh)
# H3 881f99a511fffff: 1 colonnine, 555.4 kWh coperti su 804.4 kWh (Domanda agg: 804.4 kWh)
# H3 881ea4c99bfffff: 1 colonnine, 555.4 kWh coperti su 807.3 kWh (Domanda agg: 807.3 kWh)
# H3 881ea4c8adfffff: 1 colonnine, 555.4 kWh coperti su 787.7 kWh (Domanda agg: 787.7 kWh)
# H3 881ea4c8a5fffff: 1 colonnine, 555.4 kWh coperti su 801.6 kWh (Domanda agg: 801.6 kWh)
# H3 881ea4c9abfffff: 1 colonnine, 555.4 kWh coperti su 611.6 kWh (Domanda agg: 611.6 kWh)
# H3 881ea4c995fffff: 1 colonnine, 555.4 kWh coperti su 846.7 kWh (Domanda agg: 846.7 kWh)
# H3 881f992159fffff: 1 colonnine, 555.4 kWh coperti su 884.0 kWh (Domanda agg: 884.0 kWh)
# H3 881ea6966bfffff: 1 colonnine, 555.4 kWh coperti su 595.4 kWh (Domanda agg: 595.4 kWh)
# H3 881f99af17fffff: 1 colonnine, 555.4 kWh coperti su 789.4 kWh (Domanda agg: 789.4 kWh)
# H3 881f99af19fffff: 1 colonnine, 555.4 kWh coperti su 861.5 kWh (Domanda agg: 861.5 kWh)
# H3 881f8a78b7fffff: 1 colonnine, 555.4 kWh coperti su 1020.9 kWh (Domanda agg: 1020.9 kWh)
# H3 881ea6928bfffff: 1 colonnine, 555.4 kWh coperti su 604.6 kWh (Domanda agg: 604.6 kWh)
# H3 881ea4ce2dfffff: 1 colonnine, 555.4 kWh coperti su 645.9 kWh (Domanda agg: 645.9 kWh)
# H3 881ea4ce65fffff: 1 colonnine, 555.4 kWh coperti su 685.5 kWh (Domanda agg: 685.5 kWh)
# H3 881f8a693dfffff: 1 colonnine, 555.4 kWh coperti su 746.0 kWh (Domanda agg: 746.0 kWh)
# H3 881f99a709fffff: 1 colonnine, 555.4 kWh coperti su 698.0 kWh (Domanda agg: 698.0 kWh)
# H3 881f8a692bfffff: 1 colonnine, 555.4 kWh coperti su 774.0 kWh (Domanda agg: 774.0 kWh)
# H3 881ea4cb67fffff: 1 colonnine, 555.4 kWh coperti su 570.3 kWh (Domanda agg: 570.3 kWh)
#
# Domanda totale coperta: 2243381.77 kWh

# %% [markdown]
# ### Map visualisation

# %%
mappa = crea_mappa_colonnine_discrete(gdf_risultati_cons2030_alpha)
mappa
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Save the map as an HTML file
mappa.save("/content/drive/Shareddrives/OM in Business Analytics/OM in BA - Project/Codice/04 - Modello/log_heatmap_fifth_model_def.html")

# %% [markdown]
# ### Results

# %%
total_allocated_chargers = gdf_risultati_cons2030_alpha["Colonnine allocate"].sum()
total_covered_demand = gdf_risultati_cons2030_alpha["Domanda coperta (kWh)"].sum()
total_demand = gdf_risultati_cons2030_alpha["Domanda Giornaliera Ponderata (kWh)"].sum()

print(f"Total allocated charging stations: {total_allocated_chargers}")
print(f"Total covered demand (kWh): {total_covered_demand:.2f}")
print(f"Total demand (kWh): {total_demand:.2f}")
# Out:
# Total allocated charging stations: 4039
# Total covered demand (kWh): 2243381.77
# Total demand (kWh): 10009341.21

# %% [markdown]
# ## SIXTH MODEL
# ## Charging Station Allocation Model – 2030 Optimistic Scenario
# This model estimates the allocation of 7,345 charging stations under an optimistic 2030 scenario. It assumes increased energy demand. The building index has been excluded, as estimating future building locations and counts would require a separate, dedicated analysis.

# %%
# !pip install h3==3.*
# Out:
# Requirement already satisfied: h3==3.* in /usr/local/lib/python3.11/dist-packages (3.7.7)

# %% [markdown]
# ### Neighbor list

# %%
import h3

# Get the unique list of hexagons in your GeoDataFrame
h3_ids_presenti = set(gdf_ottimistico['h3_id'])

# Create a dictionary {index in gdf : list of neighboring indices}
h3_id_to_idx = {h3_id: idx for idx, h3_id in enumerate(gdf_ottimistico['h3_id'])}

neighbors_dict = {}

for idx, row in gdf_ottimistico.iterrows():
    h3_id = row['h3_id']
    # Get H3 neighbors (k_ring with radius 1)
    vicini_h3 = h3.k_ring(h3_id, 1)
    # Filter only those present in your dataframe
    vicini_presenti = [h3_id_to_idx[v] for v in vicini_h3 if v in h3_ids_presenti and v != h3_id]
    neighbors_dict[idx] = vicini_presenti

print(f"Neighbor dictionary created with {len(neighbors_dict)} hexagons")
# Out:
# Neighbor dictionary created with 6495 hexagons

# %%
gdf_risultati_ott2030 = ottimizza_colonnine_con_domanda_aggregata(gdf_ottimistico, p_colonnine=7435)
# Out:
# H3 881f99274bfffff: 10 colonnine, 5554.3 kWh coperti su 33496.5 kWh (Domanda agg: 33496.5 kWh)
# H3 881f992215fffff: 10 colonnine, 5554.3 kWh coperti su 42338.8 kWh (Domanda agg: 42338.8 kWh)
# H3 881f992213fffff: 10 colonnine, 5554.3 kWh coperti su 69387.1 kWh (Domanda agg: 69387.1 kWh)
# H3 881f9935c7fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f9935a1fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f9922ddfffff: 10 colonnine, 5554.3 kWh coperti su 113962.5 kWh (Domanda agg: 113962.5 kWh)
# H3 881f992285fffff: 10 colonnine, 5554.3 kWh coperti su 56753.4 kWh (Domanda agg: 56753.4 kWh)
# H3 881f9922e3fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f992217fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f993501fffff: 10 colonnine, 5554.3 kWh coperti su 73222.5 kWh (Domanda agg: 73222.5 kWh)
# H3 881f99353bfffff: 10 colonnine, 5554.3 kWh coperti su 118573.8 kWh (Domanda agg: 118573.8 kWh)
# H3 881f992295fffff: 10 colonnine, 5554.3 kWh coperti su 58835.9 kWh (Domanda agg: 58835.9 kWh)
# H3 881f9922cdfffff: 10 colonnine, 5554.3 kWh coperti su 85878.7 kWh (Domanda agg: 85878.7 kWh)
# H3 881f9920d9fffff: 10 colonnine, 5554.3 kWh coperti su 51398.2 kWh (Domanda agg: 51398.2 kWh)
# H3 881f992745fffff: 10 colonnine, 5554.3 kWh coperti su 52737.5 kWh (Domanda agg: 52737.5 kWh)
# H3 881f992291fffff: 10 colonnine, 5554.3 kWh coperti su 77255.8 kWh (Domanda agg: 77255.8 kWh)
# H3 881f992233fffff: 10 colonnine, 5554.3 kWh coperti su 73473.6 kWh (Domanda agg: 73473.6 kWh)
# H3 881f993537fffff: 10 colonnine, 5554.3 kWh coperti su 22696.7 kWh (Domanda agg: 22696.7 kWh)
# H3 881f993531fffff: 10 colonnine, 5554.3 kWh coperti su 85781.8 kWh (Domanda agg: 85781.8 kWh)
# H3 881f9922c9fffff: 10 colonnine, 5554.3 kWh coperti su 92415.9 kWh (Domanda agg: 92415.9 kWh)
# H3 881f992741fffff: 10 colonnine, 5554.3 kWh coperti su 76560.3 kWh (Domanda agg: 76560.3 kWh)
# H3 881f993511fffff: 10 colonnine, 5554.3 kWh coperti su 82796.8 kWh (Domanda agg: 82796.8 kWh)
# H3 881f99270dfffff: 10 colonnine, 5554.3 kWh coperti su 91679.6 kWh (Domanda agg: 91679.6 kWh)
# H3 881f992287fffff: 10 colonnine, 5554.3 kWh coperti su 33407.4 kWh (Domanda agg: 33407.4 kWh)
# H3 881f992253fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f992211fffff: 10 colonnine, 5554.3 kWh coperti su 93525.1 kWh (Domanda agg: 93525.1 kWh)
# H3 881f992231fffff: 10 colonnine, 5554.3 kWh coperti su 48146.7 kWh (Domanda agg: 48146.7 kWh)
# H3 881f9922d7fffff: 10 colonnine, 5554.3 kWh coperti su 63423.5 kWh (Domanda agg: 63423.5 kWh)
# H3 881f9935a7fffff: 10 colonnine, 5554.3 kWh coperti su 30520.5 kWh (Domanda agg: 30520.5 kWh)
# H3 881f99221bfffff: 10 colonnine, 5554.3 kWh coperti su 61989.3 kWh (Domanda agg: 61989.3 kWh)
# H3 881f992239fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f992761fffff: 10 colonnine, 5554.3 kWh coperti su 75255.9 kWh (Domanda agg: 75255.9 kWh)
# H3 881f9935a5fffff: 10 colonnine, 5554.3 kWh coperti su 73676.1 kWh (Domanda agg: 73676.1 kWh)
# H3 881f993557fffff: 10 colonnine, 5554.3 kWh coperti su 86996.5 kWh (Domanda agg: 86996.5 kWh)
# H3 881f9935e1fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f99358dfffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f9922b3fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f9922edfffff: 10 colonnine, 5554.3 kWh coperti su 54261.8 kWh (Domanda agg: 54261.8 kWh)
# H3 881f99223bfffff: 10 colonnine, 5554.3 kWh coperti su 56688.6 kWh (Domanda agg: 56688.6 kWh)
# H3 881f992283fffff: 10 colonnine, 5554.3 kWh coperti su 98841.8 kWh (Domanda agg: 98841.8 kWh)
# H3 881f993519fffff: 10 colonnine, 5554.3 kWh coperti su 85502.5 kWh (Domanda agg: 85502.5 kWh)
# H3 881f993553fffff: 10 colonnine, 5554.3 kWh coperti su 81220.2 kWh (Domanda agg: 81220.2 kWh)
# H3 881f993535fffff: 10 colonnine, 5554.3 kWh coperti su 68032.1 kWh (Domanda agg: 68032.1 kWh)
# H3 881f993585fffff: 10 colonnine, 5554.3 kWh coperti su 70039.5 kWh (Domanda agg: 70039.5 kWh)
# H3 881f993539fffff: 10 colonnine, 5554.3 kWh coperti su 88737.6 kWh (Domanda agg: 88737.6 kWh)
# H3 881f992203fffff: 10 colonnine, 5554.3 kWh coperti su 42778.6 kWh (Domanda agg: 42778.6 kWh)
# H3 881f9935e9fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f992299fffff: 10 colonnine, 5554.3 kWh coperti su 46732.0 kWh (Domanda agg: 46732.0 kWh)
# H3 881f9922d1fffff: 10 colonnine, 5554.3 kWh coperti su 160025.3 kWh (Domanda agg: 160025.3 kWh)
# H3 881f992251fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f993507fffff: 10 colonnine, 5554.3 kWh coperti su 126241.4 kWh (Domanda agg: 126241.4 kWh)
# H3 881f9922a9fffff: 10 colonnine, 5554.3 kWh coperti su 97680.5 kWh (Domanda agg: 97680.5 kWh)
# H3 881f992765fffff: 10 colonnine, 5554.3 kWh coperti su 54803.1 kWh (Domanda agg: 54803.1 kWh)
# H3 881f99229bfffff: 10 colonnine, 5554.3 kWh coperti su 106877.8 kWh (Domanda agg: 106877.8 kWh)
# H3 881f99276dfffff: 10 colonnine, 5554.3 kWh coperti su 79241.2 kWh (Domanda agg: 79241.2 kWh)
# H3 881f99353dfffff: 10 colonnine, 5554.3 kWh coperti su 99546.3 kWh (Domanda agg: 99546.3 kWh)
# H3 881f9922c7fffff: 10 colonnine, 5554.3 kWh coperti su 81913.2 kWh (Domanda agg: 81913.2 kWh)
# H3 881f993563fffff: 10 colonnine, 5554.3 kWh coperti su 48280.9 kWh (Domanda agg: 48280.9 kWh)
# H3 881f992293fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f99352bfffff: 10 colonnine, 5554.3 kWh coperti su 95832.4 kWh (Domanda agg: 95832.4 kWh)
# H3 881f9935cdfffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f993581fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f99351bfffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f992297fffff: 10 colonnine, 5554.3 kWh coperti su 52641.7 kWh (Domanda agg: 52641.7 kWh)
# H3 881f9922c5fffff: 10 colonnine, 5554.3 kWh coperti su 153173.5 kWh (Domanda agg: 153173.5 kWh)
# H3 881f992769fffff: 10 colonnine, 5554.3 kWh coperti su 71717.1 kWh (Domanda agg: 71717.1 kWh)
# H3 881f993425fffff: 10 colonnine, 5554.3 kWh coperti su 58271.1 kWh (Domanda agg: 58271.1 kWh)
# H3 881f9935adfffff: 10 colonnine, 5554.3 kWh coperti su 23421.0 kWh (Domanda agg: 23421.0 kWh)
# H3 881f992219fffff: 10 colonnine, 5554.3 kWh coperti su 104756.7 kWh (Domanda agg: 104756.7 kWh)
# H3 881f99274dfffff: 10 colonnine, 5554.3 kWh coperti su 96197.7 kWh (Domanda agg: 96197.7 kWh)
# H3 881f9922c1fffff: 10 colonnine, 5554.3 kWh coperti su 130813.0 kWh (Domanda agg: 130813.0 kWh)
# H3 881f993427fffff: 10 colonnine, 5554.3 kWh coperti su 31535.6 kWh (Domanda agg: 31535.6 kWh)
# H3 881f9922cbfffff: 10 colonnine, 5554.3 kWh coperti su 89937.0 kWh (Domanda agg: 89937.0 kWh)
# H3 881f993503fffff: 10 colonnine, 5554.3 kWh coperti su 82830.3 kWh (Domanda agg: 82830.3 kWh)
# H3 881f992237fffff: 10 colonnine, 5554.3 kWh coperti su 77983.7 kWh (Domanda agg: 77983.7 kWh)
# H3 881f99205bfffff: 10 colonnine, 5554.3 kWh coperti su 41832.7 kWh (Domanda agg: 41832.7 kWh)
# H3 881f9935a3fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f99229dfffff: 10 colonnine, 5554.3 kWh coperti su 68147.7 kWh (Domanda agg: 68147.7 kWh)
# H3 881f9935c5fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f99351dfffff: 10 colonnine, 5554.3 kWh coperti su 52646.9 kWh (Domanda agg: 52646.9 kWh)
# H3 881f993515fffff: 10 colonnine, 5554.3 kWh coperti su 80835.3 kWh (Domanda agg: 80835.3 kWh)
# H3 881f992749fffff: 10 colonnine, 5554.3 kWh coperti su 53837.3 kWh (Domanda agg: 53837.3 kWh)
# H3 881f9935e5fffff: 10 colonnine, 5554.3 kWh coperti su 49902.7 kWh (Domanda agg: 49902.7 kWh)
# H3 881f9935ebfffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f99352dfffff: 10 colonnine, 5554.3 kWh coperti su 62713.6 kWh (Domanda agg: 62713.6 kWh)
# H3 881f99228dfffff: 10 colonnine, 5554.3 kWh coperti su 125897.6 kWh (Domanda agg: 125897.6 kWh)
# H3 881f9935e3fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f993513fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f993567fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f9922adfffff: 10 colonnine, 5554.3 kWh coperti su 36909.1 kWh (Domanda agg: 36909.1 kWh)
# H3 881f9935e7fffff: 10 colonnine, 5554.3 kWh coperti su 98139.6 kWh (Domanda agg: 98139.6 kWh)
# H3 881f992747fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f99276bfffff: 10 colonnine, 5554.3 kWh coperti su 59715.6 kWh (Domanda agg: 59715.6 kWh)
# H3 881f993527fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f993529fffff: 10 colonnine, 5554.3 kWh coperti su 39955.8 kWh (Domanda agg: 39955.8 kWh)
# H3 881f992289fffff: 10 colonnine, 5554.3 kWh coperti su 89605.0 kWh (Domanda agg: 89605.0 kWh)
# H3 881f9935edfffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f9922d9fffff: 10 colonnine, 5554.3 kWh coperti su 184481.2 kWh (Domanda agg: 184481.2 kWh)
# H3 881f99350dfffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f992281fffff: 10 colonnine, 5554.3 kWh coperti su 152588.2 kWh (Domanda agg: 152588.2 kWh)
# H3 881f99228bfffff: 10 colonnine, 5554.3 kWh coperti su 67323.4 kWh (Domanda agg: 67323.4 kWh)
# H3 881f9922e1fffff: 10 colonnine, 5554.3 kWh coperti su 72497.1 kWh (Domanda agg: 72497.1 kWh)
# H3 881f9922d5fffff: 10 colonnine, 5554.3 kWh coperti su 76941.6 kWh (Domanda agg: 76941.6 kWh)
# H3 881f993505fffff: 10 colonnine, 5554.3 kWh coperti su 59927.1 kWh (Domanda agg: 59927.1 kWh)
# H3 881f993517fffff: 10 colonnine, 5554.3 kWh coperti su 53607.2 kWh (Domanda agg: 53607.2 kWh)
# H3 881f9935abfffff: 10 colonnine, 5554.3 kWh coperti su 22006.5 kWh (Domanda agg: 22006.5 kWh)
# H3 881f9922bbfffff: 10 colonnine, 5554.3 kWh coperti su 49516.5 kWh (Domanda agg: 49516.5 kWh)
# H3 881f9922d3fffff: 10 colonnine, 5554.3 kWh coperti su 100694.3 kWh (Domanda agg: 100694.3 kWh)
# H3 881f993521fffff: 10 colonnine, 5554.3 kWh coperti su 94077.8 kWh (Domanda agg: 94077.8 kWh)
# H3 881f9922ebfffff: 10 colonnine, 5554.3 kWh coperti su 99967.7 kWh (Domanda agg: 99967.7 kWh)
# H3 881f9922e9fffff: 10 colonnine, 5554.3 kWh coperti su 72617.4 kWh (Domanda agg: 72617.4 kWh)
# H3 881f993525fffff: 10 colonnine, 5554.3 kWh coperti su 52695.1 kWh (Domanda agg: 52695.1 kWh)
# H3 881f9935b5fffff: 10 colonnine, 5554.3 kWh coperti su 50585.9 kWh (Domanda agg: 50585.9 kWh)
# H3 881f9922c3fffff: 10 colonnine, 5554.3 kWh coperti su 69437.5 kWh (Domanda agg: 69437.5 kWh)
# H3 881f9922e7fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f9935a9fffff: 10 colonnine, 5554.3 kWh coperti su 111836.0 kWh (Domanda agg: 111836.0 kWh)
# H3 881f99225bfffff: 10 colonnine, 5554.3 kWh coperti su 60751.7 kWh (Domanda agg: 60751.7 kWh)
# H3 881f9922dbfffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f992059fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f9922e5fffff: 10 colonnine, 5554.3 kWh coperti su 50009.1 kWh (Domanda agg: 50009.1 kWh)
# H3 881f993523fffff: 10 colonnine, 5554.3 kWh coperti su 58967.9 kWh (Domanda agg: 58967.9 kWh)
# H3 881f993533fffff: 10 colonnine, 5554.3 kWh coperti su 74957.1 kWh (Domanda agg: 74957.1 kWh)
# H3 881f992497fffff: 10 colonnine, 5554.3 kWh coperti su 7083.3 kWh (Domanda agg: 7083.3 kWh)
# H3 881ea45135fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45333fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea4510dfffff: 10 colonnine, 5554.3 kWh coperti su 15072.5 kWh (Domanda agg: 15072.5 kWh)
# H3 881ea45ad1fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45addfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45149fffff: 10 colonnine, 5554.3 kWh coperti su 9646.1 kWh (Domanda agg: 9646.1 kWh)
# H3 881ea4512dfffff: 10 colonnine, 5554.3 kWh coperti su 6835.6 kWh (Domanda agg: 6835.6 kWh)
# H3 881ea45153fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45109fffff: 8 colonnine, 4443.4 kWh coperti su 4763.2 kWh (Domanda agg: 4763.2 kWh)
# H3 881ea45a81fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea451e7fffff: 10 colonnine, 5554.3 kWh coperti su 19703.0 kWh (Domanda agg: 19703.0 kWh)
# H3 881ea45161fffff: 10 colonnine, 5554.3 kWh coperti su 14810.0 kWh (Domanda agg: 14810.0 kWh)
# H3 881ea45a83fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea451e3fffff: 10 colonnine, 5554.3 kWh coperti su 8850.3 kWh (Domanda agg: 8850.3 kWh)
# H3 881ea451e1fffff: 10 colonnine, 5554.3 kWh coperti su 12317.5 kWh (Domanda agg: 12317.5 kWh)
# H3 881ea45025fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45107fffff: 10 colonnine, 5554.3 kWh coperti su 6127.9 kWh (Domanda agg: 6127.9 kWh)
# H3 881ea4515dfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45ac3fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea451edfffff: 10 colonnine, 5554.3 kWh coperti su 8614.1 kWh (Domanda agg: 8614.1 kWh)
# H3 881ea45133fffff: 10 colonnine, 5554.3 kWh coperti su 9659.1 kWh (Domanda agg: 9659.1 kWh)
# H3 881ea45a99fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea4513dfffff: 10 colonnine, 5554.3 kWh coperti su 9230.5 kWh (Domanda agg: 9230.5 kWh)
# H3 881ea45103fffff: 10 colonnine, 5554.3 kWh coperti su 15092.9 kWh (Domanda agg: 15092.9 kWh)
# H3 881ea451a1fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45147fffff: 10 colonnine, 5554.3 kWh coperti su 11821.1 kWh (Domanda agg: 11821.1 kWh)
# H3 881ea4502dfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea4511bfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45143fffff: 10 colonnine, 5554.3 kWh coperti su 6632.2 kWh (Domanda agg: 6632.2 kWh)
# H3 881ea45ac9fffff: 10 colonnine, 5554.3 kWh coperti su 8501.9 kWh (Domanda agg: 8501.9 kWh)
# H3 881ea45ab9fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea4514bfffff: 10 colonnine, 5554.3 kWh coperti su 7509.1 kWh (Domanda agg: 7509.1 kWh)
# H3 881ea45061fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea4513bfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45a87fffff: 9 colonnine, 4998.9 kWh coperti su 5128.0 kWh (Domanda agg: 5128.0 kWh)
# H3 881ea4515bfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45117fffff: 10 colonnine, 5554.3 kWh coperti su 13736.6 kWh (Domanda agg: 13736.6 kWh)
# H3 881ea451abfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45119fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea451e5fffff: 10 colonnine, 5554.3 kWh coperti su 9815.7 kWh (Domanda agg: 9815.7 kWh)
# H3 881ea45065fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45129fffff: 10 colonnine, 5554.3 kWh coperti su 12628.9 kWh (Domanda agg: 12628.9 kWh)
# H3 881ea451adfffff: 10 colonnine, 5554.3 kWh coperti su 8756.4 kWh (Domanda agg: 8756.4 kWh)
# H3 881ea45115fffff: 10 colonnine, 5554.3 kWh coperti su 13456.7 kWh (Domanda agg: 13456.7 kWh)
# H3 881ea45ad3fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45169fffff: 10 colonnine, 5554.3 kWh coperti su 9389.4 kWh (Domanda agg: 9389.4 kWh)
# H3 881ea451e9fffff: 10 colonnine, 5554.3 kWh coperti su 7212.5 kWh (Domanda agg: 7212.5 kWh)
# H3 881ea45337fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea4512bfffff: 10 colonnine, 5554.3 kWh coperti su 12509.1 kWh (Domanda agg: 12509.1 kWh)
# H3 881ea4514dfffff: 10 colonnine, 5554.3 kWh coperti su 8653.5 kWh (Domanda agg: 8653.5 kWh)
# H3 881ea45139fffff: 10 colonnine, 5554.3 kWh coperti su 10934.6 kWh (Domanda agg: 10934.6 kWh)
# H3 881ea45adbfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45145fffff: 10 colonnine, 5554.3 kWh coperti su 7038.6 kWh (Domanda agg: 7038.6 kWh)
# H3 881ea45105fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea451a5fffff: 10 colonnine, 5554.3 kWh coperti su 8299.7 kWh (Domanda agg: 8299.7 kWh)
# H3 881ea45155fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45167fffff: 10 colonnine, 5554.3 kWh coperti su 9103.4 kWh (Domanda agg: 9103.4 kWh)
# H3 881ea45163fffff: 10 colonnine, 5554.3 kWh coperti su 12419.7 kWh (Domanda agg: 12419.7 kWh)
# H3 881ea45113fffff: 10 colonnine, 5554.3 kWh coperti su 9290.0 kWh (Domanda agg: 9290.0 kWh)
# H3 881ea45101fffff: 10 colonnine, 5554.3 kWh coperti su 13960.7 kWh (Domanda agg: 13960.7 kWh)
# H3 881ea45ad5fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45335fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea451a9fffff: 10 colonnine, 5554.3 kWh coperti su 7708.9 kWh (Domanda agg: 7708.9 kWh)
# H3 881ea45131fffff: 10 colonnine, 5554.3 kWh coperti su 13763.4 kWh (Domanda agg: 13763.4 kWh)
# H3 881ea45123fffff: 10 colonnine, 5554.3 kWh coperti su 7437.1 kWh (Domanda agg: 7437.1 kWh)
# H3 881ea4516bfffff: 10 colonnine, 5554.3 kWh coperti su 16163.0 kWh (Domanda agg: 16163.0 kWh)
# H3 881ea451ebfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea4510bfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45137fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45121fffff: 10 colonnine, 5554.3 kWh coperti su 6373.2 kWh (Domanda agg: 6373.2 kWh)
# H3 881ea45b53fffff: 10 colonnine, 5554.3 kWh coperti su 6730.2 kWh (Domanda agg: 6730.2 kWh)
# H3 881f9925e7fffff: 10 colonnine, 5554.3 kWh coperti su 8470.6 kWh (Domanda agg: 8470.6 kWh)
# H3 881f992e91fffff: 10 colonnine, 5554.3 kWh coperti su 6853.8 kWh (Domanda agg: 6853.8 kWh)
# H3 881f992ec5fffff: 10 colonnine, 5554.3 kWh coperti su 8362.5 kWh (Domanda agg: 8362.5 kWh)
# H3 881f992583fffff: 10 colonnine, 5554.3 kWh coperti su 7954.7 kWh (Domanda agg: 7954.7 kWh)
# H3 881f992501fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f992515fffff: 10 colonnine, 5554.3 kWh coperti su 6417.0 kWh (Domanda agg: 6417.0 kWh)
# H3 881f992ed3fffff: 10 colonnine, 5554.3 kWh coperti su 8473.2 kWh (Domanda agg: 8473.2 kWh)
# H3 881f99250bfffff: 10 colonnine, 5554.3 kWh coperti su 6382.4 kWh (Domanda agg: 6382.4 kWh)
# H3 881ea45b47fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f992e9bfffff: 10 colonnine, 5554.3 kWh coperti su 8819.4 kWh (Domanda agg: 8819.4 kWh)
# H3 881ea45b65fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881ea45b09fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f992527fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881ea45b69fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f992537fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881ea45b4dfffff: 10 colonnine, 5554.3 kWh coperti su 11667.6 kWh (Domanda agg: 11667.6 kWh)
# H3 881f9925adfffff: 10 colonnine, 5554.3 kWh coperti su 9432.0 kWh (Domanda agg: 9432.0 kWh)
# H3 881ea45b0dfffff: 10 colonnine, 5554.3 kWh coperti su 5841.3 kWh (Domanda agg: 5841.3 kWh)
# H3 881f992e8bfffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f9925edfffff: 10 colonnine, 5554.3 kWh coperti su 10178.0 kWh (Domanda agg: 10178.0 kWh)
# H3 881ea45b0bfffff: 10 colonnine, 5554.3 kWh coperti su 7985.9 kWh (Domanda agg: 7985.9 kWh)
# H3 881f992e8dfffff: 10 colonnine, 5554.3 kWh coperti su 6643.3 kWh (Domanda agg: 6643.3 kWh)
# H3 881f9925a3fffff: 10 colonnine, 5554.3 kWh coperti su 9707.4 kWh (Domanda agg: 9707.4 kWh)
# H3 881ea45b67fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f992539fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f9925abfffff: 10 colonnine, 5554.3 kWh coperti su 13435.9 kWh (Domanda agg: 13435.9 kWh)
# H3 881f992587fffff: 10 colonnine, 5554.3 kWh coperti su 7909.3 kWh (Domanda agg: 7909.3 kWh)
# H3 881f992ed5fffff: 10 colonnine, 5554.3 kWh coperti su 9333.3 kWh (Domanda agg: 9333.3 kWh)
# H3 881f992e99fffff: 10 colonnine, 5554.3 kWh coperti su 13251.5 kWh (Domanda agg: 13251.5 kWh)
# H3 881f9925a7fffff: 10 colonnine, 5554.3 kWh coperti su 8337.3 kWh (Domanda agg: 8337.3 kWh)
# H3 881f9925b3fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f9925b1fffff: 10 colonnine, 5554.3 kWh coperti su 6998.7 kWh (Domanda agg: 6998.7 kWh)
# H3 881f992eb9fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881ea45b4bfffff: 10 colonnine, 5554.3 kWh coperti su 7187.1 kWh (Domanda agg: 7187.1 kWh)
# H3 881f992eddfffff: 9 colonnine, 4998.9 kWh coperti su 5191.1 kWh (Domanda agg: 5191.1 kWh)
# H3 881f9925ebfffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881ea45b63fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f99252bfffff: 10 colonnine, 5554.3 kWh coperti su 6623.6 kWh (Domanda agg: 6623.6 kWh)
# H3 881f9925a1fffff: 10 colonnine, 5554.3 kWh coperti su 12196.0 kWh (Domanda agg: 12196.0 kWh)
# H3 881f992503fffff: 10 colonnine, 5554.3 kWh coperti su 7234.0 kWh (Domanda agg: 7234.0 kWh)
# H3 881f992519fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f992ec1fffff: 10 colonnine, 5554.3 kWh coperti su 10002.8 kWh (Domanda agg: 10002.8 kWh)
# H3 881ea45b6dfffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881ea45b55fffff: 10 colonnine, 5554.3 kWh coperti su 12675.7 kWh (Domanda agg: 12675.7 kWh)
# H3 881f992ecdfffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f992509fffff: 10 colonnine, 5554.3 kWh coperti su 11371.9 kWh (Domanda agg: 11371.9 kWh)
# H3 881f992ec7fffff: 10 colonnine, 5554.3 kWh coperti su 6645.5 kWh (Domanda agg: 6645.5 kWh)
# H3 881f992585fffff: 10 colonnine, 5554.3 kWh coperti su 7330.2 kWh (Domanda agg: 7330.2 kWh)
# H3 881ea45b6bfffff: 10 colonnine, 5554.3 kWh coperti su 6646.8 kWh (Domanda agg: 6646.8 kWh)
# H3 881ea45b49fffff: 10 colonnine, 5554.3 kWh coperti su 7946.9 kWh (Domanda agg: 7946.9 kWh)
# H3 881f9925e5fffff: 10 colonnine, 5554.3 kWh coperti su 18541.8 kWh (Domanda agg: 18541.8 kWh)
# H3 881f99253bfffff: 10 colonnine, 5554.3 kWh coperti su 7197.9 kWh (Domanda agg: 7197.9 kWh)
# H3 881f992589fffff: 10 colonnine, 5554.3 kWh coperti su 6961.6 kWh (Domanda agg: 6961.6 kWh)
# H3 881f9925a9fffff: 10 colonnine, 5554.3 kWh coperti su 7940.4 kWh (Domanda agg: 7940.4 kWh)
# H3 881f992ec3fffff: 10 colonnine, 5554.3 kWh coperti su 8467.8 kWh (Domanda agg: 8467.8 kWh)
# H3 881f992ed9fffff: 10 colonnine, 5554.3 kWh coperti su 7664.1 kWh (Domanda agg: 7664.1 kWh)
# H3 881f992ec9fffff: 10 colonnine, 5554.3 kWh coperti su 6442.6 kWh (Domanda agg: 6442.6 kWh)
# H3 881ea45b57fffff: 10 colonnine, 5554.3 kWh coperti su 7029.5 kWh (Domanda agg: 7029.5 kWh)
# H3 881f9925b7fffff: 10 colonnine, 5554.3 kWh coperti su 7221.8 kWh (Domanda agg: 7221.8 kWh)
# H3 881f9925a5fffff: 10 colonnine, 5554.3 kWh coperti su 9615.8 kWh (Domanda agg: 9615.8 kWh)
# H3 881f9925e3fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881ea45b51fffff: 10 colonnine, 5554.3 kWh coperti su 7322.2 kWh (Domanda agg: 7322.2 kWh)
# H3 881f992529fffff: 10 colonnine, 5554.3 kWh coperti su 7497.0 kWh (Domanda agg: 7497.0 kWh)
# H3 881f992ed7fffff: 10 colonnine, 5554.3 kWh coperti su 6808.6 kWh (Domanda agg: 6808.6 kWh)
# H3 881f992523fffff: 10 colonnine, 5554.3 kWh coperti su 7393.2 kWh (Domanda agg: 7393.2 kWh)
# H3 881f992531fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881ea45b43fffff: 10 colonnine, 5554.3 kWh coperti su 11796.0 kWh (Domanda agg: 11796.0 kWh)
# H3 881ea45b45fffff: 10 colonnine, 5554.3 kWh coperti su 7412.5 kWh (Domanda agg: 7412.5 kWh)
# H3 881ea45b5bfffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f992513fffff: 10 colonnine, 5554.3 kWh coperti su 7067.4 kWh (Domanda agg: 7067.4 kWh)
# H3 881f9925b9fffff: 10 colonnine, 5554.3 kWh coperti su 6023.4 kWh (Domanda agg: 6023.4 kWh)
# H3 881ea45b41fffff: 10 colonnine, 5554.3 kWh coperti su 8358.8 kWh (Domanda agg: 8358.8 kWh)
# H3 881f9925b5fffff: 10 colonnine, 5554.3 kWh coperti su 10183.5 kWh (Domanda agg: 10183.5 kWh)
# H3 881f992535fffff: 6 colonnine, 3332.6 kWh coperti su 3526.8 kWh (Domanda agg: 3526.8 kWh)
# H3 881f992ebbfffff: 10 colonnine, 5554.3 kWh coperti su 7078.9 kWh (Domanda agg: 7078.9 kWh)
# H3 881f992eb3fffff: 10 colonnine, 5554.3 kWh coperti su 5817.6 kWh (Domanda agg: 5817.6 kWh)
# H3 881f992517fffff: 10 colonnine, 5554.3 kWh coperti su 6261.0 kWh (Domanda agg: 6261.0 kWh)
# H3 881f992edbfffff: 10 colonnine, 5554.3 kWh coperti su 6640.5 kWh (Domanda agg: 6640.5 kWh)
# H3 881f99362bfffff: 7 colonnine, 3888.0 kWh coperti su 4285.9 kWh (Domanda agg: 4285.9 kWh)
# H3 881f99360bfffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f993453fffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f99345bfffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f9936c5fffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f9936a9fffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f993617fffff: 10 colonnine, 5554.3 kWh coperti su 8148.5 kWh (Domanda agg: 8148.5 kWh)
# H3 881f99363dfffff: 10 colonnine, 5554.3 kWh coperti su 7233.5 kWh (Domanda agg: 7233.5 kWh)
# H3 881f993449fffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f99368dfffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f993635fffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f993601fffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f99344bfffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f99363bfffff: 10 colonnine, 5554.3 kWh coperti su 7546.0 kWh (Domanda agg: 7546.0 kWh)
# H3 881f99334dfffff: 6 colonnine, 3332.6 kWh coperti su 3354.4 kWh (Domanda agg: 3354.4 kWh)
# H3 881f9906a3fffff: 10 colonnine, 5554.3 kWh coperti su 11005.1 kWh (Domanda agg: 11005.1 kWh)
# H3 881f993369fffff: 10 colonnine, 5554.3 kWh coperti su 8627.4 kWh (Domanda agg: 8627.4 kWh)
# H3 881f9906a5fffff: 3 colonnine, 1666.3 kWh coperti su 2050.7 kWh (Domanda agg: 2050.7 kWh)
# H3 881f990695fffff: 10 colonnine, 5554.3 kWh coperti su 7666.3 kWh (Domanda agg: 7666.3 kWh)
# H3 881f990693fffff: 10 colonnine, 5554.3 kWh coperti su 7549.6 kWh (Domanda agg: 7549.6 kWh)
# H3 881f9906e7fffff: 6 colonnine, 3332.6 kWh coperti su 3463.2 kWh (Domanda agg: 3463.2 kWh)
# H3 881f9906a9fffff: 10 colonnine, 5554.3 kWh coperti su 7629.3 kWh (Domanda agg: 7629.3 kWh)
# H3 881f9906b1fffff: 9 colonnine, 4998.9 kWh coperti su 5300.2 kWh (Domanda agg: 5300.2 kWh)
# H3 881f9906b9fffff: 10 colonnine, 5554.3 kWh coperti su 6495.5 kWh (Domanda agg: 6495.5 kWh)
# H3 881f9904c7fffff: 3 colonnine, 1666.3 kWh coperti su 2050.7 kWh (Domanda agg: 2050.7 kWh)
# H3 881f9906b7fffff: 10 colonnine, 5554.3 kWh coperti su 5767.6 kWh (Domanda agg: 5767.6 kWh)
# H3 881f9904ebfffff: 3 colonnine, 1666.3 kWh coperti su 2050.7 kWh (Domanda agg: 2050.7 kWh)
# H3 881f9906bdfffff: 10 colonnine, 5554.3 kWh coperti su 11843.1 kWh (Domanda agg: 11843.1 kWh)
# H3 881f990685fffff: 10 colonnine, 5554.3 kWh coperti su 5887.0 kWh (Domanda agg: 5887.0 kWh)
# H3 881f9906b5fffff: 10 colonnine, 5554.3 kWh coperti su 6460.6 kWh (Domanda agg: 6460.6 kWh)
# H3 881f9906bbfffff: 10 colonnine, 5554.3 kWh coperti su 7172.6 kWh (Domanda agg: 7172.6 kWh)
# H3 881f990687fffff: 10 colonnine, 5554.3 kWh coperti su 9199.9 kWh (Domanda agg: 9199.9 kWh)
# H3 881f9906abfffff: 10 colonnine, 5554.3 kWh coperti su 13186.9 kWh (Domanda agg: 13186.9 kWh)
# H3 881f990697fffff: 10 colonnine, 5554.3 kWh coperti su 10115.6 kWh (Domanda agg: 10115.6 kWh)
# H3 881f993157fffff: 10 colonnine, 5554.3 kWh coperti su 6660.8 kWh (Domanda agg: 6660.8 kWh)
# H3 881f993adbfffff: 10 colonnine, 5554.3 kWh coperti su 6450.1 kWh (Domanda agg: 6450.1 kWh)
# H3 881f99315bfffff: 10 colonnine, 5554.3 kWh coperti su 7677.5 kWh (Domanda agg: 7677.5 kWh)
# H3 881f993133fffff: 9 colonnine, 4998.9 kWh coperti su 5080.1 kWh (Domanda agg: 5080.1 kWh)
# H3 881f993117fffff: 6 colonnine, 3332.6 kWh coperti su 3524.4 kWh (Domanda agg: 3524.4 kWh)
# H3 881f993135fffff: 9 colonnine, 4998.9 kWh coperti su 5006.7 kWh (Domanda agg: 5006.7 kWh)
# H3 881f99311dfffff: 10 colonnine, 5554.3 kWh coperti su 11493.6 kWh (Domanda agg: 11493.6 kWh)
# H3 881f993153fffff: 7 colonnine, 3888.0 kWh coperti su 4223.0 kWh (Domanda agg: 4223.0 kWh)
# H3 881f993027fffff: 10 colonnine, 5554.3 kWh coperti su 5747.4 kWh (Domanda agg: 5747.4 kWh)
# H3 881f993025fffff: 10 colonnine, 5554.3 kWh coperti su 7113.1 kWh (Domanda agg: 7113.1 kWh)
# H3 881f993111fffff: 10 colonnine, 5554.3 kWh coperti su 6985.5 kWh (Domanda agg: 6985.5 kWh)
# H3 881f993115fffff: 3 colonnine, 1666.3 kWh coperti su 1947.4 kWh (Domanda agg: 1947.4 kWh)
# H3 881f993ad9fffff: 10 colonnine, 5554.3 kWh coperti su 6627.9 kWh (Domanda agg: 6627.9 kWh)
# H3 881f9931e7fffff: 3 colonnine, 1666.3 kWh coperti su 1850.8 kWh (Domanda agg: 1850.8 kWh)
# H3 881f9931e5fffff: 3 colonnine, 1666.3 kWh coperti su 1850.8 kWh (Domanda agg: 1850.8 kWh)
# H3 881f993155fffff: 10 colonnine, 5554.3 kWh coperti su 9494.9 kWh (Domanda agg: 9494.9 kWh)
# H3 881f99313dfffff: 9 colonnine, 4998.9 kWh coperti su 5072.7 kWh (Domanda agg: 5072.7 kWh)
# H3 881f993151fffff: 9 colonnine, 4998.9 kWh coperti su 5511.9 kWh (Domanda agg: 5511.9 kWh)
# H3 881f993a6bfffff: 10 colonnine, 5554.3 kWh coperti su 7529.7 kWh (Domanda agg: 7529.7 kWh)
# H3 881f990493fffff: 3 colonnine, 1666.3 kWh coperti su 2037.7 kWh (Domanda agg: 2037.7 kWh)
# H3 881f993a09fffff: 10 colonnine, 5554.3 kWh coperti su 5792.8 kWh (Domanda agg: 5792.8 kWh)
# H3 881f993a4bfffff: 10 colonnine, 5554.3 kWh coperti su 9150.4 kWh (Domanda agg: 9150.4 kWh)
# H3 881f993a5dfffff: 10 colonnine, 5554.3 kWh coperti su 8575.0 kWh (Domanda agg: 8575.0 kWh)
# H3 881f9904a5fffff: 3 colonnine, 1666.3 kWh coperti su 2037.7 kWh (Domanda agg: 2037.7 kWh)
# H3 881f993a57fffff: 8 colonnine, 4443.4 kWh coperti su 4514.9 kWh (Domanda agg: 4514.9 kWh)
# H3 881f993a51fffff: 10 colonnine, 5554.3 kWh coperti su 9293.8 kWh (Domanda agg: 9293.8 kWh)
# H3 881f9904e3fffff: 10 colonnine, 5554.3 kWh coperti su 5784.0 kWh (Domanda agg: 5784.0 kWh)
# H3 881f9904b7fffff: 10 colonnine, 5554.3 kWh coperti su 11664.2 kWh (Domanda agg: 11664.2 kWh)
# H3 881f993a53fffff: 10 colonnine, 5554.3 kWh coperti su 6341.0 kWh (Domanda agg: 6341.0 kWh)
# H3 881f9904b5fffff: 10 colonnine, 5554.3 kWh coperti su 6435.2 kWh (Domanda agg: 6435.2 kWh)
# H3 881f993167fffff: 3 colonnine, 1666.3 kWh coperti su 2037.7 kWh (Domanda agg: 2037.7 kWh)
# H3 881f993a01fffff: 10 colonnine, 5554.3 kWh coperti su 8303.8 kWh (Domanda agg: 8303.8 kWh)
# H3 881f993a5bfffff: 10 colonnine, 5554.3 kWh coperti su 5605.5 kWh (Domanda agg: 5605.5 kWh)
# H3 881f990495fffff: 10 colonnine, 5554.3 kWh coperti su 6236.9 kWh (Domanda agg: 6236.9 kWh)
# H3 881f993a0bfffff: 10 colonnine, 5554.3 kWh coperti su 5853.4 kWh (Domanda agg: 5853.4 kWh)
# H3 881f993a0dfffff: 10 colonnine, 5554.3 kWh coperti su 6460.5 kWh (Domanda agg: 6460.5 kWh)
# H3 881f993a49fffff: 10 colonnine, 5554.3 kWh coperti su 6671.6 kWh (Domanda agg: 6671.6 kWh)
# H3 881f993a4dfffff: 10 colonnine, 5554.3 kWh coperti su 6157.0 kWh (Domanda agg: 6157.0 kWh)
# H3 881f993a59fffff: 9 colonnine, 4998.9 kWh coperti su 5523.0 kWh (Domanda agg: 5523.0 kWh)
# H3 881f99316dfffff: 10 colonnine, 5554.3 kWh coperti su 7591.5 kWh (Domanda agg: 7591.5 kWh)
# H3 881f990497fffff: 10 colonnine, 5554.3 kWh coperti su 5988.3 kWh (Domanda agg: 5988.3 kWh)
# H3 881f9904bbfffff: 10 colonnine, 5554.3 kWh coperti su 6292.2 kWh (Domanda agg: 6292.2 kWh)
# H3 881f993a69fffff: 10 colonnine, 5554.3 kWh coperti su 5850.5 kWh (Domanda agg: 5850.5 kWh)
# H3 881f9904b1fffff: 10 colonnine, 5554.3 kWh coperti su 5612.6 kWh (Domanda agg: 5612.6 kWh)
# H3 881f9904bdfffff: 10 colonnine, 5554.3 kWh coperti su 7840.9 kWh (Domanda agg: 7840.9 kWh)
# H3 881f9904b3fffff: 10 colonnine, 5554.3 kWh coperti su 10737.5 kWh (Domanda agg: 10737.5 kWh)
# H3 881f9904b9fffff: 10 colonnine, 5554.3 kWh coperti su 7278.7 kWh (Domanda agg: 7278.7 kWh)
# H3 881f993a47fffff: 9 colonnine, 4998.9 kWh coperti su 5127.7 kWh (Domanda agg: 5127.7 kWh)
# H3 881f992e53fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992c09fffff: 10 colonnine, 5554.3 kWh coperti su 6564.0 kWh (Domanda agg: 6564.0 kWh)
# H3 881f992c07fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992c43fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992c47fffff: 5 colonnine, 2777.2 kWh coperti su 3165.1 kWh (Domanda agg: 3165.1 kWh)
# H3 881f992081fffff: 9 colonnine, 4998.9 kWh coperti su 5052.8 kWh (Domanda agg: 5052.8 kWh)
# H3 881f9920b1fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f9920b5fffff: 10 colonnine, 5554.3 kWh coperti su 6647.7 kWh (Domanda agg: 6647.7 kWh)
# H3 881f992e41fffff: 10 colonnine, 5554.3 kWh coperti su 5749.7 kWh (Domanda agg: 5749.7 kWh)
# H3 881f992c4dfffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992c55fffff: 10 colonnine, 5554.3 kWh coperti su 6424.4 kWh (Domanda agg: 6424.4 kWh)
# H3 881f992e4dfffff: 10 colonnine, 5554.3 kWh coperti su 5779.7 kWh (Domanda agg: 5779.7 kWh)
# H3 881f992e27fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992c5dfffff: 6 colonnine, 3332.6 kWh coperti su 3462.0 kWh (Domanda agg: 3462.0 kWh)
# H3 881f992e4bfffff: 10 colonnine, 5554.3 kWh coperti su 7306.0 kWh (Domanda agg: 7306.0 kWh)
# H3 881f992e15fffff: 10 colonnine, 5554.3 kWh coperti su 9231.1 kWh (Domanda agg: 9231.1 kWh)
# H3 881f992e47fffff: 8 colonnine, 4443.4 kWh coperti su 4640.1 kWh (Domanda agg: 4640.1 kWh)
# H3 881f992e29fffff: 10 colonnine, 5554.3 kWh coperti su 7414.9 kWh (Domanda agg: 7414.9 kWh)
# H3 881f992ee1fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992e51fffff: 10 colonnine, 5554.3 kWh coperti su 7310.1 kWh (Domanda agg: 7310.1 kWh)
# H3 881f992561fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f99256dfffff: 2 colonnine, 1110.9 kWh coperti su 4738.9 kWh (Domanda agg: 4738.9 kWh)
# H3 881f992e01fffff: 10 colonnine, 5554.3 kWh coperti su 7537.6 kWh (Domanda agg: 7537.6 kWh)
# H3 881f992e35fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992e03fffff: 10 colonnine, 5554.3 kWh coperti su 11194.6 kWh (Domanda agg: 11194.6 kWh)
# H3 881f992e13fffff: 10 colonnine, 5554.3 kWh coperti su 5910.0 kWh (Domanda agg: 5910.0 kWh)
# H3 881f992e07fffff: 10 colonnine, 5554.3 kWh coperti su 6219.1 kWh (Domanda agg: 6219.1 kWh)
# H3 881f992e0bfffff: 10 colonnine, 5554.3 kWh coperti su 11204.8 kWh (Domanda agg: 11204.8 kWh)
# H3 881f992e5bfffff: 10 colonnine, 5554.3 kWh coperti su 5740.2 kWh (Domanda agg: 5740.2 kWh)
# H3 881f992e63fffff: 10 colonnine, 5554.3 kWh coperti su 7843.3 kWh (Domanda agg: 7843.3 kWh)
# H3 881f992e43fffff: 10 colonnine, 5554.3 kWh coperti su 9944.3 kWh (Domanda agg: 9944.3 kWh)
# H3 881f992c49fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992e19fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992e55fffff: 10 colonnine, 5554.3 kWh coperti su 6395.1 kWh (Domanda agg: 6395.1 kWh)
# H3 881f992e0dfffff: 10 colonnine, 5554.3 kWh coperti su 7925.7 kWh (Domanda agg: 7925.7 kWh)
# H3 881f992567fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f9920bdfffff: 9 colonnine, 4998.9 kWh coperti su 5485.2 kWh (Domanda agg: 5485.2 kWh)
# H3 881f992c4bfffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992e17fffff: 5 colonnine, 2777.2 kWh coperti su 2947.2 kWh (Domanda agg: 2947.2 kWh)
# H3 881ea45ae9fffff: 3 colonnine, 1666.3 kWh coperti su 4078.2 kWh (Domanda agg: 4078.2 kWh)
# H3 881ea45a03fffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881f9924e3fffff: 10 colonnine, 5554.3 kWh coperti su 7665.5 kWh (Domanda agg: 7665.5 kWh)
# H3 881ea45a1dfffff: 10 colonnine, 5554.3 kWh coperti su 6164.5 kWh (Domanda agg: 6164.5 kWh)
# H3 881f9924b9fffff: 6 colonnine, 3332.6 kWh coperti su 3842.5 kWh (Domanda agg: 3842.5 kWh)
# H3 881ea45a59fffff: 8 colonnine, 4443.4 kWh coperti su 4870.8 kWh (Domanda agg: 4870.8 kWh)
# H3 881ea45aedfffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881ea45a11fffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881f992481fffff: 10 colonnine, 5554.3 kWh coperti su 6841.8 kWh (Domanda agg: 6841.8 kWh)
# H3 881ea45a5bfffff: 4 colonnine, 2221.7 kWh coperti su 2483.7 kWh (Domanda agg: 2483.7 kWh)
# H3 881f9924b5fffff: 10 colonnine, 5554.3 kWh coperti su 6595.4 kWh (Domanda agg: 6595.4 kWh)
# H3 881ea45a0bfffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881ea45165fffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881ea45aa1fffff: 2 colonnine, 1110.9 kWh coperti su 1651.0 kWh (Domanda agg: 1651.0 kWh)
# H3 881f9924ddfffff: 5 colonnine, 2777.2 kWh coperti su 3116.1 kWh (Domanda agg: 3116.1 kWh)
# H3 881f992483fffff: 10 colonnine, 5554.3 kWh coperti su 9226.4 kWh (Domanda agg: 9226.4 kWh)
# H3 881f992495fffff: 10 colonnine, 5554.3 kWh coperti su 7323.0 kWh (Domanda agg: 7323.0 kWh)
# H3 881f992489fffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881f9924bdfffff: 10 colonnine, 5554.3 kWh coperti su 8243.0 kWh (Domanda agg: 8243.0 kWh)
# H3 881ea45125fffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881f9924a3fffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881ea4516dfffff: 10 colonnine, 5554.3 kWh coperti su 10461.7 kWh (Domanda agg: 10461.7 kWh)
# H3 881f9924bbfffff: 10 colonnine, 5554.3 kWh coperti su 9078.1 kWh (Domanda agg: 9078.1 kWh)
# H3 881ea45aebfffff: 6 colonnine, 3332.6 kWh coperti su 3798.1 kWh (Domanda agg: 3798.1 kWh)
# H3 881f9924b1fffff: 10 colonnine, 5554.3 kWh coperti su 12081.8 kWh (Domanda agg: 12081.8 kWh)
# H3 881f9924b3fffff: 5 colonnine, 2777.2 kWh coperti su 3273.0 kWh (Domanda agg: 3273.0 kWh)
# H3 881f992485fffff: 10 colonnine, 5554.3 kWh coperti su 6873.1 kWh (Domanda agg: 6873.1 kWh)
# H3 881f992493fffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881ea45a19fffff: 10 colonnine, 5554.3 kWh coperti su 7711.8 kWh (Domanda agg: 7711.8 kWh)
# H3 881ea45a53fffff: 10 colonnine, 5554.3 kWh coperti su 6442.8 kWh (Domanda agg: 6442.8 kWh)
# H3 881ea45a09fffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881f9926b7fffff: 10 colonnine, 5554.3 kWh coperti su 7303.9 kWh (Domanda agg: 7303.9 kWh)
# H3 881ea45a13fffff: 10 colonnine, 5554.3 kWh coperti su 5849.9 kWh (Domanda agg: 5849.9 kWh)
# H3 881f9930b3fffff: 6 colonnine, 3332.6 kWh coperti su 3752.6 kWh (Domanda agg: 3752.6 kWh)
# H3 881f9930d7fffff: 2 colonnine, 1110.9 kWh coperti su 1606.4 kWh (Domanda agg: 1606.4 kWh)
# H3 881f9930b7fffff: 10 colonnine, 5554.3 kWh coperti su 10018.3 kWh (Domanda agg: 10018.3 kWh)
# H3 881f993767fffff: 6 colonnine, 3332.6 kWh coperti su 3783.2 kWh (Domanda agg: 3783.2 kWh)
# H3 881f993091fffff: 10 colonnine, 5554.3 kWh coperti su 5802.5 kWh (Domanda agg: 5802.5 kWh)
# H3 881f99309bfffff: 9 colonnine, 4998.9 kWh coperti su 5014.7 kWh (Domanda agg: 5014.7 kWh)
# H3 881f993097fffff: 7 colonnine, 3888.0 kWh coperti su 4103.1 kWh (Domanda agg: 4103.1 kWh)
# H3 881f9930bbfffff: 2 colonnine, 1110.9 kWh coperti su 1606.4 kWh (Domanda agg: 1606.4 kWh)
# H3 881f9930b9fffff: 2 colonnine, 1110.9 kWh coperti su 1606.4 kWh (Domanda agg: 1606.4 kWh)
# H3 881f99370dfffff: 2 colonnine, 1110.9 kWh coperti su 1606.4 kWh (Domanda agg: 1606.4 kWh)
# H3 881f9930d3fffff: 8 colonnine, 4443.4 kWh coperti su 4714.2 kWh (Domanda agg: 4714.2 kWh)
# H3 881f993761fffff: 10 colonnine, 5554.3 kWh coperti su 7022.5 kWh (Domanda agg: 7022.5 kWh)
# H3 881f99372dfffff: 10 colonnine, 5554.3 kWh coperti su 7552.0 kWh (Domanda agg: 7552.0 kWh)
# H3 881f993727fffff: 2 colonnine, 1110.9 kWh coperti su 1606.4 kWh (Domanda agg: 1606.4 kWh)
# H3 881f993769fffff: 10 colonnine, 5554.3 kWh coperti su 5831.3 kWh (Domanda agg: 5831.3 kWh)
# H3 881f992259fffff: 10 colonnine, 5554.3 kWh coperti su 8043.8 kWh (Domanda agg: 8043.8 kWh)
# H3 881f99356dfffff: 6 colonnine, 3332.6 kWh coperti su 3436.4 kWh (Domanda agg: 3436.4 kWh)
# H3 881f99373bfffff: 10 colonnine, 5554.3 kWh coperti su 8207.7 kWh (Domanda agg: 8207.7 kWh)
# H3 881f99346dfffff: 10 colonnine, 5554.3 kWh coperti su 5596.5 kWh (Domanda agg: 5596.5 kWh)
# H3 881f99373dfffff: 10 colonnine, 5554.3 kWh coperti su 5822.3 kWh (Domanda agg: 5822.3 kWh)
# H3 881f993703fffff: 10 colonnine, 5554.3 kWh coperti su 6146.1 kWh (Domanda agg: 6146.1 kWh)
# H3 881f993465fffff: 10 colonnine, 5554.3 kWh coperti su 6060.8 kWh (Domanda agg: 6060.8 kWh)
# H3 881f993739fffff: 10 colonnine, 5554.3 kWh coperti su 5590.4 kWh (Domanda agg: 5590.4 kWh)
# H3 881f993461fffff: 2 colonnine, 1110.9 kWh coperti su 1409.9 kWh (Domanda agg: 1409.9 kWh)
# H3 881f99a62dfffff: 2 colonnine, 1110.9 kWh coperti su 1398.6 kWh (Domanda agg: 1398.6 kWh)
# H3 881f99a461fffff: 2 colonnine, 1110.9 kWh coperti su 1398.6 kWh (Domanda agg: 1398.6 kWh)
# H3 881f99a707fffff: 10 colonnine, 5554.3 kWh coperti su 5616.1 kWh (Domanda agg: 5616.1 kWh)
# H3 881f99a625fffff: 10 colonnine, 5554.3 kWh coperti su 5755.6 kWh (Domanda agg: 5755.6 kWh)
# H3 881f99a715fffff: 10 colonnine, 5554.3 kWh coperti su 6740.5 kWh (Domanda agg: 6740.5 kWh)
# H3 881f99a713fffff: 5 colonnine, 2777.2 kWh coperti su 3055.4 kWh (Domanda agg: 3055.4 kWh)
# H3 881f99a759fffff: 2 colonnine, 1110.9 kWh coperti su 1398.6 kWh (Domanda agg: 1398.6 kWh)
# H3 881f99a711fffff: 10 colonnine, 5554.3 kWh coperti su 8082.0 kWh (Domanda agg: 8082.0 kWh)
# H3 881f99a605fffff: 2 colonnine, 1110.9 kWh coperti su 1398.6 kWh (Domanda agg: 1398.6 kWh)
# H3 881f99a719fffff: 10 colonnine, 5554.3 kWh coperti su 8438.5 kWh (Domanda agg: 8438.5 kWh)
# H3 881f99a739fffff: 10 colonnine, 5554.3 kWh coperti su 7486.4 kWh (Domanda agg: 7486.4 kWh)
# H3 881f99a71bfffff: 10 colonnine, 5554.3 kWh coperti su 6249.6 kWh (Domanda agg: 6249.6 kWh)
# H3 881f99a71dfffff: 8 colonnine, 4443.4 kWh coperti su 4855.4 kWh (Domanda agg: 4855.4 kWh)
# H3 881f99a445fffff: 2 colonnine, 1110.9 kWh coperti su 1398.6 kWh (Domanda agg: 1398.6 kWh)
# H3 881f99a703fffff: 7 colonnine, 3888.0 kWh coperti su 4246.2 kWh (Domanda agg: 4246.2 kWh)
# H3 881f99a661fffff: 2 colonnine, 1110.9 kWh coperti su 1398.6 kWh (Domanda agg: 1398.6 kWh)
# H3 881f99a405fffff: 2 colonnine, 1110.9 kWh coperti su 1398.6 kWh (Domanda agg: 1398.6 kWh)
# H3 881f99a751fffff: 2 colonnine, 1110.9 kWh coperti su 1398.6 kWh (Domanda agg: 1398.6 kWh)
# H3 881f99319dfffff: 2 colonnine, 1110.9 kWh coperti su 1541.7 kWh (Domanda agg: 1541.7 kWh)
# H3 881f993199fffff: 2 colonnine, 1110.9 kWh coperti su 1541.7 kWh (Domanda agg: 1541.7 kWh)
# H3 881f9931d3fffff: 10 colonnine, 5554.3 kWh coperti su 6532.2 kWh (Domanda agg: 6532.2 kWh)
# H3 881f9931d1fffff: 8 colonnine, 4443.4 kWh coperti su 4811.2 kWh (Domanda agg: 4811.2 kWh)
# H3 881f9931dbfffff: 2 colonnine, 1110.9 kWh coperti su 1541.7 kWh (Domanda agg: 1541.7 kWh)
# H3 881f992f37fffff: 4 colonnine, 2221.7 kWh coperti su 2745.7 kWh (Domanda agg: 2745.7 kWh)
# H3 881f9921b1fffff: 6 colonnine, 3332.6 kWh coperti su 3831.6 kWh (Domanda agg: 3831.6 kWh)
# H3 881f992f35fffff: 10 colonnine, 5554.3 kWh coperti su 6008.1 kWh (Domanda agg: 6008.1 kWh)
# H3 881f992f5bfffff: 10 colonnine, 5554.3 kWh coperti su 6099.3 kWh (Domanda agg: 6099.3 kWh)
# H3 881f992f09fffff: 10 colonnine, 5554.3 kWh coperti su 7889.9 kWh (Domanda agg: 7889.9 kWh)
# H3 881f992d51fffff: 7 colonnine, 3888.0 kWh coperti su 3934.5 kWh (Domanda agg: 3934.5 kWh)
# H3 881f992f1bfffff: 3 colonnine, 1666.3 kWh coperti su 1805.1 kWh (Domanda agg: 1805.1 kWh)
# H3 881f992f63fffff: 3 colonnine, 1666.3 kWh coperti su 1805.1 kWh (Domanda agg: 1805.1 kWh)
# H3 881f992e65fffff: 5 colonnine, 2777.2 kWh coperti su 3126.2 kWh (Domanda agg: 3126.2 kWh)
# H3 881f992f29fffff: 3 colonnine, 1666.3 kWh coperti su 1805.1 kWh (Domanda agg: 1805.1 kWh)
# H3 881f992f0bfffff: 10 colonnine, 5554.3 kWh coperti su 7185.5 kWh (Domanda agg: 7185.5 kWh)
# H3 881f992c6bfffff: 7 colonnine, 3888.0 kWh coperti su 4154.1 kWh (Domanda agg: 4154.1 kWh)
# H3 881f992f21fffff: 7 colonnine, 3888.0 kWh coperti su 3966.5 kWh (Domanda agg: 3966.5 kWh)
# H3 881f992c67fffff: 3 colonnine, 1666.3 kWh coperti su 1805.1 kWh (Domanda agg: 1805.1 kWh)
# H3 881f992f19fffff: 3 colonnine, 1666.3 kWh coperti su 1805.1 kWh (Domanda agg: 1805.1 kWh)
# H3 881f992f03fffff: 10 colonnine, 5554.3 kWh coperti su 7744.5 kWh (Domanda agg: 7744.5 kWh)
# H3 881f992f55fffff: 10 colonnine, 5554.3 kWh coperti su 5671.6 kWh (Domanda agg: 5671.6 kWh)
# H3 881f992f39fffff: 10 colonnine, 5554.3 kWh coperti su 6130.4 kWh (Domanda agg: 6130.4 kWh)
# H3 881f992197fffff: 3 colonnine, 1666.3 kWh coperti su 1805.1 kWh (Domanda agg: 1805.1 kWh)
# H3 881f992f51fffff: 10 colonnine, 5554.3 kWh coperti su 6644.3 kWh (Domanda agg: 6644.3 kWh)
# H3 881f992f07fffff: 3 colonnine, 1666.3 kWh coperti su 1805.1 kWh (Domanda agg: 1805.1 kWh)
# H3 881f992d59fffff: 10 colonnine, 5554.3 kWh coperti su 7192.0 kWh (Domanda agg: 7192.0 kWh)
# H3 881f992f43fffff: 10 colonnine, 5554.3 kWh coperti su 5761.3 kWh (Domanda agg: 5761.3 kWh)
# H3 881f992f45fffff: 8 colonnine, 4443.4 kWh coperti su 4877.3 kWh (Domanda agg: 4877.3 kWh)
# H3 881f992f3dfffff: 5 colonnine, 2777.2 kWh coperti su 3077.5 kWh (Domanda agg: 3077.5 kWh)
# H3 881f992f5dfffff: 10 colonnine, 5554.3 kWh coperti su 6113.7 kWh (Domanda agg: 6113.7 kWh)
# H3 881f992e61fffff: 6 colonnine, 3332.6 kWh coperti su 3820.4 kWh (Domanda agg: 3820.4 kWh)
# H3 881f992d5bfffff: 9 colonnine, 4998.9 kWh coperti su 5118.9 kWh (Domanda agg: 5118.9 kWh)
# H3 881f992c6dfffff: 3 colonnine, 1666.3 kWh coperti su 1805.1 kWh (Domanda agg: 1805.1 kWh)
# H3 881f99234bfffff: 2 colonnine, 1110.9 kWh coperti su 1523.1 kWh (Domanda agg: 1523.1 kWh)
# H3 881f99226dfffff: 7 colonnine, 3888.0 kWh coperti su 4133.3 kWh (Domanda agg: 4133.3 kWh)
# H3 881f99319bfffff: 3 colonnine, 1666.3 kWh coperti su 2011.6 kWh (Domanda agg: 2011.6 kWh)
# H3 881f993191fffff: 2 colonnine, 1110.9 kWh coperti su 1523.1 kWh (Domanda agg: 1523.1 kWh)
# H3 881f99235dfffff: 9 colonnine, 4998.9 kWh coperti su 5056.9 kWh (Domanda agg: 5056.9 kWh)
# H3 881f992719fffff: 10 colonnine, 5554.3 kWh coperti su 5783.3 kWh (Domanda agg: 5783.3 kWh)
# H3 881f992703fffff: 9 colonnine, 4998.9 kWh coperti su 5127.6 kWh (Domanda agg: 5127.6 kWh)
# H3 881f992709fffff: 9 colonnine, 4998.9 kWh coperti su 5000.1 kWh (Domanda agg: 5000.1 kWh)
# H3 881f992711fffff: 10 colonnine, 5554.3 kWh coperti su 5573.3 kWh (Domanda agg: 5573.3 kWh)
# H3 881f992753fffff: 3 colonnine, 1666.3 kWh coperti su 1908.5 kWh (Domanda agg: 1908.5 kWh)
# H3 881f992763fffff: 2 colonnine, 1110.9 kWh coperti su 1420.9 kWh (Domanda agg: 1420.9 kWh)
# H3 881f99275bfffff: 2 colonnine, 1110.9 kWh coperti su 1420.9 kWh (Domanda agg: 1420.9 kWh)
# ...
# H3 881ea69769fffff: 3 colonnine, 1666.3 kWh coperti su 1802.4 kWh (Domanda agg: 1802.4 kWh)
# H3 881ea69745fffff: 2 colonnine, 1110.9 kWh coperti su 1305.2 kWh (Domanda agg: 1305.2 kWh)
# H3 881f992da9fffff: 1 colonnine, 555.4 kWh coperti su 585.8 kWh (Domanda agg: 585.8 kWh)
# H3 881f992da5fffff: 2 colonnine, 1110.9 kWh coperti su 1348.8 kWh (Domanda agg: 1348.8 kWh)
# H3 881ea692d7fffff: 1 colonnine, 555.4 kWh coperti su 585.8 kWh (Domanda agg: 585.8 kWh)
# H3 881f992db5fffff: 2 colonnine, 1110.9 kWh coperti su 1330.2 kWh (Domanda agg: 1330.2 kWh)
# H3 881ea6929dfffff: 2 colonnine, 1110.9 kWh coperti su 1558.4 kWh (Domanda agg: 1558.4 kWh)
# H3 881f992db3fffff: 3 colonnine, 1666.3 kWh coperti su 1856.1 kWh (Domanda agg: 1856.1 kWh)
# H3 881ea69295fffff: 1 colonnine, 555.4 kWh coperti su 875.5 kWh (Domanda agg: 875.5 kWh)
# H3 881ea69741fffff: 3 colonnine, 1666.3 kWh coperti su 1968.7 kWh (Domanda agg: 1968.7 kWh)
# H3 881ea69765fffff: 1 colonnine, 555.4 kWh coperti su 585.8 kWh (Domanda agg: 585.8 kWh)
# H3 881f99350bfffff: 3 colonnine, 1666.3 kWh coperti su 1803.1 kWh (Domanda agg: 1803.1 kWh)
# H3 881f992a05fffff: 2 colonnine, 1110.9 kWh coperti su 1413.3 kWh (Domanda agg: 1413.3 kWh)
# H3 881f992a07fffff: 2 colonnine, 1110.9 kWh coperti su 1469.4 kWh (Domanda agg: 1469.4 kWh)
# H3 881f993997fffff: 1 colonnine, 555.4 kWh coperti su 649.2 kWh (Domanda agg: 649.2 kWh)
# H3 881f992a03fffff: 4 colonnine, 2221.7 kWh coperti su 2431.7 kWh (Domanda agg: 2431.7 kWh)
# H3 881f992a29fffff: 3 colonnine, 1666.3 kWh coperti su 1738.4 kWh (Domanda agg: 1738.4 kWh)
# H3 881f9939b3fffff: 2 colonnine, 1110.9 kWh coperti su 1543.6 kWh (Domanda agg: 1543.6 kWh)
# H3 881f992a0dfffff: 2 colonnine, 1110.9 kWh coperti su 1379.2 kWh (Domanda agg: 1379.2 kWh)
# H3 881f8a7a93fffff: 1 colonnine, 555.4 kWh coperti su 1110.0 kWh (Domanda agg: 1110.0 kWh)
# H3 881f8a71b5fffff: 1 colonnine, 555.4 kWh coperti su 638.9 kWh (Domanda agg: 638.9 kWh)
# H3 881f8a634dfffff: 2 colonnine, 1110.9 kWh coperti su 1476.2 kWh (Domanda agg: 1476.2 kWh)
# H3 881f8a71b1fffff: 1 colonnine, 555.4 kWh coperti su 828.7 kWh (Domanda agg: 828.7 kWh)
# H3 881f99ac87fffff: 1 colonnine, 555.4 kWh coperti su 705.5 kWh (Domanda agg: 705.5 kWh)
# H3 881f99acabfffff: 1 colonnine, 555.4 kWh coperti su 920.1 kWh (Domanda agg: 920.1 kWh)
# H3 881ea4d8a1fffff: 2 colonnine, 1110.9 kWh coperti su 1166.5 kWh (Domanda agg: 1166.5 kWh)
# H3 881ea4d989fffff: 3 colonnine, 1666.3 kWh coperti su 1691.2 kWh (Domanda agg: 1691.2 kWh)
# H3 881ea4d9d5fffff: 2 colonnine, 1110.9 kWh coperti su 1320.0 kWh (Domanda agg: 1320.0 kWh)
# H3 881ea4d9d7fffff: 1 colonnine, 555.4 kWh coperti su 1096.2 kWh (Domanda agg: 1096.2 kWh)
# H3 881ea4d9d1fffff: 1 colonnine, 555.4 kWh coperti su 677.1 kWh (Domanda agg: 677.1 kWh)
# H3 881ea4d8adfffff: 1 colonnine, 555.4 kWh coperti su 1010.4 kWh (Domanda agg: 1010.4 kWh)
# H3 881f993859fffff: 2 colonnine, 1110.9 kWh coperti su 1338.7 kWh (Domanda agg: 1338.7 kWh)
# H3 881f993a31fffff: 1 colonnine, 555.4 kWh coperti su 886.2 kWh (Domanda agg: 886.2 kWh)
# H3 881f992ae9fffff: 1 colonnine, 555.4 kWh coperti su 1048.6 kWh (Domanda agg: 1048.6 kWh)
# H3 881f992ae1fffff: 2 colonnine, 1110.9 kWh coperti su 1272.4 kWh (Domanda agg: 1272.4 kWh)
# H3 881f992ae7fffff: 1 colonnine, 555.4 kWh coperti su 1013.7 kWh (Domanda agg: 1013.7 kWh)
# H3 881f992a17fffff: 2 colonnine, 1110.9 kWh coperti su 1250.0 kWh (Domanda agg: 1250.0 kWh)
# H3 881f992ac1fffff: 2 colonnine, 1110.9 kWh coperti su 1210.1 kWh (Domanda agg: 1210.1 kWh)
# H3 881f992a1dfffff: 1 colonnine, 555.4 kWh coperti su 962.4 kWh (Domanda agg: 962.4 kWh)
# H3 881f992d95fffff: 2 colonnine, 1110.9 kWh coperti su 1596.5 kWh (Domanda agg: 1596.5 kWh)
# H3 881f992dddfffff: 2 colonnine, 1110.9 kWh coperti su 1133.8 kWh (Domanda agg: 1133.8 kWh)
# H3 881f992d9dfffff: 1 colonnine, 555.4 kWh coperti su 1020.2 kWh (Domanda agg: 1020.2 kWh)
# H3 881ea4cb55fffff: 1 colonnine, 555.4 kWh coperti su 961.7 kWh (Domanda agg: 961.7 kWh)
# H3 881ea4cb59fffff: 3 colonnine, 1666.3 kWh coperti su 1685.8 kWh (Domanda agg: 1685.8 kWh)
# H3 881ea4cb5bfffff: 1 colonnine, 555.4 kWh coperti su 759.2 kWh (Domanda agg: 759.2 kWh)
# H3 881ea4cb1bfffff: 3 colonnine, 1666.3 kWh coperti su 1823.7 kWh (Domanda agg: 1823.7 kWh)
# H3 881f992615fffff: 1 colonnine, 555.4 kWh coperti su 715.7 kWh (Domanda agg: 715.7 kWh)
# H3 881f992611fffff: 2 colonnine, 1110.9 kWh coperti su 1280.0 kWh (Domanda agg: 1280.0 kWh)
# H3 881f992657fffff: 3 colonnine, 1666.3 kWh coperti su 1733.6 kWh (Domanda agg: 1733.6 kWh)
# H3 881f992619fffff: 2 colonnine, 1110.9 kWh coperti su 1285.8 kWh (Domanda agg: 1285.8 kWh)
# H3 881f99263bfffff: 2 colonnine, 1110.9 kWh coperti su 1135.7 kWh (Domanda agg: 1135.7 kWh)
# H3 881f992913fffff: 2 colonnine, 1110.9 kWh coperti su 1272.2 kWh (Domanda agg: 1272.2 kWh)
# H3 881f992869fffff: 2 colonnine, 1110.9 kWh coperti su 1149.3 kWh (Domanda agg: 1149.3 kWh)
# H3 881ea4d339fffff: 1 colonnine, 555.4 kWh coperti su 812.5 kWh (Domanda agg: 812.5 kWh)
# H3 881ea4d149fffff: 1 colonnine, 555.4 kWh coperti su 555.5 kWh (Domanda agg: 555.5 kWh)
# H3 881ea4d311fffff: 1 colonnine, 555.4 kWh coperti su 958.2 kWh (Domanda agg: 958.2 kWh)
# H3 881ea4d343fffff: 1 colonnine, 555.4 kWh coperti su 874.4 kWh (Domanda agg: 874.4 kWh)
# H3 881ea4d335fffff: 2 colonnine, 1110.9 kWh coperti su 1126.1 kWh (Domanda agg: 1126.1 kWh)
# H3 881f99a6d1fffff: 2 colonnine, 1110.9 kWh coperti su 1188.5 kWh (Domanda agg: 1188.5 kWh)
# H3 881ea4d1bbfffff: 1 colonnine, 555.4 kWh coperti su 787.9 kWh (Domanda agg: 787.9 kWh)
# H3 881ea4d1b3fffff: 1 colonnine, 555.4 kWh coperti su 742.8 kWh (Domanda agg: 742.8 kWh)
# H3 881ea4d133fffff: 1 colonnine, 555.4 kWh coperti su 993.2 kWh (Domanda agg: 993.2 kWh)
# H3 881ea4d1edfffff: 2 colonnine, 1110.9 kWh coperti su 1293.3 kWh (Domanda agg: 1293.3 kWh)
# H3 881ea4d1cdfffff: 1 colonnine, 555.4 kWh coperti su 599.1 kWh (Domanda agg: 599.1 kWh)
# H3 881ea4d055fffff: 1 colonnine, 555.4 kWh coperti su 741.8 kWh (Domanda agg: 741.8 kWh)
# H3 881ea4d1a9fffff: 2 colonnine, 1110.9 kWh coperti su 1503.7 kWh (Domanda agg: 1503.7 kWh)
# H3 881ea4d1e1fffff: 2 colonnine, 1110.9 kWh coperti su 1607.8 kWh (Domanda agg: 1607.8 kWh)
# H3 881f99234dfffff: 2 colonnine, 1110.9 kWh coperti su 1225.3 kWh (Domanda agg: 1225.3 kWh)
# H3 881f99236bfffff: 2 colonnine, 1110.9 kWh coperti su 1189.5 kWh (Domanda agg: 1189.5 kWh)
# H3 881f9931a7fffff: 1 colonnine, 555.4 kWh coperti su 999.2 kWh (Domanda agg: 999.2 kWh)
# H3 881f992347fffff: 2 colonnine, 1110.9 kWh coperti su 1117.7 kWh (Domanda agg: 1117.7 kWh)
# H3 881f992343fffff: 2 colonnine, 1110.9 kWh coperti su 1175.0 kWh (Domanda agg: 1175.0 kWh)
# H3 881f99059bfffff: 1 colonnine, 555.4 kWh coperti su 1051.8 kWh (Domanda agg: 1051.8 kWh)
# H3 881f99059dfffff: 1 colonnine, 555.4 kWh coperti su 720.9 kWh (Domanda agg: 720.9 kWh)
# H3 881f990597fffff: 3 colonnine, 1666.3 kWh coperti su 2038.8 kWh (Domanda agg: 2038.8 kWh)
# H3 881f990591fffff: 2 colonnine, 1110.9 kWh coperti su 1665.0 kWh (Domanda agg: 1665.0 kWh)
# H3 881f9938e1fffff: 3 colonnine, 1666.3 kWh coperti su 1947.2 kWh (Domanda agg: 1947.2 kWh)
# H3 881f9938e7fffff: 1 colonnine, 555.4 kWh coperti su 565.1 kWh (Domanda agg: 565.1 kWh)
# H3 881f9938a5fffff: 1 colonnine, 555.4 kWh coperti su 997.0 kWh (Domanda agg: 997.0 kWh)
# H3 881f9939d3fffff: 2 colonnine, 1110.9 kWh coperti su 1229.9 kWh (Domanda agg: 1229.9 kWh)
# H3 881f993991fffff: 2 colonnine, 1110.9 kWh coperti su 1143.2 kWh (Domanda agg: 1143.2 kWh)
# H3 881f99399bfffff: 1 colonnine, 555.4 kWh coperti su 1098.5 kWh (Domanda agg: 1098.5 kWh)
# H3 881f992683fffff: 1 colonnine, 555.4 kWh coperti su 810.2 kWh (Domanda agg: 810.2 kWh)
# H3 881f9926c3fffff: 2 colonnine, 1110.9 kWh coperti su 1362.3 kWh (Domanda agg: 1362.3 kWh)
# H3 881f9930c5fffff: 5 colonnine, 2777.2 kWh coperti su 2961.9 kWh (Domanda agg: 2961.9 kWh)
# H3 881f993013fffff: 1 colonnine, 555.4 kWh coperti su 985.3 kWh (Domanda agg: 985.3 kWh)
# H3 881ea45a9bfffff: 1 colonnine, 555.4 kWh coperti su 869.9 kWh (Domanda agg: 869.9 kWh)
# H3 881ea44345fffff: 2 colonnine, 1110.9 kWh coperti su 1308.9 kWh (Domanda agg: 1308.9 kWh)
# H3 881ea4430dfffff: 2 colonnine, 1110.9 kWh coperti su 1182.8 kWh (Domanda agg: 1182.8 kWh)
# H3 881ea44341fffff: 1 colonnine, 555.4 kWh coperti su 1072.6 kWh (Domanda agg: 1072.6 kWh)
# H3 881ea44347fffff: 1 colonnine, 555.4 kWh coperti su 913.2 kWh (Domanda agg: 913.2 kWh)
# H3 881ea4436bfffff: 1 colonnine, 555.4 kWh coperti su 894.1 kWh (Domanda agg: 894.1 kWh)
# H3 881f99a5c9fffff: 1 colonnine, 555.4 kWh coperti su 828.5 kWh (Domanda agg: 828.5 kWh)
# H3 881f99a51bfffff: 3 colonnine, 1666.3 kWh coperti su 1707.3 kWh (Domanda agg: 1707.3 kWh)
# H3 881f992323fffff: 1 colonnine, 555.4 kWh coperti su 872.8 kWh (Domanda agg: 872.8 kWh)
# H3 881f992335fffff: 1 colonnine, 555.4 kWh coperti su 660.6 kWh (Domanda agg: 660.6 kWh)
# H3 881f992321fffff: 1 colonnine, 555.4 kWh coperti su 957.8 kWh (Domanda agg: 957.8 kWh)
# H3 881f992143fffff: 1 colonnine, 555.4 kWh coperti su 809.9 kWh (Domanda agg: 809.9 kWh)
# H3 881ea4c8a1fffff: 2 colonnine, 1110.9 kWh coperti su 1424.3 kWh (Domanda agg: 1424.3 kWh)
# H3 881ea4c99dfffff: 2 colonnine, 1110.9 kWh coperti su 1134.8 kWh (Domanda agg: 1134.8 kWh)
# H3 881ea4c983fffff: 2 colonnine, 1110.9 kWh coperti su 1266.9 kWh (Domanda agg: 1266.9 kWh)
# H3 881ea4c987fffff: 2 colonnine, 1110.9 kWh coperti su 1307.7 kWh (Domanda agg: 1307.7 kWh)
# H3 881ea4c9ebfffff: 1 colonnine, 555.4 kWh coperti su 794.8 kWh (Domanda agg: 794.8 kWh)
# H3 881ea69621fffff: 2 colonnine, 1110.9 kWh coperti su 1203.7 kWh (Domanda agg: 1203.7 kWh)
# H3 881ea6971bfffff: 1 colonnine, 555.4 kWh coperti su 728.2 kWh (Domanda agg: 728.2 kWh)
# H3 881ea69647fffff: 1 colonnine, 555.4 kWh coperti su 790.4 kWh (Domanda agg: 790.4 kWh)
# H3 881ea69629fffff: 1 colonnine, 555.4 kWh coperti su 754.6 kWh (Domanda agg: 754.6 kWh)
# H3 881ea69661fffff: 1 colonnine, 555.4 kWh coperti su 1102.3 kWh (Domanda agg: 1102.3 kWh)
# H3 881ea69663fffff: 2 colonnine, 1110.9 kWh coperti su 1231.9 kWh (Domanda agg: 1231.9 kWh)
# H3 881f99ac21fffff: 1 colonnine, 555.4 kWh coperti su 690.9 kWh (Domanda agg: 690.9 kWh)
# H3 881f99ac67fffff: 1 colonnine, 555.4 kWh coperti su 786.3 kWh (Domanda agg: 786.3 kWh)
# H3 881f99ad19fffff: 1 colonnine, 555.4 kWh coperti su 776.1 kWh (Domanda agg: 776.1 kWh)
# H3 881f99ac25fffff: 1 colonnine, 555.4 kWh coperti su 773.1 kWh (Domanda agg: 773.1 kWh)
# H3 881f9932bdfffff: 1 colonnine, 555.4 kWh coperti su 888.3 kWh (Domanda agg: 888.3 kWh)
# H3 881f9932d7fffff: 1 colonnine, 555.4 kWh coperti su 715.4 kWh (Domanda agg: 715.4 kWh)
# H3 881f99ac69fffff: 1 colonnine, 555.4 kWh coperti su 938.3 kWh (Domanda agg: 938.3 kWh)
# H3 881f9934b5fffff: 1 colonnine, 555.4 kWh coperti su 696.1 kWh (Domanda agg: 696.1 kWh)
# H3 881f9934a3fffff: 1 colonnine, 555.4 kWh coperti su 713.5 kWh (Domanda agg: 713.5 kWh)
# H3 881f9934b7fffff: 2 colonnine, 1110.9 kWh coperti su 1492.0 kWh (Domanda agg: 1492.0 kWh)
# H3 881f992d21fffff: 1 colonnine, 555.4 kWh coperti su 779.0 kWh (Domanda agg: 779.0 kWh)
# H3 881f992d35fffff: 1 colonnine, 555.4 kWh coperti su 670.0 kWh (Domanda agg: 670.0 kWh)
# H3 881ea45349fffff: 1 colonnine, 555.4 kWh coperti su 868.5 kWh (Domanda agg: 868.5 kWh)
# H3 881ea4c9e7fffff: 1 colonnine, 555.4 kWh coperti su 905.3 kWh (Domanda agg: 905.3 kWh)
# H3 881ea4cf51fffff: 1 colonnine, 555.4 kWh coperti su 706.8 kWh (Domanda agg: 706.8 kWh)
# H3 881ea4ce0dfffff: 1 colonnine, 555.4 kWh coperti su 651.0 kWh (Domanda agg: 651.0 kWh)
# H3 881ea4c1b3fffff: 2 colonnine, 1110.9 kWh coperti su 1401.6 kWh (Domanda agg: 1401.6 kWh)
# H3 881ea4c197fffff: 1 colonnine, 555.4 kWh coperti su 751.7 kWh (Domanda agg: 751.7 kWh)
# H3 881ea4c1b9fffff: 1 colonnine, 555.4 kWh coperti su 634.8 kWh (Domanda agg: 634.8 kWh)
# H3 881ea4ce29fffff: 1 colonnine, 555.4 kWh coperti su 595.2 kWh (Domanda agg: 595.2 kWh)
# H3 881f992885fffff: 1 colonnine, 555.4 kWh coperti su 660.3 kWh (Domanda agg: 660.3 kWh)
# H3 881f992d29fffff: 1 colonnine, 555.4 kWh coperti su 717.6 kWh (Domanda agg: 717.6 kWh)
# H3 881f992d41fffff: 1 colonnine, 555.4 kWh coperti su 731.2 kWh (Domanda agg: 731.2 kWh)
# H3 881f8a693dfffff: 2 colonnine, 1110.9 kWh coperti su 1119.1 kWh (Domanda agg: 1119.1 kWh)
# H3 881ea4c889fffff: 1 colonnine, 555.4 kWh coperti su 1088.7 kWh (Domanda agg: 1088.7 kWh)
# H3 881ea4c8c1fffff: 2 colonnine, 1110.9 kWh coperti su 1655.1 kWh (Domanda agg: 1655.1 kWh)
# H3 881ea45357fffff: 1 colonnine, 555.4 kWh coperti su 612.1 kWh (Domanda agg: 612.1 kWh)
# H3 881f9932d9fffff: 1 colonnine, 555.4 kWh coperti su 558.9 kWh (Domanda agg: 558.9 kWh)
# H3 881f99a6c1fffff: 1 colonnine, 555.4 kWh coperti su 733.1 kWh (Domanda agg: 733.1 kWh)
# H3 881f9939cbfffff: 1 colonnine, 555.4 kWh coperti su 754.6 kWh (Domanda agg: 754.6 kWh)
# H3 881f99398bfffff: 2 colonnine, 1110.9 kWh coperti su 1382.5 kWh (Domanda agg: 1382.5 kWh)
# H3 881f9928ebfffff: 1 colonnine, 555.4 kWh coperti su 877.1 kWh (Domanda agg: 877.1 kWh)
# H3 881f9928c7fffff: 1 colonnine, 555.4 kWh coperti su 726.1 kWh (Domanda agg: 726.1 kWh)
# H3 881f9928c1fffff: 1 colonnine, 555.4 kWh coperti su 590.2 kWh (Domanda agg: 590.2 kWh)
# H3 881f9928c3fffff: 1 colonnine, 555.4 kWh coperti su 608.7 kWh (Domanda agg: 608.7 kWh)
# H3 881ea69269fffff: 1 colonnine, 555.4 kWh coperti su 748.8 kWh (Domanda agg: 748.8 kWh)
# H3 881f992a51fffff: 1 colonnine, 555.4 kWh coperti su 761.4 kWh (Domanda agg: 761.4 kWh)
# H3 881f992a57fffff: 1 colonnine, 555.4 kWh coperti su 586.5 kWh (Domanda agg: 586.5 kWh)
# H3 881f8a6859fffff: 2 colonnine, 1110.9 kWh coperti su 1323.4 kWh (Domanda agg: 1323.4 kWh)
# H3 881f99a70dfffff: 1 colonnine, 555.4 kWh coperti su 814.5 kWh (Domanda agg: 814.5 kWh)
# H3 881f9934d7fffff: 1 colonnine, 555.4 kWh coperti su 1029.0 kWh (Domanda agg: 1029.0 kWh)
# H3 881ea4c72bfffff: 1 colonnine, 555.4 kWh coperti su 921.7 kWh (Domanda agg: 921.7 kWh)
# H3 881ea4c465fffff: 2 colonnine, 1110.9 kWh coperti su 1122.6 kWh (Domanda agg: 1122.6 kWh)
# H3 881ea4c461fffff: 1 colonnine, 555.4 kWh coperti su 809.7 kWh (Domanda agg: 809.7 kWh)
# H3 881ea4c551fffff: 1 colonnine, 555.4 kWh coperti su 828.1 kWh (Domanda agg: 828.1 kWh)
# H3 881ea4c445fffff: 1 colonnine, 555.4 kWh coperti su 771.5 kWh (Domanda agg: 771.5 kWh)
# H3 881ea4d161fffff: 1 colonnine, 555.4 kWh coperti su 732.7 kWh (Domanda agg: 732.7 kWh)
# H3 881f992ca5fffff: 1 colonnine, 555.4 kWh coperti su 781.9 kWh (Domanda agg: 781.9 kWh)
# H3 881f992ca1fffff: 1 colonnine, 555.4 kWh coperti su 667.3 kWh (Domanda agg: 667.3 kWh)
# H3 881f992ca3fffff: 1 colonnine, 555.4 kWh coperti su 569.3 kWh (Domanda agg: 569.3 kWh)
# H3 881f99ad11fffff: 1 colonnine, 555.4 kWh coperti su 786.4 kWh (Domanda agg: 786.4 kWh)
# H3 881f8a692bfffff: 2 colonnine, 1110.9 kWh coperti su 1160.8 kWh (Domanda agg: 1160.8 kWh)
# H3 881f8a7a81fffff: 1 colonnine, 555.4 kWh coperti su 559.1 kWh (Domanda agg: 559.1 kWh)
# H3 881ea4d883fffff: 1 colonnine, 555.4 kWh coperti su 569.9 kWh (Domanda agg: 569.9 kWh)
# H3 881ea4d891fffff: 1 colonnine, 555.4 kWh coperti su 738.8 kWh (Domanda agg: 738.8 kWh)
# H3 881ea4c14dfffff: 1 colonnine, 555.4 kWh coperti su 773.4 kWh (Domanda agg: 773.4 kWh)
# H3 881ea69219fffff: 2 colonnine, 1110.9 kWh coperti su 1157.9 kWh (Domanda agg: 1157.9 kWh)
# H3 881f8a7427fffff: 1 colonnine, 555.4 kWh coperti su 1063.7 kWh (Domanda agg: 1063.7 kWh)
# H3 881f9938d3fffff: 1 colonnine, 555.4 kWh coperti su 567.7 kWh (Domanda agg: 567.7 kWh)
# H3 881ea4cb69fffff: 1 colonnine, 555.4 kWh coperti su 575.6 kWh (Domanda agg: 575.6 kWh)
# H3 881f993695fffff: 1 colonnine, 555.4 kWh coperti su 833.2 kWh (Domanda agg: 833.2 kWh)
# H3 881f99236dfffff: 1 colonnine, 555.4 kWh coperti su 718.0 kWh (Domanda agg: 718.0 kWh)
# H3 881ea4cb4dfffff: 1 colonnine, 555.4 kWh coperti su 590.3 kWh (Domanda agg: 590.3 kWh)
# H3 881f9938c7fffff: 1 colonnine, 555.4 kWh coperti su 567.7 kWh (Domanda agg: 567.7 kWh)
# H3 881ea69233fffff: 1 colonnine, 555.4 kWh coperti su 636.6 kWh (Domanda agg: 636.6 kWh)
# H3 881f99acd9fffff: 1 colonnine, 555.4 kWh coperti su 720.3 kWh (Domanda agg: 720.3 kWh)
# H3 881ea4c563fffff: 1 colonnine, 555.4 kWh coperti su 690.4 kWh (Domanda agg: 690.4 kWh)
#
# Domanda totale coperta: 4129622.05 kWh

# %% [markdown]
# ### Map visualisation

# %%
mappa = crea_mappa_colonnine_discrete(gdf_risultati_ott2030)
mappa
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Save the map as an HTML file
mappa.save("/content/drive/Shareddrives/OM in Business Analytics/OM in BA - Project/Codice/04 - Modello/log_heatmap_sixth_model_def.html")

# %% [markdown]
# ### Results

# %%
total_allocated_chargers = gdf_risultati_ott2030["Colonnine allocate"].sum()
total_covered_demand = gdf_risultati_ott2030["Domanda coperta (kWh)"].sum()
total_demand = gdf_risultati_ott2030["Domanda Giornaliera Ponderata (kWh)"].sum()

print(f"Total allocated charging stations: {total_allocated_chargers}")
print(f"Total covered demand (kWh): {total_covered_demand:.2f}")
print(f"Total demand (kWh): {total_demand:.2f}")
# Out:
# Total allocated charging stations: 7435
# Total covered demand (kWh): 4129622.05
# Total demand (kWh): 15014065.22

# %% [markdown]
# ## SEVENTH MODEL
# ## Charging Station Allocation Model Alpha – 2030 Optimistic Scenario

# %%
gdf_risultati_ott2030_alpha = ottimizza_colonnine_con_alpha(gdf_ottimistico, p_colonnine=7435, alpha=0.167)
# Out:
# H3 881f99274bfffff: 10 colonnine, 5554.3 kWh coperti su 33496.5 kWh (Domanda agg: 33496.5 kWh)
# H3 881f992215fffff: 10 colonnine, 5554.3 kWh coperti su 42338.8 kWh (Domanda agg: 42338.8 kWh)
# H3 881f992213fffff: 10 colonnine, 5554.3 kWh coperti su 69387.1 kWh (Domanda agg: 69387.1 kWh)
# H3 881f9935c7fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f9935a1fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f9922ddfffff: 10 colonnine, 5554.3 kWh coperti su 113962.5 kWh (Domanda agg: 113962.5 kWh)
# H3 881f992285fffff: 10 colonnine, 5554.3 kWh coperti su 56753.4 kWh (Domanda agg: 56753.4 kWh)
# H3 881f9922e3fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f992217fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f993501fffff: 10 colonnine, 5554.3 kWh coperti su 73222.5 kWh (Domanda agg: 73222.5 kWh)
# H3 881f99353bfffff: 10 colonnine, 5554.3 kWh coperti su 118573.8 kWh (Domanda agg: 118573.8 kWh)
# H3 881f992295fffff: 10 colonnine, 5554.3 kWh coperti su 58835.9 kWh (Domanda agg: 58835.9 kWh)
# H3 881f9922cdfffff: 10 colonnine, 5554.3 kWh coperti su 85878.7 kWh (Domanda agg: 85878.7 kWh)
# H3 881f9920d9fffff: 10 colonnine, 5554.3 kWh coperti su 51398.2 kWh (Domanda agg: 51398.2 kWh)
# H3 881f992745fffff: 10 colonnine, 5554.3 kWh coperti su 52737.5 kWh (Domanda agg: 52737.5 kWh)
# H3 881f992291fffff: 10 colonnine, 5554.3 kWh coperti su 77255.8 kWh (Domanda agg: 77255.8 kWh)
# H3 881f992233fffff: 10 colonnine, 5554.3 kWh coperti su 73473.6 kWh (Domanda agg: 73473.6 kWh)
# H3 881f993537fffff: 10 colonnine, 5554.3 kWh coperti su 22696.7 kWh (Domanda agg: 22696.7 kWh)
# H3 881f993531fffff: 10 colonnine, 5554.3 kWh coperti su 85781.8 kWh (Domanda agg: 85781.8 kWh)
# H3 881f9922c9fffff: 10 colonnine, 5554.3 kWh coperti su 92415.9 kWh (Domanda agg: 92415.9 kWh)
# H3 881f992741fffff: 10 colonnine, 5554.3 kWh coperti su 76560.3 kWh (Domanda agg: 76560.3 kWh)
# H3 881f993511fffff: 10 colonnine, 5554.3 kWh coperti su 82796.8 kWh (Domanda agg: 82796.8 kWh)
# H3 881f99270dfffff: 10 colonnine, 5554.3 kWh coperti su 91679.6 kWh (Domanda agg: 91679.6 kWh)
# H3 881f992287fffff: 10 colonnine, 5554.3 kWh coperti su 33407.4 kWh (Domanda agg: 33407.4 kWh)
# H3 881f992253fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f992211fffff: 10 colonnine, 5554.3 kWh coperti su 93525.1 kWh (Domanda agg: 93525.1 kWh)
# H3 881f992231fffff: 10 colonnine, 5554.3 kWh coperti su 48146.7 kWh (Domanda agg: 48146.7 kWh)
# H3 881f9922d7fffff: 10 colonnine, 5554.3 kWh coperti su 63423.5 kWh (Domanda agg: 63423.5 kWh)
# H3 881f9935a7fffff: 10 colonnine, 5554.3 kWh coperti su 30520.5 kWh (Domanda agg: 30520.5 kWh)
# H3 881f99221bfffff: 10 colonnine, 5554.3 kWh coperti su 61989.3 kWh (Domanda agg: 61989.3 kWh)
# H3 881f992239fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f992761fffff: 10 colonnine, 5554.3 kWh coperti su 75255.9 kWh (Domanda agg: 75255.9 kWh)
# H3 881f9935a5fffff: 10 colonnine, 5554.3 kWh coperti su 73676.1 kWh (Domanda agg: 73676.1 kWh)
# H3 881f993557fffff: 10 colonnine, 5554.3 kWh coperti su 86996.5 kWh (Domanda agg: 86996.5 kWh)
# H3 881f9935e1fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f99358dfffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f9922b3fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f9922edfffff: 10 colonnine, 5554.3 kWh coperti su 54261.8 kWh (Domanda agg: 54261.8 kWh)
# H3 881f99223bfffff: 10 colonnine, 5554.3 kWh coperti su 56688.6 kWh (Domanda agg: 56688.6 kWh)
# H3 881f992283fffff: 10 colonnine, 5554.3 kWh coperti su 98841.8 kWh (Domanda agg: 98841.8 kWh)
# H3 881f993519fffff: 10 colonnine, 5554.3 kWh coperti su 85502.5 kWh (Domanda agg: 85502.5 kWh)
# H3 881f993553fffff: 10 colonnine, 5554.3 kWh coperti su 81220.2 kWh (Domanda agg: 81220.2 kWh)
# H3 881f993535fffff: 10 colonnine, 5554.3 kWh coperti su 68032.1 kWh (Domanda agg: 68032.1 kWh)
# H3 881f993585fffff: 10 colonnine, 5554.3 kWh coperti su 70039.5 kWh (Domanda agg: 70039.5 kWh)
# H3 881f993539fffff: 10 colonnine, 5554.3 kWh coperti su 88737.6 kWh (Domanda agg: 88737.6 kWh)
# H3 881f992203fffff: 10 colonnine, 5554.3 kWh coperti su 42778.6 kWh (Domanda agg: 42778.6 kWh)
# H3 881f9935e9fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f992299fffff: 10 colonnine, 5554.3 kWh coperti su 46732.0 kWh (Domanda agg: 46732.0 kWh)
# H3 881f9922d1fffff: 10 colonnine, 5554.3 kWh coperti su 160025.3 kWh (Domanda agg: 160025.3 kWh)
# H3 881f992251fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f993507fffff: 10 colonnine, 5554.3 kWh coperti su 126241.4 kWh (Domanda agg: 126241.4 kWh)
# H3 881f9922a9fffff: 10 colonnine, 5554.3 kWh coperti su 97680.5 kWh (Domanda agg: 97680.5 kWh)
# H3 881f992765fffff: 10 colonnine, 5554.3 kWh coperti su 54803.1 kWh (Domanda agg: 54803.1 kWh)
# H3 881f99229bfffff: 10 colonnine, 5554.3 kWh coperti su 106877.8 kWh (Domanda agg: 106877.8 kWh)
# H3 881f99276dfffff: 10 colonnine, 5554.3 kWh coperti su 79241.2 kWh (Domanda agg: 79241.2 kWh)
# H3 881f99353dfffff: 10 colonnine, 5554.3 kWh coperti su 99546.3 kWh (Domanda agg: 99546.3 kWh)
# H3 881f9922c7fffff: 10 colonnine, 5554.3 kWh coperti su 81913.2 kWh (Domanda agg: 81913.2 kWh)
# H3 881f993563fffff: 10 colonnine, 5554.3 kWh coperti su 48280.9 kWh (Domanda agg: 48280.9 kWh)
# H3 881f992293fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f99352bfffff: 10 colonnine, 5554.3 kWh coperti su 95832.4 kWh (Domanda agg: 95832.4 kWh)
# H3 881f9935cdfffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f993581fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f99351bfffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f992297fffff: 10 colonnine, 5554.3 kWh coperti su 52641.7 kWh (Domanda agg: 52641.7 kWh)
# H3 881f9922c5fffff: 10 colonnine, 5554.3 kWh coperti su 153173.5 kWh (Domanda agg: 153173.5 kWh)
# H3 881f992769fffff: 10 colonnine, 5554.3 kWh coperti su 71717.1 kWh (Domanda agg: 71717.1 kWh)
# H3 881f993425fffff: 10 colonnine, 5554.3 kWh coperti su 58271.1 kWh (Domanda agg: 58271.1 kWh)
# H3 881f9935adfffff: 10 colonnine, 5554.3 kWh coperti su 23421.0 kWh (Domanda agg: 23421.0 kWh)
# H3 881f992219fffff: 10 colonnine, 5554.3 kWh coperti su 104756.7 kWh (Domanda agg: 104756.7 kWh)
# H3 881f99274dfffff: 10 colonnine, 5554.3 kWh coperti su 96197.7 kWh (Domanda agg: 96197.7 kWh)
# H3 881f9922c1fffff: 10 colonnine, 5554.3 kWh coperti su 130813.0 kWh (Domanda agg: 130813.0 kWh)
# H3 881f993427fffff: 10 colonnine, 5554.3 kWh coperti su 31535.6 kWh (Domanda agg: 31535.6 kWh)
# H3 881f9922cbfffff: 10 colonnine, 5554.3 kWh coperti su 89937.0 kWh (Domanda agg: 89937.0 kWh)
# H3 881f993503fffff: 10 colonnine, 5554.3 kWh coperti su 82830.3 kWh (Domanda agg: 82830.3 kWh)
# H3 881f992237fffff: 10 colonnine, 5554.3 kWh coperti su 77983.7 kWh (Domanda agg: 77983.7 kWh)
# H3 881f99205bfffff: 10 colonnine, 5554.3 kWh coperti su 41832.7 kWh (Domanda agg: 41832.7 kWh)
# H3 881f9935a3fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f99229dfffff: 10 colonnine, 5554.3 kWh coperti su 68147.7 kWh (Domanda agg: 68147.7 kWh)
# H3 881f9935c5fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f99351dfffff: 10 colonnine, 5554.3 kWh coperti su 52646.9 kWh (Domanda agg: 52646.9 kWh)
# H3 881f993515fffff: 10 colonnine, 5554.3 kWh coperti su 80835.3 kWh (Domanda agg: 80835.3 kWh)
# H3 881f992749fffff: 10 colonnine, 5554.3 kWh coperti su 53837.3 kWh (Domanda agg: 53837.3 kWh)
# H3 881f9935e5fffff: 10 colonnine, 5554.3 kWh coperti su 49902.7 kWh (Domanda agg: 49902.7 kWh)
# H3 881f9935ebfffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f99352dfffff: 10 colonnine, 5554.3 kWh coperti su 62713.6 kWh (Domanda agg: 62713.6 kWh)
# H3 881f99228dfffff: 10 colonnine, 5554.3 kWh coperti su 125897.6 kWh (Domanda agg: 125897.6 kWh)
# H3 881f9935e3fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f993513fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f993567fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f9922adfffff: 10 colonnine, 5554.3 kWh coperti su 36909.1 kWh (Domanda agg: 36909.1 kWh)
# H3 881f9935e7fffff: 10 colonnine, 5554.3 kWh coperti su 98139.6 kWh (Domanda agg: 98139.6 kWh)
# H3 881f992747fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f99276bfffff: 10 colonnine, 5554.3 kWh coperti su 59715.6 kWh (Domanda agg: 59715.6 kWh)
# H3 881f993527fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f993529fffff: 10 colonnine, 5554.3 kWh coperti su 39955.8 kWh (Domanda agg: 39955.8 kWh)
# H3 881f992289fffff: 10 colonnine, 5554.3 kWh coperti su 89605.0 kWh (Domanda agg: 89605.0 kWh)
# H3 881f9935edfffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f9922d9fffff: 10 colonnine, 5554.3 kWh coperti su 184481.2 kWh (Domanda agg: 184481.2 kWh)
# H3 881f99350dfffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f992281fffff: 10 colonnine, 5554.3 kWh coperti su 152588.2 kWh (Domanda agg: 152588.2 kWh)
# H3 881f99228bfffff: 10 colonnine, 5554.3 kWh coperti su 67323.4 kWh (Domanda agg: 67323.4 kWh)
# H3 881f9922e1fffff: 10 colonnine, 5554.3 kWh coperti su 72497.1 kWh (Domanda agg: 72497.1 kWh)
# H3 881f9922d5fffff: 10 colonnine, 5554.3 kWh coperti su 76941.6 kWh (Domanda agg: 76941.6 kWh)
# H3 881f993505fffff: 10 colonnine, 5554.3 kWh coperti su 59927.1 kWh (Domanda agg: 59927.1 kWh)
# H3 881f993517fffff: 10 colonnine, 5554.3 kWh coperti su 53607.2 kWh (Domanda agg: 53607.2 kWh)
# H3 881f9935abfffff: 10 colonnine, 5554.3 kWh coperti su 22006.5 kWh (Domanda agg: 22006.5 kWh)
# H3 881f9922bbfffff: 10 colonnine, 5554.3 kWh coperti su 49516.5 kWh (Domanda agg: 49516.5 kWh)
# H3 881f9922d3fffff: 10 colonnine, 5554.3 kWh coperti su 100694.3 kWh (Domanda agg: 100694.3 kWh)
# H3 881f993521fffff: 10 colonnine, 5554.3 kWh coperti su 94077.8 kWh (Domanda agg: 94077.8 kWh)
# H3 881f9922ebfffff: 10 colonnine, 5554.3 kWh coperti su 99967.7 kWh (Domanda agg: 99967.7 kWh)
# H3 881f9922e9fffff: 10 colonnine, 5554.3 kWh coperti su 72617.4 kWh (Domanda agg: 72617.4 kWh)
# H3 881f993525fffff: 10 colonnine, 5554.3 kWh coperti su 52695.1 kWh (Domanda agg: 52695.1 kWh)
# H3 881f9935b5fffff: 10 colonnine, 5554.3 kWh coperti su 50585.9 kWh (Domanda agg: 50585.9 kWh)
# H3 881f9922c3fffff: 10 colonnine, 5554.3 kWh coperti su 69437.5 kWh (Domanda agg: 69437.5 kWh)
# H3 881f9922e7fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f9935a9fffff: 10 colonnine, 5554.3 kWh coperti su 111836.0 kWh (Domanda agg: 111836.0 kWh)
# H3 881f99225bfffff: 10 colonnine, 5554.3 kWh coperti su 60751.7 kWh (Domanda agg: 60751.7 kWh)
# H3 881f9922dbfffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f992059fffff: 10 colonnine, 5554.3 kWh coperti su 20858.7 kWh (Domanda agg: 20858.7 kWh)
# H3 881f9922e5fffff: 10 colonnine, 5554.3 kWh coperti su 50009.1 kWh (Domanda agg: 50009.1 kWh)
# H3 881f993523fffff: 10 colonnine, 5554.3 kWh coperti su 58967.9 kWh (Domanda agg: 58967.9 kWh)
# H3 881f993533fffff: 10 colonnine, 5554.3 kWh coperti su 74957.1 kWh (Domanda agg: 74957.1 kWh)
# H3 881f992497fffff: 10 colonnine, 5554.3 kWh coperti su 7083.3 kWh (Domanda agg: 7083.3 kWh)
# H3 881ea45135fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45333fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea4510dfffff: 10 colonnine, 5554.3 kWh coperti su 15072.5 kWh (Domanda agg: 15072.5 kWh)
# H3 881ea45ad1fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45addfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45149fffff: 10 colonnine, 5554.3 kWh coperti su 9646.1 kWh (Domanda agg: 9646.1 kWh)
# H3 881ea4512dfffff: 10 colonnine, 5554.3 kWh coperti su 6835.6 kWh (Domanda agg: 6835.6 kWh)
# H3 881ea45153fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45109fffff: 8 colonnine, 4443.4 kWh coperti su 4763.2 kWh (Domanda agg: 4763.2 kWh)
# H3 881ea45a81fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea451e7fffff: 10 colonnine, 5554.3 kWh coperti su 19703.0 kWh (Domanda agg: 19703.0 kWh)
# H3 881ea45161fffff: 10 colonnine, 5554.3 kWh coperti su 14810.0 kWh (Domanda agg: 14810.0 kWh)
# H3 881ea45a83fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea451e3fffff: 10 colonnine, 5554.3 kWh coperti su 8850.3 kWh (Domanda agg: 8850.3 kWh)
# H3 881ea451e1fffff: 10 colonnine, 5554.3 kWh coperti su 12317.5 kWh (Domanda agg: 12317.5 kWh)
# H3 881ea45025fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45107fffff: 10 colonnine, 5554.3 kWh coperti su 6127.9 kWh (Domanda agg: 6127.9 kWh)
# H3 881ea4515dfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45ac3fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea451edfffff: 10 colonnine, 5554.3 kWh coperti su 8614.1 kWh (Domanda agg: 8614.1 kWh)
# H3 881ea45133fffff: 10 colonnine, 5554.3 kWh coperti su 9659.1 kWh (Domanda agg: 9659.1 kWh)
# H3 881ea45a99fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea4513dfffff: 10 colonnine, 5554.3 kWh coperti su 9230.5 kWh (Domanda agg: 9230.5 kWh)
# H3 881ea45103fffff: 10 colonnine, 5554.3 kWh coperti su 15092.9 kWh (Domanda agg: 15092.9 kWh)
# H3 881ea451a1fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45147fffff: 10 colonnine, 5554.3 kWh coperti su 11821.1 kWh (Domanda agg: 11821.1 kWh)
# H3 881ea4502dfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea4511bfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45143fffff: 10 colonnine, 5554.3 kWh coperti su 6632.2 kWh (Domanda agg: 6632.2 kWh)
# H3 881ea45ac9fffff: 10 colonnine, 5554.3 kWh coperti su 8501.9 kWh (Domanda agg: 8501.9 kWh)
# H3 881ea45ab9fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea4514bfffff: 10 colonnine, 5554.3 kWh coperti su 7509.1 kWh (Domanda agg: 7509.1 kWh)
# H3 881ea45061fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea4513bfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45a87fffff: 9 colonnine, 4998.9 kWh coperti su 5128.0 kWh (Domanda agg: 5128.0 kWh)
# H3 881ea4515bfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45117fffff: 10 colonnine, 5554.3 kWh coperti su 13736.6 kWh (Domanda agg: 13736.6 kWh)
# H3 881ea451abfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45119fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea451e5fffff: 10 colonnine, 5554.3 kWh coperti su 9815.7 kWh (Domanda agg: 9815.7 kWh)
# H3 881ea45065fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45129fffff: 10 colonnine, 5554.3 kWh coperti su 12628.9 kWh (Domanda agg: 12628.9 kWh)
# H3 881ea451adfffff: 10 colonnine, 5554.3 kWh coperti su 8756.4 kWh (Domanda agg: 8756.4 kWh)
# H3 881ea45115fffff: 10 colonnine, 5554.3 kWh coperti su 13456.7 kWh (Domanda agg: 13456.7 kWh)
# H3 881ea45ad3fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45169fffff: 10 colonnine, 5554.3 kWh coperti su 9389.4 kWh (Domanda agg: 9389.4 kWh)
# H3 881ea451e9fffff: 10 colonnine, 5554.3 kWh coperti su 7212.5 kWh (Domanda agg: 7212.5 kWh)
# H3 881ea45337fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea4512bfffff: 10 colonnine, 5554.3 kWh coperti su 12509.1 kWh (Domanda agg: 12509.1 kWh)
# H3 881ea4514dfffff: 10 colonnine, 5554.3 kWh coperti su 8653.5 kWh (Domanda agg: 8653.5 kWh)
# H3 881ea45139fffff: 10 colonnine, 5554.3 kWh coperti su 10934.6 kWh (Domanda agg: 10934.6 kWh)
# H3 881ea45adbfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45145fffff: 10 colonnine, 5554.3 kWh coperti su 7038.6 kWh (Domanda agg: 7038.6 kWh)
# H3 881ea45105fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea451a5fffff: 10 colonnine, 5554.3 kWh coperti su 8299.7 kWh (Domanda agg: 8299.7 kWh)
# H3 881ea45155fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45167fffff: 10 colonnine, 5554.3 kWh coperti su 9103.4 kWh (Domanda agg: 9103.4 kWh)
# H3 881ea45163fffff: 10 colonnine, 5554.3 kWh coperti su 12419.7 kWh (Domanda agg: 12419.7 kWh)
# H3 881ea45113fffff: 10 colonnine, 5554.3 kWh coperti su 9290.0 kWh (Domanda agg: 9290.0 kWh)
# H3 881ea45101fffff: 10 colonnine, 5554.3 kWh coperti su 13960.7 kWh (Domanda agg: 13960.7 kWh)
# H3 881ea45ad5fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45335fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea451a9fffff: 10 colonnine, 5554.3 kWh coperti su 7708.9 kWh (Domanda agg: 7708.9 kWh)
# H3 881ea45131fffff: 10 colonnine, 5554.3 kWh coperti su 13763.4 kWh (Domanda agg: 13763.4 kWh)
# H3 881ea45123fffff: 10 colonnine, 5554.3 kWh coperti su 7437.1 kWh (Domanda agg: 7437.1 kWh)
# H3 881ea4516bfffff: 10 colonnine, 5554.3 kWh coperti su 16163.0 kWh (Domanda agg: 16163.0 kWh)
# H3 881ea451ebfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea4510bfffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45137fffff: 6 colonnine, 3332.6 kWh coperti su 3657.3 kWh (Domanda agg: 3657.3 kWh)
# H3 881ea45121fffff: 10 colonnine, 5554.3 kWh coperti su 6373.2 kWh (Domanda agg: 6373.2 kWh)
# H3 881ea45b53fffff: 10 colonnine, 5554.3 kWh coperti su 6730.2 kWh (Domanda agg: 6730.2 kWh)
# H3 881f9925e7fffff: 10 colonnine, 5554.3 kWh coperti su 8470.6 kWh (Domanda agg: 8470.6 kWh)
# H3 881f992e91fffff: 10 colonnine, 5554.3 kWh coperti su 6853.8 kWh (Domanda agg: 6853.8 kWh)
# H3 881f992ec5fffff: 10 colonnine, 5554.3 kWh coperti su 8362.5 kWh (Domanda agg: 8362.5 kWh)
# H3 881f992583fffff: 10 colonnine, 5554.3 kWh coperti su 7954.7 kWh (Domanda agg: 7954.7 kWh)
# H3 881f992501fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f992515fffff: 10 colonnine, 5554.3 kWh coperti su 6417.0 kWh (Domanda agg: 6417.0 kWh)
# H3 881f992ed3fffff: 10 colonnine, 5554.3 kWh coperti su 8473.2 kWh (Domanda agg: 8473.2 kWh)
# H3 881f99250bfffff: 10 colonnine, 5554.3 kWh coperti su 6382.4 kWh (Domanda agg: 6382.4 kWh)
# H3 881ea45b47fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f992e9bfffff: 10 colonnine, 5554.3 kWh coperti su 8819.4 kWh (Domanda agg: 8819.4 kWh)
# H3 881ea45b65fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881ea45b09fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f992527fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881ea45b69fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f992537fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881ea45b4dfffff: 10 colonnine, 5554.3 kWh coperti su 11667.6 kWh (Domanda agg: 11667.6 kWh)
# H3 881f9925adfffff: 10 colonnine, 5554.3 kWh coperti su 9432.0 kWh (Domanda agg: 9432.0 kWh)
# H3 881ea45b0dfffff: 10 colonnine, 5554.3 kWh coperti su 5841.3 kWh (Domanda agg: 5841.3 kWh)
# H3 881f992e8bfffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f9925edfffff: 10 colonnine, 5554.3 kWh coperti su 10178.0 kWh (Domanda agg: 10178.0 kWh)
# H3 881ea45b0bfffff: 10 colonnine, 5554.3 kWh coperti su 7985.9 kWh (Domanda agg: 7985.9 kWh)
# H3 881f992e8dfffff: 10 colonnine, 5554.3 kWh coperti su 6643.3 kWh (Domanda agg: 6643.3 kWh)
# H3 881f9925a3fffff: 10 colonnine, 5554.3 kWh coperti su 9707.4 kWh (Domanda agg: 9707.4 kWh)
# H3 881ea45b67fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f992539fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f9925abfffff: 10 colonnine, 5554.3 kWh coperti su 13435.9 kWh (Domanda agg: 13435.9 kWh)
# H3 881f992587fffff: 10 colonnine, 5554.3 kWh coperti su 7909.3 kWh (Domanda agg: 7909.3 kWh)
# H3 881f992ed5fffff: 10 colonnine, 5554.3 kWh coperti su 9333.3 kWh (Domanda agg: 9333.3 kWh)
# H3 881f992e99fffff: 10 colonnine, 5554.3 kWh coperti su 13251.5 kWh (Domanda agg: 13251.5 kWh)
# H3 881f9925a7fffff: 10 colonnine, 5554.3 kWh coperti su 8337.3 kWh (Domanda agg: 8337.3 kWh)
# H3 881f9925b3fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f9925b1fffff: 10 colonnine, 5554.3 kWh coperti su 6998.7 kWh (Domanda agg: 6998.7 kWh)
# H3 881f992eb9fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881ea45b4bfffff: 10 colonnine, 5554.3 kWh coperti su 7187.1 kWh (Domanda agg: 7187.1 kWh)
# H3 881f992eddfffff: 9 colonnine, 4998.9 kWh coperti su 5191.1 kWh (Domanda agg: 5191.1 kWh)
# H3 881f9925ebfffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881ea45b63fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f99252bfffff: 10 colonnine, 5554.3 kWh coperti su 6623.6 kWh (Domanda agg: 6623.6 kWh)
# H3 881f9925a1fffff: 10 colonnine, 5554.3 kWh coperti su 12196.0 kWh (Domanda agg: 12196.0 kWh)
# H3 881f992503fffff: 10 colonnine, 5554.3 kWh coperti su 7234.0 kWh (Domanda agg: 7234.0 kWh)
# H3 881f992519fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f992ec1fffff: 10 colonnine, 5554.3 kWh coperti su 10002.8 kWh (Domanda agg: 10002.8 kWh)
# H3 881ea45b6dfffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881ea45b55fffff: 10 colonnine, 5554.3 kWh coperti su 12675.7 kWh (Domanda agg: 12675.7 kWh)
# H3 881f992ecdfffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f992509fffff: 10 colonnine, 5554.3 kWh coperti su 11371.9 kWh (Domanda agg: 11371.9 kWh)
# H3 881f992ec7fffff: 10 colonnine, 5554.3 kWh coperti su 6645.5 kWh (Domanda agg: 6645.5 kWh)
# H3 881f992585fffff: 10 colonnine, 5554.3 kWh coperti su 7330.2 kWh (Domanda agg: 7330.2 kWh)
# H3 881ea45b6bfffff: 10 colonnine, 5554.3 kWh coperti su 6646.8 kWh (Domanda agg: 6646.8 kWh)
# H3 881ea45b49fffff: 10 colonnine, 5554.3 kWh coperti su 7946.9 kWh (Domanda agg: 7946.9 kWh)
# H3 881f9925e5fffff: 10 colonnine, 5554.3 kWh coperti su 18541.8 kWh (Domanda agg: 18541.8 kWh)
# H3 881f99253bfffff: 10 colonnine, 5554.3 kWh coperti su 7197.9 kWh (Domanda agg: 7197.9 kWh)
# H3 881f992589fffff: 10 colonnine, 5554.3 kWh coperti su 6961.6 kWh (Domanda agg: 6961.6 kWh)
# H3 881f9925a9fffff: 10 colonnine, 5554.3 kWh coperti su 7940.4 kWh (Domanda agg: 7940.4 kWh)
# H3 881f992ec3fffff: 10 colonnine, 5554.3 kWh coperti su 8467.8 kWh (Domanda agg: 8467.8 kWh)
# H3 881f992ed9fffff: 10 colonnine, 5554.3 kWh coperti su 7664.1 kWh (Domanda agg: 7664.1 kWh)
# H3 881f992ec9fffff: 10 colonnine, 5554.3 kWh coperti su 6442.6 kWh (Domanda agg: 6442.6 kWh)
# H3 881ea45b57fffff: 10 colonnine, 5554.3 kWh coperti su 7029.5 kWh (Domanda agg: 7029.5 kWh)
# H3 881f9925b7fffff: 10 colonnine, 5554.3 kWh coperti su 7221.8 kWh (Domanda agg: 7221.8 kWh)
# H3 881f9925a5fffff: 10 colonnine, 5554.3 kWh coperti su 9615.8 kWh (Domanda agg: 9615.8 kWh)
# H3 881f9925e3fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881ea45b51fffff: 10 colonnine, 5554.3 kWh coperti su 7322.2 kWh (Domanda agg: 7322.2 kWh)
# H3 881f992529fffff: 10 colonnine, 5554.3 kWh coperti su 7497.0 kWh (Domanda agg: 7497.0 kWh)
# H3 881f992ed7fffff: 10 colonnine, 5554.3 kWh coperti su 6808.6 kWh (Domanda agg: 6808.6 kWh)
# H3 881f992523fffff: 10 colonnine, 5554.3 kWh coperti su 7393.2 kWh (Domanda agg: 7393.2 kWh)
# H3 881f992531fffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881ea45b43fffff: 10 colonnine, 5554.3 kWh coperti su 11796.0 kWh (Domanda agg: 11796.0 kWh)
# H3 881ea45b45fffff: 10 colonnine, 5554.3 kWh coperti su 7412.5 kWh (Domanda agg: 7412.5 kWh)
# H3 881ea45b5bfffff: 5 colonnine, 2777.2 kWh coperti su 3048.9 kWh (Domanda agg: 3048.9 kWh)
# H3 881f992513fffff: 10 colonnine, 5554.3 kWh coperti su 7067.4 kWh (Domanda agg: 7067.4 kWh)
# H3 881f9925b9fffff: 10 colonnine, 5554.3 kWh coperti su 6023.4 kWh (Domanda agg: 6023.4 kWh)
# H3 881ea45b41fffff: 10 colonnine, 5554.3 kWh coperti su 8358.8 kWh (Domanda agg: 8358.8 kWh)
# H3 881f9925b5fffff: 10 colonnine, 5554.3 kWh coperti su 10183.5 kWh (Domanda agg: 10183.5 kWh)
# H3 881f992535fffff: 6 colonnine, 3332.6 kWh coperti su 3526.8 kWh (Domanda agg: 3526.8 kWh)
# H3 881f992ebbfffff: 10 colonnine, 5554.3 kWh coperti su 7078.9 kWh (Domanda agg: 7078.9 kWh)
# H3 881f992eb3fffff: 10 colonnine, 5554.3 kWh coperti su 5817.6 kWh (Domanda agg: 5817.6 kWh)
# H3 881f992517fffff: 10 colonnine, 5554.3 kWh coperti su 6261.0 kWh (Domanda agg: 6261.0 kWh)
# H3 881f992edbfffff: 10 colonnine, 5554.3 kWh coperti su 6640.5 kWh (Domanda agg: 6640.5 kWh)
# H3 881f99362bfffff: 7 colonnine, 3888.0 kWh coperti su 4285.9 kWh (Domanda agg: 4285.9 kWh)
# H3 881f99360bfffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f993453fffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f99345bfffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f9936c5fffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f9936a9fffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f993617fffff: 10 colonnine, 5554.3 kWh coperti su 8148.5 kWh (Domanda agg: 8148.5 kWh)
# H3 881f99363dfffff: 10 colonnine, 5554.3 kWh coperti su 7233.5 kWh (Domanda agg: 7233.5 kWh)
# H3 881f993449fffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f99368dfffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f993635fffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f993601fffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f99344bfffff: 1 colonnine, 555.4 kWh coperti su 683.1 kWh (Domanda agg: 683.1 kWh)
# H3 881f99363bfffff: 10 colonnine, 5554.3 kWh coperti su 7546.0 kWh (Domanda agg: 7546.0 kWh)
# H3 881f99334dfffff: 6 colonnine, 3332.6 kWh coperti su 3354.4 kWh (Domanda agg: 3354.4 kWh)
# H3 881f9906a3fffff: 10 colonnine, 5554.3 kWh coperti su 11005.1 kWh (Domanda agg: 11005.1 kWh)
# H3 881f993369fffff: 10 colonnine, 5554.3 kWh coperti su 8627.4 kWh (Domanda agg: 8627.4 kWh)
# H3 881f9906a5fffff: 3 colonnine, 1666.3 kWh coperti su 2050.7 kWh (Domanda agg: 2050.7 kWh)
# H3 881f990695fffff: 10 colonnine, 5554.3 kWh coperti su 7666.3 kWh (Domanda agg: 7666.3 kWh)
# H3 881f990693fffff: 10 colonnine, 5554.3 kWh coperti su 7549.6 kWh (Domanda agg: 7549.6 kWh)
# H3 881f9906e7fffff: 6 colonnine, 3332.6 kWh coperti su 3463.2 kWh (Domanda agg: 3463.2 kWh)
# H3 881f9906a9fffff: 10 colonnine, 5554.3 kWh coperti su 7629.3 kWh (Domanda agg: 7629.3 kWh)
# H3 881f9906b1fffff: 9 colonnine, 4998.9 kWh coperti su 5300.2 kWh (Domanda agg: 5300.2 kWh)
# H3 881f9906b9fffff: 10 colonnine, 5554.3 kWh coperti su 6495.5 kWh (Domanda agg: 6495.5 kWh)
# H3 881f9904c7fffff: 3 colonnine, 1666.3 kWh coperti su 2050.7 kWh (Domanda agg: 2050.7 kWh)
# H3 881f9906b7fffff: 10 colonnine, 5554.3 kWh coperti su 5767.6 kWh (Domanda agg: 5767.6 kWh)
# H3 881f9904ebfffff: 3 colonnine, 1666.3 kWh coperti su 2050.7 kWh (Domanda agg: 2050.7 kWh)
# H3 881f9906bdfffff: 10 colonnine, 5554.3 kWh coperti su 11843.1 kWh (Domanda agg: 11843.1 kWh)
# H3 881f990685fffff: 10 colonnine, 5554.3 kWh coperti su 5887.0 kWh (Domanda agg: 5887.0 kWh)
# H3 881f9906b5fffff: 10 colonnine, 5554.3 kWh coperti su 6460.6 kWh (Domanda agg: 6460.6 kWh)
# H3 881f9906bbfffff: 10 colonnine, 5554.3 kWh coperti su 7172.6 kWh (Domanda agg: 7172.6 kWh)
# H3 881f990687fffff: 10 colonnine, 5554.3 kWh coperti su 9199.9 kWh (Domanda agg: 9199.9 kWh)
# H3 881f9906abfffff: 10 colonnine, 5554.3 kWh coperti su 13186.9 kWh (Domanda agg: 13186.9 kWh)
# H3 881f990697fffff: 10 colonnine, 5554.3 kWh coperti su 10115.6 kWh (Domanda agg: 10115.6 kWh)
# H3 881f993157fffff: 10 colonnine, 5554.3 kWh coperti su 6660.8 kWh (Domanda agg: 6660.8 kWh)
# H3 881f993adbfffff: 10 colonnine, 5554.3 kWh coperti su 6450.1 kWh (Domanda agg: 6450.1 kWh)
# H3 881f99315bfffff: 10 colonnine, 5554.3 kWh coperti su 7677.5 kWh (Domanda agg: 7677.5 kWh)
# H3 881f993133fffff: 9 colonnine, 4998.9 kWh coperti su 5080.1 kWh (Domanda agg: 5080.1 kWh)
# H3 881f993117fffff: 6 colonnine, 3332.6 kWh coperti su 3524.4 kWh (Domanda agg: 3524.4 kWh)
# H3 881f993135fffff: 9 colonnine, 4998.9 kWh coperti su 5006.7 kWh (Domanda agg: 5006.7 kWh)
# H3 881f99311dfffff: 10 colonnine, 5554.3 kWh coperti su 11493.6 kWh (Domanda agg: 11493.6 kWh)
# H3 881f993153fffff: 7 colonnine, 3888.0 kWh coperti su 4223.0 kWh (Domanda agg: 4223.0 kWh)
# H3 881f993027fffff: 10 colonnine, 5554.3 kWh coperti su 5747.4 kWh (Domanda agg: 5747.4 kWh)
# H3 881f993025fffff: 10 colonnine, 5554.3 kWh coperti su 7113.1 kWh (Domanda agg: 7113.1 kWh)
# H3 881f993111fffff: 10 colonnine, 5554.3 kWh coperti su 6985.5 kWh (Domanda agg: 6985.5 kWh)
# H3 881f993115fffff: 3 colonnine, 1666.3 kWh coperti su 1947.4 kWh (Domanda agg: 1947.4 kWh)
# H3 881f993ad9fffff: 10 colonnine, 5554.3 kWh coperti su 6627.9 kWh (Domanda agg: 6627.9 kWh)
# H3 881f9931e7fffff: 3 colonnine, 1666.3 kWh coperti su 1850.8 kWh (Domanda agg: 1850.8 kWh)
# H3 881f9931e5fffff: 3 colonnine, 1666.3 kWh coperti su 1850.8 kWh (Domanda agg: 1850.8 kWh)
# H3 881f993155fffff: 10 colonnine, 5554.3 kWh coperti su 9494.9 kWh (Domanda agg: 9494.9 kWh)
# H3 881f99313dfffff: 9 colonnine, 4998.9 kWh coperti su 5072.7 kWh (Domanda agg: 5072.7 kWh)
# H3 881f993151fffff: 9 colonnine, 4998.9 kWh coperti su 5511.9 kWh (Domanda agg: 5511.9 kWh)
# H3 881f993a6bfffff: 10 colonnine, 5554.3 kWh coperti su 7529.7 kWh (Domanda agg: 7529.7 kWh)
# H3 881f990493fffff: 3 colonnine, 1666.3 kWh coperti su 2037.7 kWh (Domanda agg: 2037.7 kWh)
# H3 881f993a09fffff: 10 colonnine, 5554.3 kWh coperti su 5792.8 kWh (Domanda agg: 5792.8 kWh)
# H3 881f993a4bfffff: 10 colonnine, 5554.3 kWh coperti su 9150.4 kWh (Domanda agg: 9150.4 kWh)
# H3 881f993a5dfffff: 10 colonnine, 5554.3 kWh coperti su 8575.0 kWh (Domanda agg: 8575.0 kWh)
# H3 881f9904a5fffff: 3 colonnine, 1666.3 kWh coperti su 2037.7 kWh (Domanda agg: 2037.7 kWh)
# H3 881f993a57fffff: 8 colonnine, 4443.4 kWh coperti su 4514.9 kWh (Domanda agg: 4514.9 kWh)
# H3 881f993a51fffff: 10 colonnine, 5554.3 kWh coperti su 9293.8 kWh (Domanda agg: 9293.8 kWh)
# H3 881f9904e3fffff: 10 colonnine, 5554.3 kWh coperti su 5784.0 kWh (Domanda agg: 5784.0 kWh)
# H3 881f9904b7fffff: 10 colonnine, 5554.3 kWh coperti su 11664.2 kWh (Domanda agg: 11664.2 kWh)
# H3 881f993a53fffff: 10 colonnine, 5554.3 kWh coperti su 6341.0 kWh (Domanda agg: 6341.0 kWh)
# H3 881f9904b5fffff: 10 colonnine, 5554.3 kWh coperti su 6435.2 kWh (Domanda agg: 6435.2 kWh)
# H3 881f993167fffff: 3 colonnine, 1666.3 kWh coperti su 2037.7 kWh (Domanda agg: 2037.7 kWh)
# H3 881f993a01fffff: 10 colonnine, 5554.3 kWh coperti su 8303.8 kWh (Domanda agg: 8303.8 kWh)
# H3 881f993a5bfffff: 10 colonnine, 5554.3 kWh coperti su 5605.5 kWh (Domanda agg: 5605.5 kWh)
# H3 881f990495fffff: 10 colonnine, 5554.3 kWh coperti su 6236.9 kWh (Domanda agg: 6236.9 kWh)
# H3 881f993a0bfffff: 10 colonnine, 5554.3 kWh coperti su 5853.4 kWh (Domanda agg: 5853.4 kWh)
# H3 881f993a0dfffff: 10 colonnine, 5554.3 kWh coperti su 6460.5 kWh (Domanda agg: 6460.5 kWh)
# H3 881f993a49fffff: 10 colonnine, 5554.3 kWh coperti su 6671.6 kWh (Domanda agg: 6671.6 kWh)
# H3 881f993a4dfffff: 10 colonnine, 5554.3 kWh coperti su 6157.0 kWh (Domanda agg: 6157.0 kWh)
# H3 881f993a59fffff: 9 colonnine, 4998.9 kWh coperti su 5523.0 kWh (Domanda agg: 5523.0 kWh)
# H3 881f99316dfffff: 10 colonnine, 5554.3 kWh coperti su 7591.5 kWh (Domanda agg: 7591.5 kWh)
# H3 881f990497fffff: 10 colonnine, 5554.3 kWh coperti su 5988.3 kWh (Domanda agg: 5988.3 kWh)
# H3 881f9904bbfffff: 10 colonnine, 5554.3 kWh coperti su 6292.2 kWh (Domanda agg: 6292.2 kWh)
# H3 881f993a69fffff: 10 colonnine, 5554.3 kWh coperti su 5850.5 kWh (Domanda agg: 5850.5 kWh)
# H3 881f9904b1fffff: 10 colonnine, 5554.3 kWh coperti su 5612.6 kWh (Domanda agg: 5612.6 kWh)
# H3 881f9904bdfffff: 10 colonnine, 5554.3 kWh coperti su 7840.9 kWh (Domanda agg: 7840.9 kWh)
# H3 881f9904b3fffff: 10 colonnine, 5554.3 kWh coperti su 10737.5 kWh (Domanda agg: 10737.5 kWh)
# H3 881f9904b9fffff: 10 colonnine, 5554.3 kWh coperti su 7278.7 kWh (Domanda agg: 7278.7 kWh)
# H3 881f993a47fffff: 9 colonnine, 4998.9 kWh coperti su 5127.7 kWh (Domanda agg: 5127.7 kWh)
# H3 881f992e53fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992c09fffff: 10 colonnine, 5554.3 kWh coperti su 6564.0 kWh (Domanda agg: 6564.0 kWh)
# H3 881f992c07fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992c43fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992c47fffff: 5 colonnine, 2777.2 kWh coperti su 3165.1 kWh (Domanda agg: 3165.1 kWh)
# H3 881f992081fffff: 9 colonnine, 4998.9 kWh coperti su 5052.8 kWh (Domanda agg: 5052.8 kWh)
# H3 881f9920b1fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f9920b5fffff: 10 colonnine, 5554.3 kWh coperti su 6647.7 kWh (Domanda agg: 6647.7 kWh)
# H3 881f992e41fffff: 10 colonnine, 5554.3 kWh coperti su 5749.7 kWh (Domanda agg: 5749.7 kWh)
# H3 881f992c4dfffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992c55fffff: 10 colonnine, 5554.3 kWh coperti su 6424.4 kWh (Domanda agg: 6424.4 kWh)
# H3 881f992e4dfffff: 10 colonnine, 5554.3 kWh coperti su 5779.7 kWh (Domanda agg: 5779.7 kWh)
# H3 881f992e27fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992c5dfffff: 6 colonnine, 3332.6 kWh coperti su 3462.0 kWh (Domanda agg: 3462.0 kWh)
# H3 881f992e4bfffff: 10 colonnine, 5554.3 kWh coperti su 7306.0 kWh (Domanda agg: 7306.0 kWh)
# H3 881f992e15fffff: 10 colonnine, 5554.3 kWh coperti su 9231.1 kWh (Domanda agg: 9231.1 kWh)
# H3 881f992e47fffff: 8 colonnine, 4443.4 kWh coperti su 4640.1 kWh (Domanda agg: 4640.1 kWh)
# H3 881f992e29fffff: 10 colonnine, 5554.3 kWh coperti su 7414.9 kWh (Domanda agg: 7414.9 kWh)
# H3 881f992ee1fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992e51fffff: 10 colonnine, 5554.3 kWh coperti su 7310.1 kWh (Domanda agg: 7310.1 kWh)
# H3 881f992561fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f99256dfffff: 2 colonnine, 1110.9 kWh coperti su 4738.9 kWh (Domanda agg: 4738.9 kWh)
# H3 881f992e01fffff: 10 colonnine, 5554.3 kWh coperti su 7537.6 kWh (Domanda agg: 7537.6 kWh)
# H3 881f992e35fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992e03fffff: 10 colonnine, 5554.3 kWh coperti su 11194.6 kWh (Domanda agg: 11194.6 kWh)
# H3 881f992e13fffff: 10 colonnine, 5554.3 kWh coperti su 5910.0 kWh (Domanda agg: 5910.0 kWh)
# H3 881f992e07fffff: 10 colonnine, 5554.3 kWh coperti su 6219.1 kWh (Domanda agg: 6219.1 kWh)
# H3 881f992e0bfffff: 10 colonnine, 5554.3 kWh coperti su 11204.8 kWh (Domanda agg: 11204.8 kWh)
# H3 881f992e5bfffff: 10 colonnine, 5554.3 kWh coperti su 5740.2 kWh (Domanda agg: 5740.2 kWh)
# H3 881f992e63fffff: 10 colonnine, 5554.3 kWh coperti su 7843.3 kWh (Domanda agg: 7843.3 kWh)
# H3 881f992e43fffff: 10 colonnine, 5554.3 kWh coperti su 9944.3 kWh (Domanda agg: 9944.3 kWh)
# H3 881f992c49fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992e19fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992e55fffff: 10 colonnine, 5554.3 kWh coperti su 6395.1 kWh (Domanda agg: 6395.1 kWh)
# H3 881f992e0dfffff: 10 colonnine, 5554.3 kWh coperti su 7925.7 kWh (Domanda agg: 7925.7 kWh)
# H3 881f992567fffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f9920bdfffff: 9 colonnine, 4998.9 kWh coperti su 5485.2 kWh (Domanda agg: 5485.2 kWh)
# H3 881f992c4bfffff: 4 colonnine, 2221.7 kWh coperti su 2243.5 kWh (Domanda agg: 2243.5 kWh)
# H3 881f992e17fffff: 5 colonnine, 2777.2 kWh coperti su 2947.2 kWh (Domanda agg: 2947.2 kWh)
# H3 881ea45ae9fffff: 3 colonnine, 1666.3 kWh coperti su 4078.2 kWh (Domanda agg: 4078.2 kWh)
# H3 881ea45a03fffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881f9924e3fffff: 10 colonnine, 5554.3 kWh coperti su 7665.5 kWh (Domanda agg: 7665.5 kWh)
# H3 881ea45a1dfffff: 10 colonnine, 5554.3 kWh coperti su 6164.5 kWh (Domanda agg: 6164.5 kWh)
# H3 881f9924b9fffff: 6 colonnine, 3332.6 kWh coperti su 3842.5 kWh (Domanda agg: 3842.5 kWh)
# H3 881ea45a59fffff: 8 colonnine, 4443.4 kWh coperti su 4870.8 kWh (Domanda agg: 4870.8 kWh)
# H3 881ea45aedfffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881ea45a11fffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881f992481fffff: 10 colonnine, 5554.3 kWh coperti su 6841.8 kWh (Domanda agg: 6841.8 kWh)
# H3 881ea45a5bfffff: 4 colonnine, 2221.7 kWh coperti su 2483.7 kWh (Domanda agg: 2483.7 kWh)
# H3 881f9924b5fffff: 10 colonnine, 5554.3 kWh coperti su 6595.4 kWh (Domanda agg: 6595.4 kWh)
# H3 881ea45a0bfffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881ea45165fffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881ea45aa1fffff: 2 colonnine, 1110.9 kWh coperti su 1651.0 kWh (Domanda agg: 1651.0 kWh)
# H3 881f9924ddfffff: 5 colonnine, 2777.2 kWh coperti su 3116.1 kWh (Domanda agg: 3116.1 kWh)
# H3 881f992483fffff: 10 colonnine, 5554.3 kWh coperti su 9226.4 kWh (Domanda agg: 9226.4 kWh)
# H3 881f992495fffff: 10 colonnine, 5554.3 kWh coperti su 7323.0 kWh (Domanda agg: 7323.0 kWh)
# H3 881f992489fffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881f9924bdfffff: 10 colonnine, 5554.3 kWh coperti su 8243.0 kWh (Domanda agg: 8243.0 kWh)
# H3 881ea45125fffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881f9924a3fffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881ea4516dfffff: 10 colonnine, 5554.3 kWh coperti su 10461.7 kWh (Domanda agg: 10461.7 kWh)
# H3 881f9924bbfffff: 10 colonnine, 5554.3 kWh coperti su 9078.1 kWh (Domanda agg: 9078.1 kWh)
# H3 881ea45aebfffff: 6 colonnine, 3332.6 kWh coperti su 3798.1 kWh (Domanda agg: 3798.1 kWh)
# H3 881f9924b1fffff: 10 colonnine, 5554.3 kWh coperti su 12081.8 kWh (Domanda agg: 12081.8 kWh)
# H3 881f9924b3fffff: 5 colonnine, 2777.2 kWh coperti su 3273.0 kWh (Domanda agg: 3273.0 kWh)
# H3 881f992485fffff: 10 colonnine, 5554.3 kWh coperti su 6873.1 kWh (Domanda agg: 6873.1 kWh)
# H3 881f992493fffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881ea45a19fffff: 10 colonnine, 5554.3 kWh coperti su 7711.8 kWh (Domanda agg: 7711.8 kWh)
# H3 881ea45a53fffff: 10 colonnine, 5554.3 kWh coperti su 6442.8 kWh (Domanda agg: 6442.8 kWh)
# H3 881ea45a09fffff: 2 colonnine, 1110.9 kWh coperti su 1633.1 kWh (Domanda agg: 1633.1 kWh)
# H3 881f9926b7fffff: 10 colonnine, 5554.3 kWh coperti su 7303.9 kWh (Domanda agg: 7303.9 kWh)
# H3 881ea45a13fffff: 10 colonnine, 5554.3 kWh coperti su 5849.9 kWh (Domanda agg: 5849.9 kWh)
# H3 881f9930b3fffff: 6 colonnine, 3332.6 kWh coperti su 3752.6 kWh (Domanda agg: 3752.6 kWh)
# H3 881f9930d7fffff: 2 colonnine, 1110.9 kWh coperti su 1606.4 kWh (Domanda agg: 1606.4 kWh)
# H3 881f9930b7fffff: 10 colonnine, 5554.3 kWh coperti su 10018.3 kWh (Domanda agg: 10018.3 kWh)
# H3 881f993767fffff: 6 colonnine, 3332.6 kWh coperti su 3783.2 kWh (Domanda agg: 3783.2 kWh)
# H3 881f993091fffff: 10 colonnine, 5554.3 kWh coperti su 5802.5 kWh (Domanda agg: 5802.5 kWh)
# H3 881f99309bfffff: 9 colonnine, 4998.9 kWh coperti su 5014.7 kWh (Domanda agg: 5014.7 kWh)
# H3 881f993097fffff: 7 colonnine, 3888.0 kWh coperti su 4103.1 kWh (Domanda agg: 4103.1 kWh)
# H3 881f9930bbfffff: 2 colonnine, 1110.9 kWh coperti su 1606.4 kWh (Domanda agg: 1606.4 kWh)
# H3 881f9930b9fffff: 2 colonnine, 1110.9 kWh coperti su 1606.4 kWh (Domanda agg: 1606.4 kWh)
# H3 881f99370dfffff: 2 colonnine, 1110.9 kWh coperti su 1606.4 kWh (Domanda agg: 1606.4 kWh)
# H3 881f9930d3fffff: 8 colonnine, 4443.4 kWh coperti su 4714.2 kWh (Domanda agg: 4714.2 kWh)
# H3 881f993761fffff: 10 colonnine, 5554.3 kWh coperti su 7022.5 kWh (Domanda agg: 7022.5 kWh)
# H3 881f99372dfffff: 10 colonnine, 5554.3 kWh coperti su 7552.0 kWh (Domanda agg: 7552.0 kWh)
# H3 881f993727fffff: 2 colonnine, 1110.9 kWh coperti su 1606.4 kWh (Domanda agg: 1606.4 kWh)
# H3 881f993769fffff: 10 colonnine, 5554.3 kWh coperti su 5831.3 kWh (Domanda agg: 5831.3 kWh)
# H3 881f992259fffff: 10 colonnine, 5554.3 kWh coperti su 8043.8 kWh (Domanda agg: 8043.8 kWh)
# H3 881f99356dfffff: 6 colonnine, 3332.6 kWh coperti su 3436.4 kWh (Domanda agg: 3436.4 kWh)
# H3 881f99373bfffff: 10 colonnine, 5554.3 kWh coperti su 8207.7 kWh (Domanda agg: 8207.7 kWh)
# H3 881f99346dfffff: 10 colonnine, 5554.3 kWh coperti su 5596.5 kWh (Domanda agg: 5596.5 kWh)
# H3 881f99373dfffff: 10 colonnine, 5554.3 kWh coperti su 5822.3 kWh (Domanda agg: 5822.3 kWh)
# H3 881f993703fffff: 10 colonnine, 5554.3 kWh coperti su 6146.1 kWh (Domanda agg: 6146.1 kWh)
# H3 881f993465fffff: 10 colonnine, 5554.3 kWh coperti su 6060.8 kWh (Domanda agg: 6060.8 kWh)
# H3 881f993739fffff: 10 colonnine, 5554.3 kWh coperti su 5590.4 kWh (Domanda agg: 5590.4 kWh)
# H3 881f993461fffff: 2 colonnine, 1110.9 kWh coperti su 1409.9 kWh (Domanda agg: 1409.9 kWh)
# H3 881f99a62dfffff: 2 colonnine, 1110.9 kWh coperti su 1398.6 kWh (Domanda agg: 1398.6 kWh)
# H3 881f99a461fffff: 2 colonnine, 1110.9 kWh coperti su 1398.6 kWh (Domanda agg: 1398.6 kWh)
# H3 881f99a707fffff: 10 colonnine, 5554.3 kWh coperti su 5616.1 kWh (Domanda agg: 5616.1 kWh)
# H3 881f99a625fffff: 10 colonnine, 5554.3 kWh coperti su 5755.6 kWh (Domanda agg: 5755.6 kWh)
# H3 881f99a715fffff: 10 colonnine, 5554.3 kWh coperti su 6740.5 kWh (Domanda agg: 6740.5 kWh)
# H3 881f99a713fffff: 5 colonnine, 2777.2 kWh coperti su 3055.4 kWh (Domanda agg: 3055.4 kWh)
# H3 881f99a759fffff: 2 colonnine, 1110.9 kWh coperti su 1398.6 kWh (Domanda agg: 1398.6 kWh)
# H3 881f99a711fffff: 10 colonnine, 5554.3 kWh coperti su 8082.0 kWh (Domanda agg: 8082.0 kWh)
# H3 881f99a605fffff: 2 colonnine, 1110.9 kWh coperti su 1398.6 kWh (Domanda agg: 1398.6 kWh)
# H3 881f99a719fffff: 10 colonnine, 5554.3 kWh coperti su 8438.5 kWh (Domanda agg: 8438.5 kWh)
# H3 881f99a739fffff: 10 colonnine, 5554.3 kWh coperti su 7486.4 kWh (Domanda agg: 7486.4 kWh)
# H3 881f99a71bfffff: 10 colonnine, 5554.3 kWh coperti su 6249.6 kWh (Domanda agg: 6249.6 kWh)
# H3 881f99a71dfffff: 8 colonnine, 4443.4 kWh coperti su 4855.4 kWh (Domanda agg: 4855.4 kWh)
# H3 881f99a445fffff: 2 colonnine, 1110.9 kWh coperti su 1398.6 kWh (Domanda agg: 1398.6 kWh)
# H3 881f99a703fffff: 7 colonnine, 3888.0 kWh coperti su 4246.2 kWh (Domanda agg: 4246.2 kWh)
# H3 881f99a661fffff: 2 colonnine, 1110.9 kWh coperti su 1398.6 kWh (Domanda agg: 1398.6 kWh)
# H3 881f99a405fffff: 2 colonnine, 1110.9 kWh coperti su 1398.6 kWh (Domanda agg: 1398.6 kWh)
# H3 881f99a751fffff: 2 colonnine, 1110.9 kWh coperti su 1398.6 kWh (Domanda agg: 1398.6 kWh)
# H3 881f99319dfffff: 2 colonnine, 1110.9 kWh coperti su 1541.7 kWh (Domanda agg: 1541.7 kWh)
# H3 881f993199fffff: 2 colonnine, 1110.9 kWh coperti su 1541.7 kWh (Domanda agg: 1541.7 kWh)
# H3 881f9931d3fffff: 10 colonnine, 5554.3 kWh coperti su 6532.2 kWh (Domanda agg: 6532.2 kWh)
# H3 881f9931d1fffff: 8 colonnine, 4443.4 kWh coperti su 4811.2 kWh (Domanda agg: 4811.2 kWh)
# H3 881f9931dbfffff: 2 colonnine, 1110.9 kWh coperti su 1541.7 kWh (Domanda agg: 1541.7 kWh)
# H3 881f992f37fffff: 4 colonnine, 2221.7 kWh coperti su 2745.7 kWh (Domanda agg: 2745.7 kWh)
# H3 881f9921b1fffff: 6 colonnine, 3332.6 kWh coperti su 3831.6 kWh (Domanda agg: 3831.6 kWh)
# H3 881f992f35fffff: 10 colonnine, 5554.3 kWh coperti su 6008.1 kWh (Domanda agg: 6008.1 kWh)
# H3 881f992f5bfffff: 10 colonnine, 5554.3 kWh coperti su 6099.3 kWh (Domanda agg: 6099.3 kWh)
# H3 881f992f09fffff: 10 colonnine, 5554.3 kWh coperti su 7889.9 kWh (Domanda agg: 7889.9 kWh)
# H3 881f992d51fffff: 7 colonnine, 3888.0 kWh coperti su 3934.5 kWh (Domanda agg: 3934.5 kWh)
# H3 881f992f1bfffff: 3 colonnine, 1666.3 kWh coperti su 1805.1 kWh (Domanda agg: 1805.1 kWh)
# H3 881f992f63fffff: 3 colonnine, 1666.3 kWh coperti su 1805.1 kWh (Domanda agg: 1805.1 kWh)
# H3 881f992e65fffff: 5 colonnine, 2777.2 kWh coperti su 3126.2 kWh (Domanda agg: 3126.2 kWh)
# H3 881f992f29fffff: 3 colonnine, 1666.3 kWh coperti su 1805.1 kWh (Domanda agg: 1805.1 kWh)
# H3 881f992f0bfffff: 10 colonnine, 5554.3 kWh coperti su 7185.5 kWh (Domanda agg: 7185.5 kWh)
# H3 881f992c6bfffff: 7 colonnine, 3888.0 kWh coperti su 4154.1 kWh (Domanda agg: 4154.1 kWh)
# H3 881f992f21fffff: 7 colonnine, 3888.0 kWh coperti su 3966.5 kWh (Domanda agg: 3966.5 kWh)
# H3 881f992c67fffff: 3 colonnine, 1666.3 kWh coperti su 1805.1 kWh (Domanda agg: 1805.1 kWh)
# H3 881f992f19fffff: 3 colonnine, 1666.3 kWh coperti su 1805.1 kWh (Domanda agg: 1805.1 kWh)
# H3 881f992f03fffff: 10 colonnine, 5554.3 kWh coperti su 7744.5 kWh (Domanda agg: 7744.5 kWh)
# H3 881f992f55fffff: 10 colonnine, 5554.3 kWh coperti su 5671.6 kWh (Domanda agg: 5671.6 kWh)
# H3 881f992f39fffff: 10 colonnine, 5554.3 kWh coperti su 6130.4 kWh (Domanda agg: 6130.4 kWh)
# H3 881f992197fffff: 3 colonnine, 1666.3 kWh coperti su 1805.1 kWh (Domanda agg: 1805.1 kWh)
# H3 881f992f51fffff: 10 colonnine, 5554.3 kWh coperti su 6644.3 kWh (Domanda agg: 6644.3 kWh)
# H3 881f992f07fffff: 3 colonnine, 1666.3 kWh coperti su 1805.1 kWh (Domanda agg: 1805.1 kWh)
# H3 881f992d59fffff: 10 colonnine, 5554.3 kWh coperti su 7192.0 kWh (Domanda agg: 7192.0 kWh)
# H3 881f992f43fffff: 10 colonnine, 5554.3 kWh coperti su 5761.3 kWh (Domanda agg: 5761.3 kWh)
# H3 881f992f45fffff: 8 colonnine, 4443.4 kWh coperti su 4877.3 kWh (Domanda agg: 4877.3 kWh)
# H3 881f992f3dfffff: 5 colonnine, 2777.2 kWh coperti su 3077.5 kWh (Domanda agg: 3077.5 kWh)
# H3 881f992f5dfffff: 10 colonnine, 5554.3 kWh coperti su 6113.7 kWh (Domanda agg: 6113.7 kWh)
# H3 881f992e61fffff: 6 colonnine, 3332.6 kWh coperti su 3820.4 kWh (Domanda agg: 3820.4 kWh)
# H3 881f992d5bfffff: 9 colonnine, 4998.9 kWh coperti su 5118.9 kWh (Domanda agg: 5118.9 kWh)
# H3 881f992c6dfffff: 3 colonnine, 1666.3 kWh coperti su 1805.1 kWh (Domanda agg: 1805.1 kWh)
# H3 881f99234bfffff: 2 colonnine, 1110.9 kWh coperti su 1523.1 kWh (Domanda agg: 1523.1 kWh)
# H3 881f99226dfffff: 7 colonnine, 3888.0 kWh coperti su 4133.3 kWh (Domanda agg: 4133.3 kWh)
# H3 881f99319bfffff: 3 colonnine, 1666.3 kWh coperti su 2011.6 kWh (Domanda agg: 2011.6 kWh)
# H3 881f993191fffff: 2 colonnine, 1110.9 kWh coperti su 1523.1 kWh (Domanda agg: 1523.1 kWh)
# H3 881f99235dfffff: 9 colonnine, 4998.9 kWh coperti su 5056.9 kWh (Domanda agg: 5056.9 kWh)
# H3 881f992719fffff: 10 colonnine, 5554.3 kWh coperti su 5783.3 kWh (Domanda agg: 5783.3 kWh)
# H3 881f992703fffff: 9 colonnine, 4998.9 kWh coperti su 5127.6 kWh (Domanda agg: 5127.6 kWh)
# H3 881f992709fffff: 9 colonnine, 4998.9 kWh coperti su 5000.1 kWh (Domanda agg: 5000.1 kWh)
# H3 881f992711fffff: 10 colonnine, 5554.3 kWh coperti su 5573.3 kWh (Domanda agg: 5573.3 kWh)
# H3 881f992753fffff: 3 colonnine, 1666.3 kWh coperti su 1908.5 kWh (Domanda agg: 1908.5 kWh)
# H3 881f992763fffff: 2 colonnine, 1110.9 kWh coperti su 1420.9 kWh (Domanda agg: 1420.9 kWh)
# H3 881f99275bfffff: 2 colonnine, 1110.9 kWh coperti su 1420.9 kWh (Domanda agg: 1420.9 kWh)
# ...
# H3 881ea69769fffff: 3 colonnine, 1666.3 kWh coperti su 1802.4 kWh (Domanda agg: 1802.4 kWh)
# H3 881ea69745fffff: 2 colonnine, 1110.9 kWh coperti su 1305.2 kWh (Domanda agg: 1305.2 kWh)
# H3 881f992da9fffff: 1 colonnine, 555.4 kWh coperti su 585.8 kWh (Domanda agg: 585.8 kWh)
# H3 881f992da5fffff: 2 colonnine, 1110.9 kWh coperti su 1348.8 kWh (Domanda agg: 1348.8 kWh)
# H3 881ea692d7fffff: 1 colonnine, 555.4 kWh coperti su 585.8 kWh (Domanda agg: 585.8 kWh)
# H3 881f992db5fffff: 2 colonnine, 1110.9 kWh coperti su 1330.2 kWh (Domanda agg: 1330.2 kWh)
# H3 881ea6929dfffff: 2 colonnine, 1110.9 kWh coperti su 1558.4 kWh (Domanda agg: 1558.4 kWh)
# H3 881f992db3fffff: 3 colonnine, 1666.3 kWh coperti su 1856.1 kWh (Domanda agg: 1856.1 kWh)
# H3 881ea69295fffff: 1 colonnine, 555.4 kWh coperti su 875.5 kWh (Domanda agg: 875.5 kWh)
# H3 881ea69741fffff: 3 colonnine, 1666.3 kWh coperti su 1968.7 kWh (Domanda agg: 1968.7 kWh)
# H3 881ea69765fffff: 1 colonnine, 555.4 kWh coperti su 585.8 kWh (Domanda agg: 585.8 kWh)
# H3 881f99350bfffff: 3 colonnine, 1666.3 kWh coperti su 1803.1 kWh (Domanda agg: 1803.1 kWh)
# H3 881f992a05fffff: 2 colonnine, 1110.9 kWh coperti su 1413.3 kWh (Domanda agg: 1413.3 kWh)
# H3 881f992a07fffff: 2 colonnine, 1110.9 kWh coperti su 1469.4 kWh (Domanda agg: 1469.4 kWh)
# H3 881f993997fffff: 1 colonnine, 555.4 kWh coperti su 649.2 kWh (Domanda agg: 649.2 kWh)
# H3 881f992a03fffff: 4 colonnine, 2221.7 kWh coperti su 2431.7 kWh (Domanda agg: 2431.7 kWh)
# H3 881f992a29fffff: 3 colonnine, 1666.3 kWh coperti su 1738.4 kWh (Domanda agg: 1738.4 kWh)
# H3 881f9939b3fffff: 2 colonnine, 1110.9 kWh coperti su 1543.6 kWh (Domanda agg: 1543.6 kWh)
# H3 881f992a0dfffff: 2 colonnine, 1110.9 kWh coperti su 1379.2 kWh (Domanda agg: 1379.2 kWh)
# H3 881f8a7a93fffff: 1 colonnine, 555.4 kWh coperti su 1110.0 kWh (Domanda agg: 1110.0 kWh)
# H3 881f8a71b5fffff: 1 colonnine, 555.4 kWh coperti su 638.9 kWh (Domanda agg: 638.9 kWh)
# H3 881f8a634dfffff: 2 colonnine, 1110.9 kWh coperti su 1476.2 kWh (Domanda agg: 1476.2 kWh)
# H3 881f8a71b1fffff: 1 colonnine, 555.4 kWh coperti su 828.7 kWh (Domanda agg: 828.7 kWh)
# H3 881f99ac87fffff: 1 colonnine, 555.4 kWh coperti su 705.5 kWh (Domanda agg: 705.5 kWh)
# H3 881f99acabfffff: 1 colonnine, 555.4 kWh coperti su 920.1 kWh (Domanda agg: 920.1 kWh)
# H3 881ea4d8a1fffff: 2 colonnine, 1110.9 kWh coperti su 1166.5 kWh (Domanda agg: 1166.5 kWh)
# H3 881ea4d989fffff: 3 colonnine, 1666.3 kWh coperti su 1691.2 kWh (Domanda agg: 1691.2 kWh)
# H3 881ea4d9d5fffff: 2 colonnine, 1110.9 kWh coperti su 1320.0 kWh (Domanda agg: 1320.0 kWh)
# H3 881ea4d9d7fffff: 1 colonnine, 555.4 kWh coperti su 1096.2 kWh (Domanda agg: 1096.2 kWh)
# H3 881ea4d9d1fffff: 1 colonnine, 555.4 kWh coperti su 677.1 kWh (Domanda agg: 677.1 kWh)
# H3 881ea4d8adfffff: 1 colonnine, 555.4 kWh coperti su 1010.4 kWh (Domanda agg: 1010.4 kWh)
# H3 881f993859fffff: 2 colonnine, 1110.9 kWh coperti su 1338.7 kWh (Domanda agg: 1338.7 kWh)
# H3 881f993a31fffff: 1 colonnine, 555.4 kWh coperti su 886.2 kWh (Domanda agg: 886.2 kWh)
# H3 881f992ae9fffff: 1 colonnine, 555.4 kWh coperti su 1048.6 kWh (Domanda agg: 1048.6 kWh)
# H3 881f992ae1fffff: 2 colonnine, 1110.9 kWh coperti su 1272.4 kWh (Domanda agg: 1272.4 kWh)
# H3 881f992ae7fffff: 1 colonnine, 555.4 kWh coperti su 1013.7 kWh (Domanda agg: 1013.7 kWh)
# H3 881f992a17fffff: 2 colonnine, 1110.9 kWh coperti su 1250.0 kWh (Domanda agg: 1250.0 kWh)
# H3 881f992ac1fffff: 2 colonnine, 1110.9 kWh coperti su 1210.1 kWh (Domanda agg: 1210.1 kWh)
# H3 881f992a1dfffff: 1 colonnine, 555.4 kWh coperti su 962.4 kWh (Domanda agg: 962.4 kWh)
# H3 881f992d95fffff: 2 colonnine, 1110.9 kWh coperti su 1596.5 kWh (Domanda agg: 1596.5 kWh)
# H3 881f992dddfffff: 2 colonnine, 1110.9 kWh coperti su 1133.8 kWh (Domanda agg: 1133.8 kWh)
# H3 881f992d9dfffff: 1 colonnine, 555.4 kWh coperti su 1020.2 kWh (Domanda agg: 1020.2 kWh)
# H3 881ea4cb55fffff: 1 colonnine, 555.4 kWh coperti su 961.7 kWh (Domanda agg: 961.7 kWh)
# H3 881ea4cb59fffff: 3 colonnine, 1666.3 kWh coperti su 1685.8 kWh (Domanda agg: 1685.8 kWh)
# H3 881ea4cb5bfffff: 1 colonnine, 555.4 kWh coperti su 759.2 kWh (Domanda agg: 759.2 kWh)
# H3 881ea4cb1bfffff: 3 colonnine, 1666.3 kWh coperti su 1823.7 kWh (Domanda agg: 1823.7 kWh)
# H3 881f992615fffff: 1 colonnine, 555.4 kWh coperti su 715.7 kWh (Domanda agg: 715.7 kWh)
# H3 881f992611fffff: 2 colonnine, 1110.9 kWh coperti su 1280.0 kWh (Domanda agg: 1280.0 kWh)
# H3 881f992657fffff: 3 colonnine, 1666.3 kWh coperti su 1733.6 kWh (Domanda agg: 1733.6 kWh)
# H3 881f992619fffff: 2 colonnine, 1110.9 kWh coperti su 1285.8 kWh (Domanda agg: 1285.8 kWh)
# H3 881f99263bfffff: 2 colonnine, 1110.9 kWh coperti su 1135.7 kWh (Domanda agg: 1135.7 kWh)
# H3 881f992913fffff: 2 colonnine, 1110.9 kWh coperti su 1272.2 kWh (Domanda agg: 1272.2 kWh)
# H3 881f992869fffff: 2 colonnine, 1110.9 kWh coperti su 1149.3 kWh (Domanda agg: 1149.3 kWh)
# H3 881ea4d339fffff: 1 colonnine, 555.4 kWh coperti su 812.5 kWh (Domanda agg: 812.5 kWh)
# H3 881ea4d149fffff: 1 colonnine, 555.4 kWh coperti su 555.5 kWh (Domanda agg: 555.5 kWh)
# H3 881ea4d311fffff: 1 colonnine, 555.4 kWh coperti su 958.2 kWh (Domanda agg: 958.2 kWh)
# H3 881ea4d343fffff: 1 colonnine, 555.4 kWh coperti su 874.4 kWh (Domanda agg: 874.4 kWh)
# H3 881ea4d335fffff: 2 colonnine, 1110.9 kWh coperti su 1126.1 kWh (Domanda agg: 1126.1 kWh)
# H3 881f99a6d1fffff: 2 colonnine, 1110.9 kWh coperti su 1188.5 kWh (Domanda agg: 1188.5 kWh)
# H3 881ea4d1bbfffff: 1 colonnine, 555.4 kWh coperti su 787.9 kWh (Domanda agg: 787.9 kWh)
# H3 881ea4d1b3fffff: 1 colonnine, 555.4 kWh coperti su 742.8 kWh (Domanda agg: 742.8 kWh)
# H3 881ea4d133fffff: 1 colonnine, 555.4 kWh coperti su 993.2 kWh (Domanda agg: 993.2 kWh)
# H3 881ea4d1edfffff: 2 colonnine, 1110.9 kWh coperti su 1293.3 kWh (Domanda agg: 1293.3 kWh)
# H3 881ea4d1cdfffff: 1 colonnine, 555.4 kWh coperti su 599.1 kWh (Domanda agg: 599.1 kWh)
# H3 881ea4d055fffff: 1 colonnine, 555.4 kWh coperti su 741.8 kWh (Domanda agg: 741.8 kWh)
# H3 881ea4d1a9fffff: 2 colonnine, 1110.9 kWh coperti su 1503.7 kWh (Domanda agg: 1503.7 kWh)
# H3 881ea4d1e1fffff: 2 colonnine, 1110.9 kWh coperti su 1607.8 kWh (Domanda agg: 1607.8 kWh)
# H3 881f99234dfffff: 2 colonnine, 1110.9 kWh coperti su 1225.3 kWh (Domanda agg: 1225.3 kWh)
# H3 881f99236bfffff: 2 colonnine, 1110.9 kWh coperti su 1189.5 kWh (Domanda agg: 1189.5 kWh)
# H3 881f9931a7fffff: 1 colonnine, 555.4 kWh coperti su 999.2 kWh (Domanda agg: 999.2 kWh)
# H3 881f992347fffff: 2 colonnine, 1110.9 kWh coperti su 1117.7 kWh (Domanda agg: 1117.7 kWh)
# H3 881f992343fffff: 2 colonnine, 1110.9 kWh coperti su 1175.0 kWh (Domanda agg: 1175.0 kWh)
# H3 881f99059bfffff: 1 colonnine, 555.4 kWh coperti su 1051.8 kWh (Domanda agg: 1051.8 kWh)
# H3 881f99059dfffff: 1 colonnine, 555.4 kWh coperti su 720.9 kWh (Domanda agg: 720.9 kWh)
# H3 881f990597fffff: 3 colonnine, 1666.3 kWh coperti su 2038.8 kWh (Domanda agg: 2038.8 kWh)
# H3 881f990591fffff: 2 colonnine, 1110.9 kWh coperti su 1665.0 kWh (Domanda agg: 1665.0 kWh)
# H3 881f9938e1fffff: 3 colonnine, 1666.3 kWh coperti su 1947.2 kWh (Domanda agg: 1947.2 kWh)
# H3 881f9938e7fffff: 1 colonnine, 555.4 kWh coperti su 565.1 kWh (Domanda agg: 565.1 kWh)
# H3 881f9938a5fffff: 1 colonnine, 555.4 kWh coperti su 997.0 kWh (Domanda agg: 997.0 kWh)
# H3 881f9939d3fffff: 2 colonnine, 1110.9 kWh coperti su 1229.9 kWh (Domanda agg: 1229.9 kWh)
# H3 881f993991fffff: 2 colonnine, 1110.9 kWh coperti su 1143.2 kWh (Domanda agg: 1143.2 kWh)
# H3 881f99399bfffff: 1 colonnine, 555.4 kWh coperti su 1098.5 kWh (Domanda agg: 1098.5 kWh)
# H3 881f992683fffff: 1 colonnine, 555.4 kWh coperti su 810.2 kWh (Domanda agg: 810.2 kWh)
# H3 881f9926c3fffff: 2 colonnine, 1110.9 kWh coperti su 1362.3 kWh (Domanda agg: 1362.3 kWh)
# H3 881f9930c5fffff: 5 colonnine, 2777.2 kWh coperti su 2961.9 kWh (Domanda agg: 2961.9 kWh)
# H3 881f993013fffff: 1 colonnine, 555.4 kWh coperti su 985.3 kWh (Domanda agg: 985.3 kWh)
# H3 881ea45a9bfffff: 1 colonnine, 555.4 kWh coperti su 869.9 kWh (Domanda agg: 869.9 kWh)
# H3 881ea44345fffff: 2 colonnine, 1110.9 kWh coperti su 1308.9 kWh (Domanda agg: 1308.9 kWh)
# H3 881ea4430dfffff: 2 colonnine, 1110.9 kWh coperti su 1182.8 kWh (Domanda agg: 1182.8 kWh)
# H3 881ea44341fffff: 1 colonnine, 555.4 kWh coperti su 1072.6 kWh (Domanda agg: 1072.6 kWh)
# H3 881ea44347fffff: 1 colonnine, 555.4 kWh coperti su 913.2 kWh (Domanda agg: 913.2 kWh)
# H3 881ea4436bfffff: 1 colonnine, 555.4 kWh coperti su 894.1 kWh (Domanda agg: 894.1 kWh)
# H3 881f99a5c9fffff: 1 colonnine, 555.4 kWh coperti su 828.5 kWh (Domanda agg: 828.5 kWh)
# H3 881f99a51bfffff: 3 colonnine, 1666.3 kWh coperti su 1707.3 kWh (Domanda agg: 1707.3 kWh)
# H3 881f992323fffff: 1 colonnine, 555.4 kWh coperti su 872.8 kWh (Domanda agg: 872.8 kWh)
# H3 881f992335fffff: 1 colonnine, 555.4 kWh coperti su 660.6 kWh (Domanda agg: 660.6 kWh)
# H3 881f992321fffff: 1 colonnine, 555.4 kWh coperti su 957.8 kWh (Domanda agg: 957.8 kWh)
# H3 881f992143fffff: 1 colonnine, 555.4 kWh coperti su 809.9 kWh (Domanda agg: 809.9 kWh)
# H3 881ea4c8a1fffff: 2 colonnine, 1110.9 kWh coperti su 1424.3 kWh (Domanda agg: 1424.3 kWh)
# H3 881ea4c99dfffff: 2 colonnine, 1110.9 kWh coperti su 1134.8 kWh (Domanda agg: 1134.8 kWh)
# H3 881ea4c983fffff: 2 colonnine, 1110.9 kWh coperti su 1266.9 kWh (Domanda agg: 1266.9 kWh)
# H3 881ea4c987fffff: 2 colonnine, 1110.9 kWh coperti su 1307.7 kWh (Domanda agg: 1307.7 kWh)
# H3 881ea4c9ebfffff: 1 colonnine, 555.4 kWh coperti su 794.8 kWh (Domanda agg: 794.8 kWh)
# H3 881ea69621fffff: 2 colonnine, 1110.9 kWh coperti su 1203.7 kWh (Domanda agg: 1203.7 kWh)
# H3 881ea6971bfffff: 1 colonnine, 555.4 kWh coperti su 728.2 kWh (Domanda agg: 728.2 kWh)
# H3 881ea69647fffff: 1 colonnine, 555.4 kWh coperti su 790.4 kWh (Domanda agg: 790.4 kWh)
# H3 881ea69629fffff: 1 colonnine, 555.4 kWh coperti su 754.6 kWh (Domanda agg: 754.6 kWh)
# H3 881ea69661fffff: 1 colonnine, 555.4 kWh coperti su 1102.3 kWh (Domanda agg: 1102.3 kWh)
# H3 881ea69663fffff: 2 colonnine, 1110.9 kWh coperti su 1231.9 kWh (Domanda agg: 1231.9 kWh)
# H3 881f99ac21fffff: 1 colonnine, 555.4 kWh coperti su 690.9 kWh (Domanda agg: 690.9 kWh)
# H3 881f99ac67fffff: 1 colonnine, 555.4 kWh coperti su 786.3 kWh (Domanda agg: 786.3 kWh)
# H3 881f99ad19fffff: 1 colonnine, 555.4 kWh coperti su 776.1 kWh (Domanda agg: 776.1 kWh)
# H3 881f99ac25fffff: 1 colonnine, 555.4 kWh coperti su 773.1 kWh (Domanda agg: 773.1 kWh)
# H3 881f9932bdfffff: 1 colonnine, 555.4 kWh coperti su 888.3 kWh (Domanda agg: 888.3 kWh)
# H3 881f9932d7fffff: 1 colonnine, 555.4 kWh coperti su 715.4 kWh (Domanda agg: 715.4 kWh)
# H3 881f99ac69fffff: 1 colonnine, 555.4 kWh coperti su 938.3 kWh (Domanda agg: 938.3 kWh)
# H3 881f9934b5fffff: 1 colonnine, 555.4 kWh coperti su 696.1 kWh (Domanda agg: 696.1 kWh)
# H3 881f9934a3fffff: 1 colonnine, 555.4 kWh coperti su 713.5 kWh (Domanda agg: 713.5 kWh)
# H3 881f9934b7fffff: 2 colonnine, 1110.9 kWh coperti su 1492.0 kWh (Domanda agg: 1492.0 kWh)
# H3 881f992d21fffff: 1 colonnine, 555.4 kWh coperti su 779.0 kWh (Domanda agg: 779.0 kWh)
# H3 881f992d35fffff: 1 colonnine, 555.4 kWh coperti su 670.0 kWh (Domanda agg: 670.0 kWh)
# H3 881ea45349fffff: 1 colonnine, 555.4 kWh coperti su 868.5 kWh (Domanda agg: 868.5 kWh)
# H3 881ea4c9e7fffff: 1 colonnine, 555.4 kWh coperti su 905.3 kWh (Domanda agg: 905.3 kWh)
# H3 881ea4cf51fffff: 1 colonnine, 555.4 kWh coperti su 706.8 kWh (Domanda agg: 706.8 kWh)
# H3 881ea4ce0dfffff: 1 colonnine, 555.4 kWh coperti su 651.0 kWh (Domanda agg: 651.0 kWh)
# H3 881ea4c1b3fffff: 2 colonnine, 1110.9 kWh coperti su 1401.6 kWh (Domanda agg: 1401.6 kWh)
# H3 881ea4c197fffff: 1 colonnine, 555.4 kWh coperti su 751.7 kWh (Domanda agg: 751.7 kWh)
# H3 881ea4c1b9fffff: 1 colonnine, 555.4 kWh coperti su 634.8 kWh (Domanda agg: 634.8 kWh)
# H3 881ea4ce29fffff: 1 colonnine, 555.4 kWh coperti su 595.2 kWh (Domanda agg: 595.2 kWh)
# H3 881f992885fffff: 1 colonnine, 555.4 kWh coperti su 660.3 kWh (Domanda agg: 660.3 kWh)
# H3 881f992d29fffff: 1 colonnine, 555.4 kWh coperti su 717.6 kWh (Domanda agg: 717.6 kWh)
# H3 881f992d41fffff: 1 colonnine, 555.4 kWh coperti su 731.2 kWh (Domanda agg: 731.2 kWh)
# H3 881f8a693dfffff: 2 colonnine, 1110.9 kWh coperti su 1119.1 kWh (Domanda agg: 1119.1 kWh)
# H3 881ea4c889fffff: 1 colonnine, 555.4 kWh coperti su 1088.7 kWh (Domanda agg: 1088.7 kWh)
# H3 881ea4c8c1fffff: 2 colonnine, 1110.9 kWh coperti su 1655.1 kWh (Domanda agg: 1655.1 kWh)
# H3 881ea45357fffff: 1 colonnine, 555.4 kWh coperti su 612.1 kWh (Domanda agg: 612.1 kWh)
# H3 881f9932d9fffff: 1 colonnine, 555.4 kWh coperti su 558.9 kWh (Domanda agg: 558.9 kWh)
# H3 881f99a6c1fffff: 1 colonnine, 555.4 kWh coperti su 733.1 kWh (Domanda agg: 733.1 kWh)
# H3 881f9939cbfffff: 1 colonnine, 555.4 kWh coperti su 754.6 kWh (Domanda agg: 754.6 kWh)
# H3 881f99398bfffff: 2 colonnine, 1110.9 kWh coperti su 1382.5 kWh (Domanda agg: 1382.5 kWh)
# H3 881f9928ebfffff: 1 colonnine, 555.4 kWh coperti su 877.1 kWh (Domanda agg: 877.1 kWh)
# H3 881f9928c7fffff: 1 colonnine, 555.4 kWh coperti su 726.1 kWh (Domanda agg: 726.1 kWh)
# H3 881f9928c1fffff: 1 colonnine, 555.4 kWh coperti su 590.2 kWh (Domanda agg: 590.2 kWh)
# H3 881f9928c3fffff: 1 colonnine, 555.4 kWh coperti su 608.7 kWh (Domanda agg: 608.7 kWh)
# H3 881ea69269fffff: 1 colonnine, 555.4 kWh coperti su 748.8 kWh (Domanda agg: 748.8 kWh)
# H3 881f992a51fffff: 1 colonnine, 555.4 kWh coperti su 761.4 kWh (Domanda agg: 761.4 kWh)
# H3 881f992a57fffff: 1 colonnine, 555.4 kWh coperti su 586.5 kWh (Domanda agg: 586.5 kWh)
# H3 881f8a6859fffff: 2 colonnine, 1110.9 kWh coperti su 1323.4 kWh (Domanda agg: 1323.4 kWh)
# H3 881f99a70dfffff: 1 colonnine, 555.4 kWh coperti su 814.5 kWh (Domanda agg: 814.5 kWh)
# H3 881f9934d7fffff: 1 colonnine, 555.4 kWh coperti su 1029.0 kWh (Domanda agg: 1029.0 kWh)
# H3 881ea4c72bfffff: 1 colonnine, 555.4 kWh coperti su 921.7 kWh (Domanda agg: 921.7 kWh)
# H3 881ea4c465fffff: 2 colonnine, 1110.9 kWh coperti su 1122.6 kWh (Domanda agg: 1122.6 kWh)
# H3 881ea4c461fffff: 1 colonnine, 555.4 kWh coperti su 809.7 kWh (Domanda agg: 809.7 kWh)
# H3 881ea4c551fffff: 1 colonnine, 555.4 kWh coperti su 828.1 kWh (Domanda agg: 828.1 kWh)
# H3 881ea4c445fffff: 1 colonnine, 555.4 kWh coperti su 771.5 kWh (Domanda agg: 771.5 kWh)
# H3 881ea4d161fffff: 1 colonnine, 555.4 kWh coperti su 732.7 kWh (Domanda agg: 732.7 kWh)
# H3 881f992ca5fffff: 1 colonnine, 555.4 kWh coperti su 781.9 kWh (Domanda agg: 781.9 kWh)
# H3 881f992ca1fffff: 1 colonnine, 555.4 kWh coperti su 667.3 kWh (Domanda agg: 667.3 kWh)
# H3 881f992ca3fffff: 1 colonnine, 555.4 kWh coperti su 569.3 kWh (Domanda agg: 569.3 kWh)
# H3 881f99ad11fffff: 1 colonnine, 555.4 kWh coperti su 786.4 kWh (Domanda agg: 786.4 kWh)
# H3 881f8a692bfffff: 2 colonnine, 1110.9 kWh coperti su 1160.8 kWh (Domanda agg: 1160.8 kWh)
# H3 881f8a7a81fffff: 1 colonnine, 555.4 kWh coperti su 559.1 kWh (Domanda agg: 559.1 kWh)
# H3 881ea4d883fffff: 1 colonnine, 555.4 kWh coperti su 569.9 kWh (Domanda agg: 569.9 kWh)
# H3 881ea4d891fffff: 1 colonnine, 555.4 kWh coperti su 738.8 kWh (Domanda agg: 738.8 kWh)
# H3 881ea4c14dfffff: 1 colonnine, 555.4 kWh coperti su 773.4 kWh (Domanda agg: 773.4 kWh)
# H3 881ea69219fffff: 2 colonnine, 1110.9 kWh coperti su 1157.9 kWh (Domanda agg: 1157.9 kWh)
# H3 881f8a7427fffff: 1 colonnine, 555.4 kWh coperti su 1063.7 kWh (Domanda agg: 1063.7 kWh)
# H3 881f9938d3fffff: 1 colonnine, 555.4 kWh coperti su 567.7 kWh (Domanda agg: 567.7 kWh)
# H3 881ea4cb69fffff: 1 colonnine, 555.4 kWh coperti su 575.6 kWh (Domanda agg: 575.6 kWh)
# H3 881f993695fffff: 1 colonnine, 555.4 kWh coperti su 833.2 kWh (Domanda agg: 833.2 kWh)
# H3 881f99236dfffff: 1 colonnine, 555.4 kWh coperti su 718.0 kWh (Domanda agg: 718.0 kWh)
# H3 881ea4cb4dfffff: 1 colonnine, 555.4 kWh coperti su 590.3 kWh (Domanda agg: 590.3 kWh)
# H3 881f9938c7fffff: 1 colonnine, 555.4 kWh coperti su 567.7 kWh (Domanda agg: 567.7 kWh)
# H3 881ea69233fffff: 1 colonnine, 555.4 kWh coperti su 636.6 kWh (Domanda agg: 636.6 kWh)
# H3 881f99acd9fffff: 1 colonnine, 555.4 kWh coperti su 720.3 kWh (Domanda agg: 720.3 kWh)
# H3 881ea4c563fffff: 1 colonnine, 555.4 kWh coperti su 690.4 kWh (Domanda agg: 690.4 kWh)
#
# Domanda totale coperta: 4129622.05 kWh

# %% [markdown]
# ### Map visualisation

# %%
mappa = crea_mappa_colonnine_discrete(gdf_risultati_ott2030_alpha)
mappa
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Save the map as an HTML file
mappa.save("/content/drive/Shareddrives/OM in Business Analytics/OM in BA - Project/Codice/04 - Modello/log_heatmap_seventh_model_def.html")

# %% [markdown]
# ### Results

# %%
total_allocated_chargers = gdf_risultati_ott2030_alpha["Colonnine allocate"].sum()
total_covered_demand = gdf_risultati_ott2030_alpha["Domanda coperta (kWh)"].sum()
total_demand = gdf_risultati_ott2030_alpha["Domanda Giornaliera Ponderata (kWh)"].sum()

print(f"Total allocated charging stations: {total_allocated_chargers}")
print(f"Total covered demand (kWh): {total_covered_demand:.2f}")
print(f"Total demand (kWh): {total_demand:.2f}")
# Out:
# Total allocated charging stations: 7435
# Total covered demand (kWh): 4129622.05
# Total demand (kWh): 15014065.22
